# %%
modelfolder = "/content/stable-diffusion-webui/models/Stable-diffusion"
sd_models_on_gdrive = "/content/gdrive/MyDrive/stable-diffusion-webui/models/Stable-diffusion/"
# %cd -q $modelfolder
'''def continue_installation(): # придется завернуть всю последующую установку, и повесить ее на кнопку "скачать"
  print ("продолжение установки...")
  print ("распаковка репозиториев...")
  print ("скачивание моделей апскейла...")
  print ("скачивание дополнений...")
  print ("запуск...")'''

try:
  print(ok)
except NameError:
  # !wget -q -P /content/.config/ "https://raw.githubusercontent.com/PR0LAPSE/StableDiffusionWebUIColab/main/src/httpie.ipynb"
  # %run /content/.config/httpie.ipynb
  cou.clear()

def dl_gdrive():
  if not os.path.exists('/content/gdrive/MyDrive'):
    print("\033[01;38;05;166mТы не подключил гуглодиск ранее но поставил галочку для скачивания на него!\nПодключись сейчас, или отменив - модели буду качаться в дефольную папку колаба!\033[")
    try:
      from google.colab import drive
      drive.mount('/content/drive')
    except Exception:
      print(f"ты отказался от подключения гуглодиска!\nпапка для загрузки моделей сброшена на дефолтную")
      # %cd -q $modelfolder
  else:
    print("Модели будут качаться на гуглодиск.")
    if not os.path.exists(sd_models_on_gdrive): # eсли папки моделей нет или она указана не верно - папка будет создана
      print("Папка для скачивания не была найдена и была создана только что.")
      os.makedirs(sd_models_on_gdrive)
      # %cd -q $sd_models_on_gdrive
  # !sleep 1

def css():
  display(HTML('''
  <style>
  @media (prefers-color-scheme: light) {
    :root {
      --text: #191919;
      --bg-tab: #ffffff;
      --act-tb: #e6e6e6;
      --inact-tb: #c7c7c7;
      --textbox: #cececf;
      --placeholder: #353232;
      --dl-btn-grad1: #2fbb04;
      --dl-btn-grad2: #1ba300;
      --dl-btn-grad3: #27af19;
      --dl-btn-txt: #effeed;
      --dl-btn-txt-hover: #adffa4;
      /*--ownlinktxt: #181818;
      --ownlinktxt-hover: #081fcc;
      --ownlink-bg: transparent;
      --ownlink-bg-hover: transparent;*/
    }
    span[style="font-weight: bold; color: var(--ansi-gray);"]{
      color: #000000 !important;
    }
  }
  @media (prefers-color-scheme: dark) {
    :root {
      --text: #e6e6e6;
      --bg-tab: #000000;
      --act-tb: #191919;
      --inact-tb: #383838;
      --textbox: #313130;
      --placeholder: #acacac;
      --dl-btn-grad1: #1ed94f;
      --dl-btn-grad2: #009c46;
      --dl-btn-grad3: #47f293;
      --dl-btn-txt: #b5ffc3;
      --dl-btn-txt-hover: #156624;
      /*--ownlinktxt: #c8c7b8;
      --ownlinktxt-hover: #cbc68e;
      --ownlink-bg: transparent;
      --ownlink-bg-hover: transparent;*/
    }
  }

  @media only screen and (min-width: 768px) {
    div.lm-Widget.p-Widget.lm-TabBar.p-TabBar.p-TabPanel-tabBar.widget-tab-bar > ul {
      display: flex;
      flex-wrap: wrap;
    }
    /* div.lm-Widget.p-Widget.lm-TabBar.p-TabBar.p-TabPanel-tabBar.widget-tab-bar > ul {
    display: flex;
    flex-wrap: wrap;
    /*display: grid;
    grid-template-columns: repeat(9, 1fr);
    }*/
  }
  @media only screen and (max-width: 767px) {
    div.lm-Widget.p-Widget.lm-TabBar.p-TabBar.p-TabPanel-tabBar.widget-tab-bar > ul {
      display: block;
    }
  }

  div.lm-Widget.p-Widget.lm-TabBar.p-TabBar.p-TabPanel-tabBar.widget-tab-bar {
    /* слой панели вкладок*/
  }

  div.lm-Widget.p-Widget.lm-TabBar.p-TabBar.p-TabPanel-tabBar.widget-tab-bar > ul > li {
    /* отдельная вкладка (каждая имеет свой id: #tab-key-0, #tab-key-1 ... #tab-key-16 ) */
  }
  .p-TabBar-content {
    background: var(--bg-tab);
  }
  .jupyter-widgets.widget-tab > .p-TabBar .p-TabBar-tab.p-mod-current {
    /* активная вкладка */
    background: var(--act-tb) !important;
    color: var(--text) !important;
  }
  .jupyter-widgets.widget-tab > .p-TabBar .p-TabBar-tab {
    /* неактивная вкладка */
    background: var(--inact-tb) !important;
    color: var(--text) !important;
  }
  .jupyter-widgets.widget-tab > .widget-tab-contents {
    /* содержимое активной вкладки */
    color: var(--text) !important;
    font-weight: normal !important;
    background: var(--act-tb) !important;
  }
  .widget-text input {
    /* панель поиска*/
    color: var(--text) !important;
    font-weight: normal !important;
    background: var(--textbox) !important;
    border-radius: 5px;
  }
  input[placeholder="начни вводить для глобального поиска"]::placeholder {
    color: var(--placeholder);
  }
  .poisk {
    /*position: relative;
    top: -420px;
    top: -15px;*/
    position: absolute!important;
    top: -20px!important;
    left: 3px!important;
    width: 99%;
    margin: 0 auto;
    background: var(--act-tb);
    padding: 10px;
    display: flex;
    flex-flow: column wrap;
  }
  .poisk:before {
    position: relative;
    content: "Вот что удалось найти:";
    font-weight: bold;
    color: var(--dl-btn-grad3);
    padding: 0!important;
    top: -8px;
  }
   @supports not (-moz-appearance: none) {
    .display_data:has(.poisk) {
        position: relative;
        top: -400px;
        display: flex;
        justify-content: center;
        width: auto!important;
        height: 2em!important;
        padding: 0!important;
        margin: 0!important;
    }
   }
   @supports (-moz-appearance: none) {
    .output-id-6 {
        position: relative;
        top: -400px;
        display: flex;
        justify-content: center;
        width: auto!important;
        height: 2em!important;
        padding: 0!important;
        margin: 0!important;
    }
   }
  div.lm-Widget.p-Widget.jupyter-widgets.widget-inline-hbox.widget-checkbox.googledisk_checkbox,
  div.lm-Widget.p-Widget.jupyter-widgets.widget-inline-hbox.widget-checkbox.googledisk_checkbox > label.widget-label-basic{
    min-width: 235px !important;
    margin-left: 2em !important;
    font-family: sans-serif!important;
  }
  .googledisk_checkbox input[type=checkbox]:checked::before {
    -moz-appearance:initial!important;
    content: url("data:image/svg+xml,%3Csvg id='eSU2Jr1tiez1' xmlns='http://www.w3.org/2000/svg' xmlns:xlink='http://www.w3.org/1999/xlink' viewBox='0 0 29.76 26.59' shape-rendering='geometricPrecision' text-rendering='geometricPrecision'%3E%3Cpath d='M20.39,18.07l1.29,4.46l3.39,3.65c.46-.26.85-.65,1.12-1.12l3.15-5.45c.27-.47.41-1,.41-1.53l-4.84-.94-4.53.94Z' fill='%23ea4335'/%3E%3Cpath d='M19.56,0.41C19.1,0.15,18.57,0,18.03,0h-6.3c-.55,0-1.08.15-1.53.41l1.36,4.57L14.87,8.5v.02c0,0,3.35-3.56,3.35-3.56l1.35-4.55Z' fill='%23188038'/%3E%3Cpath d='M9.37,18.07L4.54,16.96L0,18.07c0,.53.14,1.06.41,1.53l3.15,5.46c.27.47.66.86,1.12,1.12l3.34-3.44l1.34-4.67Z' fill='%231967d2'/%3E%3Cpath d='M25.01,9.03l-4.33-7.5c-.27-.48-.66-.86-1.12-1.12L14.88,8.52l5.51,9.55h9.37c0-.53-.14-1.06-.41-1.53l-4.33-7.5Z' fill='%23fbbc04'/%3E%3Cpath d='M20.39,18.07h-11.02L4.69,26.18c.46.26.99.41,1.53.41h17.32c.55,0,1.08-.15,1.53-.41l-4.68-8.11Z' fill='%234285f4'/%3E%3Cpath d='M14.88,8.52L10.19,0.41c-.46.26-.85.65-1.12,1.12L0.41,16.54c-.27.47-.41,1-.41,1.53h9.37l5.51-9.55Z' fill='%2334a853'/%3E%3C/svg%3E") !important;
    border: none !important;
    position: relative;
    cursor: pointer;
    background-color: transparent !important;
  }
  .widget-label-basic {
    /*цвет названий моделей*/
    color: var(--text) !important;
  }
  .widget-checkbox {
    /* шрифт моделей/чекбоксов*/
    font-family: monospace;
    max-width: 150px;
  }
  .widget-checkbox > .widget-label { /* убрать пустой отступ лева от моделей */
    display: none;
  }
  .widget-vbox {
    /* ~ по 12 моделей на колонку */
    height: 400px;
    display: flex;
    flex-direction: column;
    flex-wrap: wrap;
  }
  .widget-vbox:nth-child() {
    page-break-inside: avoid;
    break-inside: avoid;
  }
  .jupyter-button {
    /* кнопка скачать */
    background-image: linear-gradient(
      to right,
      var(--dl-btn-grad1) 0%,
      var(--dl-btn-grad2) 51%,
      var(--dl-btn-grad3) 100%
    );
    background-size: 200% auto;
    border-radius: 5px;
    margin-left: 12px;
    font-weight: 600;
    color: var(--dl-btn-txt) !important;
    font-size: 1.2em;
    transition: 0.5s;
  }
  .jupyter-button:hover {
    /* кнопка скачать */
    background-position: right center;
    color: var(--dl-btn-txt-hover) !important;
    font-size: 1.22em;
    transition: 0.5s;
  }
  input[placeholder="только прямая ссылка на файл модели"],
  #output-body > div.display_data.output-id-5 > div > div > div > div {
    min-width: 350px !important;
    display:flex;
    flex-wrap: wrap;
  }
  #output-body > div.display_data.output-id-5 > div > div > div > div> .widget-inline-hbox {
    margin-right:60px!important;
  }
  #output-body > div.display_data.output-id-5 > div > div > div > div > div:nth-child(1){
    display:flex;
    flex-wrap: wrap;
  }
  input[placeholder="только прямая ссылка на файл модели"]::placeholder {
    color: var(--placeholder);
  }
  label[title="Прямая ссылка:"] {
    display: none !important;
  }
  .widget-label-basic {
    cursor: pointer;
  }
  input[type=checkbox] {
    -moz-appearance:initial!important;
    visibility: hidden;
    cursor: pointer;
    width: 1em;
  }
  // фиксы для фаерфокса
  @supports (-moz-appearance: none) {
    input[type="checkbox"]::before, input[type="checkbox"]:checked::before {
    top: 0.2em !important;
    }
  }
  input[type=checkbox]::before {
    visibility: visible;
    content: url("data:image/svg+xml,%3C%3Fxml version='1.0' encoding='UTF-8'%3F%3E%3Csvg xmlns='http://www.w3.org/2000/svg' viewBox='0 0 161 161'%3E%3Cdefs%3E%3Cstyle%3E.b%7Bfill:none;stroke:%23808080;stroke-miterlimit:10;stroke-width:3px;%7D%3C/style%3E%3C/defs%3E%3Crect class='b' x='1.5' y='1.5' width='158' height='158'/%3E%3C/svg%3E") !important;
    position: relative;
    cursor: pointer;
  }
  input[type=checkbox]:checked::before {
    visibility: visible;
    content: url("data:image/svg+xml,%3C%3Fxml version='1.0' encoding='UTF-8'%3F%3E%3Csvg xmlns='http://www.w3.org/2000/svg' viewBox='0 0 161 161'%3E%3Cdefs%3E%3Cstyle%3E.b%7Bfill:%2339b54a;stroke:%2339b54a;stroke-miterlimit:10;stroke-width:3px;%7D%3C/style%3E%3C/defs%3E%3Crect class='b' x='68.5' y='1.5' width='24' height='158'/%3E%3Crect class='b' x='68.5' y='1.5' width='24' height='158' transform='translate(0 161) rotate(-90)'/%3E%3C/svg%3E") !important;
    border: none;
    position: relative;
    cursor: pointer;
  }
  .close_poisk,
  .close_poisk:hover,
  .close_poisk:active,
  .close_poisk:focus{
      position: relative;
      top:-55px;
      left:35%;
      width: auto!important;
      height: auto!important;
      padding: 0.5em!important;
      line-height: 0;
      margin: 0.3em!important;
      border:0px transparent!important;
      border-radius: 0!important;
      background: none!important;
      color: var(--text)!important;
      filter: none!important;
      box-shadow: 0 0 0 transparent!important;
      font-size: 1em!important;
  }
  /* свой фон у каждой категории на примере последней вкладки: div:nth-child(№) где № - номер вкладки
  #output-body > div.display_data.output-id-4 > div > div.lm-Widget.p-Widget.lm-Panel.p-Panel.p-TabPanel-tabContents.widget-tab-contents > div:nth-child(18) {
    background-image: url("data:image/svg+xml,%3C%3Fxml version='1.0' encoding='UTF-8'%3F%3E%3Csvg xmlns='http://www.w3.org/2000/svg' viewBox='0 0 987.88 988.06'%3E%3Cdefs%3E%3Cstyle%3E.b%7Bopacity:.02; fill:var(--fill)%7D @media (prefers-color-scheme: light) %7B :root %7B --fill: %23000;%0A%7D%0A%7D%0A@media (prefers-color-scheme: dark) %7B :root %7B --fill: %23fff;%0A%7D%7D%0A%3C/style%3E%3C/defs%3E%3Cpath class='b' d='m820.58,232.69c-3.78-4.44-7.52-8.47-10.81-12.83-2.21-2.93-4.22-3.11-7.59-1.92-23.35,8.29-46.77,16.37-70.21,24.39-4.85,1.66-9.87,2.8-15.38,4.34.94,2.41,1.7,4.53,2.59,6.6,17.51,40.49,29.93,82.53,38.49,125.76.76,3.85.52,7.01-2.26,10.06-12.22,13.41-24.31,26.94-36.47,40.4-.27.3-.83.36-1.63.68-5.61-60.18-18.51-118.35-42.31-174.17-54.27,10.49-108.77,15-164.05,15.96-.09,2.1-.24,3.86-.24,5.63-.01,63.83-.03,127.66.06,191.49,0,2.09,1.11,4.18,1.88,6.92-18.06,8.89-37.59,17.5-56.1,27.93-17.14,9.65-34.68,13.03-54.26,12.57-42.81-1.01-85.66-.31-128.49-.31-2.11,0-4.22,0-6.92,0,.81,11.06,1.24,21.36,2.39,31.59,1.52,13.56,3.67,27.05,5.35,40.59.21,1.7-.21,4.62-1.26,5.16-13.74,7.04-27.64,13.75-42.43,21-2.39-15.13-5.12-29.47-6.81-43.94-1.93-16.53-3.02-33.16-4.3-49.76-.25-3.2-.97-4.71-4.62-4.7-45,.11-90,.07-134.99.09-1.13,0-2.25.23-3.94.41,3.59,66.13,21.96,127.62,54.51,185.01-.29.4-.59.79-.88,1.19-9.4-4.44-19.04-8.44-28.15-13.4-18.37-10-35.12-22.3-49.83-37.28-11.21-11.42-22.66-22.6-33.86-34.02-1.66-1.69-3.18-3.96-3.73-6.21C1.74,559.84-2.89,507.12,1.78,453.71c10.85-124.1,61.12-229.71,150.52-316.2C219.23,72.75,298.88,30.92,389.94,11.11,435.32,1.24,481.24-2.03,527.55,1.2c74.73,5.21,144.8,26.17,210.03,63.12,1.3.73,2.63,1.51,3.7,2.51,27.6,25.78,51.77,54.21,67.85,88.77,10.89,23.4,16.44,47.78,12.69,73.74-.1.66-.16,1.32-.33,1.97-.07.29-.35.54-.92,1.38Zm-352.02,241.33v-202.35c-2.63-.23-5.08-.54-7.53-.65-48.95-2.16-97.57-7.39-145.74-16.43-4.76-.89-6.56.06-8.29,4.49-26.52,67.93-38.35,138.62-40.18,211.23-.03,1.26.21,2.52.32,3.7h201.43Zm-249.19.03c2.38-79.59,18.32-156.02,49.19-229.13-1.15-.56-1.57-.85-2.03-.98-27.7-7.37-54.87-16.22-80.84-28.53-1.22-.58-4.19.47-5.15,1.7-12.57,16.16-25.87,31.86-37.15,48.89-36.57,55.25-57.87,116.21-65.32,182.01-.97,8.53-1.39,17.13-2.09,26.04h143.38Zm434.97-260.11c-.56-1.32-.76-1.94-1.07-2.5-27.88-50.46-64-94.09-108.48-130.78-1-.83-2.18-1.85-3.37-1.98-10.03-1.07-20.08-1.96-30.38-2.92v153.88c48.15-2.02,95.52-7.71,143.29-15.7Zm-185.74-137.76c-10.6,1.14-20.49,2.43-30.42,3.18-4.84.36-8.32,2.49-11.76,5.62-39.37,35.76-71.35,77.23-96.27,124.18-.65,1.22-1.06,2.57-1.75,4.27,46.81,8.44,93.15,14.73,140.21,16.46V76.18Zm149.35,18.34c.61,1.3.68,1.65.89,1.88,29.8,32.38,54.86,68.13,75.91,106.73,1.31,2.4,2.67,2.76,5.16,2.08,22.76-6.18,45.56-12.22,68.32-18.38,2.09-.57,4.04-1.66,6.63-2.75-46.06-41.39-97.85-70.96-156.92-89.57Zm-405.17,89.82c2.09.78,3.42,1.4,4.8,1.78,21.45,5.94,42.94,11.74,64.34,17.86,4.19,1.2,6.08.09,8.02-3.63,18.29-35.09,40.04-67.88,65.63-98.1.76-.89,1.34-1.94,2.72-3.98-54.97,19.12-102.83,47.55-145.51,86.07Zm506.97,331.83h-149.87c3.44-13.49,6.61-26.39,10.19-39.18.34-1.23,3.16-2.52,4.83-2.53,23.5-.17,47-.12,70.49-.12,19.67,0,39.33,0,59,0,1.63,0,3.27,0,5.19,0v-17.19c15.69-1.06,31.41-2.13,47.7-3.24.28,5.76.62,11.04.75,16.34.07,2.81.89,4.15,4.06,4.14,45.66-.09,91.33-.06,136.99-.08.64,0,1.29-.2,2.75-.45-.76-9.07-.99-18.2-2.38-27.14-2.68-17.25-6.07-34.39-9-51.61-.25-1.48.29-3.81,1.34-4.69,20.96-17.43,39.83-36.91,57.29-57.8.19-.22.57-.29.86-.42,60.6,161.93,31.88,410.79-177.99,562.61-199.01,143.97-460.16,112.6-619.31-35.07,9.61,2.12,19.12,4.59,28.77,6.29,28.69,5.06,57.38,3.99,86.04-.56,1.15-.18,2.39-.13,3.44-.55,10.59-4.17,19.54-.43,29.09,4.39,14.92,7.53,30.59,13.59,45.95,20.27.28-.44.57-.87.85-1.31-8.26-11.7-16.52-23.4-24.97-35.37,14.47-5.4,28.4-10.6,42.82-15.98,1.22,1.69,2.58,3.54,3.89,5.42,15.29,21.89,31.87,42.75,50.69,61.73,2.01,2.03,5.19,3.57,8.03,3.99,10.18,1.5,20.45,2.42,31.43,3.65v-31.62c2.93,1.58,5.03,2.72,7.65,4.13,3.31-12.98,6.5-25.5,9.68-38.02,9.78-38.54,19.64-77.06,29.24-115.64,1.14-4.57,2.94-5.54,7.48-5.11,25.2,2.37,50.51,3.73,75.63,6.69,21.13,2.5,42.08,6.59,63.05,10.31,3.56.63,4.97-.11,6.36-3.26,23.55-53.48,40.03-108.97,47.3-167.02,2.09-16.68,3.17-33.48,4.68-50.23.15-1.64.02-3.3.02-5.79Zm48.66.34c-2.53,83.47-22.32,162.45-56.23,237.3,27.26,9.94,53.94,19.71,80.7,29.26,1.24.44,3.78-.71,4.78-1.9,13.08-15.74,26.93-30.96,38.76-47.6,39.58-55.7,63.32-117.81,72.33-185.52,1.37-10.33,2.02-20.75,3.04-31.53h-143.38Zm-257.39,395.23c1.27,0,2.24.08,3.2-.01,11.92-1.14,23.83-2.5,35.77-3.37,4.55-.33,7.58-2.26,10.6-5.46,32.92-34.81,59.97-73.82,83.19-115.59.51-.91.73-1.99,1.2-3.31-44.59-7.96-89-13.79-133.96-16.78v144.51Zm121.72-24.62c.25.37.5.73.75,1.1,46.75-16.65,89.27-40.71,128.03-72.91-2.41-1.09-3.86-1.95-5.42-2.43-19.68-6.06-39.4-11.96-59.04-18.15-3.68-1.16-5.24-.04-6.92,3.09-14.92,27.74-31.79,54.26-50.35,79.71-2.34,3.21-4.7,6.4-7.05,9.59Zm-88.52-392.9c-114.45,56.29-227.83,112.05-341.84,168.12,20.99,12.44,41.25,24.45,61.62,36.52-7.81,15.28-19.52,25.35-34.16,32-26.16,11.88-53.58,12.47-81.29,7.63-30.72-5.37-58.19-18.64-83.59-36.32-9.52-6.63-18.49-14.06-28.32-21.59,1.01,4.31,1.72,8.19,2.82,11.95,18.47,62.76,59.51,105.65,118.16,132.25,37.44,16.98,76.95,17.05,116.71,10.52,40.58-6.67,78.8-20.51,115.21-39.45,2.6-1.35,4.42-1.16,6.79.42,10.66,7.13,21.44,14.08,32.18,21.08,9.45,6.16,18.91,12.3,28.86,18.77,28.97-114.02,57.78-227.41,86.87-341.89Zm227.62-71.88c14.69-5.27,29.83-9.58,43.97-16.07,51.64-23.71,94.09-59.35,130.08-102.96,1.28-1.55,1.88-4.24,1.71-6.31-.69-8.46-1.55-16.92-2.82-25.3-5.41-35.91-17.18-69.36-39.04-98.77-26.66-35.88-62.59-59.15-103.43-75.68-.19-.08-.51.18-.1.02,6.52,6.49,13.81,12.67,19.81,19.93,20.35,24.61,28.47,53.77,29.97,85.09,1.38,28.87-2.91,57.14-10.13,84.97-12.48,48.11-33.9,91.61-67.58,128.63-1.99,2.18-4.04,4.31-6.67,7.1,2.04-.3,3.2-.28,4.23-.65Z'/%3E%3C/svg%3E");
    background-repeat: no-repeat;
    background-position: right;
  } */
  /* фиксы для фаерфокса */
  @supports (-moz-appearance: none) {
    input[type="checkbox"]::before,
    input[type="checkbox"]:checked::before,
    .googledisk_checkbox input[type=checkbox]:checked::before {
    top: 0.2em !important;
    }
  }
  @supports not (-moz-appearance: none) {
    input[type="checkbox"]::before,
    input[type="checkbox"]:checked::before,
    .googledisk_checkbox input[type=checkbox]:checked::before {
    top: -0.2em !important;
    }
  }
  </style>
      '''))


gdrive_dl = widgets.Checkbox(value=False, description='скачивать модели на гуглодиск').add_class("googledisk_checkbox")

ownlink1 = widgets.Text(
    value='',
    placeholder='только прямая ссылка на файл модели',
    description='Прямая ссылка:'
)
ownlink2 = widgets.Text(
    value='',
    placeholder='только прямая ссылка на файл модели',
    description='Прямая ссылка:'
)
ownlink3 = widgets.Text(
    value='',
    placeholder='только прямая ссылка на файл модели',
    description='Прямая ссылка:'
)
ownlink4 = widgets.Text(
    value='',
    placeholder='только прямая ссылка на файл модели',
    description='Прямая ссылка:'
)
ownlink5 = widgets.Text(
    value='',
    placeholder='только прямая ссылка на файл модели',
    description='Прямая ссылка:'
)
ownlink6 = widgets.Text(
    value='',
    placeholder='только прямая ссылка на файл модели',
    description='Прямая ссылка:'
)
ownlink7 = widgets.Text(
    value='',
    placeholder='только прямая ссылка на файл модели',
    description='Прямая ссылка:'
)
ownlink8 = widgets.Text(
    value='',
    placeholder='только прямая ссылка на файл модели',
    description='Прямая ссылка:'
)
ownlink9 = widgets.Text(
    value='',
    placeholder='только прямая ссылка на файл модели',
    description='Прямая ссылка:'
)
ownlink10 = widgets.Text(
    value='',
    placeholder='только прямая ссылка на файл модели',
    description='Прямая ссылка:'
)

models_A = ["Anime_80s", "_8528Diffusion_final_v05", "AbyssOrangeMix", "AbyssOrangeMix2", "Anonmix", "Antlers_mix", "Any222Trinart", "Anything_Berrymix", "Anything_V3", "Anything_v3_better_vae", "Anything_v4_0", "Anything_v4_5", "AnythingGape", "BerryCandy", "Berrymix_Zeipher222", "BloodOrangeMix", "Bstaber", "BstaberElysium_Anime", "ChinaBerry_nofix_f222_v1_4_pt2", "Cyberpunk_Anime_Diffusion", "EerieOrangeMix", "EerieOrangeMix2", "ElyOrangeMix", "Freckle_mix", "GAPE60", "GrapefruitHentaiModel", "monstermash4_anyv3", "monstermash6_anyv3", "NAI", "OrangeMixs_All", "PastelMix", "Plat", "protogenV22Anime", "Trinart", "WaifuDiffusion", "Yohan_Diffusion"]
checkboxes_A = [widgets.Checkbox(description=model, value=False) for model in models_A]
category_A = widgets.VBox(checkboxes_A)

models_B = ["AnimePencil", "App_Icons", "ColoringBook", "vectorArt"]
checkboxes_B = [widgets.Checkbox(description=model, value=False) for model in models_B]
category_B = widgets.VBox(checkboxes_B)

models_C = ["artErosAErosATribute_aEros", "Babes", "bkdbj", "F222", "GenericFemaleMix", "HassanBlend", "pyros_blowjob", "RealEldenApocalypse_AnalogSexKnoll_4CandyPureSimp_FEET", "uberRealisticPornMer_urpMv12"]
checkboxes_C = [widgets.Checkbox(description=model, value=False) for model in models_C]
category_C = widgets.VBox(checkboxes_C)

models_D = ["Black_Souls", "Bloodborne", "Borderlands", "DarkSouls", "DiscoElysium_style", "EldenRing_style", "GalaxyTimemachines", "Hogwarts_Legacy", "pokemon", "ProtoGenDragonX59", "protogenX3_4", "Starsector_Portrait", "TronLegacy_style"]
checkboxes_D = [widgets.Checkbox(description=model, value=False) for model in models_D]
category_D = widgets.VBox(checkboxes_D)

models_E = ["EpicSpaceMachine", "James_Webb_Cosmos", "nousr_robot", "ProtoGenInfinityX86"]
checkboxes_E = [widgets.Checkbox(description=model, value=False) for model in models_E]
category_E = widgets.VBox(checkboxes_E)

models_F = ["blotmon", "Creepy_Diffusion", "newhorrorfantasy_style", "rotten_zombie"]
checkboxes_F = [widgets.Checkbox(description=model, value=False) for model in models_F]
category_F = widgets.VBox(checkboxes_F)

models_G = ["macroDiffusion", "Microscopic"]
checkboxes_G = [widgets.Checkbox(description=model, value=False) for model in models_G]
category_G = widgets.VBox(checkboxes_G)

models_H = ["chkn_петухи", "ГигаЧэд", "hyperpreg__round_belly", "Pepe"]
checkboxes_H = [widgets.Checkbox(description=model, value=False) for model in models_H]
category_H = widgets.VBox(checkboxes_H)

models_I = ["AIroticArtsPenis", "DaddyDiffusion", "Homoerotic", "TwinkDiffusion", "UncutPenises"]
checkboxes_I = [widgets.Checkbox(description=model, value=False) for model in models_I]
category_I = widgets.VBox(checkboxes_I)

models_J = ["Arcane_style", "Archer_style", "Classic_Disney_style", "megaPals", "Modern_Disney_style", "SpiderVerse_style"]
checkboxes_J = [widgets.Checkbox(description=model, value=False) for model in models_J]
category_J = widgets.VBox(checkboxes_J)

models_K = ["All_In_1_Pixel", "MinecraftRTX", "Pixel_Art", "pixel_landscape"]
checkboxes_K = [widgets.Checkbox(description=model, value=False) for model in models_K]
category_K = widgets.VBox(checkboxes_K)

models_L = ["aloeVeraSSimpMaker3K_simpMaker3K1", "hAS3Dkx11_3Dkx11", "microworld", "PFG", "PostApocalypse", "Redshift", "RPG", "SPYBG_Toolkit"]
checkboxes_L = [widgets.Checkbox(description=model, value=False) for model in models_L]
category_L = widgets.VBox(checkboxes_L)

models_M = ["elldrethSLucidMix", "epicDiffusion", "MMD", "RealisticVision", "SD_v2_1", "SD_v1_5", "SD_v1_5_full", "SD_v1_4", "Vintedois_Diffusion", "Wavy_fusion"]
checkboxes_M = [widgets.Checkbox(description=model, value=False) for model in models_M]
category_M = widgets.VBox(checkboxes_M)

models_N = ["Analog_diffusion", "Clarity", "classicNegative", "dreamlikePhotoReal", "ModelShoot", "Poolsuite", "Portrait_Plus", "PowerfulMix", "Protogen_X53_Photorealism", "Radiant", "realisticHASDX", "s4w3d0ff_Blend", "Timeless", "uberrealistic_mix_PFG_URPM_Openjourney", "woopwoopPhoto"]
checkboxes_N = [widgets.Checkbox(description=model, value=False) for model in models_N]
category_N = widgets.VBox(checkboxes_N)

models_O = ["FurSlut", "YIFFY_EPOCH18", "YIFFY_GAPE", "YiffyMix", "Zack3D_Kinky"]
checkboxes_O = [widgets.Checkbox(description=model, value=False) for model in models_O]
category_O = widgets.VBox(checkboxes_O)

models_P = ["AnyFutaGape", "FutaAllAnime", "FutaAnime", "Futacum_Anything", "Futacum_r34", "Futagen"]
checkboxes_P = [widgets.Checkbox(description=model, value=False) for model in models_P]
category_P = widgets.VBox(checkboxes_P)

models_Q = ["Abstract_Swirls", "ATitanStrawBerry", "Babes", "BackgroundsDiffusion", "beeple", "Beksinski", "BubblyDubbly", "CALARTS", "Cats_Tabaxi", "Cthulhu_illithid", "DanMumford_Style", "DBWayneBarlowe_JM", "dreamlikediffusion", "DreamShaper", "HASDX", "img2img_PaintingGenerator", "Ложкин", "Midjourney", "MosaicArt", "OldJourney", "OpenJourney", "Protogen_Eclipse", "Protogen_X58_Rebuil", "protogenNovaX80", "reasonableDrink", "reonArgondiansStyle", "ssmoky", "SynthwavePunk", "Van_Gogh", "WiKiArt"]
checkboxes_Q = [widgets.Checkbox(description=model, value=False) for model in models_Q]
category_Q = widgets.VBox(checkboxes_Q)

category_R = widgets.VBox([ownlink1, ownlink2, ownlink3, ownlink4, ownlink5, ownlink6, ownlink7, ownlink8, ownlink9, ownlink10])

from string import ascii_uppercase
cat = "category_"
L = list(ascii_uppercase[:18]) # тут указать число вкладок (оно должно совпадать с тем что прописано в коде выше)
categories = [cat + x for x in L]
tab_contents = ','.join(categories) # [category_A,category_B,...category_Q]
tab = widgets.Tab(children=eval(tab_contents))

tab.set_title(0, "аниме")
tab.set_title(1, "лийнарт")
tab.set_title(2, "женские")
tab.set_title(3, "игры и кино")
tab.set_title(4, "техника и космос")
tab.set_title(5, "крипота")
tab.set_title(6, "макро")
tab.set_title(7, "мемные")
tab.set_title(8, "мужские")
tab.set_title(9, "мультфильмы")
tab.set_title(10, "пиксельарт")
tab.set_title(11, "трехмерная графика")
tab.set_title(12, "универсальные")
tab.set_title(13, "фотореализм")
tab.set_title(14, "фурри")
tab.set_title(15, "футанари")
tab.set_title(16, "художественные")
tab.set_title(17, "📥 свои ссылки")

checkboxes = []
for var_name in list(globals().keys()): #более аккуратный вариант 
  if var_name.startswith('checkboxes_'):
    #checkboxes.append(globals()[var_name]) # - это выдает ошибку
    checkboxes += globals()[var_name] # - это ошибку не выдает
"""
def filter_models(change):
  search_string = change['new'].lower()
  for checkbox in checkboxes:
    if search_string in checkbox.description.lower():
      checkbox.layout.display = 'flex'
    else:
      checkbox.layout.display = 'none'
"""
def filter_models(change):
    search_string = change['new'].lower()
    if not search_string:
        filtered = []
        filtered_checkboxes.layout.visibility = 'hidden'
        close_button.layout.visibility = 'hidden'
    else:
        filtered = [cb for cb in checkboxes if search_string in cb.description.lower()]
        filtered_checkboxes.layout.visibility = 'visible'
        close_button.layout.visibility = 'visible'
    filtered_checkboxes.children = filtered

def on_close_button_click(b):
  filtered_checkboxes.layout.visibility = 'hidden'
  close_button.layout.visibility = 'hidden'
  search_bar.value = ""

close_button = widgets.Button(description='закрыть результаты поиска', button_style='danger').add_class("close_poisk")
filtered_checkboxes = widgets.VBox().add_class("poisk")
filtered_checkboxes.layout.visibility = 'hidden'
close_button.layout.visibility = 'hidden'
search_bar = widgets.Text(placeholder='начни вводить для глобального поиска')
download_button = widgets.Button(description='Скачать', button_style='success').add_class("dl_button")
search_and_button = widgets.HBox([search_bar, download_button, gdrive_dl])
search_bar.observe(filter_models, names='value')
def on_download_click(b):
  if gdrive_dl.value:
    dl_gdrive()
  if ownlink1.value:
    # !$dl $ownlink1.value
  if ownlink2.value:
    # !$dl $ownlink2.value
  if ownlink3.value:
    # !$dl $ownlink3.value
  if ownlink4.value:
    # !$dl $ownlink4.value
  if ownlink5.value:
    # !$dl $ownlink5.value
  if ownlink6.value:
    # !$dl $ownlink6.value
  if ownlink7.value:
    # !$dl $ownlink7.value
  if ownlink8.value:
    # !$dl $ownlink8.value
  if ownlink9.value:
    # !$dl $ownlink9.value
  if ownlink10.value:
    # !$dl $ownlink10.value
  for checkbox in checkboxes:
    if checkbox.value:
      if checkbox.description == "Anime_80s":
        # !$dl_hf'80s_anime_test_5_anythingmodel.safetensors' -o Anime_80s.safetensors
      if checkbox.description == "_8528Diffusion_final_v05":
        # !$dl_hf'8528diffusion_final_v05.safetensors'
      if checkbox.description == "AbyssOrangeMix":
        # !$dl_hf'AbyssOrangeMix_half.safetensors'
        # !$dl_hf'AbyssOrangeMix.safetensors'
        # !$dl_hf'AbyssOrangeMix_Night.safetensors'
        # !$dl_hf'AbyssOrangeMix_base.safetensors'
      if checkbox.description == "AbyssOrangeMix2":
        # !$dl_hf'AbyssOrangeMix2_sfw.safetensors'
        # !$dl_hf'AbyssOrangeMix2_hard.safetensors'
        # !$dl_hf'AbyssOrangeMix2_nsfw.safetensors'
      if checkbox.description == "Anonmix":
        # !$dl_hf'Anonmix_fp16.safetensors' -o Anonmix.safetensors
      if checkbox.description == "Antlers_mix":
        # !$dl_hf'antlers_mix.safetensors'
      if checkbox.description == "Any222Trinart":
        # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/any222trinart_fp16.safetensors -o Any222Trinart.safetensors
      if checkbox.description == "Anything_Berrymix":
        # !$dl_hf'Anything_Berrymix_fp16.safetensors' -o Anything_Berrymix.safetensors
      if checkbox.description == "Anything_V3":
        # !$dl_hf'Anything-V3.0_fp16.safetensors' -o anything_v3.safetensors
        # !$dl_pt'Anything-V3.0.vae.pt' -o anything_v3.vae.pt
        #!$dl_hf'anything_v3.vae.safetensors'
        # !$dl_hf'anything_v3_better_vae.safetensors'
      if checkbox.description == "Anything_v4_0":
        # !$dl_hf'Anything_v4_0.safetensors'
        # !$dl_hf'Anything_v4_0.vae.safetensors'
      if checkbox.description == "Anything_v4_5":
        # !$dl_hf'Anything_v4_5.safetensors'
        # !$dl_hf'Anything_v4_0.vae.safetensors' -o Anything_v4_5.vae.safetensors
      if checkbox.description == "AnythingGape":
        # !$dl_hf'ag/AnythingGape.safetensors'
        # !$dl_hf'ag/AnythingGape.vae.pt'
        # !$dl_hf'ag/AnythingGape_fp16.safetensors'
        # !$dl_hf'ag/AnythingGape_fp16_emaonly.safetensors'
      if checkbox.description == "BerryCandy":
        # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/BerryCandy20_v2.fp16.safetensors -o BerryCandy20_v2.safetensors
      if checkbox.description == "Berrymix_Zeipher222":
        # !$dl_hf'Berrymix_Zeipher222_fp16.safetensors' -o Berrymix_Zeipher222.safetensors
      if checkbox.description == "BloodOrangeMix":
        # !$dl_hf'BloodOrangeMix.safetensors'
        # !$dl_hf'BloodOrangeMix_half.safetensors'
        # !$dl_hf'BloodNightOrangeMix.safetensors'
      if checkbox.description == "Bstaber":
        # !$dl_hf'Bstaber.safetensors'
      if checkbox.description == "BstaberElysium_Anime":
        # !$dl_hf'Bstaber_0.65-Elysium_Anime_V3_0.35-Weighted_sum-merged_fp16.safetensors'
      if checkbox.description == "ChinaBerry_nofix_f222_v1_4_pt2":
        # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/chinaberry%20(nofix%20f222%201.4)%20part2-fp16.safetensors-o ChinaBerry_nofix_f222_v1_4_pt2.safetensors
      if checkbox.description == "Cyberpunk_Anime_Diffusion":
        # !$dl_hf'Cyberpunk-Anime-Diffusion.safetensors'
      if checkbox.description == "EerieOrangeMix":
        # !$dl_hf'EerieOrangeMix2_half.safetensors'
        # !$dl_hf'EerieOrangeMix2.safetensors'
        # !$dl_hf'EerieOrangeMix2_night.safetensors'
        # !$dl_hf'EerieOrangeMix2_base.safetensors'
      if checkbox.description == "EerieOrangeMix2":
        # !$dl_hf'EerieOrangeMix_night.safetensors'
        # !$dl_hf'EerieOrangeMix.safetensors'
        # !$dl_hf'EerieOrangeMix_half.safetensors'
        # !$dl_hf'EerieOrangeMix_base.safetensors'
      if checkbox.description == "ElyOrangeMix":
        # !$dl_hf'ElyOrangeMix.safetensors'
        # !$dl_hf'ElyNightOrangeMix.safetensors'
        # !$dl_hf'ElyOrangeMix_half.safetensors'
      if checkbox.description == "Freckle_mix":
        # !$dl_hf'freckle_mix_fp16.safetensors' -o freckle_mix.safetensors
      if checkbox.description == "GAPE60":
        # !$dl_hf'gape60_fp16.safetensors' -o gape60.safetensors
      if checkbox.description == "GrapefruitHentaiModel":
        # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/grapefruitHentaiModel_grapefruitv23_fp16.safetensors -o GrapefruitHentaiModelv2_3.safetensors
        # !$dl_hf'GrapefruitHentaiModelv2_3.vae.pt'
        # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/grapefruitHentaiModel_grapefruitv31_fp16.safetensors -o GrapefruitHentaiModelv3_1.safetensors
        # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/grapefruitHentaiModel_grapefruitv3_fp16.safetensors -o GrapefruitHentaiModelv3.safetensors
        # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/grapefruitHentaiModel_lemon_fp16.safetensors -o GrapefruitHentaiModel_lemon.safetensors
        # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/grapefruitHentaiModel_grapefruitv24_fp16.safetensors -o GrapefruitHentaiModelv2_4.safetensors
      if checkbox.description == "monstermash4_anyv3":
        # !$dl_pt'monstermash4+anyv3.safetensors' -o monstermash4_anyv3.safetensors
      if checkbox.description == "monstermash6_anyv3":
        # !$dl_pt'monstermash6+anyv3.safetensors' -o monstermash6_anyv3.safetensors
      if checkbox.description == "NAI":
        # !$dl_hf'novelai_fp16.safetensors' -o novelai.safetensors
        # !$dl_pt'novelai.vae.pt'
      if checkbox.description == "OrangeMixs_All":
        # !$dl_hf'ElderOrangeMix.safetensors'
        # !$dl_hf'AbyssOrangeMix_half.safetensors'
        # !$dl_hf'AbyssOrangeMix.safetensors'
        # !$dl_hf'AbyssOrangeMix_Night.safetensors'
        # !$dl_hf'AbyssOrangeMix_base.safetensors'
        # !$dl_hf'AbyssOrangeMix2_sfw.safetensors'
        # !$dl_hf'AbyssOrangeMix2_hard.safetensors'
        # !$dl_hf'AbyssOrangeMix2_nsfw.safetensors'
        # !$dl_hf'BloodOrangeMix.safetensors'
        # !$dl_hf'BloodOrangeMix_half.safetensors'
        # !$dl_hf'BloodNightOrangeMix.safetensors'
        # !$dl_hf'EerieOrangeMix2_half.safetensors'
        # !$dl_hf'EerieOrangeMix2.safetensors'
        # !$dl_hf'EerieOrangeMix2_night.safetensors'
        # !$dl_hf'EerieOrangeMix2_base.safetensors'
        # !$dl_hf'EerieOrangeMix_night.safetensors'
        # !$dl_hf'EerieOrangeMix.safetensors'
        # !$dl_hf'EerieOrangeMix_half.safetensors'
        # !$dl_hf'EerieOrangeMix_base.safetensors'
        # !$dl_hf'ElyOrangeMix.safetensors'
        # !$dl_hf'ElyNightOrangeMix.safetensors'
        # !$dl_hf'ElyOrangeMix_half.safetensors'
      if checkbox.description == "PastelMix":
        # !$dl https://huggingface.co/andite/pastel-mix/resolve/main/pastelmix-better-vae-fp16.safetensors -o Pastelmix_betterVAE.safetensors
      if checkbox.description == "Plat":
        #!$dl_hf'Plat_v1_3.safetensors'
        # !$dk https://huggingface.co/p1atdev/pd-archive/resolve/main/plat-v1-3-1-fp16.safetensors -o Plat_v1_3_1.safetensors
        # !$dl https://huggingface.co/p1atdev/pd-archive/resolve/main/plat-v1-3-0.yaml -o Plat_v1_3_1.yaml
        # !$dl https://huggingface.co/hakurei/waifu-diffusion-v1-4/resolve/main/vae/kl-f8-anime2.ckpt -o Plat_v1_3_1.vae.pt
      if checkbox.description == "protogenV22Anime":
        # !$dl_pt'protogenV22Anime_22_fp16.safetensors' -o protogenV22Anime.safetensors
      if checkbox.description == "Trinart":
        # !$dl_hf'trinart2.safetensors'
      if checkbox.description == "WaifuDiffusion":
        # !$dl_hf'WaifuDiffusion_v1_4.safetensors'
        # !$dl_hf'WaifuDiffusion_v1_4.yaml'
        # !$dl_hf'WaifuDiffusion_v1_4.vae.safetensors'
        # !$dl_hf'WaifuDiffusion_v1_4.vae.yaml'
        # !$dl_hf'wd-v1-3_fp16.safetensors' -o WaifuDiffusion.safetensors
      if checkbox.description == "Yohan_Diffusion":
        # !$dl_hf'Cocoa.safetensors'
        # !$dl_hf'Butter.safetensors'
        # !$dl_hf'Latte.safetensors'
        # !$dl_hf'yohan-diffusion.safetensors'
      if checkbox.description == "AnimePencil":
        # !$dl_hf'anime-pencil-diffusion-v4.safetensors'
      if checkbox.description == "App_Icons":
        # !$dl_hf'App_Icons.safetensors'
      if checkbox.description == "ColoringBook":
        # !$dl_hf'ColoringBook.safetensors'
        # !$dl_hf'ColoringBook.yaml' -q
      if checkbox.description == "vectorArt":
        # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/vectorArt_vectorArtBeta.safetensors -o vectorArt.safetensors
        # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/vectorArt_vectorArtBeta.yaml -o vectorArt.yaml
      if checkbox.description == "artErosAErosATribute_aEros":
        # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/artErosAErosATribute_aErosCkpt-ema-fp16.safetensors -o artErosAErosATribute_aEros.safetensors
        # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/artErosAerosATribute_aerosINPAINTINGNovae-inpainting_fp16.safetensors -o artErosAErosATribute_NoVAE-inpainting.safetensors.safetensors
        # !$dl_hf'artErosAErosATribute_NoVAE.safetensors'
      if checkbox.description == "Babes":
        # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/babes_babes11_fp16.safetensors -o Babes.safetensors
        # !$dl https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.ckpt -o Babes.vae.pt
        #!$dl_hf'Babes.vae.safetensors'
      if checkbox.description == "bkdbj":
        # !$dl_hf'bkdbj_fp16.safetensors' -o bkdbj.safetensors
      if checkbox.description == "F222":
        # !$dl_hf'f222_fp16.safetensors' -o f222.safetensors
      if checkbox.description == "GenericFemaleMix":
        # !$dl_hf'GenericFemaleMix_v2-1.safetensors'
      if checkbox.description == "HassanBlend":
        #!$dl_hf'HassanBlend1.5.safetensors'
        # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/hassanblend1512And_hassanblend1512_fp16.safetensors -o HassanBlend1_5_12.safetensors
        # !$dl_hf'HassanBlend_1.4_fp16.safetensors' -o HassanBlend_v1_4.safetensors
        # !$dl_hf'HassansBlend_1.2_fp16.safetensors' -o HassanBlend_v1_2.safetensors
      if checkbox.description == "pyros_blowjob":
        # !$dl_hf'pbj_v1.safetensors'
      if checkbox.description == "RealEldenApocalypse_AnalogSexKnoll_4CandyPureSimp_FEET":
        # !$dl_hf'realEldenApocalypseA_realEldenApocalypseAsexKnoll4CandyPureSimpFeet-ema.fp16.safetensors' -o RealEldenApocalypse_AnalogSexKnoll_4CandyPureSimp_FEET.safetensors
      if checkbox.description == "uberRealisticPornMer_urpMv12":
        # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/uberRealisticPornMerge_urpmv12.safetensors -o uberRealisticPornMer_urpMv12.safetensors
        # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/uberRealisticPornMerge_urpmv12Inpainting-inpainting_fp16.safetensors -o uberRealisticPornMer_urpMv12-inpainting.safetensors
      if checkbox.description == "Black_Souls":
        # !$dl_hf'Black_Souls.safetensors'
      if checkbox.description == "Bloodborne":
        # !$dl_hf'Bloodborne_Style.safetensors'
      if checkbox.description == "Borderlands":
        # !$dl_hf'borderlands.safetensors'
      if checkbox.description == "DarkSouls":
        # !$dl_hf'DarkSouls_Style.safetensors'
      if checkbox.description == "DiscoElysium_style":
        # !$dl_hf'discoElysium-pruned.safetensors' -o discoelysium_style.safetensors
      if checkbox.description == "EldenRing_style":
        # !$dl_hf'eldenring-v2-pruned.safetensors' -o elden_ring_style.safetensors
      if checkbox.description == "GalaxyTimemachines":
        # !$dl_hf'GalaxyTimemachines_v3_Inpainting.safetensors'
      if checkbox.description == "Hogwarts_Legacy":
        # !$dl_hf'HogLegStyle-v2.4.safetensors' -o HogLeg_Style.safetensors
      if checkbox.description == "pokemon":
        # !$dl_hf'pokemon_fp16.safetensors' -o pokemon.safetensors
      if checkbox.description == "ProtoGenDragonX59":
        # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/protogenDragon_protogenX59_fp16.safetensors -o ProtoGenDragonX59.safetensors
      if checkbox.description == "protogenX3_4":
        # !$dl_hf'protogenX3.4-fp16-ema.safetensors' -o protogenX3_4.safetensors
      if checkbox.description == "Starsector_Portrait":
        # !$dl_hf'starsectorportrait.safetensors'
        # !$dl_pt'HN_ssportrait.pt' -o /content/stable-diffusion-webui/models/hypernetworks/HN_ssportrait.pt
      if checkbox.description == "TronLegacy_style":
        # !$dl_hf'Tron-Legacy-Style-trnlgcy.safetensors' -o trnlgcy.safetensors
      if checkbox.description == "EpicSpaceMachine":
        # !$dl_hf'EpicSpaceMachine.safetensors'
      if checkbox.description == "James_Webb_Cosmos":
        # !$dl_hf'JWST-Deep-Space.safetensors'
      if checkbox.description == "nousr_robot":
        # !$dl_hf'robo-diffusion-v2-base.safetensors' -o nousr_robot.safetensors
      if checkbox.description == "ProtoGenInfinityX86":
        # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/protogenInfinity_protogenX86.safetensors -o ProtoGenInfinityX86.safetensors
      if checkbox.description == "blotmon":
        # !$dl_hf'blotmon-v1-5000.safetensors' -o blotmon.safetensors
      if checkbox.description == "Creepy_Diffusion":
        # !$dl_hf'creepy-diffusion.safetensors'
      if checkbox.description == "newhorrorfantasy_style":
        # !$dl_hf'newhorrorfantasy_style.safetensors'
      if checkbox.description == "rotten_zombie":
        # !$dl_hf'RottingZombie_person.safetensors'
      if checkbox.description == "Microscopic":
        # !$dl_hf'Microscopic_v1_fp16.safetensors' -o Microscopic.safetensors
      if checkbox.description == "macroDiffusion":
        # !$dl_hf'macroDiffusion_10.safetensors'
      if checkbox.description == "chkn_петухи":
        # !$dl_hf'chkn.safetensors'
      if checkbox.description == "ГигаЧэд":
        # !$dl_hf'gigachad_2000.safetensors' -o gigachad.safetensors
      if checkbox.description == "hyperpreg__round_belly":
        # !$dl_hf'hyperpreg__round_belly.safetensors'
      if checkbox.description == "Pepe":
        # !$dl_hf'pepestylev2_2200.safetensors' -o pepestyle_person.safetensors
      if checkbox.description == "AIroticArtsPenis":
        # !$dl_hf'airoticartsPenis.safetensors' -o airoticartsPenis_v1-inpainting.safetensors
      if checkbox.description == "TwinkDiffusion":
        # !$dl_hf'twinkdiffusionv2.safetensors'
      if checkbox.description == "Homoerotic":
        # !$dl_hf'homoerotic_v2.safetensors'
      if checkbox.description == "DaddyDiffusion":
        # !$dl_hf'daddyDiffusion_v1.safetensors'
      if checkbox.description == "UncutPenises":
        # !$dl_hf'unctpns_fp16.safetensors' -o uncut-penis.safetensors
      if checkbox.description == "Arcane_style":
        # !$dl_hf'arcane-diffusion-v3.safetensors' -o arcane_style.safetensors
      if checkbox.description == "Archer_style":
        # !$dl_hf'archer-v1.safetensors' -o archer_style.safetensors
      if checkbox.description == "Classic_Disney_style":
        # !$dl_hf'classicAnim-v1.safetensors' -o classic_disney_style.safetensors
      if checkbox.description == "megaPals":
        # !$dl_hf'megaPals.safetensors'
      if checkbox.description == "Modern_Disney_style":
        # !$dl_hf'moDi-v1-pruned.safetensors' -o modern_disney_style.safetensors
      if checkbox.description == "SpiderVerse_style":
        # !$dl_hf'spiderverse-v1-pruned.safetensors' -o spiderverse_style.safetensors
      if checkbox.description == "elldrethSLucidMix":
        # !$dl_hf'elldrethSLucidMix_v10-ema-fp16.safetensors' -o elldrethSLucidMix_v10.safetensors
      if checkbox.description == "epicDiffusion":
        # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/epicDiffusion_epicDiffusion10.safetensors -o epicDiffusion.safetensors
      if checkbox.description == "MMD":
        # !$dl_pt'MMDv1-18_fp16.safetensors' -o MMDv1_18.safetensors
      if checkbox.description == "RealisticVision":
        # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/realisticVisionV12_v12_fp16.safetensors -o RealisticVision.safetensors
      if checkbox.description == "SD_v2_1":
        # !$dl_hf'SDv2_1_768.yaml' --quiet
        # !$dl_hf'SDv2_1_512.yaml' --quiet
        # !$dl_hf'SDv2_1_512_inpaiting.yaml' --quiet
        # !$dl_hf'SDv2_1_512.safetensors'
        # !$dl_hf'SDv2_1_512_inpaiting.safetensors'
        # !$dl_hf'SDv2_1_768.safetensors'
        # !sed -i 's@def load_state_dict(checkpoint_path: str, map_location.*@def load_state_dict(checkpoint_path: str, map_location="cuda"):@' /usr/local/lib/python3.8/dist-packages/open_clip/factory.py
      if checkbox.description == "SD_v1_5":
        # !$dl_hf'sd-v1-5_fp16.safetensors' -o sd-v1-5.safetensors
        # !$dl_pt'sd-v1-5.vae.pt'
        #!$dl_hf'sd-v1-5.vae.safetensors'
        # !$dl_hf'sd-v1-5.inpainting_fp16.safetensors' -o sd-v1-5.inpainting.safetensors
        # !$dl_pt'sd-v1-5.inpainting.vae.pt'
        #!$dl_hf'sd-v1-5.inpainting.vae.safetensors'
      if checkbox.description == "SD_v1_5_full":
        # !$dl_hf'v1-5-ema.safetensors'
        # !$dl_pt'sd-v1-5.vae.pt' -o v1-5-ema.vae.pt
      if checkbox.description == "SD_v1_4":
        # !$dl_hf'sd-v1-4_fp16.safetensors' -o sd-v1-4.safetensors
      if checkbox.description == "Vintedois_Diffusion":
        # !$dl_hf'vintedois-diffusion-v01.safetensors'
      if checkbox.description == "Wavy_fusion":
        # !$dl https://huggingface.co/wavymulder/wavyfusion/resolve/main/wa-vy-fusion_1.0.safetensors -o Wavy_fusion_v1.safetensors
      if checkbox.description == "All_In_1_Pixel":
        # !$dl_hf'Public-Prompts-Pixel-Model.safetensors' -o all_in_one_PixelModel.safetensors
      if checkbox.description == "MinecraftRTX":
        # !$dl_hf'BlockWorldRTX.safetensors'
      if checkbox.description == "Pixel_Art":
        # !$dl_hf'Pixel_Art.safetensors'
      if checkbox.description == "pixel_landscape":
        # !$dl_hf'16-bit-landscape_PublicPrompts.safetensors' -o 16bit_landscape.safetensors
      if checkbox.description == "Redshift":
        # !$dl_hf'redshift-diffusion-v1.safetensors' -o redshift.safetensors
      if checkbox.description == "hAS3Dkx11_3Dkx11":
        # !$dl_hf'hAS3Dkx11_3Dkx11.safetensors'
      if checkbox.description == "PostApocalypse":
        # !$dl_hf'postapocalypse_v1.safetensors'
      if checkbox.description == "PFG":
        # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/pfg_111Safetensors_fp16.safetensors -o PFG.safetensors
      if checkbox.description == "microworld":
        # !$dl_hf'microworld.safetensors'
      if checkbox.description == "aloeVeraSSimpMaker3K_simpMaker3K1":
        # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/aloeVeraSSimpMaker3K_simpMaker3K1-ema-fp16.safetensors -o aloeVeraSSimpMaker3K_simpMaker3K1.safetensors
      if checkbox.description == "RPG":
        # !$dl_hf'RPG-v2.safetensors'
      if checkbox.description == "SPYBG_Toolkit":
        # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/spybgsToolkitFor_v35.yaml -o SPYBG_Toolkit.yaml -q
        # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/spybgsToolkitFor_v35.safetensors -o SPYBG_Toolkit.safetensors
      if checkbox.description == "Analog_diffusion":
        # !$dl https://huggingface.co/wavymulder/Analog-Diffusion/resolve/main/analog-diffusion-1.0.safetensors -o analog-diffusion.safetensors
      if checkbox.description == "Clarity":
        # !$dl_hf'Clarity.safetensors'
        # !$dl_hf'Clarity.vae.pt'
        # !$dl_hf'Clarity-inpainting.safetensors'
      if checkbox.description == "classicNegative":
        # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/classicnegative.safetensors
        # !$dl_hf'classicNegative768px.safetensors'
        # !$dl_hf'classicNegative768px.yaml'
      if checkbox.description == "dreamlikePhotoReal":
        # !$dl_hf'dreamlikePhotoRealV2_dreamlikePhotoRealV2.safetensors' -o dreamlikePhotoRealV2.safetensors
      if checkbox.description == "ModelShoot":
        # !$dl https://huggingface.co/wavymulder/modelshoot/resolve/main/modelshoot-1.0.safetensors -o ModelShoot_v1.safetensors
      if checkbox.description == "Poolsuite":
        # !$dl_hf'poolsuite_step2010.safetensors'  -o poolsuite_style.safetensors
      if checkbox.description == "Portrait_Plus":
        # !$dl https://huggingface.co/wavymulder/portraitplus/resolve/main/portrait%2B1.0.safetensors -o Portrait_Plus.safetensors
      if checkbox.description == "PowerfulMix":
        # !$dl_hf'PowerfulMix_v2.safetensors'
      if checkbox.description == "Protogen_X53_Photorealism":
        # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/protogenX53Photorealism_10_fp16.safetensors -o Protogen_X53_Photorealism.safetensors
      if checkbox.description == "Radiant":
        # !$dl_hf'Radiant_v3.safetensors'
      if checkbox.description == "realisticHASDX":
        # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/hasdx_realisticHASDX.safetensors -o realisticHASDX.safetensors
      if checkbox.description == "s4w3d0ff_Blend":
        # !$dl_hf's4w3d0ff_Blend.safetensors'
      if checkbox.description == "Timeless":
        # !$dl https://huggingface.co/wavymulder/timeless-diffusion/resolve/main/timeless-1.0.safetensors -o Timeless_v1.safetensors
      if checkbox.description == "uberrealistic_mix_PFG_URPM_Openjourney":
        # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/uberrealistic_mix_PFG_URPM_Openjourney_fp16.safetensors -o uberrealistic_mix_PFG_URPM_Openjourney.safetensors
      if checkbox.description == "woopwoopPhoto":
        # !$dl_hf'woopwoopPhoto_12.safetensors'
      if checkbox.description == "FurSlut":
        # !$dl_hf'furslut.safetensors'
      if checkbox.description == "YIFFY_EPOCH18":
        # !$dl_hf'yiffy-e18_fp16.safetensors' -o yiffy-e18.safetensors
      if checkbox.description == "YIFFY_GAPE":
        # !$dl_hf'gape22_yiffy15_fp16.safetensors' -o gape_yiffy.safetensors
      if checkbox.description == "YiffyMix":
        # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/yiffymix_yiffymix_fp16.safetensors -o YiffyMix.safetensors
      if checkbox.description == "Zack3D_Kinky":
        # !$dl_hf'Zack3D_Kinky-v1_fp16.safetensors' -o Zack3D_Kinky.safetensors
      if checkbox.description == "Futagen":
        # !$dl_hf'Futagen_v2.safetensors'
      if checkbox.description == "Abstract_Swirls":
        # !$dl_hf'Abstract_Swirls.safetensors' -o AbstractSwirls.safetensors
      if checkbox.description == "ATitanStrawBerry":
        # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/ATitanStrawBerry_fp16.safetensors -o ATitanStrawBerry.safetensors
      if checkbox.description == "BackgroundsDiffusion":
        # !$dl_hf'sjh_style_fp16.safetensors' -o sjh_style.safetensors
      if checkbox.description == "beeple":
        # !$dl_hf'beeple.safetensors'
      if checkbox.description == "Beksinski":
        # !$dl_hf'beksinski-style.safetensors'
      if checkbox.description == "BubblyDubbly":
        # !$dl_hf'bubblydubbly_7k_fp16.safetensors' -o bubblydubbly_7k.safetensors
        # !$dl_hf'bubblydubbly_fp16.safetensors' -o bubblydubbly.safetensors
      if checkbox.description == "CALARTS":
        # !$dl_hf'CALARTS.safetensors'
      if checkbox.description == "Cats_Tabaxi":
        # !$dl_hf'tabaxi2500person.safetensors' -o tabaxi_person.safetensors
      if checkbox.description == "Cthulhu_illithid":
        # !$dl_hf'DnDAi-illithid_Person_fp16.safetensors' -o illithid_person.safetensors
      if checkbox.description == "DanMumford_Style":
        # !$dl_hf'DanMumford_Style.safetensors'
      if checkbox.description == "DBWayneBarlowe_JM":
        # !$dl_hf'DBWayneBarlowe_JM_fp16.safetensors' -o DBWayneBarlowe_JM.safetensors
      if checkbox.description == "dreamlikediffusion":
        # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/dreamlikediffusion1.0.safetensors -o dreamlikediffusion.safetensors
      if checkbox.description == "DreamShaper":
        #!$dl_hf'DreamShaper_v3_3.safetensors'
        # !$dl_hf'DreamShaper_v3_3.vae.pt' -o DreamShaper.vae.pt
        #!$dl_hf'DreamShaper_v3_3.vae.safetensors'
        # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/dreamshaper_332BakedVaeClipFix_fp16.safetensors -o DreamShaper.safetensors
      if checkbox.description == "HASDX":
        # !$dl_hf'HASDX-ema-fp16.safetensors' -o HASDX.safetensors
      if checkbox.description == "img2img_PaintingGenerator":
        # !$dl_hf'img2img_PaintingGenerator.safetensors'
      if checkbox.description == "Ложкин":
        # !$dl_hf'lozhkin.safetensors'
      if checkbox.description == "Midjourney":
        # !$dl_hf'mdjrny-v4_style.safetensors'
      if checkbox.description == "MosaicArt":
        # !$dl_hf'MosaicArt_v2.safetensors'
        # !$dl_hf'MosaicArt_v2.yaml'
      if checkbox.description == "OldJourney":
        # !$dl_hf'OldJourney.safetensors'
        # !$dl_hf'OldJourney.yaml'
      if checkbox.description == "OpenJourney":
        # !$dl_hf'mdjrny-v4_style-openjourney.safetensors'
      if checkbox.description == "Protogen_Eclipse":
        # !$dl_hf'protogenEclipse_protogenX74.safetensors'
      if checkbox.description == "Protogen_X58_Rebuil":
        # !$dl_pt'Protogen_x5.8_Rebuilt_pruned.safetensors' -o Protogen_X58_Rebuil.safetensors
      if checkbox.description == "protogenNovaX80":
        # !$dl_hf'protogenNovaX80.safetensors'
      if checkbox.description == "reasonableDrink":
        # !$dl_hf'reasonableDrink.safetensors'
      if checkbox.description == "reonArgondiansStyle":
        # !$dl_hf'reonArgondiansStyle.safetensors'
      if checkbox.description == "ssmoky":
        # !$dl_hf'ssmoky1_3000.safetensors' -o ssmoky.safetensors
      if checkbox.description == "SynthwavePunk":
        # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/synthwavepunk_v2.safetensors -o synthwavepunk_v2.safetensors
      if checkbox.description == "Van_Gogh":
        # !$dl_hf'lvngvncnt_Van-Gogh.safetensors'
      if checkbox.description == "WiKiArt":
        # !$dl_hf'sd-wikiart-v2.safetensors' -o wikiart_v2.safetensors
      if checkbox.description == "AnyFutaGape":
        # !$dl_hf'AnyFutaGape.safetensors'
      if checkbox.description == "FutaAllAnime":
        # !$dl_hf'FutaAllAnime_v7_1.safetensors'
        # !$dl_hf'FutaAllAnime_v7.safetensors'
      if checkbox.description == "FutaAnime":
        # !$dl_hf'FutaAnime.safetensors'
      if checkbox.description == "Futacum_Anything":
        # !$dl_hf'futacum_anything.safetensors'
      if checkbox.description == "Futacum_r34":
        # !$dl_hf'Futacum_r34.safetensors'
  print('          Выбранные модели скачались')
  print('[1;32m 🡹 Теперь запускай ячейку: Запуск/перезапуск WebUI 🡹')
  if gdrive_dl.value:
    cou.eval_js(f'new Audio("{gh}dl2gd.mp3").play()')
  else:
    cou.eval_js(f'new Audio("{gh}dl2cl.mp3").play()')

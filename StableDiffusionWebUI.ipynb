# %% [markdown]
# <p align="right"><a href="https://colab.research.google.com/github/PR0LAPSE/StableDiffusionWebUIColab/blob/main/StableDiffusionWebUI.ipynb" target="_blank" rel="nofollow"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="открыть Colab"></a> <a href="https://colab.research.google.com/drive/1TC4SSLncPWytSPvquR6Y4-U7wZRfAXrV" target="_blank" rel="nofollow"><img src="https://github.com/PR0LAPSE/StableDiffusionWebUIColab/raw/main/src/open_gdrive.svg" alt="открыть с гуглодиска"></a> <a href="https://github.com/PR0LAPSE/StableDiffusionWebUIColab/raw/main/StableDiffusionWebUI.ipynb" target="_blank" rel="nofollow"><img src="https://github.com/PR0LAPSE/StableDiffusionWebUIColab/raw/main/src/download_Ipynb.svg?" alt="скачать .ipynb"></a> <a href="https://colab.to/PR0LAPSE/StableDiffusionWebUIColab/StableDiffusionWebUI.ipynb" target="_blank" rel="nofollow"><img src="https://github.com/PR0LAPSE/StableDiffusionWebUIColab/raw/main/src/short_url.svg" alt="короткая ссылка"></a></p>

# %% [markdown]
# **<font size='3'>Браузерный графический интерфейс для Стабильной Диффузии</font>**
#
#
# Основано на [AUTOMATIC1111](https://github.com/AUTOMATIC1111/stable-diffusion-webui)

# %% [markdown]
# <details>
#   <summary><font size='4'><big>Cписок изменений</big></font></summary>
# <p>07.01.2023:</p>
# <ol>
# <li>Добавлены модели v2.1 (v2.0 ставить не стал). Для работы SDv2.1 нужен xformers, так что галочку с него не снимаем! Версия 768px имеет нативное разрешение 768х768, так что ставить меньше (например 512) - не нужно (будет жмыхнутое мыло). После запуска сам руками в левом верхнем углу WebUI выбери модель для генерации, по дефолту может подхватится модель inpaiting (ее нужно выбирать для вкладки изо-в-изо). Поскольку поддержка новых версий теперь реализована нормально, то можешь собирать и присылать модели и миксы на базе v2(.1)</li>
# <li>По твоему совету добавлены новые модели:
# <ul>
# <li>dreamlikePhotoRealV2</li>
# <li>HASDX</li>
# <li>elldrethSLucidMix_v10</li>
# <li>hAS3Dkx11_3Dkx11</li>
# <li>RealEldenApocalypse_AnalogSexKnoll_4CandyPureSimp+FEET</li>
# <li>protogenX3_4</li>
# </ul>
# </li>
# </ol>
# <p>06.01.2023:</p>
# <ol>
# <li>Отправка сгенерированных картинок на другие вкладки(изо-в-изо, апскейл, и т.д.) снова работают</li>
# <li>Объединение установки, подключения гуглодиска и запуска в одну ячейку. Теперь нужно поставить нужные галочки и нажать один раз запуск. По завершению установки - будет аудиоуведомление, перед запускам WebUI - тоже. Можно запустить и идти пить чай.</li>
# <li>По твоей просьбе добавлены новые модели:
# <ul>
# <li>analog-diffusion</li>
# <li>Protogen_x5.8_Rebuilt</li>
# <li>protogenV22Anime_22</li>
# <li>BloodNightOrangeMix</li>
# <li>ElyOrangeMix</li>
# <li>AbyssOrangeMix</li>
# <li>MMDv1-18</li>
# </ul>
# </li>
# <li>Добавлена <a href="#scrollTo=3yZXlc_hvzAF">ячейка</a> для пакетной конвертации в safetensors (NovelAI и некоторые модели на ее основе вызывают переполнение всей RAM)</li>
# <li>Автоматика разбанили на жидхабе, откат на старый репозиторий</li>
# </ol>
# <p>05.01.2023:</p>
# <ol>
# <li>Добавлена <a href="#scrollTo=otsDSY8bCdVN">ячейка</a> для прунинга больших моделей с целью уменьшения их размера</li>
# <li>Добавлена <a href="#scrollTo=QuW09EK-mIvg">ячейка</a> для конвертации ckpt в новый формат моделей safetensors</li>
# <li>Модель Anything_Berrymix.ckpt (7.2 Гб) заменена на Anything_Berrymix-pruned.ckpt (3.85 Гб)</li>
# <li>В связи с баном Автоматика1111 на жидхабе, переезд на <a href="https://gitgud.io/AUTOMATIC1111/stable-diffusion-webui.git">новую</a> репу (новый хостинг очень медленный, установка будет дольше), и откат на <a href="https://web.archive.org/web/20230101173248if_/https://codeload.github.com/AUTOMATIC1111/stable-diffusion-webui/zip/refs/heads/master">архив</a> репозитория за 01.01 (для варианта без xformers)</li>
# <li>В связи с баном аккаунта Автоматик1111, отвалились и пока не восстановились следующие дополнения:<br />эстетичные градиенты <a href="https://github.com/AUTOMATIC1111/stable-diffusion-webui-aesthetic-gradients">https://github.com/AUTOMATIC1111/stable-diffusion-webui-aesthetic-gradients</a>;<br />подстановочные знаки <a href="https://github.com/AUTOMATIC1111/stable-diffusion-webui-wildcards">https://github.com/AUTOMATIC1111/stable-diffusion-webui-wildcards</a>;<br />просмтор токенизации промпта <a href="https://github.com/AUTOMATIC1111/stable-diffusion-webui-tokenizer">https://github.com/AUTOMATIC1111/stable-diffusion-webui-tokenizer</a>;<br />каталог расширений и установка из вебинтерфейса, естественно тоже уничтожены.</li>
# <li>обновлены некоторые преинсталированные <a href="https://huggingface.co/utnah/LDSR/blob/main/zavisimosti">зависимости</a> для варианта с xformers</li>
# </ol>
# <p>04.01.2023:</p>
# <ol>
# <li>фикс для gradio</li>
# <li>откат webui на состояние 02.01</li>
# <li>ускоритель Xformers снова работает<sup>*</sup><br /><sup>*</sup><small>учитывай, что с ним могут конфликтовать какие-то дополнения, а так же увеличивается энтропия.</small></li>
# </ol>
# </details>

# %% [markdown]
# ---
#
# <details>
#   <summary><big>👈 <font color='#FF4500'>Внимание! В последнее время участились баны аккаунтов</font></big> (нажми чтобы развернуть)</summary>
# В последнее время участились баны аккаунтов из-за «злоупотреблений» колабом.<br>Причины? - Диффузоры зaeбaли гугл генерацией своих картинок круглосуточно терабайтами.<br>Попытаться этого избежать можно:<br>
# • не запускать несколько копий колаба одновременно под разными учётами с одного IP.<br>
# • не генерировать лолей, свастоны и прочую неодобрительную символику и контент (гугл не только проверяет картинки, но и читает названия файлов - в котором твой промпт),<br>
# • при смене аккаунта помнить, что гугл читает не только куки и IP, но и локалсторадж, отпечаток браузера, временную зону ПК, id установленных расширений браузера и т.д. - так что детектить тебя не составляет труда во всех твоих фейках;<br><hr><p>
# Тебе нужно использовать отдельный браузер, который всегда работает в режиме инкогнито и ничего не сохраняет после закрытия, vpn, блокировщики canvas/dom или иные расширения для спуффинга отпечатков браузера.</p><hr>
# </details>
#
# Если завис ВебУИ - презагружай вкладку с ним (не эту, не с колабом!) или перезапускай, бывает отваливается `gradio.app` или дисконектится колаб. Лучше используй ссылку на `ngrok.io` - он работает стабильнее, иногда неплохо работает и `loca.lt`. Повлиять на отвалы/зависания gradio.app со стороны этого колаба нельзя. <br>В случае проблем, останавливай ячейку и перезапускай снова, если это не помогло - выполни ниже ячейку "Перезапуск среды выполнения (если что-то пошло не так)" и запускай снова ячейку запуска WebUI. Если проблема не решается, выбери в верхнем меню `Среда выполнения → Управление сеансами → Завершить` и перезагружай эту страницу (Shift+F5). Если ничего не помогает - попробуй написать <a href="https://t.me/colabSDbot">боту</a>.
#
# <b>Слишком много букав и кнопочек?</b> [Попробуй упрощенную версию](https://colab.research.google.com/drive/1xspncncuwztQYt7GXj9Kavp1ql6p3mng#scrollTo=jnXUwtACCHOy) или [эту версию](https://colab.research.google.com/drive/1kfwm6YK_kY5aLf_nX1iM_RujS94a7W7C#scrollTo=dNaggHpybFoQ)
#
# <details>
#   <summary><big><big>👈 <font color='#e14f4f'>Как пользоваться</font></big></big> (разверни спойлер для просмотра)</summary>
#
# > Во-первых - читай внимательно все что написано, Во-вторых, в ячейке установки и запуска установи нужные тебе галочки и выбери нужную модель, все параметры подписаны и пояснены, главное прочитай буковки. Один раз сделаешь - второй уже на автомате.
#
#
#
# **Чтобы запусть ячейку нужно нажать вот такую кнопочку**  <img width='30px' src='https://files.catbox.moe/2iq7o3.gif'>
#
#
# > В конце вывода ячейки запуска читай внимательно текст, ищи там ссылку вида типа:<br> `cool-brooms-admire-23-251-149-142.loca.lt` или для Ngrok: `http://e402-34-126-159-209.ngrok.io` и переходи по ней, нажимай кнопку "Visit site". Так же будет ссылка типа `https://0bf89138a7c4877f.gradio.app/`. *См. скриншот:*
#
# <big><font color='#FF4500'>СКРИНШОТ где искать ссылки </font></big>
#   <img src="https://files.catbox.moe/c57s73.gif"/>
#
#
# Можешь поработать в Ngrok и в Gradio и в LocalIT, посмотреть что будет стабильнее для тебя. Для Ngrok нужен свой личный токен, [зарегистрируйся](https://ngrok.com/signup) у них на сайте и получи свой [тoкен](https://dashboard.ngrok.com/get-started/your-authtoken) (никому его не давай и не показывай, иначе по нему можно будет зайти в твой WebUI)
#
#
#
# Имхо, проще сразу создавать картинки прямо на гуглодиске, а не сохранять по одной. Впрочем, это не обязательно, тогда и доступ к диску колабу можешь не давать.
#
#
# **Выше была преамбула, непосредственно работа начинается с первой ячейки ниже:**
# </details>
#
# <br>
# <img src="https://telegram.org/img/t_logo.svg" alt="обратная связь в telegram" width="26"/>&ensp;<big><big><sup> <a href="https://t.me/colabSDbot"> сообщить об ошибке боту</a></sup></big></big>

# %%
#@title Автокликер кнопки подключения при бездействии { display-mode: "form" }
#@markdown ℹ️ Эта ячейка запускает код JS, который будет автоматически жмякать кнопку повторного подключения, когда блокнот отключился из-за простоя.<br>Работает не во всех браузерах (протестированно в Chrome Dev 109.0.5396.2). [Альтернативне коды](https://telegra.ph/Konsolnye-kody-dlya-kolaba-11-11), которые могут помочь для твоего браузера


import IPython
from IPython.display import clear_output
from google.colab import output

display(IPython.display.Javascript('''
 function ClickConnect(){
   btn = document.querySelector("colab-toolbar-button")
   if (btn != null){
     console.log("Clicked on the connect button"); 
     btn.click() 
     }
   
   btn = document.getElementById('connect')
   if (btn != null){
     console.log("Clicked on the reconnect button"); 
     btn.click() 
     }
  }
  
setInterval(ClickConnect,60000)
'''))

clear_output()

# %% [markdown]
# ---

# %%
#@title # Установка зависимостей и моделей | Подключение гуглодиска | Запуск { display-mode: "form" }
#полезные модули
import os
import os.path
import glob
import time
from IPython.display import clear_output
from google.colab import output
from IPython.display import HTML
from subprocess import getoutput
from re import search
clear_out = True
#@markdown <font color='#38c013' size='2' face="Verdana"><b>Примонтировать гуглодиск?</b> </font><br>
гуглодиск = False #@param {type:"boolean"}
#@markdown Опционально, без гуглодиска можно сохранять картинки поштучно из вебинтерфейса или после завершения можно [скачать архив](#scrollTo=V-2LlLHZPgoB), если успеешь до истечения бесплатной сессии. Картинки будут сохранятся по пути `/content/gdrive/MyDrive/SD`.<br>Гугл отключает твой бесплатный колаб внезапно, и все файлы тут же удалятся. Обидно, не так ли? Потому работать удобнее сразу на гуглодиске.<br>Так же полезно при обучении нейросети - все входные и выходные файлы будут на гуглодиске.<hr> Если на гуглодиске в папке `SD` создашь файл `styles.csv` можно будет сохранять туда свои стили из промптов и работать с ними в последующем.<details><summary>👈ГДЕ СОХРАТЬ СТИЛИ В WEBUI (разверни спойлер для просмотра)</summary><img src="https://files.catbox.moe/4m8cy2.png"/></details><br>Несколько фейковых акков? Ок, просто расшарь ярлык на оригинальный styles.csv на все свои фейковые гуглоаккаунты и создай ссылку на файл в их папках SD. При расшаривании разреши редактирование для твоих аккаунтов. Тогда у тебя всегда будет свой файлик со стилями.<details><summary>👈ПРИМЕР (разверни спойлер для просмотра)</summary><img width="500px" src="https://files.catbox.moe/ox0o4d.png"/><p>а затем добавить ярлык на файл в свои аккаунты в папку SD</p><img width="500px" src="https://files.catbox.moe/plk4lg.webp"/></details><br>
подтянуть_модели_с_гулодиска = False #@param {type:"boolean"}
#@markdown Обязательно корректно укажи путь до папки с моделями на гуглодиске:
папка_с_моделями_на_гуглодиске = "/content/gdrive/MyDrive/models" #@param {type:"string"}
#@markdown Отметь галочку ниже, если планируешь использовать только свои модели, и ничего скачивать в этой ячейке(тем не менее на гуглодиск можешь скачать нужные модели потом из <a href="#scrollTo=rcAPPhbyhx3t">этой ячеки</a>):
модели_только_с_гуглодиска = False #@param {type:"boolean"}
if гуглодиск:
  from google.colab import output
  from google.colab import drive
  drive.mount('/content/gdrive')
  # !sleep 2
if not гуглодиск:
  подтянуть_модели_с_гулодиска = False
  модели_только_с_гуглодиска = False
if not папка_с_моделями_на_гуглодиске or len(папка_с_моделями_на_гуглодиске) < 24 or "gdrive" not in папка_с_моделями_на_гуглодиске:
  print("Папка с моделями на гуглодиске указана неверно!")
  подтянуть_модели_с_гулодиска = False
  модели_только_с_гуглодиска = False
if not os.path.exists(папка_с_моделями_на_гуглодиске):
  print("Папка с моделями на гуглодиске указана неверно!")
  подтянуть_модели_с_гулодиска = False
  модели_только_с_гуглодиска = False
if not glob.glob(f'{папка_с_моделями_на_гуглодиске}/*.ckpt') or not glob.glob(f'{папка_с_моделями_на_гуглодиске}/*.safetensors'):
  print("Папка с моделями на гуглодиске не содержит в корне никаких моделей!")
  подтянуть_модели_с_гулодиска = False
  модели_только_с_гуглодиска = False
#@markdown <font color='#38c013' size='2' face="Verdana"><b>Поставить с ускорителем Xformers?</b> </font><br>
xformers = True #@param {type:"boolean"}
#@markdown Иксформеры - поделие фейсбука которое ускоряет рендер картинок на местной nvidia Т4 в максимуме с 1.5-4 it/s до 4.5-6 it/s. Эта опция вносит большой уровень энтропии, приводит к неповторяемости результатов и может негативно сказаться на качестве картинок. **[Обсуждение на гитхабе](https://github.com/AUTOMATIC1111/stable-diffusion-webui/discussions/2705#discussioncomment-4024378)**. <br> Важно: некоторые дополнения могут конфликтовать, если появляются ошибки, попробуй сначала перезапуститься с отключенным xformers.
#Клонирование суппозиториев
# !git clone https://github.com/Stability-AI/stablediffusion
if not xformers:
    #!git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui
    #!git checkout 11d432d92d63660c516540dcb48faac87669b4f0
    # !wget https://github.com/AUTOMATIC1111/stable-diffusion-webui/archive/fd4461d44c7256d56889f5b5ed9fb660a859172f.zip
    # !unzip /content/fd4461d44c7256d56889f5b5ed9fb660a859172f.zip -d /content/
    # !mv /content/stable-diffusion-webui-fd4461d44c7256d56889f5b5ed9fb660a859172f /content/stable-diffusion-webui/
    # !rm /content/fd4461d44c7256d56889f5b5ed9fb660a859172f.zip
    #!wget -O stable-diffusion-webui.zip https://web.archive.org/web/20230101173248if_/https://codeload.github.com/AUTOMATIC1111/stable-diffusion-webui/zip/refs/heads/master
    #!unzip /content/stable-diffusion-webui.zip -d /content/
    #!mv /content/stable-diffusion-webui-master/ /content/stable-diffusion-webui/
    #!rm stable-diffusion-webui.zip
    # %cd /content/stable-diffusion-webui/
    # !COMMANDLINE_ARGS="--exit" REQS_FILE="requirements.txt" python launch.py
if clear_out:
    output.clear()
if xformers:
    # !git clone --depth 1 https://github.com/AUTOMATIC1111/stable-diffusion-webui
    #!git clone https://gitgud.io/AUTOMATIC1111/stable-diffusion-webui.git
    # %cd /content/stable-diffusion-webui/
    # !mkdir repositories
    # %cd /content/stable-diffusion-webui/repositories
    # !git clone https://github.com/CompVis/taming-transformers
    # !git clone https://github.com/openai/CLIP
    # !git clone https://github.com/TencentARC/GFPGAN
    # !git clone https://github.com/salesforce/BLIP
    # !git clone https://github.com/sczhou/CodeFormer
    # !git clone https://github.com/xinntao/Real-ESRGAN
    # !git clone https://github.com/crowsonkb/k-diffusion
    # !git clone https://github.com/Hafiidz/latent-diffusion
    # !git clone https://github.com/CompVis/stable-diffusion
    # !cp -r /content/stable-diffusion-webui/repositories/k-diffusion/k_diffusion /content/stable-diffusion-webui/
    # %cd /content/stable-diffusion-webui/
    #!COMMANDLINE_ARGS="--exit" REQS_FILE="requirements.txt" python launch.py
    # !wget -q https://is.gd/usr_bin -O /content/.config/usr_bin.ipynb
    # %run /content/.config/usr_bin.ipynb
    if clear_out:
        output.clear()

# установка дополнений
#@markdown <font color='#38c013' size='2' face="Verdana"><b>Нужно ли установить дополнения?</b></font><br>
#@markdown (Deforum, aesthetic gradients, aesthetic scorer, latent mirroring, wildcards, inspiration, artists2study, dataset tag editor, training picker, tokenizer, и т.д.)
дополнения = False #@param {type:"boolean"}
#@markdown Впрочем, теперь дополнения можно поставить из самого WebUI в любой момент, выбрав из списка и понажимав на кнопочки "install". Стоит отметить, что далеко не все дополнения нормально работают в колабе (как и скрипты), некоторые разрабы игнорируют нормальную поддержку линукса. Dreambooth пока работать не будет в этом WebUI из-за несовместимости с этим окружением. Да оно и не очень нужно на самом деле - проще запустить отдельный колаб с Dreambooth (ссылка чуть позже).
if дополнения:
  # !wget -q https://is.gd/extentions_webui -O /content/.config/extentions.ipynb
  # %run /content/.config/extentions.ipynb
if clear_out:
  output.clear()

#Установка скриптов
# !wget -q https://is.gd/sd_scripts  -O /content/.config/sd_scripts.ipynb
# %run /content/.config/sd_scripts.ipynb
#if clear_out:
#  output.clear()

#@markdown <font color='#38c013' size='2' face="Verdana"><b>Нужно ли установить модель апскейла LDSR?</b></font><br>
#@markdown данная модель заточена под фотореализм и текстурки. Для всего остального лучше использовать апскелер ESRGAN с его зоопарком моделей. В комплекте (**не забудь активировать в настройках!**) будет Lolipop, SwinIR, Nickelback, FoolhardyRemacri, 4xESRGAN и немного других, которые могут подтянуться автоматически.
#Установка модели апскейла LDSR - не обязательно
LDSR = False #@param {type:"boolean"}
if LDSR:
  # !mkdir /content/stable-diffusion-webui/repositories/latent-diffusion
  # !mkdir /content/stable-diffusion-webui/repositories/latent-diffusion/experiments/
  # !mkdir /content/stable-diffusion-webui/repositories/latent-diffusion/experiments/pretrained_models/
  # !wget -nv --show-progress https://huggingface.co/utnah/LDSR/resolve/main/project.yaml -O /content/stable-diffusion-webui/repositories/latent-diffusion/experiments/pretrained_models/project.yaml
  # !wget -nv --show-progress https://huggingface.co/utnah/LDSR/resolve/main/model.ckpt -O /content/stable-diffusion-webui/repositories/latent-diffusion/experiments/pretrained_models/model.ckpt
  # !cp -a /content/stable-diffusion-webui/repositories/latent-diffusion* /content/stable-diffusion-webui/modules
#if clear_out:
#  output.clear()
# !sleep 3
#скачивание внедрений (embeddings)
#@markdown <font color='#38c013' size='2' face="Verdana"><b>Нужно ли установить внедрения (embeddings)?</font>
внедрения = False #@param {type:"boolean"}
#@markdown <details><summary>внедрения с их названиями-токенами</summary><img src='https://files.catbox.moe/85l9d1.png' width='230vw'></details>
#@markdown <br>
#@markdown <font color='#38c013' size='2' face="Verdana"><b>Нужно ли установить DeepDanbooru и Booru tag autocompletion?</font>
deepdanbooru = False #@param {type:"boolean"}
#@markdown DeepDanbooru — это система оценки тегов изображений в стиле аниме.<br> Booru tag autocompletion  — скрипт, который <a href='https://files.catbox.moe/ej16sh.webm'>будет автоматически</a> дополнять промпт нужными ключами с Danbooru, для наилучшего результата картинок в стиле аниме
#@markdown <hr>
if внедрения:
  # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/embeddings -O emb.zip
  # !unzip -n -q emb.zip -d /content/stable-diffusion-webui/embeddings
  # !rm emb.zip
#if clear_out:
#  output.clear()

#@markdown <font color='#38c013' size='2' face="Verdana"><b>Загрузка моделей весов</b></font><br>
#@markdown По дефолту SD v1.5 с доп. inpaiting моделью + VAE (<b>перед генерацией, не забудь выбрать конкретную модель в левом верхнем углу WebUI!</b>).<br>

#@markdown <details><summary><big><big><big>👈Описание моделей, ключи для их вызова</big></big></big> (разверни спойлер, чтобы прочитать)</summary><p><b>SD v2.0</b> — это обновленная, некстген модель, полностью заново обученная, вторая версия. При выборе опции будет установлена полная sd-v2-0-768, модель sd-v2-0-inpainting, базовая v2-512(с отфильтрованным порно-контентом), модель апскейлинга через изо-в-изо sd-v2-0_4x-upscaler и модель глубины sd-v2-0-depth. Нововведений довольно много, <a href='https://stability.ai/blog/stable-diffusion-v2-release'>можно почитать в офф. блоге.</a> Для стандартной модели <b>минимальное разрешение 768x768</b>! Учитывай это! Ставить одну из сторон меньше 768 не рекомендуется. Поскольку токинайзер новый, то старые промпты с 1.5 уже не будут работать как раньше. И самое важное и печальное: из датасета модели было удалено все что связанно с NSFW, так что никаких какашек с дедами, никаких сисек и писек, да и вообще анатомии обнаженного тела - пизда... Но для хуежеств она стала получше (правда некоторые художники/стили были удалены). Ждем кастомных моделей на ее основе.</p><p><b>SD v1.5 и SD v1.4</b> — это стандартные модели, обе дообучались на SD v1.2, специфических токенов нет, идеальны для общих нужд. Эта модель является базой, на которой строятся все остальные узкоспецифические модели. Моделька 1.5 идет в комплекте с VAE(тонко настроенный вариационный автоэнкодер, немного улучшает качество генерации) и моделью для Inpaiting(она тоже с VAE), которую надо выбрать перед работой в img2img inpaint. Особого смысла в 1.4 уже нет, она добавлена для совместимости со старыми сидами/промптами.</p><p><b>SD v1.5 full для обучения</b> — это стандартная модель, из которой не были удалены данные для обучения, потому она весит в два раза больше. Особого смысла генерить на ней нет, но для тренировки внедрений, гиперсети и т.д. - она годится (возможно) лучше. Требует очень много памяти, так что следи за настройками обучения, чтобы уместиться в 15гб VRAM. Если честно, то такие модели создаются только для нативного обучения, а не для Dreambooth, внедрений, гиперсети. А нативным обучением в колабе, да и на рядовом ПК при всем желании заняться не получится. По большому счету - эта модель просто <i>что бы было</i>.</p><p><b>Члены</b> — модель умеет рисовать только хуи, обычные русские необрезанные члены. В промпт нужно писать токен <code>uncut-penis</code> и <code>uncutpenis</code> и <code>uncut penis</code>. Модель тестовая и предназначена для ценителей эстетики членов. Можно попытаться мержить с другими моделями. А лучше нагенерить пачку хуёв для вайпа, например. Если честно - это модель появилась просто во время теста работы Dreambooth в колабе и скрипта конвертации моделей, обучалась модель на 50 фотках. Тебя разве не огрчает низкое качество членов в стандартной модели?</p><p><b>Beksinski</b> — стиль загадочного и потрясающего художника Здислава Бексинского, в промпт добавлять <code>beksinski style</code></p><p><b>Van_Gogh</b> — модель натренирована на кадрах из фильма «Ван Гог. С любовью, Винсент» — который выполнен в стилистике рисовки Ван Гога, это первый в мире анимационный полнометражный фильм, полностью нарисованный масляными красками на досках! В промпт важно добавить в самое начало <code>lvngvncnt</code>, например: <code>lvngvncnt, handsome attractive shirtless younker, highly detailed</code> Если не нравится слишком синюшная гамма и желтые рожи — в негативный промпт надо написать что-то вроде <code>yellow face, blue</code> Моделька ахуенная, рисует и людей и природу и здания — очень хорошо. Поскольку моделька высокохудожественная, то не поднимайте высоко CFG Scale, чтобы нейросеть могла больше «фантазировать», 4-7 — будет норм.</p><p><b>DBWayneBarlowe_JM</b> — демоническая, оккультная, религиозная и сатанинская темататика, в промпт писать все что с этим связанно, основана на работах художника Уэйна Барлоу, сначала рекомендую ознакомится c ним, чтобы понять что к чему.</p><p><b>Cats_Tabaxi</b> — рисует антропофорфных котиков и прочих каджитов. Основной ключ <code>tabaxi person</code>, и далее - все что связанно с котаи - львы, тигры, рыси, и прочие котики. В негативный промпт нужно написать типа: <code>mutation, human hands, big head</code>. Примеры промптов: <code>portrait of a male white cat tabaxi person, rpg illustration by alex horley and dan mumford</code> | <code>portrait of a lion tabaxi person, in aplate armor, realisic render, octane render, zbrush, still from a movie, alexa, cooke 55mm, award winning photgraphy</code> | <code>portrait of a tiger boy tabaxi person, in a thief dark leather armor, black hood on her head, realisic render, octane render, zbrush, still from a movie, alexa, cooke 55mm</code></p><p><b>Cthulhu_illithid</b> — на самом деле модель у автора называется просто illithid, но чтобы было понятно - я добавил про Ктулху, потому что модель натренированна на молюско-подобной рассе, вдохновленной рисунками по мотивам произведений Лавкрафта и его Древними. В промпт нужно писать <code>illithid Person</code> или <code>illithid_Person</code>.</p><p><b>BubblyDubbly</b> — рисованные портреты в стиле BubblyDubbly, что это такое: https://imgur.com/a/yEchVjv . Ключ <code>art by bubblydubbly</code>, в негативный промпт можно добавить: <code>heavy contrast, red eyes, blue hair</code>, простой пример: <code>attractive boy, soft colors, art by bubblydubbly</code></p><p><b>pachu artwork style</b> — модель обучена на рисунках иллюстратора Плейбоя — Пачу Торреса, после подгрузки модели, в промпт добавить pachu <code>artwork style</code></p><p><b>Redshift</b> — модель обученная на 3Д рендерах высокого разрешения через Redshift, в начало промпта нужно добавлять <code>redshift style</code></p><p><b>modern disney style</b> — совремеменный пластмассовый диснеевский стиль, в промпт добавить <code>modern disney style</code></p><p><b>classic disney style</b> — стиль Диснея прошлого века с качественной мультяшной рисовкой, в промпт добавить <code>classic disney style</code></p><p><b>tron legacy style</b> — стилистика из фильма «Трон: Наследие», в промпт нужно добавлять <code>trnlgcy</code></p><p><b>elden ring style</b> — моделька на основе игровых артов из Elden Ring, в пропмт нужно писать <code>elden ring style</code></p><p><b>spiderverse style</b> — стиль мультика «Человек-паук: Через вселенные», в пропте надо писать <code>spiderverse style</code></p><p><b>discoelysium style</b> — стиль персонажей из игры Disco Elysium, в промпт надо добавлять токен <code>discoelysium style</code></p><p><b>arcane style</b> — стилистика фентезийного мультсериала «Аркейн», в промпт нужно воткнуть токен <code>arcane style</code></p><p><b>archer style</b> — стиль шпионского мальтсериала «Арчер», в пропмпте нужно указать <code>archer style</code></p><p><b>Bloodborne</b> — модель обученная стилю из игры Bloodborne, в промпт надо добавлять <code>Bloodborne Style</code></p><p><b>DarkSouls</b> — модель обученная стилю серии DarkSouls, в промпт добавлять <code>DarkSouls Style</code>, автор рекомендует рендер на Euler_a 20 шагов или DPM++ 2M Karras.</p><p><b>Borderlands</b> — модель для создания изображений в стиле Borderlands, соответсвтенно в промпт надо писать токен <code>borderlands</code></p><p><b>Starsector_Portrait</b> — модель обученная на скринах из видеоигры Starsector, лучще всего заточена под портреты, в промпт нужно добавить <code>starsectorportrait</code>, например <code>a starsectorportrait of a man wearing a green balaclava and armored spacesuit</code> сочетается с добавочными токенами <code>sabattier effect</code> — для эффекта освещения, <code>brush strokes</code> — для большей художественности портретов, <code>conte</code> — более аккуратные мазки. Модель <u>будет установлена с гиперсетью</u>, которую нужно будет подключить/отключить в настройках</p><p><b>EpicSpaceMachine</b> — футристичные космические корабли, станции и т. п., в промт добавлять <code>EpicSpaceMachine</code>, к примеру: <code>Photo of a futuristic space liner, 4K, award winning in EpicSpaceMachine style</code></p><p><b>reasonableDrink</b> — модель для фентезийных и фантастических артов, в промпт добавить <code>reasonableDrink</code></p><p><b>CALARTS</b> — рисунки персонажей в CalArts-стиле, в промпт добавить <code>CALARTS</code></p><p><b>beeple</b> — модель натренирована на работах этого художника-фотошопера: <a href="https://twitter.com/beeple">@beeple</a> в промпт нужно добавлять <code>beeple</code></p><p><b>megaPals</b> — стиль мультиков про супергероев из 70-х годов прошлого века, в промпт добавить <code>in megaPals style</code> или <code>a cartoon of  <em>КТО-ТО</em>, in megaPals style</code></p><p><b>Hogwarts_Legacy</b> — стиль из игры Хогрвардс: Наследие, в промпт писать: <code>HogLeg Style</code></p><p><b>Midjourney</b> — имитация стиля другой нейросетки, лол. Всем она известна, если нет - погугли картинки. В промпт нужно писать этот ключ: <code>mdjrny-v4 style</code>. Подробнее о промптинге <a href="https://prompthero.com/midjourney-prompts?version=4">написано тут</a>.</p><p><b>OpenJourney</b> — это форк предыдущей модели, и как утверждают разработчики, эта модель значительно допилена и годится в качестве замены проприетарной Midjourney! Стиль действительно хорошо получается, а токен для промпта тот же: <code>mdjrny-v4 style</code>. Подробнее о промптинге <a href="https://prompthero.com/midjourney-prompts?version=4">написано тут</a>.</p><p><b>WiKiArt</b> — чисто художественная модель, обученная по огромной базе из более чем 3000 художников, собственно самих художников нужно <a href="https://www.wikiart.org" >смотреть на сайте</a>: <small>осторожно, он нашпигован свиной пропагандой ЦИПсО про злых русских и очередной сбор денег для Азова, свиные баннеры заблокируйте ublock или adblock. Заходишь на художественный сайт, не думаешь о хохлах и политике - а тут такой сюрприз. В общем - предупредил. Перед заходом можешь добавить в правила блокировщика рекламы это:</small><pre>||uploads.wikiart.org/Content/wiki/img/banner_top.png$image<br />www.wikiart.org##[src="https://uploads.wikiart.org/Content/wiki/img/banner_top.png"]</pre></p><p><b>Abstract_Swirls</b> — умеет рисовать абстракцию типа жидкого мрамора или акриловых красок в воде, но умеет и в портреты в стиле жидкой краски с завитками и разводами, выглядит красиво.Основной токен: <code>abstractswirls</code>, пример: <code>portrait of a handsome slender shirtless teen boy, abstractswirls, long shot, masterpiece, by artgerm and mucha</code>. Автор генерирует на таких настройках: Steps: 10, Sampler: DPM++ 2S a Karras, CFG scale: 7.</p><p><b>poolsuite style</b> — модель натренирована на ретро-подобных весьма ламповых фотках и картинках, вот <a href="https://prompthero.com/search?q=poolsuite+style">примеры подобного</a>. В промпт надо добавлять <code>poolsuite-style</code> или <code>poolsuite style</code>.</p><p><b>newhorrorfantasy_style</b> — иллюстрации ужасов и фэнтези 2010-х годов, в промпт добавлять токен <code>newhorrorfantasy_style</code></p><p><b>James_Webb_Cosmos</b> — потрясающие космические снимки, словно сделанные новым телескопом Джеймса Уэбба, нужно добавлять <code>JWST</code>, например <code>jwst, green spiral galaxy</code></p><p><b>Microscopic</b> — а эта модель, напротив - создает фотореалистичные картинки, сделанные словно под хорогим микроскопом. Амебы, эвглены, вирусу, и прочая микробиология и гистология. В промпт нужно добавлять все что с этим связанно и обязательно в начало <code>Microscopic</code>.</p><p><b>nousr robot</b> — моделька сделанная через Дримбус для генерации футристичных роботов, нужно добавлять <code>nousr robot</code> по ближе к началу промпта</p><p><b>гнилые_зомби</b> — модель тренировалась на зомби из Ходячих Мертвецов, в промт добавлять токен <code>RottingZombie person</code></p><p><b>blotmon</b> — модель для генерации монстров из клякс, мультяшных монстриков и всякой деформированной шизы, в промт добавлять токен <code>blotmon</code></p><p><b>All_In_1_Pixel</b> — модель, которая умеет в разнонаправленную пиксельную графику. Токен <code>pixelsprite</code> будет выдавать спрайт-арт, ключ <code>16bitscene</code> активирует генерацию в стиле scene-art. Понятное дело, пиксели не идеальны, но картинки можно легко пофиксить на этом сайте: https://pinetools.com/pixelate-effect-image</p><p><b>pixel_landscape</b> — шестнадцатибитные пиксельные картинки, заточеные под пейзажи, объекты, обои рабочего стола, и т. п. В ромпт надо добавлять: <code>in 16-bit-landscape pixel art style</code></p><p><b>Pixel_Art</b> — довольно качественный пиксельарт, в промпт нужно добавить <code>in SKSKS art style</code>, например <code>little fox, in SKSKS art style</code></p><p><b>MinecraftRTX</b> — модель для стиля Майнкрафт с RTX, в промпт добавить <code>BlockWorldRTX</code></p><p><b>microworld</b> — изометрический 3Д-арт, в промпт добавить <code>in microworld render style</code>, например <code>baalbek temple of jupiter, in microworld render style</code></p><p><b>App_Icons</b> — рисует современные иконки и пиктограмы, в промпт надо добавить <code>in style of SKSKS app icon</code>, например <code>flat couch vector, minimalist, in style of SKSKS app icon</code></p><p><b>Пепе</b> — рисует очень редких лягух Пепе. Токен для промпта <code>pepestyle person</code>.</p><p><b>ГигаЧад</b> — делает фото/рисунки знаменитого гигачада, россиянина Эрнеста Халимова. В промпт добавлять <code>gigachad</code>.</p><p><b>pokemon</b> — моделька рисует покемонов, из чего угодно, в промпт писать описание предполагаемого покемона типа <code>Vladimir Putin creature</code> или <code>cute toad</code> слово pokemon во все не обязательно, модель все равно кроме покемонов ничего не умеет.</p><p><b>ssmoky</b> — моделька заточена чисто под арты с дымом и огнем, особенно с дымом, в промпт добавлять токен <code>ssmoky</code></p><p><b>F222</b> — модель улучшеной анатомии бабского тела, хорошо подходит для эротики</p><p><b>HassanBlend</b> — модель для генерации обнаженных женщин, в порноэротическом стиле, стремится к студийному фотореализму. При выборе этой опции, будет скачено и установлено три файла моделек: prunned и full версия 1.4 (prunned помогает избежать нехватки памяти, т.к. жирные модели не всегда могут нормально ворочаться в колабе) и старая версия 1.2 - ее смысл в том, что она лучше, по мнению Анона, умеет генерить, женщин еще не достигших овуляционного периода, или только-только начавших менструальные циклы. Промптинг состоит из описания наготы, порнографии в соло, писать все довольно много, поэтому промпты с нужными ключами и примерами лучше посмотреть на <a href='https://rentry.org/sdhassan#prompts'>странице модели</a>.</p><p><b>hyperpreg__round_belly</b> — генерирует БИБИК! Да, с огромным пузом, которое вот-вот РВАНЁТ! Умеет в рисунки — с токеном <code>hyperpreg</code> и в реализм, с токеном <code>round belly</code> — делать толстого Пыню теперь станет интереснее.</p><p><b>pyros_blowjob</b> — очень качественная модель про минет, сосание (нормальных) членов. Можно кого угодно заставить жадно обсасывать залупу-лупу.  Промпты должны включать <code>with cock in mouth, is sucking a cock, licking a large cock in mouth</code> Подробнее <a href="https://rentry.org/pyros-sd-model">почитай здесь</a> - там примеры промтов в фотореалистичном, рисованном и аниме-стиле.</p><p><b>bkdbj</b> — просто пиши любое имя и  <code>bkdbj</code> (модель про сосание <u>черных</u> членов кем-либо)</p><p><b>chkn_петухи</b> — очень классно ричует петухов и кур, в разных стилях, от фото до картины масло. Имхо, идеально для боевых картинок. В промпт добавлять: <code>chkn</code></p><p><b>YIFFY_EPOCH18</b> — не знаешь че такое йиффи? Лучше не лезь. На самом деле умеет не только в зверушек, но и таких животных как трапы/футы, в рисованном стиле разумеется. Вот полный список токенов для этой шизы: <a href="https://files.catbox.moe/sovd89.zip">в архиве файлик yiffy_tags.csv</a></p><p><b>Zack3D_Kinky</b> — для тех кого просто фурри уже не вставляет: щупальца, бдсм с дикими животными, боди-модификации, латекс, слизь, пытки анала и т.п. использовать теки с сайта E621 <code>то_есть_с_подчеркиванием</code></p><p><b>GAPE60 и ее прошлая версия YIFFY_GAPE</b> — фистинг и его последвствия: раздолбанные дыры пизды и анальной пизды, пролапс, вхлам растраханные отверстия, зияющие своими красными недрами, про теги и примеры посмотри <a href="https://rentry.org/gapemodel">тут</a></p><p><b>Anything_V3</b> — Последнее слово в генерации аниме! Это утечка гораздо улучшеной версии NovelAI. Подолбнее можно прочитать на <a href="https://www.bilibili.com/read/cv19603218">китайском сайте</a> через гуглпереводчик. <b>Anything_v3_fullema</b> - таже модель, только раздутая данными для тренировки.</p><p><b>Berrymix_Zeipher222</b> — мощный микс из разных моделей по особой рецептуре, в качестве важной специи - модель Зефир на улучшенную анатомию наготы, в качестве бульона - NovelAI, и еще разные специи.</p><p><b>Anything_Berrymix</b> — Суть таже что и Berrymix_Zeipher222, только вместо NovelAI более качественная аниме-модель Anything_V3</p><p><b>Anonmix</b> — Это очень качественный микс от Анона, включает такие модели как SmirkingFace + lokean puppystyle + модели из микса Berrymix. Качество генерации, пожалуй, самое лучшее из имеющихся по около-аниме тематике. Но умеет и в другие стили, просто с легким намеком на анимешность. Конечности, лица, пальцы, половые признаки получаются как нигде хорошо.</p><p><b>Antlers_mix</b> — аниме-тянки(и не только) но без главного недостатка примитивной аниме-рисовки: отсутствие светотеневого рисунка. Это микс из различных моделей и их премиксов: ((nai_0.95 + sd-1.5_0.05) + f222 - sd-1.5)_0.75 + trinart2-115000_0.25, благодаря наличию весов из реальных фоточек и улучшенной анатомии, на выходе получается аниме-стайл, только <a href='https://files.catbox.moe/yk8csq.jpg'>совершенно не плоский</a>.</p><p><b>WaifuDiffusion-1.3</b> — анимешная модель, обучалась по картинкам с Danbooru, теги берите от туда же</p><p><b>Trinart v2</b> — еще одна анимешная модель, обучалась аж на 20 лямах картинок аниме и манги, без писек/сисек</p><p><b>Freckle_mix</b> — Микс на основе Trinart и неизвестных аниме-моделей. Довольно популярна на форчке.</p><p><b>NAI</b> — утечка модели NovelAI (скачивается с VAE), когда-то вызвала бум среди анимедрочеров и считалась революционной.</p><p><b>Cyberpunk-Anime-Diffusion</b> — генерирует аниме-персонажей в стиле киберпанк. Автор рекомендует следующие настройки генерации: сэмплер Euler_a, 20 шагов, CFG Scale 7, разрешение 704px x 704px. В промпт нужно писать <code>in dgs illustration style</code>. В негативный промпт: <code>out of focus, scary, creepy, evil, disfigured, missing limbs, ugly, gross, missing fingers</code>. Примеры хороших запросов для данной модели: <code>a photo of muscular beard soldier male in dgs illustration style, half-body, holding robot arms, shirtless, strong chest</code> или <code>portrait of a girl in dgs illustration style, Anime girl, female soldier working in a cyberpunk city, cleavage, ((perfect femine face)), intricate, 8k, highly detailed, shy, digital painting, intense, sharp focus</code></p><p><b>80s_Anime</b> — модель имитирует стиль аниме конца 80-х начала 90-х, в частности, аниме Ranma 1/2. В промпте нужно использовать слово <code>80sanimestyle</code>. Автор призывает экспериментировать с различными сэмплерами, и отмечает что DPM2, DPM++ и их варианты лучше всего работают с этой моделью.</p><p><b>Black_Souls</b> — имитирует графику из корейской игры «Black Souls». В промпт добавь токен <code>bs</code>. Автор требует, чтобы CFG_Scale стоял не выше 6, рекомендует 2-6, для skip clip установлено значение 1.</p><p><b>своя прямая ссылка на модель</b> — выбираешь эту опцию, потом вставляешь в соответствующее поле <u>прямую ссылку</u> на свою модель, откуда она скачается куда нужно</p></details>

#@markdown <font color='#FF8C00' face="Arial"><b>Выбирай нужную модель из 93 штук в выпадающем списке или опцию "своя прямая ссылка на модель":</b>
выбор_модели = 'SD v2.1 512px' # @param ["SD v2.1 512px", "SD v2.1 768px", "SD v1.5", "SD v1.5 full для обучения", "SD v1.4", "dreamlikePhotoRealV2", "Beksinski", "Analog_diffusion", "Protogen_X58_Rebuil", "protogenX3_4", "RealEldenApocalypse_AnalogSexKnoll_4CandyPureSimp_FEET", "Van_Gogh", "Bloodborne", "DarkSouls", "Borderlands", "Redshift", "Starsector_Portrait", "EpicSpaceMachine", "reasonableDrink", "CALARTS", "beeple", "megaPals", "pachu artwork style", "Cats_Tabaxi", "Cthulhu_illithid", "BubblyDubbly", "Ложкин", "modern disney style", "classic disney style", "tron legacy style", "elden ring style", "spiderverse style", "discoelysium style", "arcane style", "archer style", "poolsuite style", "newhorrorfantasy_style", "Hogwarts_Legacy", "OpenJourney", "Midjourney", "WiKiArt", "Abstract_Swirls", "James_Webb_Cosmos", "Microscopic", "nousr robot", "гнилые_зомби", "blotmon", "All_In_1_Pixel", "16bit_landscape", "Pixel_Art", "MinecraftRTX", "microworld", "App_Icons", "DBWayneBarlowe_JM", "Пепе", "ГигаЧад", "pokemon", "ssmoky", "HASDX", "elldrethSLucidMix_v10", "hAS3Dkx11_3Dkx11", "HassanBlend", "F222", "pyros_blowjob", "bkdbj", "hyperpreg__round_belly", "chkn_петухи", "YIFFY_EPOCH18", "Zack3D_Kinky", "AnythingGape", "GAPE60", "YIFFY15_GAPE", "FurSlut", "Anything_V3", "Anything_v3_fullema", "WaifuDiffusion-1.3", "Anonmix", "Berrymix_Zeipher222", "Anything_Berrymix", "Antlers_mix", "monstermash4_anyv3", "monstermash6_anyv3", "Bstaber", "80s_Anime", "NAI", "Freckle_mix", "Trinart v2", "Cyberpunk-Anime-Diffusion", "Black_Souls", "protogenV22Anime", "BloodNightOrangeMix", "ElyOrangeMix", "AbyssOrangeMix", "MMDv1_18", "Члены", "своя прямая ссылка на модель"]
if not модели_только_с_гуглодиска:
  if выбор_модели == 'SD v2.1 512px':
      # !wget -nv --show-progress https://huggingface.co/stabilityai/stable-diffusion-2-1-base/resolve/main/v2-1_512-ema-pruned.safetensors -P /content/stable-diffusion-webui/models/Stable-diffusion/
      # !sleep 2
      # !wget -nv --show-progress https://huggingface.co/stabilityai/stable-diffusion-2-inpainting/resolve/main/512-inpainting-ema.safetensors -P /content/stable-diffusion-webui/models/Stable-diffusion/
  if выбор_модели == 'SD v2.1 768px':
      # !wget -nv --show-progress https://huggingface.co/stabilityai/stable-diffusion-2-1/resolve/main/v2-1_768-ema-pruned.safetensors -P /content/stable-diffusion-webui/models/Stable-diffusion/
  if выбор_модели == 'SD v1.5':
      # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/sd-v1-5.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/sd-v1-5.ckpt
      # !sleep 2
      # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/sd-v1-5.vae.pt -O /content/stable-diffusion-webui/models/Stable-diffusion/sd-v1-5.vae.pt
      # !sleep 2
      # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/sd-v1-5.inpainting.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/sd-v1-5.inpainting.ckpt
      # !sleep 2
      # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/sd-v1-5.inpainting.vae.pt -O /content/stable-diffusion-webui/models/Stable-diffusion/sd-v1-5.inpainting.vae.pt
  elif выбор_модели == 'SD v1.5 full для обучения':
      # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/sd-v1-5.full.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/sd-v1-5.full.ckpt
  elif выбор_модели == 'SD v1.4':
      # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/sd-v1-4.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/sd-v1-4.ckpt
  elif выбор_модели == 'pachu artwork style':
      # !wget -nv --show-progress https://huggingface.co/ProGamerGov/Pachu-Diffusion/resolve/main/pachu_artwork_style_v1_iter8000.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/pachu_artwork_style.ckpt
  elif выбор_модели == 'modern disney style':
      # !wget -nv --show-progress https://huggingface.co/nitrosocke/mo-di-diffusion/resolve/main/moDi-v1-pruned.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/modern_disney_style.ckpt
  elif выбор_модели == 'classic disney style':
      # !wget -nv --show-progress https://huggingface.co/nitrosocke/classic-anim-diffusion/resolve/main/classicAnim-v1.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/classic_disney_style.ckpt
  elif выбор_модели == 'tron legacy style':
      # !wget -nv --show-progress https://huggingface.co/dallinmackay/Tron-Legacy-diffusion/resolve/main/Tron-Legacy-Style-trnlgcy.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/trnlgcy.ckpt
  elif выбор_модели == 'elden ring style':
      # !wget -nv --show-progress https://huggingface.co/nitrosocke/elden-ring-diffusion/resolve/main/eldenring-v2-pruned.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/elden_ring_style.ckpt
  elif выбор_модели == 'spiderverse style':
      # !wget -nv --show-progress https://huggingface.co/nitrosocke/spider-verse-diffusion/resolve/main/spiderverse-v1-pruned.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/spiderverse_style.ckpt
  elif выбор_модели == 'discoelysium style':
      # !wget -nv --show-progress https://huggingface.co/nitrosocke/disco-elysium/resolve/main/discoElysium-pruned.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/discoelysium_style.ckpt
  elif выбор_модели == 'arcane style':
      # !wget -nv --show-progress https://huggingface.co/nitrosocke/Arcane-Diffusion/resolve/main/arcane-diffusion-v3.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/arcane_style.ckpt
  elif выбор_модели == 'archer style':
      # !wget -nv --show-progress https://huggingface.co/nitrosocke/archer-diffusion/resolve/main/archer-v1.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/archer_style.ckpt
  elif выбор_модели == 'poolsuite style':
      # !wget -nv --show-progress https://huggingface.co/prompthero/poolsuite-diffusion/resolve/main/poolsuite_step2010.ckpt  -O /content/stable-diffusion-webui/models/Stable-diffusion/poolsuite_style.ckpt
  elif выбор_модели == 'newhorrorfantasy_style':
      # !wget -nv --show-progress https://huggingface.co/elRivx/sd-newhorrorfantasy_style/resolve/main/newhorrorfantasy_style.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/newhorrorfantasy_style.ckpt
  elif выбор_модели == 'nousr robot':
      # !wget -nv --show-progress https://huggingface.co/nousr/robo-diffusion/resolve/main/models/robo-diffusion-v1.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/nousr_robot.ckpt
  elif выбор_модели == 'pokemon':
      # !wget -nv --show-progress https://huggingface.co/justinpinkney/pokemon-stable-diffusion/resolve/main/ema-only-epoch%3D000142.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/pokemon.ckpt
  elif выбор_модели == 'blotmon':
      # !wget -nv --show-progress https://huggingface.co/guumaster/blot-monster-diffusion/resolve/main/blotmon-v1-5000.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/blotmon.ckpt
  elif выбор_модели == 'ssmoky':
      # !wget -nv --show-progress https://huggingface.co/guumaster/smoke-diffusion/resolve/main/ssmoky1_3000.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/ssmoky.ckpt
  elif выбор_модели == 'YIFFY_EPOCH18':
      # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/yiffy-e18.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/yiffy-e18.ckpt
  elif выбор_модели == 'WiKiArt':
      # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/sd-wikiart-v2.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/wikiart.ckpt
  elif выбор_модели == 'Zack3D_Kinky':
      # !wget -nv --show-progress https://huggingface.co/Zack3D/Zack3D_Kinky-v1/resolve/main/Zack3D_Kinky-v1.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/kinky.ckpt
  elif выбор_модели == 'GAPE60':
      # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/gape60.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/gape60.ckpt
  elif выбор_модели == 'YIFFY15_GAPE':
      # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/gape22_yiffy15.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/gape_yiffy.ckpt
  elif выбор_модели == 'hyperpreg__round_belly':
      # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/hyperpreg__round_belly.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/hyperpreg__round_belly.ckpt
  elif выбор_модели == 'WaifuDiffusion-1.3':
      # !wget -nv --show-progress https://huggingface.co/hakurei/waifu-diffusion-v1-3/resolve/main/wd-v1-3-float32.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/waifu.ckpt
  elif выбор_модели == 'NAI':
      # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/novelai.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/novelai.ckpt
      # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/novelai.vae.pt -O /content/stable-diffusion-webui/models/Stable-diffusion/novelai.vae.pt
  elif выбор_модели == 'Anything_V3':
      # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/Anything-V3.0-pruned-fp32.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/anything_v3.ckpt
      # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/Anything-V3.0.vae.pt -O /content/stable-diffusion-webui/models/Stable-diffusion/anything_v3.vae.pt
  elif выбор_модели == 'Anything_v3_fullema':
      # !wget -nv --show-progress https://huggingface.co/utnah/big_ckpt/resolve/main/Anything_v3_fullema.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/Anything_v3_fullema.ckpt
      # !wget -nv --show-progress https://huggingface.co/utnah/big_ckpt/resolve/main/Anything_v3_fullema.vae.pt -O /content/stable-diffusion-webui/models/Stable-diffusion/Anything_v3_fullema.vae.pt
  elif выбор_модели == 'Trinart v2':
      # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/trinart2.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/trinart2.ckpt
  elif выбор_модели == 'DBWayneBarlowe_JM':
      # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/DBWayneBarlowe_JM.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/DBWayneBarlowe_JM.ckpt
  elif выбор_модели == 'F222':
      # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/f222.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/f222.ckpt
  elif выбор_модели == 'Beksinski':
      # !wget -nv --show-progress https://huggingface.co/s3nh/beksinski-style-stable-diffusion/resolve/main/model.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/beksinski.ckpt
  elif выбор_модели == 'Van_Gogh':
      # !wget -nv --show-progress https://huggingface.co/dallinmackay/Van-Gogh-diffusion/resolve/main/Van-Gogh-Style-lvngvncnt-v2.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/Van_Gogh.ckpt
  elif выбор_модели == 'Bloodborne':
      # !wget -nv --show-progress https://huggingface.co/Guizmus/Bloodborne/resolve/main/BloodborneStyle-v1.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/Bloodborne.ckpt
  elif выбор_модели == 'DarkSouls':
      # !wget -nv --show-progress https://huggingface.co/Guizmus/DarkSoulsDiffusion/resolve/main/DarkSoulsStyle-v1.2.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/DarkSouls.ckpt
  elif выбор_модели == 'Borderlands':
      # !wget -nv --show-progress https://huggingface.co/PublicPrompts/borderlands/resolve/main/borderlands.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/borderlands.ckpt
  elif выбор_модели == 'Redshift':
      # !wget -nv --show-progress https://huggingface.co/nitrosocke/redshift-diffusion/resolve/main/redshift-diffusion-v1.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/redshift.ckpt
  elif выбор_модели == 'Starsector_Portrait':
      # !wget -nv --show-progress https://huggingface.co/Severian-Void/Starsector-Portraits/resolve/main/models/starsectorportrait_v2.1_SD1.5.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/starsector_portrait.ckpt
      # !curl -L --create-dirs https://huggingface.co/Severian-Void/Starsector-Portraits/resolve/main/hypernetworks/HN_ssportrait_v2_1.5_13431.pt -o /content/stable-diffusion-webui/models/hypernetworks/HN_ssportrait.pt
  elif выбор_модели == 'EpicSpaceMachine':
      # !wget -nv --show-progress https://huggingface.co/rabidgremlin/sd-db-epic-space-machine/resolve/main/EpicSpaceMachine.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/EpicSpaceMachine.ckpt
  elif выбор_модели == 'reasonableDrink':
      # !wget -nv --show-progress https://huggingface.co/elRivx/reasonableDrink/resolve/main/reasonableDrink.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/reasonableDrink.ckpt
  elif выбор_модели == 'CALARTS':
      # !wget -nv --show-progress https://huggingface.co/PublicPrompts/CALARTS/resolve/main/CALARTS.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/CALARTS.ckpt
  elif выбор_модели == 'beeple':
      # !wget -nv --show-progress https://huggingface.co/riccardogiorato/beeple-diffusion/resolve/main/beeple.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/beeple.ckpt
  elif выбор_модели == 'megaPals':
      # !wget -nv --show-progress https://huggingface.co/elRivx/megaPals/resolve/main/megaPals.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/megaPals.ckpt
  elif выбор_модели == '16bit_landscape':
      # !wget -nv --show-progress https://huggingface.co/PublicPrompts/16-bit-landscape_PublicPrompts/resolve/main/16-bit-landscape_PublicPrompts.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/16bit_landscape.ckpt
  elif выбор_модели == 'Pixel_Art':
      # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/Pixel_Art.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/Pixel_Art.ckpt
  elif выбор_модели == 'MinecraftRTX':
      # !wget -nv --show-progress https://huggingface.co/rabidgremlin/sd-db-block-world-rtx/resolve/main/BlockWorldRTX.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/MinecraftRTX.ckpt
  elif выбор_модели == 'microworld':
      # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/microworld.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/microworld.ckpt
  elif выбор_модели == 'App_Icons':
      # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/App_Icons.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/App_Icons.ckpt
  elif выбор_модели == 'bkdbj':
      # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/bkdbj.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/bkdbj.ckpt
  elif выбор_модели == 'Berrymix_Zeipher222':
      # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/Berrymix_Zeipher222.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/Berrymix_Zeipher222.ckpt
  elif выбор_модели == 'Anything_Berrymix':
      #!wget -nv --show-progress https://huggingface.co/utnah/big_ckpt/resolve/main/Anything_Berrymix.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/Anything_Berrymix.ckpt
      # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/Anything_Berrymix-pruned.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/Anything_Berrymix-pruned.ckpt
  elif выбор_модели == 'pyros_blowjob':
      # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/pbj_v1.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/pyros_blowjob.ckpt
  elif выбор_модели == 'Пепе':
      # !wget -nv --show-progress https://huggingface.co/SpiteAnon/Pepestyle/resolve/main/pepestylev2_2200.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/pepestyle_person.ckpt
  elif выбор_модели == 'ГигаЧад':
      # !wget -nv --show-progress https://huggingface.co/SpiteAnon/gigachad-diffusion/resolve/main/gigachad_2000.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/gigachad.ckpt
  elif выбор_модели == 'James_Webb_Cosmos':
      # !wget -nv --show-progress https://huggingface.co/dallinmackay/JWST-Deep-Space-diffusion/resolve/main/JWST-Deep-Space.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/JWST.ckpt
  elif выбор_модели == 'Midjourney':
      # !wget -nv --show-progress https://huggingface.co/prompthero/midjourney-v4-diffusion/resolve/main/mdjrny-v4.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/mdjrny-v4_style.ckpt
  elif выбор_модели == 'Cats_Tabaxi':
      # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/tabaxi2500person.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/cat_tabaxi_person.ckpt
  elif выбор_модели == 'Cthulhu_illithid':
      # !wget -nv --show-progress 'https://huggingface.co/VTTRPGResources/DnDAi-illithid_Person/resolve/main/DnDAi%20-%20illithid_Person.ckpt' -O /content/stable-diffusion-webui/models/Stable-diffusion/illithid_person.ckpt
  elif выбор_модели == 'BubblyDubbly':
      # !wget -nv --show-progress https://huggingface.co/Marre-Barre/bubblydubbly/resolve/main/bubblydubbly_7k.ckpt  -O /content/stable-diffusion-webui/models/Stable-diffusion/bubblydubbly_7k.ckpt
      # !wget -nv --show-progress https://huggingface.co/Marre-Barre/bubblydubbly/resolve/main/bubblydubbly.ckpt  -O /content/stable-diffusion-webui/models/Stable-diffusion/bubblydubbly.ckpt
  elif выбор_модели == 'Microscopic':
      # !wget -nv --show-progress https://huggingface.co/Fictiverse/Stable_Diffusion_Microscopic_model/resolve/main/Microscopic_v1.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/Microscopic.ckpt
  elif выбор_модели == 'гнилые_зомби':
      # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/RottingZombie_person.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/RottingZombie_person.ckpt
  elif выбор_модели == 'Black_Souls':
      # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/Black_Souls.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/Black_Souls.ckpt
  elif выбор_модели == 'All_In_1_Pixel':
      # !wget -nv --show-progress https://huggingface.co/PublicPrompts/All-In-One-Pixel-Model/resolve/main/Public-Prompts-Pixel-Model.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/all_in_one_pixel_model.ckpt
  elif выбор_модели == 'Abstract_Swirls':
      # !wget -nv --show-progress https://huggingface.co/coder119/Abstract_Swirls_Diffusion/resolve/main/Abstract_Swirls.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/abstractswirls.ckpt
  elif выбор_модели == 'chkn_петухи':
      # !wget -nv --show-progress https://huggingface.co/fake4325634/chkn/resolve/main/chkn.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/chkn.ckpt
  elif выбор_модели == 'Hogwarts_Legacy':
      # !wget -nv --show-progress https://huggingface.co/Guizmus/Experiments/resolve/main/HogLegStyle-v2.4.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/HogLeg_Style.ckpt
  elif выбор_модели == 'Члены':
      # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/unctpns.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/uncut-penis.ckpt
  elif выбор_модели == 'Anonmix':
      # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/Anonmix.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/Anonmix.ckpt
  elif выбор_модели == 'Cyberpunk-Anime-Diffusion':
      # !wget -nv --show-progress https://huggingface.co/DGSpitzer/Cyberpunk-Anime-Diffusion/resolve/main/Cyberpunk-Anime-Diffusion.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/Cyberpunk-Anime-Diffusion.ckpt
  elif выбор_модели == 'OpenJourney':
      # !wget -nv --show-progress https://huggingface.co/openjourney/openjourney/resolve/main/mdjrny-v4.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/OpenJourney.ckpt
  elif выбор_модели == 'Antlers_mix':
      # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/antlers_mix.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/antlers_mix.ckpt
  elif выбор_модели == 'HassanBlend':
      # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/HassanBlend_1.4-pruned.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/HassanBlend_1.4-pruned.ckpt
      # !wget -nv --show-progress https://huggingface.co/hassanblend/hassanblend1.4/resolve/main/HassanBlend1.4.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/HassanBlend1.4.ckpt
      # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/HassansBlend_1.2.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/HassansBlend_1.2.ckpt
  elif выбор_модели == '80s_Anime':
      # !wget -nv --show-progress https://huggingface.co/tashachan28/ranma_diffusion/resolve/main/80s_anime_test_5_anythingmodel.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/80s_Anime.ckpt
  elif выбор_модели == 'Freckle_mix':
      # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/freckle_mix.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/freckle_mix.ckpt
  elif выбор_модели == 'Ложкин':
      # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/lozhkin.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/lozhkin.ckpt
  elif выбор_модели == 'AnythingGape':
      # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/AnythingGape.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/AnythingGape.ckpt
      # !sleep 2
      # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/AnythingGape.vae.pt -O /content/stable-diffusion-webui/models/Stable-diffusion/AnythingGape.vae.pt
  elif выбор_модели == 'FurSlut':
      # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/furslut.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/furslut.ckpt
  elif выбор_модели == 'monstermash4_anyv3':
      # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/monstermash4+anyv3.safetensors -O /content/stable-diffusion-webui/models/Stable-diffusion/monstermash4_anyv3.safetensors
  elif выбор_модели == 'monstermash6_anyv3':
      # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/monstermash6+anyv3.safetensors -O /content/stable-diffusion-webui/models/Stable-diffusion/monstermash6_anyv3.safetensors
  elif выбор_модели == 'Bstaber':
      # !wget -nv --show-progress https://huggingface.co/Pups/sd_mix/resolve/main/Bstaber.safetensors -O /content/stable-diffusion-webui/models/Stable-diffusion/Bstaber.safetensors
  elif выбор_модели == 'Analog_diffusion':
      # !wget -nv --show-progress https://huggingface.co/wavymulder/Analog-Diffusion/resolve/main/analog-diffusion-1.0.safetensors -O /content/stable-diffusion-webui/models/Stable-diffusion/analog-diffusion.safetensors
  elif выбор_модели == 'Protogen_X58_Rebuil':
      # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/Protogen_x5.8_Rebuilt_pruned.safetensors -O /content/stable-diffusion-webui/models/Stable-diffusion/Protogen_X58_Rebuil.safetensors
  elif выбор_модели == 'protogenV22Anime':
      # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/protogenV22Anime_22_fp16.safetensors -O /content/stable-diffusion-webui/models/Stable-diffusion/protogenV22Anime.safetensors
  elif выбор_модели == 'BloodNightOrangeMix':
      # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/BloodNightOrangeMix_fp16.safetensors -O /content/stable-diffusion-webui/models/Stable-diffusion/BloodNightOrangeMix.safetensors
  elif выбор_модели == 'ElyOrangeMix':
      # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/ElyOrangeMix_fp16.safetensors -O /content/stable-diffusion-webui/models/Stable-diffusion/ElyOrangeMix.safetensors
  elif выбор_модели == 'AbyssOrangeMix':
      # !wget -nv --show-progress https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/AbyssOrangeMix.safetensors -O /content/stable-diffusion-webui/models/Stable-diffusion/AbyssOrangeMix.safetensors
  elif выбор_модели == 'MMDv1_18':
      # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/MMDv1-18_fp16.safetensors -O /content/stable-diffusion-webui/models/Stable-diffusion/MMDv1_18.safetensors
  elif выбор_модели == 'HASDX':
      # !wget -nv --show-progress https://huggingface.co/utnah/safetensors/resolve/main/HASDX-ema-fp16.safetensors -O /content/stable-diffusion-webui/models/Stable-diffusion/HASDX.safetensors
  elif выбор_модели == 'dreamlikePhotoRealV2':
      # !wget -nv --show-progress https://huggingface.co/utnah/safetensors/resolve/main/dreamlikePhotoRealV2_dreamlikePhotoRealV2.safetensors -O /content/stable-diffusion-webui/models/Stable-diffusion/dreamlikePhotoRealV2.safetensors
  elif выбор_модели == 'elldrethSLucidMix_v10':
      # !wget -nv --show-progress https://huggingface.co/utnah/safetensors/resolve/main/elldrethSLucidMix_v10-ema-fp16.safetensors -O /content/stable-diffusion-webui/models/Stable-diffusion/elldrethSLucidMix_v10.safetensors
  elif выбор_модели == 'hAS3Dkx11_3Dkx11':
      # !wget -nv --show-progress https://huggingface.co/utnah/safetensors/resolve/main/hAS3Dkx11_3Dkx11.safetensors -O /content/stable-diffusion-webui/models/Stable-diffusion/hAS3Dkx11_3Dkx11.safetensors
  elif выбор_модели == 'protogenX3_4':
      # !wget -nv --show-progress https://huggingface.co/utnah/safetensors/resolve/main/protogenX3.4-fp16-ema.safetensors -O /content/stable-diffusion-webui/models/Stable-diffusion/protogenX3_4.safetensors
  elif выбор_модели == 'RealEldenApocalypse_AnalogSexKnoll_4CandyPureSimp_FEET':
      # !wget -nv --show-progress https://huggingface.co/utnah/safetensors/resolve/main/realEldenApocalypseA_realEldenApocalypseAsexKnoll4CandyPureSimpFeet-ema.fp16.safetensors -O /content/stable-diffusion-webui/models/Stable-diffusion/RealEldenApocalypse_AnalogSexKnoll_4CandyPureSimp_FEET.safetensors
  elif выбор_модели == 'своя прямая ссылка на модель':
      своя_ссылка = "https://твоя-ссылка.на/свою/модель.ckpt" #@param {type:"string"}
      # !wget --content-disposition {своя_ссылка} -P /content/stable-diffusion-webui/models/Stable-diffusion/

if not модели_только_с_гуглодиска:
  if подтянуть_модели_с_гулодиска:
    # !ln -s f"{папка_с_моделями_на_гуглодиске}/*" /content/stable-diffusion-webui/models/Stable-diffusion/

if clear_out:
  output.clear()
# !sleep 2
#@markdown - [Ячейка](#scrollTo=rcAPPhbyhx3t) для скачивания нескольких моделей (Перед запуском WebUI). 
#@markdown - Нужная модель доступна через торрент? [Ячейка](#scrollTo=CD4q5amW7Oib) для скачивания торрентов.
#@markdown - [Если пришлешь в тг-бот](https://t.me/colabSDbot) ссылку/торрент на очень нужную модель, ее можно будет добавить в меню выбора моделей.
#@markdown - Скаченные откуда-то модели, можешь удобно выгрузить на HuggingFace [в этой ячейке](#scrollTo=wsS_furff9uY), чтобы всегда иметь прямые ссылки на свои модели с максимальной скоростью загрузки.
#@markdown - Нашел модель, но она не в формате .ckpt, а в каких-то .bin-файлах? [В этой ячейке](#scrollTo=du5Xt_kv7Gd9) можешь сконвертировать diffusers-модели в нормальный формат и получить ckpt-файлик.
#@markdown - Другие модели можно найти [на этой странице](https://teletype.in/@stablediffusion/models_for_SD).

#@markdown <hr><font color='#38c013' size='2' face="Verdana"><b>Поставить дополнительные VAE?</b></font>
VAE = False #@param {type:"boolean"}
#@markdown <small>VAE - тонко настроенный вариационный автоэнкодер, немного улучшает качество генерации, по дефолту идет при установке стандартной SD модели, но может быть полезен для других моделей на ее основе, например, сделанных через Dreambooth (а это большинство самопальных моделек, которые не создавались через нативное обучение).<br><font color='#0aa93f'><b>Обрати внимание, что в данном случае VAE автоматически не подхватятся при запуске, нужную VAE требуется активировать на вкладке настроек WebUI, в разделе Стабильная Диффузия (средняя колонка, ближе к концу)</font></b></small><hr>

#@markdown <b>Установить расширение для генерации нескольких персонажей?</b>
генерация_нескольких_персонажей = False #@param {type:"boolean"}
#@markdown Это расширение (пока тествое) позволяет сгенерировать разноплановое сложное изображение. Пишется промпт для фона/окружение, и промпты для различных персонажей. Нейросеть генерит все по отдельности и опираясь на карту глубины собирает все в единую композицию. Посмотреть как это работает можно <a href='https://github.com/Extraltodeus/multi-subject-render#a-few-more-examples'>тут</a>.

#@markdown <b>Установить гиперсети?</b>
гиперсети = False #@param {type:"boolean"}
#@markdown <font color='red'>Внимание: гиперсети не работают с установленным Xformers!</font> Будет установлен небольшой пак гиперсетей, для экспериментов, и чтобы понять как они работают, прежде чем создавать свои. Данные гиперсети можно использовать, например, с анимечными и фуррийными моделями, чтобы получить различные результаты.<details><summary>список гиперсетей из пака</summary><img src='https://files.catbox.moe/fq5y8h.png' width='640px'/></details><details><summary>что это такое?</summary>Гиперсеть - дополнительный слой визуализации после основной модели. Гиперсеть обучает модель не новым изображениям, а перестраивает вектора, так чтобы определенные токены ассоциировались с каким-то новым понятием. Например нейросеть не знает что такое <i>пролапс</i> - гиперсеть укажет что это "<i>красная глянцевая прямая кишка из анального сфинктера, плотная, набухшая, что-то среднее между красной колбасой и бутоном розы</i>". При условии что модель нейросети хорошо знает все эти понятия по отдельности - гиперсеть может сопоставить их с новым термином - <i>пролапс</i>, который можно будет использовать в промпте. Более подробно можешь <a href='https://bennycheung.github.io/stable-diffusion-training-for-embeddings#:~:text=Hypernetwork,-Hypernetwork%3A%20An%20additional'>почитать в статье</a>.</details>

#@markdown <b>Установить дополнительные модели ESRGAN?</b>
модели_ESRGAN = False #@param {type:"boolean"}
#@markdown Будет установлен огромнейший пак из 110 моделей Real-ESRGAN. Тебе это совершенно не нужно для генерации и апскейла сгенерированных картинок! Для этого нужные модели скачиваются по дефолту. <details><summary>а нaxyя?</summary>А данная опция нужна только для апскейла/исправления плохих, шакальных картинок из интернета, в основном фотографий очень низкого качества. Все это это может быть полезно для подготовки обучающего датасета, когда есть много нужных картинок, но они не лучшего качества, очень старые и т.п. Например, хочется обучить нейросетку чему-то из 90-х прошлого века или нулевых, но все фотки того времени в интернете зашакалены, или вообще от них остались одни превьюшки на сайтах-галереях. Этот пак именно для этого и больше ни для чего. Предполагается тщательный ручной подбор конкретной модели под определенную картинку, потом доводка результатов в фотошопе, посредством сложения наиболее удачных частей картинки от разных моделей (например кожу лучше восстановила одна модель, волосы - другая, текстуру одежды - третья, природу на заднем плане - четвертая, кота сидящего рядом - стодесятая модель, а небо - восьмидесятая).</details>

#@markdown <hr> <font color='#38c013' size='2' face="Verdana"><b>Запустить WebUI сразу после установки?</b> </font><br>
запустить_сразу = True #@param {type:"boolean"}
ngrok_token = "\u0432\u0441\u0442\u0430\u0432\u044C \u0441\u044E\u0434\u0430 \u0441\u0432\u043E\u0439 \u0442\u043E\u043A\u0435\u043D ngrok" #@param {type:"string"}
#@markdown Получить <b>свой</b> токен для ngrok можешь [тут](https://dashboard.ngrok.com/get-started/your-authtoken) |  Если токен ngrok не будет указан в поле выше, ngrok в 99% все равно запустится - будет использован ч҉у҉ж҉о҉й токен
no_half_vae = False #@param {type:"boolean"}
#@markdown `--no-half-vae` это дополнительный аргумент запуска, позволяющий избежать черных квадратов при генерации (запрещает перевод vae в режим 16-bit floats) <hr width=50%>
#@markdown ⚠️ <font color='#32CD32'>После того как **все прогрузится**, ищи сылки типа</font>: <br> `cool-brooms-admire-23-251-149-142.loca.lt` или `0bf89138a7c4877f.gradio.app` или `e402-34-126-159-209.ngrok.io`<br>И переходи по ссылкам. Gradio - дефольный, но бывает зависает. Пробуй Ngrok или LokalIt
#@markdown <br><details><summary><font color='gold'>где искать и какие ссылки? </font></summary><img src="https://files.catbox.moe/c57s73.gif" width='1000px'/></details>
#@markdown <b><font color='#32CD32'>Рекомендую использовать ngrok.</font></b> Работа через gradio сопряжена с частыми зависаниями и потерей коннекта при пакетной генерации. loca.lt - иногда чуточку лучше. Ngrok тоже не идеален, но он более стабилен.

#@markdown Если возникают проблемы с подгрузкой жирных моделей (ema-full, non-pruned, которые под 7 гигов) - это из-за нехватки памяти на бесплатном тарифе колаба. [Воспользуйся прунингом](#scrollTo=otsDSY8bCdVN), чтобы уменьшить размер. Прунинг никак не сказывается на качестве генерации, картинки будут идентичные 100% (проверенно Аноном).

#@markdown 👉 [как составить промпт и список художников](https://teletype.in/@stablediffusion/artists_for_prompts) | [о настройках генерации](https://teletype.in/@stablediffusion/samplers_steps) 👈

#фиксы
if xformers:
  # !wget -q https://is.gd/fix_webui -O /content/.config/fix_webui.ipynb
  # %run /content/.config/fix_webui.ipynb
if not xformers:
  # !wget -q https://is.gd/russian_only -O /content/.config/localisation.ipynb
  # %run /content/.config/localisation.ipynb
# %cd /content
#принудительно выбор версии pytorch для совместимости (Автоматик уже сам пофиксил)
#!pip install pytorch-lightning==1.7.7

#Установка ngrok в качестве более стабильной альтернативы gradio
# !pip install pyngrok
#Настройка pyngrok на наш порт
# %cd /content/stable-diffusion-webui
# !npm install -g localtunnel
# !nohup lt -p 7860 > lt.log 2>&1 &

# настройка вебуи
#if xformers:
    #!COMMANDLINE_ARGS="--exit" REQS_FILE="requirements.txt" python launch.py --disable-safe-unpickle --exit
    #!wget -q https://github.com/DagnyT/hardnet/raw/master/pretrained/train_liberty_with_aug/checkpoint_liberty_with_aug.pth -O /root/.cache/torch/hub/checkpoints/checkpoint_liberty_with_aug.pth


if deepdanbooru:
  # !pip install git+https://github.com/KichangKim/DeepDanbooru.git@edf73df4cdaeea2cf00e9ac08bd8a9026b7a7b26
  # !git clone "https://github.com/DominikDoom/a1111-sd-webui-tagcomplete.git" /content/stable-diffusion-webui/extensions/tag-autocomplete

# проверка и установка обновленных зависимостей (на всякий случай, для изменившихся модулей/расширений)
#!pip install -r /content/stable-diffusion-webui/requirements.txt
if clear_out:
  output.clear()

#if выбор_модели == 'SD v2.0':
#  VAE = True
if VAE:
  # !curl -L --create-dirs https://huggingface.co/utnah/ckpt/resolve/main/vae-ft-mse-840000-ema-pruned.ckpt -o /content/stable-diffusion-webui/models/VAE/vae-ft-mse-ema-pruned.ckpt
  # !curl -L --create-dirs https://huggingface.co/stabilityai/sd-vae-ft-ema-original/resolve/main/vae-ft-ema-560000-ema-pruned.ckpt -o /content/stable-diffusion-webui/models/VAE/vae-ft-ema-ema-pruned.ckpt

if гиперсети:
  print('скачивание гиперсетей... около 2гб')
  # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/hyper.zip
  print('распаковка гиперсетей... это займет примерно 20 секунд ')
  # !unzip -q -o hyper.zip -d /content/stable-diffusion-webui/models/hypernetworks
  # !rm hyper.zip

# генерация нескольких персонажей
if xformers:
  генерация_нескольких_персонажей = True

if генерация_нескольких_персонажей:
  # !git clone https://github.com/Extraltodeus/multi-subject-render /content/stable-diffusion-webui/extensions/multi-subject-render
  # !git clone https://github.com/isl-org/MiDaS.git /content/stable-diffusion-webui/repositories/midas
  # %cd /content/stable-diffusion-webui/repositories/midas
  # !git checkout -f b845b78
  # %cd /content/stable-diffusion-webui

# скачивание моделей апскейла ESRGAN
print('скачивание моделей апскейла ESRGAN')
# !wget -nv --show-progress -P /content/stable-diffusion-webui/models/ESRGAN https://huggingface.co/utnah/LDSR/resolve/main/1x_artifacts_jpg_20_40_alsa.pth
# !wget -nv --show-progress -P /content/stable-diffusion-webui/models/ESRGAN https://huggingface.co/utnah/LDSR/resolve/main/4xESRGAN.pth
# !wget -nv --show-progress -P /content/stable-diffusion-webui/models/ESRGAN https://huggingface.co/utnah/LDSR/resolve/main/4x_Nickelback_70000G.pth
# !wget -nv --show-progress -P /content/stable-diffusion-webui/models/ESRGAN https://huggingface.co/utnah/LDSR/resolve/main/4x_foolhardy_Remacri.pth
# !wget -nv --show-progress -P /content/stable-diffusion-webui/models/ESRGAN https://huggingface.co/utnah/LDSR/resolve/main/lollypop.pth


if модели_ESRGAN:
  # !git lfs install
  # !git clone https://huggingface.co/utnah/esrgan /content/pth
  # !mv -f -n /content/pth/*.pth /content/stable-diffusion-webui/models/ESRGAN
  # !rm -rf /content/pth

# !pip install -q gradio==3.9
#!pip install gradio==3.13.0
#!pip install gradio==3.15.0
# !rm /content/stable-diffusion-webui/modules/ui_tempdir.py
# !wget -O /content/stable-diffusion-webui/modules/ui_tempdir.py https://github.com/PR0LAPSE/StableDiffusionWebUIColab/raw/main/src/ui-tempdir.py
# !pip install -q open_clip_torch
# !pip install -q torchsde
# !pip install -q scikit-image --upgrade
# !pip install -q tensorflow tensorflow-io
# !pip install -q inflection

if xformers:
  # %cd /content/stable-diffusion-webui/
  # !COMMANDLINE_ARGS="--exit" REQS_FILE="requirements.txt" python launch.py
  output.clear()
  # !rm /content/stable-diffusion-webui/modules/ui_tempdir.py
  # !wget -O /content/stable-diffusion-webui/modules/ui_tempdir.py https://github.com/PR0LAPSE/StableDiffusionWebUIColab/raw/main/src/ui-tempdir.py
  # !pip install -q gradio==3.9
  # !rm -rf /content/stablediffusion/.git
  # !rm -rf /content/stablediffusion/.gitignore
  # !rm -rf /content/stablediffusion/LICENSE
  # !rm -rf /content/stablediffusion/LICENSE-MODEL
  # !rm -rf /content/stablediffusion/README.md
  # !rm -rf /content/stablediffusion/modelcard.md
  # !rm -rf /content/stablediffusion/setup.py
  # !rm -rf /content/sample_data
  # !mv /content/stablediffusion/requirements.txt /content/stablediffusion/requirements-sd.txt
  import distutils.dir_util
  distutils.dir_util.copy_tree('/content/stablediffusion', '/content/stable-diffusion-webui')
  # !rm -rf /content/stablediffusion
  # !sed -i 's@ui.create_ui().*@ui.create_ui();shared.demo.queue(concurrency_count=999999,status_update_rate=0.1)@' /content/stable-diffusion-webui/webui.py
  # !sed -i 's@"multiple_tqdm": true,@\"multiple_tqdm": false,@' /content/stable-diffusion-webui/config.json
  # !sed -i '902s@.*@        self.logvar = self.logvar.to(self.device)@' /content/stable-diffusion-webui/ldm/models/diffusion/ddpm.py
  # !sed -i 's@cmd_opts.lowram else \"cuda\"@cmd_opts.lowram else \"cpu\"@' /content/stable-diffusion-webui/modules/shared.py

# далее костыль просто для того чтобы все окончательно скачалось сейчас, а не при первом запуске webui
# и при запуске в #3 ячейке уже ничего не скачивалось,
# а только запускалось и был красивый вывод в консольку (да, это только для красоты)
import multiprocessing
import time
# prerun - предварительный, фейковый запуск webui
def prerun():
  # %cd /content/stable-diffusion-webui
  print("доустановка... это займет около 1 минуты")
  # !python /content/stable-diffusion-webui/webui.py --disable-safe-unpickle --enable-insecure-extension-access --ui-debug-mode    

if __name__ == '__main__':
  p = multiprocessing.Process(target=prerun)
  p.start()
  p.join(70)

  if p.is_alive():
    print("\n завершение...")
    p.kill()
    # p.terminate()
    p.join()


if гуглодиск:
  # применение настроек для работы на гуглодиске
  # %cd /content/stable-diffusion-webui
  # !rm ui-config.json
  # !wget -q https://is.gd/ui_config -O ui-config.json
  # !rm config.json
  # !wget -q https://is.gd/config_wGD -O config.json

  #стили c гуглодиска (если несколько аккаунтов, придется расшарить один стиль с правами записи на все свои фейки).
  if os.path.exists("/content/gdrive/MyDrive/SD/styles.csv"):
    # !rm /content/stable-diffusion-webui/styles.csv
    # !rm /content/stable-diffusion-webui/styles.csv.bak
    # !ln -s /content/gdrive/MyDrive/SD/styles.csv /content/stable-diffusion-webui/styles.csv
    # !ln -s /content/gdrive/MyDrive/SD/styles.csv /content/stable-diffusion-webui/styles.csv.bak
    # !chmod -c 777 /content/stable-diffusion-webui/styles.csv
    # !chmod -c 777 /content/stable-diffusion-webui/styles.csv.bak
  else:
    # !rm /content/stable-diffusion-webui/styles.csv
    # !rm /content/stable-diffusion-webui/styles.bak
    # !wget -q https://pst.klgrth.io/paste/7k85j/download -O /content/gdrive/MyDrive/SD/styles.csv 
    # !ln -s /content/gdrive/MyDrive/SD/styles.csv /content/stable-diffusion-webui/styles.csv
    # !ln -s /content/gdrive/MyDrive/SD/styles.csv /content/stable-diffusion-webui/styles.csv.bak
    # !chmod -c 777 /content/stable-diffusion-webui/styles.csv
    # !chmod -c 777 /content/stable-diffusion-webui/styles.csv.bak

  output.clear()

# капельку руссификации 🇷🇺
# !grep 'your url is' -P -R -I -l  /content/stable-diffusion-webui/lt.log | xargs sed -i 's/your url is/когда модель загрузится, переходи по этой ссылке/g'
# !grep 'Invalid ngrok authtoken, ngrok connection aborted.' -P -R -I -l  /content/stable-diffusion-webui/modules/ngrok.py | xargs sed -i 's/Invalid ngrok authtoken, ngrok connection aborted./Некорректный токен Ngrok! Соединение отменяется.../g'
# !grep 'Your token' -P -R -I -l  /content/stable-diffusion-webui/modules/ngrok.py | xargs sed -i 's/Your token/Ты указал токен/g'
# !grep 'get the right one on' -P -R -I -l  /content/stable-diffusion-webui/modules/ngrok.py | xargs sed -i 's/get the right one on/ он не верный, получи нормальный тут:/g'
# !grep 'URL:' -P -R -I -l  /content/stable-diffusion-webui/modules/ngrok.py | xargs sed -i 's/URL:/Твоя ссылка:/g'
# !grep 'You can use this link after the launch is complete' -P -R -I -l  /content/stable-diffusion-webui/modules/ngrok.py | xargs sed -i 's/You can use this link after the launch is complete/Ты можешь перейти по ссылке, только когда подгрузятся модели. Увидишь это когда появится третья ссылка на gradio/g'
# !grep 'ngrok connected to localhost:{port}!' -P -R -I -l  /content/stable-diffusion-webui/modules/ngrok.py | xargs sed -i 's/ngrok connected to localhost:{port}!/Соединение с Ngrok установленно!/g'

# настройка для v2
if выбор_модели == 'SD v2.1 768px' or выбор_модели == 'SD v2.1 512px':
  # !sed -i 's@def load_state_dict(checkpoint_path: str, map_location.*@def load_state_dict(checkpoint_path: str, map_location="cuda"):@' /usr/local/lib/python3.8/dist-packages/open_clip/factory.py
  sdinference = "--config /content/stable-diffusion-webui/v2-inference-v.yaml"
else:
  # !sed -i 's@def load_state_dict(checkpoint_path: str, map_location.*@def load_state_dict(checkpoint_path: str, map_location="cpu"):@' /usr/local/lib/python3.8/dist-packages/open_clip/factory.py
  sdinference = ""

if clear_out:
  output.clear()

print('\033[01;38;05;46mУстановка завершена')
print('\033[01;38;05;33mВыбранная модель загружена')
print("\033[0m----------------------------------------------------------")
# !free -g | grep Mem | awk '{print "Всего ОЗУ: " $2 " Гб | " "Доступно ОЗУ: " $7 " Гб"}'
import os
from subprocess import getoutput
nsmi = getoutput('nvidia-smi')
if "NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running." in nsmi:
    print('\033[01;38;05;242mColab запущен без видеоускорителя \033[0m')
else:
  card = !nvidia-smi --query-gpu=gpu_name --format=csv
  vram = !nvidia-smi --query-gpu=memory.total --format=csv
  print("Видеокарта: \033[01;38;05;46mNvidia " + (card[1]) + "\033[0m |" + "\033[01;38;05;188m Объём видеопамяти: \033[01;38;05;46m" + (vram[1]) + "\033[0m ")

from google.colab import output
output.eval_js('new Audio("https://github.com/PR0LAPSE/StableDiffusionWebUIColab/raw/main/src/finish.mp3").play()')

if запустить_сразу:
  # !sleep 2
  from google.colab import output
  output.eval_js('new Audio("https://github.com/PR0LAPSE/StableDiffusionWebUIColab/raw/main/src/start.mp3").play()')
  
  #ссылка на LocalTunel (loca.lt)
  with open('/content/stable-diffusion-webui/lt.log', 'r') as testwritefile:
      print(testwritefile.read())

  # !sleep 2

  #Установка токена ngrok
  ngrok_share = '/content/.config/cfg'
  freetoken = open(ngrok_share).read().split('\n')
  import random
  sharetoken = random.choice(list(freetoken))
  token = ngrok_token
  if not ngrok_token or len(ngrok_token) < 48 or len(ngrok_token) > 51:
    ngrok = '--ngrok ' + sharetoken
  else:
    ngrok = '--ngrok ' + token

  if os.path.exists('/usr/local/lib/python3.8/dist-packages/xformers'):
    xformers = '--xformers'
  else:
    xformers = '--opt-split-attention'

if no_half_vae:
  nhv = '--no-half-vae'
if not no_half_vae:
  nhv = ''

  #Собственно запуск
  if not модели_только_с_гуглодиска:
    if not deepdanbooru:
      # !python /content/stable-diffusion-webui/webui.py --disable-safe-unpickle {nhv} --enable-insecure-extension-access --share --gradio-debug {xformers} --ckpt-dir /content/stable-diffusion-webui/models/Stable-diffusion {ngrok} --ngrok-region eu --gradio-img2img-tool editor {sdinference}
    if deepdanbooru:
      # !python /content/stable-diffusion-webui/webui.py --deepdanbooru --disable-safe-unpickle {nhv} --enable-insecure-extension-access --share --gradio-debug {xformers} --ckpt-dir /content/stable-diffusion-webui/models/Stable-diffusion {ngrok} --ngrok-region eu --gradio-img2img-tool editor {sdinference}
  if модели_только_с_гуглодиска:
    if not deepdanbooru:
      # !python /content/stable-diffusion-webui/webui.py --disable-safe-unpickle {nhv} --enable-insecure-extension-access --share --gradio-debug {xformers} --ckpt-dir {папка_с_моделями_на_гуглодиске} {ngrok} --ngrok-region eu --gradio-img2img-tool editor {sdinference}
    if deepdanbooru:
      # !python /content/stable-diffusion-webui/webui.py --deepdanbooru --disable-safe-unpickle {nhv} --enable-insecure-extension-access --share --gradio-debug {xformers} --ckpt-dir {папка_с_моделями_на_гуглодиске} {ngrok} --ngrok-region eu --gradio-img2img-tool editor {sdinference}
  #конец

  if os.path.exists("/content/gdrive/MyDrive/SD/styles.csv"):
    # !cp -f /content/stable-diffusion-webui/styles.csv /content/gdrive/MyDrive/SD/styles.csv
  from IPython.display import HTML
  end = '/content/.config/end'
  HTML(end)

# %% [markdown]
# ---

# %%
#@title # Запуск/перезапуск WebUI { display-mode: "form" }
import os

ngrok_token = "\u0432\u0441\u0442\u0430\u0432\u044C \u0441\u044E\u0434\u0430 \u0441\u0432\u043E\u0439 \u0442\u043E\u043A\u0435\u043D ngrok" #@param {type:"string"}

#@markdown Получить <b>свой</b> токен для ngrok можешь [тут](https://dashboard.ngrok.com/get-started/your-authtoken) |  Если токен ngrok не будет указан в поле выше, ngrok в 99% все равно запустится - будет использован ч҉у҉ж҉о҉й токен
no_half_vae = True #@param {type:"boolean"}
#@markdown ⚠️ <font color='#32CD32'>После того как **все прогрузится**, ищи сылки типа</font>: <br> `cool-brooms-admire-23-251-149-142.loca.lt` или `0bf89138a7c4877f.gradio.app` или `e402-34-126-159-209.ngrok.io`<br>И переходи по ссылкам. Gradio - дефольный, но бывает зависает. Пробуй Ngrok или LokalIt
#@markdown <br><details><summary><font color='gold'>где искать и какие ссылки? </font></summary><img src="https://files.catbox.moe/c57s73.gif" width='1000px'/></details>

#ссылка на LocalTunel (loca.lt)
with open('/content/stable-diffusion-webui/lt.log', 'r') as testwritefile:
    print(testwritefile.read())

# !sleep 2

#Установка токена ngrok
ngrok_share = '/content/.config/cfg'
freetoken = open(ngrok_share).read().split('\n')
import random
sharetoken = random.choice(list(freetoken))
token = ngrok_token
if not ngrok_token or len(ngrok_token) < 48 or len(ngrok_token) > 51:
  ngrok = '--ngrok ' + sharetoken
else:
  ngrok = '--ngrok ' + token

if os.path.exists('/usr/local/lib/python3.8/dist-packages/xformers'):
  xformers = '--xformers'
else:
  xformers = '--opt-split-attention'

if no_half_vae:
  nhv = '--no-half-vae'
if not no_half_vae:
  nhv = ''

#Собственно запуск
if not модели_только_с_гуглодиска:
  if not deepdanbooru:
    # !python /content/stable-diffusion-webui/webui.py --disable-safe-unpickle {nhv} --enable-insecure-extension-access --share --gradio-debug {xformers} --ckpt-dir /content/stable-diffusion-webui/models/Stable-diffusion {ngrok} --ngrok-region eu --gradio-img2img-tool editor {sdinference}
  if deepdanbooru:
    # !python /content/stable-diffusion-webui/webui.py --deepdanbooru --disable-safe-unpickle {nhv} --enable-insecure-extension-access --share --gradio-debug {xformers} --ckpt-dir /content/stable-diffusion-webui/models/Stable-diffusion {ngrok} --ngrok-region eu --gradio-img2img-tool editor {sdinference}
if модели_только_с_гуглодиска:
  if not deepdanbooru:
      # !python /content/stable-diffusion-webui/webui.py --disable-safe-unpickle {nhv} --enable-insecure-extension-access --share --gradio-debug {xformers} --ckpt-dir {папка_с_моделями_на_гуглодиске} {ngrok} --ngrok-region eu --gradio-img2img-tool editor {sdinference}
  if deepdanbooru:
      # !python /content/stable-diffusion-webui/webui.py --deepdanbooru --disable-safe-unpickle {nhv} --enable-insecure-extension-access --share --gradio-debug {xformers} --ckpt-dir {папка_с_моделями_на_гуглодиске} {ngrok} --ngrok-region eu --gradio-img2img-tool editor {sdinference}
  
#конец

if os.path.exists("/content/gdrive/MyDrive/SD/styles.csv"):
  # !cp -f /content/stable-diffusion-webui/styles.csv /content/gdrive/MyDrive/SD/styles.csv
from IPython.display import HTML
end = '/content/.config/end'
HTML(end)

# %% [markdown]
# ---

# %%
#@title 💩 Перезапуск среды выполнения (если что-то пошло не так) { display-mode: "form" }
#@markdown от этого Колаб крашнется, это так и должно быть, файлы/данные не пропадут, однако **переменные сбросятся**!
print('\033[31m Среда выполнения сброшена!')
print('\033[32m Можно перезапустить WebUI ячейке #3...')
from google.colab import output
output.eval_js('new Audio("https://github.com/PR0LAPSE/StableDiffusionWebUIColab/raw/main/src/reset.mp3").play()')
# !sleep 1
import os
os.kill(os.getpid(), 9)

# %%
#@title 💾 Создание и скачивание архива со всеми картинками { display-mode: "form" }
#@markdown **Cкачивание напрямую на ПК, минуя гуглодиск**: это нужно, если ты не захотел сразу работать на гуглодиске, после архивации - скачивание запустится автоматически.<br>

#@markdown **Прежде чем запустить скачивание архива в этой ячейке, предыдущая ячейка должна быть остановлена!** (потом можно будет ее запустить снова, если требуется)
# %cd /content/
# !zip -r /content/SD_Colab.zip /content/output
output.clear()
print('\033[35m скачивание архива начнется автоматически...')
from google.colab import files
files.download('/content/SD_Colab.zip')

# %% [markdown]
# ---

# %%
#@title Скачать несколько моделей { display-mode: "form" }
#@markdown <details><summary><big><big><big>👈Описание моделей, ключи для их вызова</big></big></big> (разверни спойлер, чтобы прочитать)</summary><p><b>SD v2.0</b> — это обновленная, некстген модель, полностью заново обученная, вторая версия. При выборе опции будет установлена полная sd-v2-0-768, модель sd-v2-0-inpainting, базовая v2-512(с отфильтрованным порно-контентом), модель апскейлинга через изо-в-изо sd-v2-0_4x-upscaler и модель глубины sd-v2-0-depth. Нововведений довольно много, <a href='https://stability.ai/blog/stable-diffusion-v2-release'>можно почитать в офф. блоге.</a> Для стандартной модели <b>минимальное разрешение 768x768</b>! Учитывай это! Ставить одну из сторон меньше 768 не рекомендуется. Поскольку токинайзер новый, то старые промпты с 1.5 уже не будут работать как раньше. И самое важное и печальное: из датасета модели было удалено все что связанно с NSFW, так что никаких какашек с дедами, никаких сисек и писек, да и вообще анатомии обнаженного тела - пизда... Но для хуежеств она стала получше (правда некоторые художники/стили были удалены). Ждем кастомных моделей на ее основе.</p><p><b>SD v1.5 и SD v1.4</b> — это стандартные модели, обе дообучались на SD v1.2, специфических токенов нет, идеальны для общих нужд. Эта модель является базой, на которой строятся все остальные узкоспецифические модели. Моделька 1.5 идет в комплекте с VAE(тонко настроенный вариационный автоэнкодер, немного улучшает качество генерации) и моделью для Inpaiting(она тоже с VAE), которую надо выбрать перед работой в img2img inpaint. Особого смысла в 1.4 уже нет, она добавлена для совместимости со старыми сидами/промптами.</p><p><b>SD v1.5 full для обучения</b> — это стандартная модель, из которой не были удалены данные для обучения, потому она весит в два раза больше. Особого смысла генерить на ней нет, но для тренировки внедрений, гиперсети и т.д. - она годится (возможно) лучше. Требует очень много памяти, так что следи за настройками обучения, чтобы уместиться в 15гб VRAM. Если честно, то такие модели создаются только для нативного обучения, а не для Dreambooth, внедрений, гиперсети. А нативным обучением в колабе, да и на рядовом ПК при всем желании заняться не получится. По большому счету - эта модель просто <i>что бы было</i>.</p><p><b>Члены</b> — модель умеет рисовать только хуи, обычные русские необрезанные члены. В промпт нужно писать токен <code>uncut-penis</code> и <code>uncutpenis</code> и <code>uncut penis</code>. Модель тестовая и предназначена для ценителей эстетики членов. Можно попытаться мержить с другими моделями. А лучше нагенерить пачку хуёв для вайпа, например. Если честно - это модель появилась просто во время теста работы Dreambooth в колабе и скрипта конвертации моделей, обучалась модель на 50 фотках. Тебя разве не огрчает низкое качество членов в стандартной модели?</p><p><b>Beksinski</b> — стиль загадочного и потрясающего художника Здислава Бексинского, в промпт добавлять <code>beksinski style</code></p><p><b>Van_Gogh</b> — модель натренирована на кадрах из фильма «Ван Гог. С любовью, Винсент» — который выполнен в стилистике рисовки Ван Гога, это первый в мире анимационный полнометражный фильм, полностью нарисованный масляными красками на досках! В промпт важно добавить в самое начало <code>lvngvncnt</code>, например: <code>lvngvncnt, handsome attractive shirtless younker, highly detailed</code> Если не нравится слишком синюшная гамма и желтые рожи — в негативный промпт надо написать что-то вроде <code>yellow face, blue</code> Моделька ахуенная, рисует и людей и природу и здания — очень хорошо. Поскольку моделька высокохудожественная, то не поднимайте высоко CFG Scale, чтобы нейросеть могла больше «фантазировать», 4-7 — будет норм.</p><p><b>DBWayneBarlowe_JM</b> — демоническая, оккультная, религиозная и сатанинская темататика, в промпт писать все что с этим связанно, основана на работах художника Уэйна Барлоу, сначала рекомендую ознакомится c ним, чтобы понять что к чему.</p><p><b>Cats_Tabaxi</b> — рисует антропофорфных котиков и прочих каджитов. Основной ключ <code>tabaxi person</code>, и далее - все что связанно с котаи - львы, тигры, рыси, и прочие котики. В негативный промпт нужно написать типа: <code>mutation, human hands, big head</code>. Примеры промптов: <code>portrait of a male white cat tabaxi person, rpg illustration by alex horley and dan mumford</code> | <code>portrait of a lion tabaxi person, in aplate armor, realisic render, octane render, zbrush, still from a movie, alexa, cooke 55mm, award winning photgraphy</code> | <code>portrait of a tiger boy tabaxi person, in a thief dark leather armor, black hood on her head, realisic render, octane render, zbrush, still from a movie, alexa, cooke 55mm</code></p><p><b>Cthulhu_illithid</b> — на самом деле модель у автора называется просто illithid, но чтобы было понятно - я добавил про Ктулху, потому что модель натренированна на молюско-подобной рассе, вдохновленной рисунками по мотивам произведений Лавкрафта и его Древними. В промпт нужно писать <code>illithid Person</code> или <code>illithid_Person</code>.</p><p><b>BubblyDubbly</b> — рисованные портреты в стиле BubblyDubbly, что это такое: https://imgur.com/a/yEchVjv . Ключ <code>art by bubblydubbly</code>, в негативный промпт можно добавить: <code>heavy contrast, red eyes, blue hair</code>, простой пример: <code>attractive boy, soft colors, art by bubblydubbly</code></p><p><b>pachu artwork style</b> — модель обучена на рисунках иллюстратора Плейбоя — Пачу Торреса, после подгрузки модели, в промпт добавить pachu <code>artwork style</code></p><p><b>Redshift</b> — модель обученная на 3Д рендерах высокого разрешения через Redshift, в начало промпта нужно добавлять <code>redshift style</code></p><p><b>modern disney style</b> — совремеменный пластмассовый диснеевский стиль, в промпт добавить <code>modern disney style</code></p><p><b>classic disney style</b> — стиль Диснея прошлого века с качественной мультяшной рисовкой, в промпт добавить <code>classic disney style</code></p><p><b>tron legacy style</b> — стилистика из фильма «Трон: Наследие», в промпт нужно добавлять <code>trnlgcy</code></p><p><b>elden ring style</b> — моделька на основе игровых артов из Elden Ring, в пропмт нужно писать <code>elden ring style</code></p><p><b>spiderverse style</b> — стиль мультика «Человек-паук: Через вселенные», в пропте надо писать <code>spiderverse style</code></p><p><b>discoelysium style</b> — стиль персонажей из игры Disco Elysium, в промпт надо добавлять токен <code>discoelysium style</code></p><p><b>arcane style</b> — стилистика фентезийного мультсериала «Аркейн», в промпт нужно воткнуть токен <code>arcane style</code></p><p><b>archer style</b> — стиль шпионского мальтсериала «Арчер», в пропмпте нужно указать <code>archer style</code></p><p><b>Bloodborne</b> — модель обученная стилю из игры Bloodborne, в промпт надо добавлять <code>Bloodborne Style</code></p><p><b>DarkSouls</b> — модель обученная стилю серии DarkSouls, в промпт добавлять <code>DarkSouls Style</code>, автор рекомендует рендер на Euler_a 20 шагов или DPM++ 2M Karras.</p><p><b>Borderlands</b> — модель для создания изображений в стиле Borderlands, соответсвтенно в промпт надо писать токен <code>borderlands</code></p><p><b>Starsector_Portrait</b> — модель обученная на скринах из видеоигры Starsector, лучще всего заточена под портреты, в промпт нужно добавить <code>starsectorportrait</code>, например <code>a starsectorportrait of a man wearing a green balaclava and armored spacesuit</code> сочетается с добавочными токенами <code>sabattier effect</code> — для эффекта освещения, <code>brush strokes</code> — для большей художественности портретов, <code>conte</code> — более аккуратные мазки. Модель <u>будет установлена с гиперсетью</u>, которую нужно будет подключить/отключить в настройках</p><p><b>EpicSpaceMachine</b> — футристичные космические корабли, станции и т. п., в промт добавлять <code>EpicSpaceMachine</code>, к примеру: <code>Photo of a futuristic space liner, 4K, award winning in EpicSpaceMachine style</code></p><p><b>reasonableDrink</b> — модель для фентезийных и фантастических артов, в промпт добавить <code>reasonableDrink</code></p><p><b>CALARTS</b> — рисунки персонажей в CalArts-стиле, в промпт добавить <code>CALARTS</code></p><p><b>beeple</b> — модель натренирована на работах этого художника-фотошопера: <a href="https://twitter.com/beeple">@beeple</a> в промпт нужно добавлять <code>beeple</code></p><p><b>megaPals</b> — стиль мультиков про супергероев из 70-х годов прошлого века, в промпт добавить <code>in megaPals style</code> или <code>a cartoon of  <em>КТО-ТО</em>, in megaPals style</code></p><p><b>Hogwarts_Legacy</b> — стиль из игры Хогрвардс: Наследие, в промпт писать: <code>HogLeg Style</code></p><p><b>Midjourney</b> — имитация стиля другой нейросетки, лол. Всем она известна, если нет - погугли картинки. В промпт нужно писать этот ключ: <code>mdjrny-v4 style</code>. Подробнее о промптинге <a href="https://prompthero.com/midjourney-prompts?version=4">написано тут</a>.</p><p><b>OpenJourney</b> — это форк предыдущей модели, и как утверждают разработчики, эта модель значительно допилена и годится в качестве замены проприетарной Midjourney! Стиль действительно хорошо получается, а токен для промпта тот же: <code>mdjrny-v4 style</code>. Подробнее о промптинге <a href="https://prompthero.com/midjourney-prompts?version=4">написано тут</a>.</p><p><b>WiKiArt</b> — чисто художественная модель, обученная по огромной базе из более чем 3000 художников, собственно самих художников нужно <a href="https://www.wikiart.org" >смотреть на сайте</a>: <small>осторожно, он нашпигован свиной пропагандой ЦИПсО про злых русских и очередной сбор денег для Азова, свиные баннеры заблокируйте ublock или adblock. Заходишь на художественный сайт, не думаешь о хохлах и политике - а тут такой сюрприз. В общем - предупредил. Перед заходом можешь добавить в правила блокировщика рекламы это:</small><pre>||uploads.wikiart.org/Content/wiki/img/banner_top.png$image<br />www.wikiart.org##[src="https://uploads.wikiart.org/Content/wiki/img/banner_top.png"]</pre></p><p><b>Abstract_Swirls</b> — умеет рисовать абстракцию типа жидкого мрамора или акриловых красок в воде, но умеет и в портреты в стиле жидкой краски с завитками и разводами, выглядит красиво.Основной токен: <code>abstractswirls</code>, пример: <code>portrait of a handsome slender shirtless teen boy, abstractswirls, long shot, masterpiece, by artgerm and mucha</code>. Автор генерирует на таких настройках: Steps: 10, Sampler: DPM++ 2S a Karras, CFG scale: 7.</p><p><b>poolsuite style</b> — модель натренирована на ретро-подобных весьма ламповых фотках и картинках, вот <a href="https://prompthero.com/search?q=poolsuite+style">примеры подобного</a>. В промпт надо добавлять <code>poolsuite-style</code> или <code>poolsuite style</code>.</p><p><b>newhorrorfantasy_style</b> — иллюстрации ужасов и фэнтези 2010-х годов, в промпт добавлять токен <code>newhorrorfantasy_style</code></p><p><b>James_Webb_Cosmos</b> — потрясающие космические снимки, словно сделанные новым телескопом Джеймса Уэбба, нужно добавлять <code>JWST</code>, например <code>jwst, green spiral galaxy</code></p><p><b>Microscopic</b> — а эта модель, напротив - создает фотореалистичные картинки, сделанные словно под хорогим микроскопом. Амебы, эвглены, вирусу, и прочая микробиология и гистология. В промпт нужно добавлять все что с этим связанно и обязательно в начало <code>Microscopic</code>.</p><p><b>nousr robot</b> — моделька сделанная через Дримбус для генерации футристичных роботов, нужно добавлять <code>nousr robot</code> по ближе к началу промпта</p><p><b>гнилые_зомби</b> — модель тренировалась на зомби из Ходячих Мертвецов, в промт добавлять токен <code>RottingZombie person</code></p><p><b>blotmon</b> — модель для генерации монстров из клякс, мультяшных монстриков и всякой деформированной шизы, в промт добавлять токен <code>blotmon</code></p><p><b>All_In_1_Pixel</b> — модель, которая умеет в разнонаправленную пиксельную графику. Токен <code>pixelsprite</code> будет выдавать спрайт-арт, ключ <code>16bitscene</code> активирует генерацию в стиле scene-art. Понятное дело, пиксели не идеальны, но картинки можно легко пофиксить на этом сайте: https://pinetools.com/pixelate-effect-image</p><p><b>pixel_landscape</b> — шестнадцатибитные пиксельные картинки, заточеные под пейзажи, объекты, обои рабочего стола, и т. п. В ромпт надо добавлять: <code>in 16-bit-landscape pixel art style</code></p><p><b>Pixel_Art</b> — довольно качественный пиксельарт, в промпт нужно добавить <code>in SKSKS art style</code>, например <code>little fox, in SKSKS art style</code></p><p><b>MinecraftRTX</b> — модель для стиля Майнкрафт с RTX, в промпт добавить <code>BlockWorldRTX</code></p><p><b>microworld</b> — изометрический 3Д-арт, в промпт добавить <code>in microworld render style</code>, например <code>baalbek temple of jupiter, in microworld render style</code></p><p><b>App_Icons</b> — рисует современные иконки и пиктограмы, в промпт надо добавить <code>in style of SKSKS app icon</code>, например <code>flat couch vector, minimalist, in style of SKSKS app icon</code></p><p><b>Пепе</b> — рисует очень редких лягух Пепе. Токен для промпта <code>pepestyle person</code>.</p><p><b>ГигаЧад</b> — делает фото/рисунки знаменитого гигачада, россиянина Эрнеста Халимова. В промпт добавлять <code>gigachad</code>.</p><p><b>pokemon</b> — моделька рисует покемонов, из чего угодно, в промпт писать описание предполагаемого покемона типа <code>Vladimir Putin creature</code> или <code>cute toad</code> слово pokemon во все не обязательно, модель все равно кроме покемонов ничего не умеет.</p><p><b>ssmoky</b> — моделька заточена чисто под арты с дымом и огнем, особенно с дымом, в промпт добавлять токен <code>ssmoky</code></p><p><b>F222</b> — модель улучшеной анатомии бабского тела, хорошо подходит для эротики</p><p><b>HassanBlend</b> — модель для генерации обнаженных женщин, в порноэротическом стиле, стремится к студийному фотореализму. При выборе этой опции, будет скачено и установлено три файла моделек: prunned и full версия 1.4 (prunned помогает избежать нехватки памяти, т.к. жирные модели не всегда могут нормально ворочаться в колабе) и старая версия 1.2 - ее смысл в том, что она лучше, по мнению Анона, умеет генерить, женщин еще не достигших овуляционного периода, или только-только начавших менструальные циклы. Промптинг состоит из описания наготы, порнографии в соло, писать все довольно много, поэтому промпты с нужными ключами и примерами лучше посмотреть на <a href='https://rentry.org/sdhassan#prompts'>странице модели</a>.</p><p><b>hyperpreg__round_belly</b> — генерирует БИБИК! Да, с огромным пузом, которое вот-вот РВАНЁТ! Умеет в рисунки — с токеном <code>hyperpreg</code> и в реализм, с токеном <code>round belly</code> — делать толстого Пыню теперь станет интереснее.</p><p><b>pyros_blowjob</b> — очень качественная модель про минет, сосание (нормальных) членов. Можно кого угодно заставить жадно обсасывать залупу-лупу.  Промпты должны включать <code>with cock in mouth, is sucking a cock, licking a large cock in mouth</code> Подробнее <a href="https://rentry.org/pyros-sd-model">почитай здесь</a> - там примеры промтов в фотореалистичном, рисованном и аниме-стиле.</p><p><b>bkdbj</b> — просто пиши любое имя и  <code>bkdbj</code> (модель про сосание <u>черных</u> членов кем-либо)</p><p><b>chkn_петухи</b> — очень классно ричует петухов и кур, в разных стилях, от фото до картины масло. Имхо, идеально для боевых картинок. В промпт добавлять: <code>chkn</code></p><p><b>YIFFY_EPOCH18</b> — не знаешь че такое йиффи? Лучше не лезь. На самом деле умеет не только в зверушек, но и таких животных как трапы/футы, в рисованном стиле разумеется. Вот полный список токенов для этой шизы: <a href="https://files.catbox.moe/sovd89.zip">в архиве файлик yiffy_tags.csv</a></p><p><b>Zack3D_Kinky</b> — для тех кого просто фурри уже не вставляет: щупальца, бдсм с дикими животными, боди-модификации, латекс, слизь, пытки анала и т.п. использовать теки с сайта E621 <code>то_есть_с_подчеркиванием</code></p><p><b>GAPE60 и ее прошлая версия YIFFY_GAPE</b> — фистинг и его последвствия: раздолбанные дыры пизды и анальной пизды, пролапс, вхлам растраханные отверстия, зияющие своими красными недрами, про теги и примеры посмотри <a href="https://rentry.org/gapemodel">тут</a></p><p><b>Anything_V3</b> — Последнее слово в генерации аниме! Это утечка гораздо улучшеной версии NovelAI. Подолбнее можно прочитать на <a href="https://www.bilibili.com/read/cv19603218">китайском сайте</a> через гуглпереводчик. <b>Anything_v3_fullema</b> - таже модель, только раздутая данными для тренировки.</p><p><b>Berrymix_Zeipher222</b> — мощный микс из разных моделей по особой рецептуре, в качестве важной специи - модель Зефир на улучшенную анатомию наготы, в качестве бульона - NovelAI, и еще разные специи.</p><p><b>Anything_Berrymix</b> — Суть таже что и Berrymix_Zeipher222, только вместо NovelAI более качественная аниме-модель Anything_V3</p><p><b>Anonmix</b> — Это очень качественный микс от Анона, включает такие модели как SmirkingFace + lokean puppystyle + модели из микса Berrymix. Качество генерации, пожалуй, самое лучшее из имеющихся по около-аниме тематике. Но умеет и в другие стили, просто с легким намеком на анимешность. Конечности, лица, пальцы, половые признаки получаются как нигде хорошо.</p><p><b>Antlers_mix</b> — аниме-тянки(и не только) но без главного недостатка примитивной аниме-рисовки: отсутствие светотеневого рисунка. Это микс из различных моделей и их премиксов: ((nai_0.95 + sd-1.5_0.05) + f222 - sd-1.5)_0.75 + trinart2-115000_0.25, благодаря наличию весов из реальных фоточек и улучшенной анатомии, на выходе получается аниме-стайл, только <a href='https://files.catbox.moe/yk8csq.jpg'>совершенно не плоский</a>.</p><p><b>WaifuDiffusion-1.3</b> — анимешная модель, обучалась по картинкам с Danbooru, теги берите от туда же</p><p><b>Trinart v2</b> — еще одна анимешная модель, обучалась аж на 20 лямах картинок аниме и манги, без писек/сисек</p><p><b>Freckle_mix</b> — Микс на основе Trinart и неизвестных аниме-моделей. Довольно популярна на форчке.</p><p><b>NAI</b> — утечка модели NovelAI (скачивается с VAE), когда-то вызвала бум среди анимедрочеров и считалась революционной.</p><p><b>Cyberpunk-Anime-Diffusion</b> — генерирует аниме-персонажей в стиле киберпанк. Автор рекомендует следующие настройки генерации: сэмплер Euler_a, 20 шагов, CFG Scale 7, разрешение 704px x 704px. В промпт нужно писать <code>in dgs illustration style</code>. В негативный промпт: <code>out of focus, scary, creepy, evil, disfigured, missing limbs, ugly, gross, missing fingers</code>. Примеры хороших запросов для данной модели: <code>a photo of muscular beard soldier male in dgs illustration style, half-body, holding robot arms, shirtless, strong chest</code> или <code>portrait of a girl in dgs illustration style, Anime girl, female soldier working in a cyberpunk city, cleavage, ((perfect femine face)), intricate, 8k, highly detailed, shy, digital painting, intense, sharp focus</code></p><p><b>80s_Anime</b> — модель имитирует стиль аниме конца 80-х начала 90-х, в частности, аниме Ranma 1/2. В промпте нужно использовать слово <code>80sanimestyle</code>. Автор призывает экспериментировать с различными сэмплерами, и отмечает что DPM2, DPM++ и их варианты лучше всего работают с этой моделью.</p><p><b>Black_Souls</b> — имитирует графику из корейской игры «Black Souls». В промпт добавь токен <code>bs</code>. Автор требует, чтобы CFG_Scale стоял не выше 6, рекомендует 2-6, для skip clip установлено значение 1.</p></details>

#@markdown да, список длинный, в 2-3 колонки его не сделать, формы не поддерживают вложенность в markdown и т.д., может быть потом будет сделано через ipywidgets, но мне не нравится как выглядят виджеты ipywidgets при темной теме
modelfolder = /content/stable-diffusion-webui/models/Stable-diffusion

скачивать_в_папку_моделей_на_гуглодиске = False #@param {type:"boolean"}
папка_с_моделями_на_гуглодиске = "/content/gdrive/MyDrive/models" #@param {type:"string"}
#@markdown в названии папки с моделями не должно быть пробелов и спецсимволов!
if скачивать_в_папку_моделей_на_гуглодиске:
  modelfolder = папка_с_моделями_на_гуглодиске

своя_ссылка_на_модель = False #@param {type:"boolean"}
if своя_ссылка_на_модель:
  ссылка = "https://huggingface.co/user/repo/resolve/main/model.ckpt" #@param {type:"string"}
  url = ссылка
  filename = url.split("/")[-1]
  # !wget --content-disposition {ссылка} -O {modelfolder}/{filename}
#@markdown <big><big>галочками отметить нужные модели</big></big> (учитывая размер диска в колабе, около 40 гигов свободными):
#SD_v2_1_512px = False #@param {type:"boolean"}
#SD_v2_1_768px = False #@param {type:"boolean"}   
SDv1_5 = False #@param {type:"boolean"}
SDv1_5_full = False #@param {type:"boolean"}
SDv1_4 = False #@param {type:"boolean"}
dreamlikePhotoRealV2 = False #@param {type:"boolean"}
Analog_diffusion = False #@param {type:"boolean"}
Protogen_X58_Rebuil = False #@param {type:"boolean"}
protogenX3_4 = False #@param {type:"boolean"}
protogenV22Anime = False #@param {type:"boolean"}
RealEldenApocalypse_AnalogSexKnoll_4CandyPureSimp_FEET = False #@param {type:"boolean"}
elldrethSLucidMix_v10 = False #@param {type:"boolean"}
HASDX = False #@param {type:"boolean"}
hAS3Dkx11_3Dkx11 = False #@param {type:"boolean"}
Beksinski = False #@param {type:"boolean"}
Van_Gogh = False #@param {type:"boolean"}
Bloodborne = False #@param {type:"boolean"}
DarkSouls = False #@param {type:"boolean"}
Borderlands = False #@param {type:"boolean"}
Redshift = False #@param {type:"boolean"}
Starsector_Portrait = False #@param {type:"boolean"}
EpicSpaceMachine = False #@param {type:"boolean"}
reasonableDrink = False #@param {type:"boolean"}
CALARTS = False #@param {type:"boolean"}
beeple = False #@param {type:"boolean"}
megaPals = False #@param {type:"boolean"}
pachu_artwork_style = False #@param {type:"boolean"}
Cats_Tabaxi = False #@param {type:"boolean"}
Cthulhu_illithid = False #@param {type:"boolean"}
BubblyDubbly = False #@param {type:"boolean"}
Ложкин = False #@param {type:"boolean"}
modern_disney_style = False #@param {type:"boolean"}
classic_disney_style = False #@param {type:"boolean"}
tron_legacy_style = False #@param {type:"boolean"}
elden_ring_style = False #@param {type:"boolean"}
spiderverse_style = False #@param {type:"boolean"}
discoelysium_style = False #@param {type:"boolean"}
arcane_style = False #@param {type:"boolean"}
archer_style = False #@param {type:"boolean"}
poolsuite_style = False #@param {type:"boolean"}
newhorrorfantasy_style = False #@param {type:"boolean"}
Hogwarts_Legacy = False #@param {type:"boolean"}
OpenJourney = False #@param {type:"boolean"}
Midjourney = False #@param {type:"boolean"}
WiKiArt = False #@param {type:"boolean"}
Abstract_Swirls = False #@param {type:"boolean"}
James_Webb_Cosmos = False #@param {type:"boolean"}
Microscopic = False #@param {type:"boolean"}
nousr_robot = False #@param {type:"boolean"}
гнилые_зомби = False #@param {type:"boolean"}
blotmon = False #@param {type:"boolean"}
All_In_1_Pixel = False #@param {type:"boolean"}
pixel_landscape = False #@param {type:"boolean"}
Pixel_Art = False #@param {type:"boolean"}
MinecraftRTX = False #@param {type:"boolean"}
microworld = False #@param {type:"boolean"}
App_Icons = False #@param {type:"boolean"}
DBWayneBarlowe_JM = False #@param {type:"boolean"}
Пепе = False #@param {type:"boolean"}
ГигаЧад = False #@param {type:"boolean"}
pokemon = False #@param {type:"boolean"}
ssmoky = False #@param {type:"boolean"}
HassanBlend = False #@param {type:"boolean"}
F222 = False #@param {type:"boolean"}
pyros_blowjob = False #@param {type:"boolean"}
bkdbj = False #@param {type:"boolean"}
hyperpreg__round_belly = False #@param {type:"boolean"}
chkn_петухи = False #@param {type:"boolean"}
YIFFY_EPOCH18 = False #@param {type:"boolean"}
FurSlut = False #@param {type:"boolean"}
Zack3D_Kinky = False #@param {type:"boolean"}
AnythingGape = False #@param {type:"boolean"}
GAPE60 = False #@param {type:"boolean"}
YIFFY_GAPE = False #@param {type:"boolean"}
Anything_V3 = False #@param {type:"boolean"}
Anything_v3_fullema = False #@param {type:"boolean"}
Anonmix = False #@param {type:"boolean"}
monstermash4_anyv3 = False #@param {type:"boolean"}
monstermash6_anyv3 = False #@param {type:"boolean"}
Bstaber = False #@param {type:"boolean"}
BloodNightOrangeMix = False #@param {type:"boolean"}
ElyOrangeMix = False #@param {type:"boolean"}
AbyssOrangeMix = False #@param {type:"boolean"}
MMDv1_18 = False #@param {type:"boolean"}
Cyberpunk_Anime_Diffusion = False #@param {type:"boolean"}
Berrymix_Zeipher222 = False #@param {type:"boolean"}
Anything_Berrymix = False #@param {type:"boolean"}
Antlers_mix = False #@param {type:"boolean"}
WaifuDiffusion = False #@param {type:"boolean"}
Trinart_v2 = False #@param {type:"boolean"}
Freckle_mix = False #@param {type:"boolean"}
NAI = False #@param {type:"boolean"}
Anime_80s = False #@param {type:"boolean"}
Black_Souls = False #@param {type:"boolean"}
Члены = False #@param {type:"boolean"}

if SDv1_5:
    # !wget https://huggingface.co/utnah/ckpt/resolve/main/sd-v1-5.ckpt -O {modelfolder}/sd-v1-5.ckpt
    # !sleep 2
    # !wget https://huggingface.co/utnah/ckpt/resolve/main/sd-v1-5.vae.pt -O {modelfolder}/sd-v1-5.vae.pt
    # !sleep 2
    # !wget https://huggingface.co/utnah/ckpt/resolve/main/sd-v1-5.inpainting.ckpt -O {modelfolder}/sd-v1-5.inpainting.ckpt
if SDv1_5_full:
    # !wget https://huggingface.co/utnah/ckpt/resolve/main/sd-v1-5.full.ckpt -O {modelfolder}/sd-v1-5.full.ckpt
if SDv1_4:
    # !wget https://huggingface.co/utnah/ckpt/resolve/main/sd-v1-4.ckpt -O {modelfolder}/sd-v1-4.ckpt
if pachu_artwork_style:
    # !wget https://huggingface.co/ProGamerGov/Pachu-Diffusion/resolve/main/pachu_artwork_style_v1_iter8000.ckpt -O {modelfolder}/pachu_artwork_style.ckpt
if modern_disney_style:
    # !wget https://huggingface.co/nitrosocke/mo-di-diffusion/resolve/main/moDi-v1-pruned.ckpt -O {modelfolder}/modern_disney_style.ckpt
if classic_disney_style:
    # !wget https://huggingface.co/nitrosocke/classic-anim-diffusion/resolve/main/classicAnim-v1.ckpt -O {modelfolder}/classic_disney_style.ckpt
if tron_legacy_style:
    # !wget https://huggingface.co/dallinmackay/Tron-Legacy-diffusion/resolve/main/Tron-Legacy-Style-trnlgcy.ckpt -O {modelfolder}/trnlgcy.ckpt
if elden_ring_style:
    # !wget https://huggingface.co/nitrosocke/elden-ring-diffusion/resolve/main/eldenring-v2-pruned.ckpt -O {modelfolder}/elden_ring_style.ckpt
if spiderverse_style:
    # !wget https://huggingface.co/nitrosocke/spider-verse-diffusion/resolve/main/spiderverse-v1-pruned.ckpt -O {modelfolder}/spiderverse_style.ckpt
if discoelysium_style:
    # !wget https://huggingface.co/nitrosocke/disco-elysium/resolve/main/discoElysium-pruned.ckpt -O {modelfolder}/discoelysium_style.ckpt
if arcane_style:
    # !wget https://huggingface.co/nitrosocke/Arcane-Diffusion/resolve/main/arcane-diffusion-v3.ckpt -O {modelfolder}/arcane_style.ckpt
if archer_style:
    # !wget https://huggingface.co/nitrosocke/archer-diffusion/resolve/main/archer-v1.ckpt -O {modelfolder}/archer_style.ckpt
if nousr_robot:
    # !wget https://huggingface.co/nousr/robo-diffusion/resolve/main/models/robo-diffusion-v1.ckpt -O {modelfolder}/nousr_robot.ckpt
if pokemon:
    # !wget https://huggingface.co/justinpinkney/pokemon-stable-diffusion/resolve/main/ema-only-epoch%3D000142.ckpt -O {modelfolder}/pokemon.ckpt
if blotmon:
    # !wget https://huggingface.co/guumaster/blot-monster-diffusion/resolve/main/blotmon-v1-5000.ckpt -O {modelfolder}/blotmon.ckpt
if ssmoky:
    # !wget https://huggingface.co/guumaster/smoke-diffusion/resolve/main/ssmoky1_3000.ckpt -O {modelfolder}/ssmoky.ckpt
if YIFFY_EPOCH18:
    # !wget https://huggingface.co/utnah/ckpt/resolve/main/yiffy-e18.ckpt -O {modelfolder}/yiffy-e18.ckpt
if poolsuite_style:
    # !wget https://huggingface.co/prompthero/poolsuite-diffusion/resolve/main/poolsuite_step2010.ckpt  -O {modelfolder}/poolsuite_style.ckpt
if newhorrorfantasy_style:
    # !wget https://huggingface.co/elRivx/sd-newhorrorfantasy_style/resolve/main/newhorrorfantasy_style.ckpt -O {modelfolder}/newhorrorfantasy_style.ckpt
if WiKiArt:
    # !wget https://huggingface.co/utnah/ckpt/resolve/main/sd-wikiart-v2.ckpt -O {modelfolder}/wikiart.ckpt
if Zack3D_Kinky:
    # !wget https://huggingface.co/Zack3D/Zack3D_Kinky-v1/resolve/main/Zack3D_Kinky-v1.ckpt -O {modelfolder}/kinky.ckpt
if YIFFY_GAPE:
    # !wget https://huggingface.co/utnah/ckpt/resolve/main/gape22_yiffy15.ckpt -O {modelfolder}/gape_yiffy.ckpt
if hyperpreg__round_belly:
    # !wget https://huggingface.co/utnah/ckpt/resolve/main/hyperpreg__round_belly.ckpt -O {modelfolder}/hyperpreg__round_belly.ckpt
if WaifuDiffusion:
    # !wget https://huggingface.co/hakurei/waifu-diffusion-v1-3/resolve/main/wd-v1-3-float32.ckpt -O {modelfolder}/waifu.ckpt
if NAI:
    # !wget https://huggingface.co/utnah/ckpt/resolve/main/novelai.ckpt -O {modelfolder}/novelai.ckpt
    # !wget https://huggingface.co/utnah/ckpt/resolve/main/novelai.vae.pt -O {modelfolder}/novelai.vae.pt
if Trinart_v2:
    # !wget https://huggingface.co/utnah/ckpt/resolve/main/trinart2.ckpt -O {modelfolder}/trinart2.ckpt
if DBWayneBarlowe_JM:
    # !wget https://huggingface.co/utnah/ckpt/resolve/main/DBWayneBarlowe_JM.ckpt -O {modelfolder}/DBWayneBarlowe_JM.ckpt
if F222:
    # !wget https://huggingface.co/utnah/ckpt/resolve/main/f222.ckpt -O {modelfolder}/f222.ckpt
if Beksinski:
    # !wget https://huggingface.co/s3nh/beksinski-style-stable-diffusion/resolve/main/model.ckpt -O {modelfolder}/beksinski.ckpt
if Van_Gogh:
    # !wget https://huggingface.co/dallinmackay/Van-Gogh-diffusion/resolve/main/Van-Gogh-Style-lvngvncnt-v2.ckpt -O {modelfolder}/Van_Gogh.ckpt
if Bloodborne:
    # !wget https://huggingface.co/Guizmus/Bloodborne/resolve/main/BloodborneStyle-v1.ckpt -O {modelfolder}/Bloodborne.ckpt
if DarkSouls:
    # !wget https://huggingface.co/Guizmus/DarkSoulsDiffusion/resolve/main/DarkSoulsStyle-v1.2.ckpt -O {modelfolder}/DarkSouls.ckpt
if Borderlands:
    # !wget https://huggingface.co/PublicPrompts/borderlands/resolve/main/borderlands.ckpt -O {modelfolder}/borderlands.ckpt
if Redshift:
    # !wget https://huggingface.co/nitrosocke/redshift-diffusion/resolve/main/redshift-diffusion-v1.ckpt -O {modelfolder}/redshift.ckpt
if Starsector_Portrait:
    # !wget https://huggingface.co/Severian-Void/Starsector-Portraits/resolve/main/models/starsectorportrait_v2.1_SD1.5.ckpt -O {modelfolder}/starsector_portrait.ckpt
    # !curl -L --create-dirs https://huggingface.co/Severian-Void/Starsector-Portraits/resolve/main/hypernetworks/HN_ssportrait_v2_1.5_13431.pt -o /content/stable-diffusion-webui/models/hypernetworks/HN_ssportrait.pt
if EpicSpaceMachine:
    # !wget https://huggingface.co/rabidgremlin/sd-db-epic-space-machine/resolve/main/EpicSpaceMachine.ckpt -O {modelfolder}/EpicSpaceMachine.ckpt
if reasonableDrink:
    # !wget https://huggingface.co/elRivx/reasonableDrink/resolve/main/reasonableDrink.ckpt -O {modelfolder}/reasonableDrink.ckpt
if CALARTS:
    # !wget https://huggingface.co/PublicPrompts/CALARTS/resolve/main/CALARTS.ckpt -O {modelfolder}/CALARTS.ckpt
if beeple:
    # !wget https://huggingface.co/riccardogiorato/beeple-diffusion/resolve/main/beeple.ckpt -O {modelfolder}/beeple.ckpt
if megaPals:
    # !wget https://huggingface.co/elRivx/megaPals/resolve/main/megaPals.ckpt -O {modelfolder}/megaPals.ckpt
if pixel_landscape:
    # !wget "https://huggingface.co/PublicPrompts/16-bit-landscape_PublicPrompts/resolve/main/16-bit-landscape_PublicPrompts.ckpt" -O {modelfolder}/pixel_landscape.ckpt
if Pixel_Art:
    # !wget https://huggingface.co/utnah/ckpt/resolve/main/Pixel_Art.ckpt -O {modelfolder}/Pixel_Art.ckpt
if MinecraftRTX:
    # !wget https://huggingface.co/rabidgremlin/sd-db-block-world-rtx/resolve/main/BlockWorldRTX.ckpt -O {modelfolder}/MinecraftRTX.ckpt
if microworld:
    # !wget https://huggingface.co/utnah/ckpt/resolve/main/microworld.ckpt -O {modelfolder}/microworld.ckpt
if App_Icons:
    # !wget https://huggingface.co/utnah/ckpt/resolve/main/App_Icons.ckpt -O {modelfolder}/App_Icons.ckpt
if bkdbj:
    # !wget https://huggingface.co/utnah/ckpt/resolve/main/bkdbj.ckpt -O {modelfolder}/bkdbj.ckpt
if Anything_V3:
  # !wget -nv --show-progress "https://huggingface.co/utnah/ckpt/resolve/main/Anything-V3.0-pruned-fp32.ckpt" -O {modelfolder}/anything_v3.ckpt
  # !wget -nv --show-progress "https://huggingface.co/utnah/ckpt/resolve/main/Anything-V3.0.vae.pt" -O {modelfolder}/anything_v3.vae.pt
if Anything_v3_fullema:
  # !wget -nv --show-progress https://huggingface.co/utnah/big_ckpt/resolve/main/Anything_v3_fullema.ckpt -O {modelfolder}/Anything_v3_fullema.ckpt
  # !wget -nv --show-progress https://huggingface.co/utnah/big_ckpt/resolve/main/Anything_v3_fullema.vae.pt -O {modelfolder}/Anything_v3_fullema.vae.pt
if GAPE60:
  # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/gape60.ckpt -O {modelfolder}/gape60.ckpt
if Berrymix_Zeipher222:
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/Berrymix_Zeipher222.ckpt -O {modelfolder}/Berrymix_Zeipher222.ckpt
if Anything_Berrymix:
    #!wget -nv --show-progress https://huggingface.co/utnah/big_ckpt/resolve/main/Anything_Berrymix.ckpt -O {modelfolder}/Anything_Berrymix.ckpt
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/Anything_Berrymix-pruned.ckpt -O {modelfolder}/Anything_Berrymix-pruned.ckpt
if pyros_blowjob:
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/pbj_v1.ckpt -O {modelfolder}/pyros_blowjob.ckpt
if Пепе:
    # !wget -nv --show-progress https://huggingface.co/SpiteAnon/Pepestyle/resolve/main/pepestylev2_2200.ckpt -O {modelfolder}/pepestyle_person.ckpt
if ГигаЧад:
    # !wget -nv --show-progress https://huggingface.co/SpiteAnon/gigachad-diffusion/resolve/main/gigachad_2000.ckpt -O {modelfolder}/gigachad.ckpt
if James_Webb_Cosmos:
    # !wget -nv --show-progress https://huggingface.co/dallinmackay/JWST-Deep-Space-diffusion/resolve/main/JWST-Deep-Space.ckpt -O {modelfolder}/JWST.ckpt
if Midjourney:
    # !wget -nv --show-progress https://huggingface.co/prompthero/midjourney-v4-diffusion/resolve/main/mdjrny-v4.ckpt -O {modelfolder}/mdjrny-v4_style.ckpt
if Cats_Tabaxi:
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/tabaxi2500person.ckpt -O {modelfolder}/cat_tabaxi_person.ckpt
if Cthulhu_illithid:
    # !wget -nv --show-progress 'https://huggingface.co/VTTRPGResources/DnDAi-illithid_Person/resolve/main/DnDAi%20-%20illithid_Person.ckpt' -O {modelfolder}/illithid_person.ckpt
if BubblyDubbly:
    # !wget -nv --show-progress https://huggingface.co/Marre-Barre/bubblydubbly/resolve/main/bubblydubbly_7k.ckpt  -O {modelfolder}/bubblydubbly_7k.ckpt
    # !wget -nv --show-progress https://huggingface.co/Marre-Barre/bubblydubbly/resolve/main/bubblydubbly.ckpt  -O {modelfolder}/bubblydubbly.ckpt
if Microscopic:
    # !wget -nv --show-progress https://huggingface.co/Fictiverse/Stable_Diffusion_Microscopic_model/resolve/main/Microscopic_v1.ckpt -O {modelfolder}/Microscopic.ckpt
if гнилые_зомби:
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/RottingZombie_person.ckpt -O {modelfolder}/RottingZombie_person.ckpt
if Black_Souls:
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/Black_Souls.ckpt -O {modelfolder}/Black_Souls.ckpt
if All_In_1_Pixel:
    # !wget -nv --show-progress https://huggingface.co/PublicPrompts/All-In-One-Pixel-Model/resolve/main/Public-Prompts-Pixel-Model.ckpt -O {modelfolder}/all_in_one_pixel_model.ckpt
if Abstract_Swirls:
    # !wget -nv --show-progress https://huggingface.co/coder119/Abstract_Swirls_Diffusion/resolve/main/Abstract_Swirls.ckpt -O {modelfolder}/abstractswirls.ckpt
if chkn_петухи:
    # !wget -nv --show-progress https://huggingface.co/fake4325634/chkn/resolve/main/chkn.ckpt -O {modelfolder}/chkn.ckpt
if Hogwarts_Legacy:
    # !wget -nv --show-progress "https://huggingface.co/Guizmus/Experiments/resolve/main/HogLegStyle-v2.4.ckpt" -O {modelfolder}/HogLeg_Style.ckpt
if Anonmix:
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/Anonmix.ckpt -O {modelfolder}/Anonmix.ckpt
if Cyberpunk_Anime_Diffusion:
    # !wget -nv --show-progress https://huggingface.co/DGSpitzer/Cyberpunk-Anime-Diffusion/resolve/main/Cyberpunk-Anime-Diffusion.ckpt -O {modelfolder}/Cyberpunk-Anime-Diffusion.ckpt
if OpenJourney:
    # !wget -nv --show-progress https://huggingface.co/openjourney/openjourney/resolve/main/mdjrny-v4.ckpt -O {modelfolder}/OpenJourney.ckpt
if Члены:
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/unctpns.ckpt -O {modelfolder}/uncut-penis.ckpt
if Antlers_mix:
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/antlers_mix.ckpt -O {modelfolder}/antlers_mix.ckpt
if HassanBlend:
    # !wget -nv --show-progress "https://huggingface.co/utnah/ckpt/resolve/main/HassanBlend_1.4-pruned.ckpt" -O {modelfolder}/HassanBlend_1.4-pruned.ckpt
    # !wget -nv --show-progress "https://huggingface.co/hassanblend/hassanblend1.4/resolve/main/HassanBlend1.4.ckpt" -O {modelfolder}/HassanBlend1.4.ckpt
    # !wget -nv --show-progress "https://huggingface.co/utnah/ckpt/resolve/main/HassansBlend_1.2.ckpt" -O {modelfolder}/HassansBlend_1.2.ckpt
if Anime_80s:
    # !wget -nv --show-progress "https://huggingface.co/tashachan28/ranma_diffusion/resolve/main/80s_anime_test_5_anythingmodel.ckpt" -O {modelfolder}/80s_Anime.ckpt
if Freckle_mix:
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/freckle_mix.ckpt -O {modelfolder}/freckle_mix.ckpt
if Ложкин:
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/lozhkin.ckpt -O {modelfolder}/lozhkin.ckpt
if AnythingGape:
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/AnythingGape.ckpt -O {modelfolder}/AnythingGape.ckpt
    # !sleep 2
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/AnythingGape.vae.pt -O {modelfolder}/AnythingGape.vae.pt
if FurSlut:
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/furslut.ckpt -O {modelfolder}/furslut.ckpt
if monstermash4_anyv3:
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/monstermash4+anyv3.safetensors -O {modelfolder}/monstermash4_anyv3.safetensors
if monstermash6_anyv3:
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/monstermash6+anyv3.safetensors -O {modelfolder}/monstermash6_anyv3.safetensors
if Bstaber:
    # !wget -nv --show-progress https://huggingface.co/Pups/sd_mix/resolve/main/Bstaber.safetensors -O {modelfolder}/Bstaber.safetensors
if Analog_diffusion:
    # !wget -nv --show-progress "https://huggingface.co/wavymulder/Analog-Diffusion/resolve/main/analog-diffusion-1.0.safetensors" -O {modelfolder}/analog-diffusion.safetensors
if Protogen_X58_Rebuil:
    # !wget -nv --show-progress "https://huggingface.co/utnah/ckpt/resolve/main/Protogen_x5.8_Rebuilt_pruned.safetensors" -O {modelfolder}/Protogen_X58_Rebuil.safetensors
if protogenV22Anime:
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/protogenV22Anime_22_fp16.safetensors -O {modelfolder}/protogenV22Anime.safetensors
if BloodNightOrangeMix:
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/BloodNightOrangeMix_fp16.safetensors -O {modelfolder}/BloodNightOrangeMix.safetensors
if ElyOrangeMix:
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/ElyOrangeMix_fp16.safetensors -O {modelfolder}/ElyOrangeMix.safetensors
if AbyssOrangeMix:
    # !wget -nv --show-progress https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/AbyssOrangeMix.safetensors -O {modelfolder}/AbyssOrangeMix.safetensors
if MMDv1_18:
    # !wget -nv --show-progress "https://huggingface.co/utnah/ckpt/resolve/main/MMDv1-18_fp16.safetensors" -O {modelfolder}/MMDv1_18.safetensors
if HASDX:
    # !wget -nv --show-progress "https://huggingface.co/utnah/safetensors/resolve/main/HASDX-ema-fp16.safetensors" -O {modelfolder}/HASDX.safetensors
if dreamlikePhotoRealV2:
    # !wget -nv --show-progress https://huggingface.co/utnah/safetensors/resolve/main/dreamlikePhotoRealV2_dreamlikePhotoRealV2.safetensors -O {modelfolder}/dreamlikePhotoRealV2.safetensors
if elldrethSLucidMix_v10:
    # !wget -nv --show-progress https://huggingface.co/utnah/safetensors/resolve/main/elldrethSLucidMix_v10-ema-fp16.safetensors -O {modelfolder}/elldrethSLucidMix_v10.safetensors
if hAS3Dkx11_3Dkx11:
    # !wget -nv --show-progress https://huggingface.co/utnah/safetensors/resolve/main/hAS3Dkx11_3Dkx11.safetensors -O {modelfolder}/hAS3Dkx11_3Dkx11.safetensors
if protogenX3_4:
    # !wget -nv --show-progress "https://huggingface.co/utnah/safetensors/resolve/main/protogenX3.4-fp16-ema.safetensors" -O {modelfolder}/protogenX3_4.safetensors
if RealEldenApocalypse_AnalogSexKnoll_4CandyPureSimp_FEET:
    # !wget -nv --show-progress https://huggingface.co/utnah/safetensors/resolve/main/realEldenApocalypseA_realEldenApocalypseAsexKnoll4CandyPureSimpFeet-ema.fp16.safetensors -O {modelfolder}/RealEldenApocalypse_AnalogSexKnoll_4CandyPureSimp_FEET.safetensors

#@markdown <center><font size='3'> <a href='#scrollTo=R-xAdMA5wxXd' >поднятся на верх к #3 ячейке запуска</a></font></center>
from google.colab import output
output.clear()
# !ls -la {modelfolder}/*.ckpt
print('          Выбранные модели скачались')
print('[1;32m 🡹 Теперь запускай ячейку #3 для старта WebUI 🡹')
from google.colab import output
output.eval_js('new Audio("https://github.com/PR0LAPSE/StableDiffusionWebUIColab/raw/main/src/models.mp3").play()')

# %% [markdown]
# ---

# %% [markdown]
# # Скачивание торрентов (можно на гуглодиск)

# %%
#@title <big>libtorrent</big> { display-mode: "form" }

import os
import time
from google.colab import output
if подключить_гуглодиск:
  from google.colab import output
  from google.colab import drive
  drive.mount('/content/gdrive')
  # !sleep 2
if not os.path.exists("/usr/share/doc/python3-libtorrent/copyright"):
  print ("сначала нужно установить торрент-клиент.\n установка...")
  # !python -m pip install jedi>=0.10 --quiet
  # !python -m pip install --upgrade pip setuptools wheel --quiet
  # !python -m pip install lbry-libtorrent --quiet
  # !apt install -qq python3-libtorrent --quiet
  # !rm '/content/=0.10'
  output.clear()
  print("установка клиента завершена")
else:
  # !sleep 1

import ipywidgets as widgets
import libtorrent as lt
from threading import Thread

ses = lt.session()
ses.listen_on(6881, 6891)
downloads = []

# !sleep 1
#@markdown чтобы скачать на гуглодиск, сначала примонтируй его, если этого не сделал ранее, или укажи другую папку для загрузки
подключить_гуглодиск = False #@param {type:"boolean"}
куда_качать = "/content/drive/My Drive/Torrent" #@param {type:"string"}
#@markdown Поставь галочку, если нужно после запуска выбрать файлы .torrent с компьютера:
torrent_файл = False #@param {type:"boolean"}
#@markdown Или вставь magnet-ссылку:


# выбрать торрент файлы?
if torrent_файл:
  from google.colab import files

  source = files.upload()
  if not source:                         
    print ('Нечего скачивать...')
    print ('Ты либо загрузи torrent-файлы, либо сними галочку и укажи magnet-ссылку')
    print ('попробуй еще раз')
    exit
  else:
    params = {
        "save_path": f"{куда_качать}",
        "ti": lt.torrent_info(list(source.keys())[0]),
    }
    downloads.append(ses.add_torrent(params))
    print ('ГОТОВО !!!')
else:
  from numpy import empty
  import libtorrent as lt
  import time
  import datetime
  ses = lt.session()
  ses.listen_on(6881, 6891)
  params = {
      'save_path': f'{куда_качать}',
      }
  link = "magnet:?xt=urn:btih:ED295B74E820777FF1E5C84B6657CB2AEB539AE1&tr=http%3A%2F%2Fbt3.t-ru.org%2Fann%3Fmagnet&dn=%D0%9C%D0%B8%D1%85%D0%B0%D0%B8%D0%BB%20%D0%91%D0%B5%D0%B9%D0%BB%D1%8C%D0%BA%D0%B8%D0%BD%20-%20%D0%A1%D0%B5%D1%80%D0%B8%D1%8F%20%D0%BA%D0%BD%D0%B8%D0%B3%20%22%D0%A1%D0%B5%D0%BA%D1%81-%D0%BB%D0%B8%D0%BA%D0%B1%D0%B5%D0%B7%22%20%D0%BF%D0%BE%20%D0%B3%D0%BE%D0%BC%D0%BE%D1%81%D0%B5%D0%BA%D1%81%D1%83%D0%B0%D0%BB%D1%8C%D0%BD%D0%BE%D1%81%D1%82%D0%B8%20%D0%B8%20%D1%81%D0%B5%D0%BA%D1%81%D0%BE%D0%BB%D0%BE%D0%B3%D0%B8%D0%B8%20%5B2006-2009%2C%20DOC%5D" #@param {type:"string"}

  if not link:                         
      print ('Ты не ввел магнет-ссылку !!!')
      exit
  if "magnet:?xt=urn:btih" not in link:
    print ('Это не магнет-ссылка !!!')
    print ('Либо вставь нормальную магнет-ссылку, либо отметь галочку и запусти и загрузи торрент-файлы.')
    exit
  else:
    handle = lt.add_magnet_uri(ses, link, params)
    ses.start_dht()

    begin = time.time()
    print(datetime.datetime.now())

    print ('Получаю метаданные...')
    while (not handle.has_metadata()):
      time.sleep(1)
    print ('Запускаю загрузку...')

    while (handle.status().state != lt.torrent_status.seeding):
        s = handle.status()
        state_str = ['очередь', 'проверка', 'получение метаданных', \
                'идет скачивание', 'готово', 'раздача', 'распределение']
        print ('%.2f%% (загрузка: %.1f kb/s отдача: %.1f kB/s пиры: %d) %s ' % \
                (s.progress * 100, s.download_rate / 1000, s.upload_rate / 1000, \
                s.num_peers, state_str[s.state]))
        time.sleep(5)

    end = time.time()
    print("ГОТОВО!")

    print("Затрачено времени: ",int((end-begin)//60),"min :", int((end-begin)%60), "sec")


#@markdown Обрати внимание: путь до папки загрузок приведен для примера (если подключен гуглодиск, допустим)! Это не путь до папки с моделями в колабе!

#@markdown Путь до стандартной папки с моделями: `/content/stable-diffusion-webui/models/Stable-diffusion`
#@markdown Торент может содержать вложенные папки и т.п., поэтому скачать лучше куда-то, а потом непосредственно файл можели перетянуть в папку где лежат все модели:
#@markdown <b><font color='forestgreen' size='2'><details><summary>скрин где найти тут папку</summary> <img src='https://files.catbox.moe/4pi0d7.png' /></details>

# %%
#@title Конвертер моделей pytorch .bin в .ckpt { display-mode: "form" }

#@markdown нужно указать путь до папки с файлами модели формата питорч, а не просто файла .bin!

#@markdown <details><summary><font color=red>как должно выглядить <u>содержимое</u> папки</font></summary><img src='https://dl.uploadgram.me/6373cae8820b1h?dl' height='500' /></details>

#@markdown [пример такой модели](https://huggingface.co/lambdalabs/sd-image-variations-diffusers/tree/main) - скачивать нужно всю папку, и вот такая папка указывается в параметрах, именно вся эта папка будет сконвертированна в один файлик модели с расширением .ckpt, пригодным для WebUI

#@markdown Если папку с моделью ты еще не скачал самостоятельно на гуглодиск, можешь вставить ссылку на репозиторий модели в поле ниже, тогда модель временно скачается в колаб и сконвертируется автоматически в ckpt куда ты укажешь, указывать дополнительно путь до нее будет не нужно, если указана ссылка на модель - поле пути до папки модели будет проигнорированно.

#@markdown Корректная ссылка должна выглядить только так: `https://huggingface.co/Юзер_Нейм/Модель_Нейм` а репозиторий должен быть открытым с доступом без всяких подтверждений лицензионных соглашений. В противном случае - скачайте папку вручную.

#@markdown Если будешь указывать путь до своей папки - ссылку удали из ее поля

ссылка_на_репозиторий_модели = "https://huggingface.co/IfanSnek/JohnDiffusion" #@param {type:"string"}

#@markdown  <hr>
# !git clone {ссылка_на_репозиторий_модели}
import os
import os.path
from google.colab import output
from IPython.display import clear_output
папка_модели_питорч = "/content/JohnDiffusion" #@param {type:"string"}
куда_сохранить_ckpt = "/content/" #@param {type:"string"}
if not ссылка_на_репозиторий_модели or "huggingface.co" not in ссылка_на_репозиторий_модели:
  ckpt_name = os.path.basename(f"{папка_модели_питорч}")
  scrpath = "/content/.config/converter/ckptconverter.py"
  # !curl -s -L --create-dirs -o {scrpath} https://github.com/PR0LAPSE/StableDiffusionWebUIColab/raw/main/src/ckptconverter.py
  # !python {scrpath} --model_path={папка_модели_питорч} --checkpoint_path={куда_сохранить_ckpt}/{ckpt_name}.ckpt
  if os.path.exists(куда_сохранить_ckpt+'/' + ckpt_name + '.ckpt'):
      output.clear()
      print("[1;32mВСЁ! модель в формате ckpt успешно создана.")
      print(куда_сохранить_ckpt+'/' + ckpt_name + '.ckpt')
      output.eval_js('new Audio("https://dl.uploadgram.me/6374ad94c98a5h?dl").play()')
  else:
      print("[1;31mчто-то пошло не так...")
      output.eval_js('new Audio("https://dl.uploadgram.me/6374ad9346cc1h?dl").play()')
else:
  # !git lfs install
  output.clear()
  # !cd /content
  output.clear()
  # !git clone {ссылка_на_репозиторий_модели}
  output.clear()
  ckpt_name = '/'.join(ссылка_на_репозиторий_модели.split('/')[-1:])
  папка_модели_питорч = f"/content/{ckpt_name}"
  scrpath = "/content/.config/converter/ckptconverter.py"
  # !curl -s -L --create-dirs -o {scrpath} https://github.com/PR0LAPSE/StableDiffusionWebUIColab/raw/main/src/ckptconverter.py
  # !python {scrpath} --model_path={папка_модели_питорч} --checkpoint_path={куда_сохранить_ckpt}/{ckpt_name}.ckpt
  if os.path.exists(куда_сохранить_ckpt+'/' + ckpt_name + '.ckpt'):
    # !rm -rf /content/{ckpt_name}
    output.clear()
    print("[1;32mВСЁ! модель в формате ckpt успешно создана.")
    print(куда_сохранить_ckpt+'/' + ckpt_name + '.ckpt')
    output.eval_js('new Audio("https://dl.uploadgram.me/6374ad94c98a5h?dl").play()')
  else:
    # !rm -rf /content/{ckpt_name}
    print("[1;31mчто-то пошло не так...")
    output.eval_js('new Audio("https://dl.uploadgram.me/6374ad9346cc1h?dl").play()')

# %%
#@title Pruning (уменьшение размера модели) { display-mode: "form" }
#@markdown Прунинг - удаление из раздутых больших моделей лишней информации для обучения, позволяя уменьшить размер готового файла в двое. Заметных глазу изменений при генерации не происходит. Данный вариант создает ema-only модели. В ячейке ниже, по мимо этого, можно удалить из модели больше данных и сделать float16 вариант.
путь_до_модели = "/content/Anything_Berrymix.ckpt" #@param {type:"string"}
import os
if not os.path.exists("/content/prune-ckpt.py"):
  from google.colab import output
  # !wget -nv --show-progress https://github.com/prettydeep/Dreambooth-SD-ckpt-pruning/raw/main/prune-ckpt.py
  output.clear()
else:
  # !sleep 1
# !python prune-ckpt.py --ckpt {путь_до_модели}

# %%
#@title Прунинг моделей (с поддержкой v2)
import os
from google.colab import output
if not os.path.exists("/content/stable-diffusion-prune/prune.py"):
  # %cd /content/
  # !git clone https://github.com/saftle/stable-diffusion-prune
  output.clear()
  #print("Установка зависимостей...")
  #!pip -q install -r /content/stable-diffusion-prune/requirements.txt
  #output.clear()
else:
  # !sleep 1

if not os.path.exists("/usr/local/lib/python3.8/dist-packages/torch-1.13.0+cu116.dist-info"):
  print("Установка зависимостей...")
  # !pip -q install -r https://github.com/AUTOMATIC1111/stable-diffusion-webui/raw/master/requirements.txt
  # !pip -q install torch --pre --extra-index-url https://download.pytorch.org/whl/nightly/cu116
  output.clear()
else:
  # !sleep 1


#@markdown Сперва нужно указать путь до исходной модели, затем путь с именем новой модели после прунинга:
исходная_модель = "/content/Anything_v3_fullema.ckpt" #@param {type:"string"}
выходная_модель = "/content/gdrive/MyDrive/SD/models/Anythingv3_pruned.ckpt" #@param {type:"string"}
#@markdown Галочками нужно отметить параметры прунинга: <br>
#@markdown `fp16 - конвертировать в float16` <br> `ema - оставить только EMA данные` <br> `no_clip - удалить веса CLIP` <br> `no_vae - удалить веса VAE` <br> `no_depth - удалить данные глубины (для моделей v2)` <br> `no_unet - удалить веса UNet`
fp16 = True #@param {type:"boolean"}
ema = True #@param {type:"boolean"}
no_clip = False #@param {type:"boolean"}
no_vae = False #@param {type:"boolean"}
no_depth = False #@param {type:"boolean"}
no_unet = False #@param {type:"boolean"}

if fp16:
  flpnt16 = "--fp16"
if not fp16:
  flpnt16 = ""

if ema:
  exmovaver = "--ema"
if not ema:
  exmovaver = ""

if no_clip:
  clip = "--no-clip"
if not no_clip:
  clip = ""

if no_vae:
  vae = "--no-vae"
if not no_vae:
  vae = ""

if no_depth:
  depth = "--no-depth"
if not no_depth:
  depth = ""

if no_unet:
  unet = "--no-unet"
if not no_unet:
  unet = ""
print("\033[01;38;05;136mСжатие модели...")
# !python /content/stable-diffusion-prune/prune.py {flpnt16} {exmovaver} {clip} {vae} {depth} {unet} {исходная_модель} {выходная_модель}
print("\033[01;38;05;34mГотово!")
import enum
class SIZE_UNIT(enum.Enum):
   BYTES = 1
   KB = 2
   MB = 3
   GB = 4
def convert_size(size_in_bytes, unit):
   if unit == SIZE_UNIT.KB:
       return size_in_bytes/1024
   elif unit == SIZE_UNIT.MB:
       return size_in_bytes/(1024*1024)
   elif unit == SIZE_UNIT.GB:
       return size_in_bytes/(1024*1024*1024)
   else:
       return size_in_bytes
import os
def get_file_size(file_name, size_type = SIZE_UNIT.BYTES ):
   size = os.path.getsize(file_name)
   return convert_size(size, size_type)
size_in = get_file_size(исходная_модель, SIZE_UNIT.GB)
size_out = get_file_size(выходная_модель, SIZE_UNIT.GB)
print('Размер новой модели:', size_out ,  'Гб!\nА размер исходной:  ', size_in,  'Гб!')

# %%
#@title Конвертор ckpt в safetensors
#@markdown После конвертации модель в новом формате будет лежать рядом с исходной в той же папке. [GUI-вариант](https://github.com/diStyApps/Safe-and-Stable-Ckpt2Safetensors-Conversion-Tool-GUI#downloads) для Windows/Linux.
исходная_ckpt = "/content/sd-v1-4.ckpt" #@param {type:"string"}
from google.colab import output
import os
from os import path

ckpt_name = path.basename(r'$исходная_ckpt')
sfname = path.splitext(исходная_ckpt)[0]

if not os.path.exists("/usr/local/lib/python3.8/dist-packages/safetensors"):
  # !pip -q install safetensors
  output.clear()
else:
  # !sleep 1

if not os.path.exists("/usr/local/lib/python3.8/dist-packages/pytorch_lightning"):
  # !pip -q install pytorch-lightning
  output.clear()
else:
  # !sleep 1

if not os.path.exists("/usr/local/lib/python3.8/dist-packages/torchsde"):
  # !pip -q install torchsde
  output.clear()
else:
  # !sleep 1

if not os.path.exists("/usr/local/lib/python3.8/dist-packages/pandas"):
  # !pip -q install pandas
  output.clear()
else:
  # !sleep 1

print("\033[01;38;05;136mКонвертирую...")
import torch
from safetensors.torch import save_file
weights = torch.load(f"{исходная_ckpt}")["state_dict"]
save_file(weights, f"{sfname}.safetensors")
print("\033[01;38;05;34mГотово!")

# %%
#@title Пакетная конвертация ckpt в safetensors
папка_ckpt = "/content/stable-diffusion-webui/models/Stable-diffusion" #@param {type:"string"}
import os
from google.colab import output
if not os.path.exists("/usr/local/lib/python3.8/dist-packages/safetensors"):
  print("Установка зависимостей...")
  # !pip -q install safetensors
  output.clear()
if not os.path.exists("/usr/local/lib/python3.8/dist-packages/torch"):
  print("Установка зависимостей...")
  # !pip -q install torch
  output.clear()
if not os.path.exists("/usr/local/lib/python3.8/dist-packages/torchsde"):
  print("Установка зависимостей...")
  # !pip -q install torchsde
  output.clear()
if not os.path.exists("/usr/local/lib/python3.8/dist-packages/pytorch_lightning"):
  print("Установка зависимостей...")
  # !pip -q install pytorch_lightning
  output.clear()

import torch
from safetensors.torch import save_file
# %cd {папка_ckpt}
files = os.listdir()
for f in files:
    if f.lower().endswith('.ckpt'):
        print(f'Загружаю {f}...')
        fn = f"{f.replace('.ckpt', '')}.safetensors"

        if fn in files:
            print(f'\033[38;05;136mПропуск, поскольку {fn} уже существует.\033[0m')
            continue
        if "novelai" in fn:
          with torch.no_grad():
                weights = torch.load(f)["state_dict"]
                weights.pop("state_dict")
                fn = f"{f.replace('.ckpt', '')}.safetensors"
                print(f'Пытаюсь сохранить {fn}...')
                save_file(weights, fn)
                print(f'Успешно сохранил {fn}')
                continue
        try:
            with torch.no_grad():
                weights = torch.load(f)["state_dict"]
                fn = f"{f.replace('.ckpt', '')}.safetensors"
                print(f'Сохраняю {fn}...')
                save_file(weights, fn)
        except EOFError:
          print(f'\033[01;38;05;167mФайл {f} поврежден, недокачан, или не является файлом модели!\033[0m')
        except KeyError:
            # !sleep 3
            with torch.no_grad():
                weights = torch.load(f)
                fn = f"{f.replace('.ckpt', '')}.safetensors"
                print(f'Пытаюсь сохранить {fn}...')
                save_file(weights, fn)
        except ValueError:
          # !sleep 3
          print(f'\033[38;05;143mМодель {f} содержит код NovelAI, сейчас колаб крашнется из-за нехватки памяти!\033[0m')
          with torch.no_grad():
                weights = torch.load(f)["state_dict"]
                weights.pop("state_dict")
                fn = f"{f.replace('.ckpt', '')}.safetensors"
                print(f'Пытаюсь сохранить {fn}...')
                save_file(weights, fn)
                print(f'Успешно сохранил {fn}')
        except Exception as ex:
          print(f'\033[01;38;05;167mОшибка конвертации {f}: {ex}\033[0m')

print('\033[38;05;34mГотово!\033[0m')
# %cd /content/

# %% [markdown]
# # Выгрузка моделей на HuggingFace в твой репозиторий

# %%
#@title Выгрузка моделей/файлов до 5 Гб { display-mode: "form" }
HuggingFace_токен = "\u0442\u0432\u043E\u0439 \u0442\u043E\u043A\u0435\u043D" #@param {type:"string"}
источник = "\u0444\u0430\u0439\u043B" #@param ["\u043F\u0430\u043F\u043A\u0430", "\u0444\u0430\u0439\u043B"]
что_загрузить = "/content/\u043A\u0430\u043A\u043E\u0439-\u0442\u043E/\u0444\u0430\u0439\u043B.ckpt" #@param {type:"string"}
репозиторий = "\u044E\u0437\u0435\u0440\u043D\u0435\u0439\u043C/\u0440\u0435\u043F\u043E\u0437\u0438\u0442\u043E\u0440\u0438\u0439" #@param {type:"string"}
#@markdown Токент нужно получить [здесь](https://huggingface.co/settings/tokens). При создании токена нужно указать **Role : Write**. <details><summary>скрин создания токена</summary><img src="https://dl.uploadgram.me/6373ee91cbbe5h?dl" height='300px'></details><br> В качестве источника можно указать путь до одного файла модели, или путь до папки с несколькими файлами - все содержимое папки будет отправленно в указанный репозиторий. В поле "репозиторий" нужно вписать твой юзернейм на HuggingFace и имя репозитория через слеш. Если репозитория еще нет - его <a href='https://huggingface.co/new'>нужно создать</a>, он должен быть публичным, чтобы загружаемые файлы потом были доступны по прямым ссылкам. Если в источнике будет файл недопустимого размера (больше 5 гигов) - загрузка даже не начнется, т.к. от дураков стоит проверка на размер файла, без этого случилось переполнение памяти и крах колаба. Для огромных файлов более 5гб нужно использовать ячейку ниже.  
import os
if not os.path.exists("/usr/local/lib/python3.7/dist-packages/huggingface_hub"):
  from google.colab import output
  # !python -m pip install huggingface_hub
  output.clear()
else:
  # !sleep 1

if not HuggingFace_токен or len(HuggingFace_токен) < 36 or "hf_" not in HuggingFace_токен:
  print("Токен указан неверно. Получить токен можно тут: https://huggingface.co/settings/tokens")
else:
  from huggingface_hub import login
  login(f'{HuggingFace_токен}', add_to_git_credential=True)

# !sleep 1

import enum
class SIZE_UNIT(enum.Enum):
   BYTES = 1
   KB = 2
   MB = 3
   GB = 4
def convert_unit(size_in_bytes, unit):
   if unit == SIZE_UNIT.KB:
       return size_in_bytes/1024
   elif unit == SIZE_UNIT.MB:
       return size_in_bytes/(1024*1024)
   elif unit == SIZE_UNIT.GB:
       return size_in_bytes/(1024*1024*1024)
   else:
       return size_in_bytes
import os
def get_file_size(file_name, size_type = SIZE_UNIT.BYTES ):
   size = os.path.getsize(file_name)
   return convert_unit(size, size_type)
file_path = что_загрузить
size = get_file_size(file_path, SIZE_UNIT.GB)
if size > 4.999:
  print('Размер модели : ', size ,  'Гб!\nЭто очень большой размер для данного метода загрузки.\nВоспользуйся методом в ячейке ниже, он предназначен для загрузки файлов более 5Гб.')
else:
  if not что_загрузить or not репозиторий:
    print("Не указан репозиторий или файл/папка для загрузки")
  if источник == "файл":
    from pathlib import Path
    p = Path(f"{что_загрузить}")
    print(p.name)
    print("жди, идет загрузка...")
    from huggingface_hub import HfApi
    api = HfApi()
    api.upload_file(
        path_or_fileobj=f"{что_загрузить}",
        path_in_repo=(p.name),
        repo_id=f"{репозиторий}",
        repo_type="model",
    )
  elif источник == "папка":
    print("жди, идет загрузка...")
    from huggingface_hub import HfApi
    api = HfApi()
    api.upload_folder(
        folder_path=f"{что_загрузить}",
        repo_id=f"{репозиторий}",
        repo_type="model",
    )

  filename = os.path.basename(f'{что_загрузить}')
  if источник == "папка":
    print(f"загрузка завершена!\nтвои файлы тут: https://huggingface.co/{репозиторий}/tree/main \nпрямые ссылки ищи там вида https://huggingface.co/{репозиторий}/resolve/main/xxx.ckpt ")
  if источник == "файл":
    print(f"загрузка завершена!\nтвои файлы тут: https://huggingface.co/{репозиторий}/tree/main \nпрямая ссылка на модель: https://huggingface.co/{репозиторий}/resolve/main/{filename} ")

# %%
#@title Выгрузка файлов больше 5 гб { display-mode: "form" }
HuggingFace_токен = "\u0442\u0432\u043E\u0439 \u0442\u043E\u043A\u0435\u043D" #@param {type:"string"}
username = "\u044E\u0437\u0435\u0440\u043D\u0435\u0439\u043C"  #@param {type:"string"}
LFS_репозиторий = "\u0440\u0435\u043F\u043E\u0437\u0438\u0442\u043E\u0440\u0438\u0439" #@param {type:"string"}
что_выгружаем = "/content/models/my_biggest_model.ckpt" #@param {type:"string"}
#@markdown можно указать файл или целую папку с файлами. Если это папка - будет загружено все ее содержимое в репозиторий, но не сама папка, если не поставлена опция "сохранить структуру".
сохранить_структуру = False #@param {type:"boolean"}
#@markdown Копировать в папку репозитория или переместить? Перемещение быстрее, но исходные файлы с диска колаба удалятся, переместившись в папку репы. 
файлы_с_диска = "\u043F\u0435\u0440\u0435\u043C\u0435\u0449\u0430\u0435\u043C" #@param ["копируем", "перемещаем"]


import os
if not os.path.exists("/usr/local/lib/python3.7/dist-packages/huggingface_hub"):
  from google.colab import output
  # !python -m pip install huggingface_hub
  output.clear()
else:
  # !sleep 1

if not HuggingFace_токен or len(HuggingFace_токен) < 36 or "hf_" not in HuggingFace_токен:
  print("Токен указан неверно. Получить токен можно тут: https://huggingface.co/settings/tokens")
else:
  from huggingface_hub import login
  login(f'{HuggingFace_токен}', add_to_git_credential=True)

# !sleep 1

#!git lfs install --skip-smudge

# !git -c filter.lfs.smudge= clone https://huggingface.co/{username}/{LFS_репозиторий}

if сохранить_структуру:
  if файлы_с_диска == "копируем":
    # !cp -f -i -R {что_выгружаем} /content/{LFS_репозиторий}
  elif файлы_с_диска == "перемещаем":
    # !mv -f -i {что_выгружаем} /content/{LFS_репозиторий}
if not сохранить_структуру:
  if файлы_с_диска == "копируем":
    # !cp -f -i -R -t /content/{LFS_репозиторий} {что_выгружаем}
  elif файлы_с_диска == "перемещаем":
    # !mv -f -i -t /content/{LFS_репозиторий} {что_выгружаем}

from huggingface_hub import Repository
repo = Repository(local_dir=f"/content/{LFS_репозиторий}")
# !huggingface-cli lfs-enable-largefiles /content/{LFS_репозиторий}

# !sleep 2

#запустить выгрузку
repo.push_to_hub(commit_message="upload with huggingface-cli")
# !sleep 1
print(f"загрузка завершена!\nтвои файлы тут: https://huggingface.co/{username}/{LFS_репозиторий}/tree/main")

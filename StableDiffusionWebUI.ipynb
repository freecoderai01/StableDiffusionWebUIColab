# %% [markdown]
# <!---
# <p align="right"><a href="https://colab.research.google.com/github/PR0LAPSE/StableDiffusionWebUIColab/blob/main/StableDiffusionWebUI.ipynb" target="_blank" rel="nofollow"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="открыть Colab"></a> <a href="https://colab.research.google.com/drive/1TC4SSLncPWytSPvquR6Y4-U7wZRfAXrV" target="_blank" rel="nofollow"><img src="https://github.com/PR0LAPSE/StableDiffusionWebUIColab/raw/main/src/open_gdrive.svg" alt="открыть с гуглодиска"></a> <a href="https://github.com/PR0LAPSE/StableDiffusionWebUIColab/raw/main/StableDiffusionWebUI.ipynb" target="_blank" rel="nofollow"><img src="https://github.com/PR0LAPSE/StableDiffusionWebUIColab/raw/main/src/download_Ipynb.svg?" alt="скачать .ipynb"></a> <a href="https://colab.to/PR0LAPSE/StableDiffusionWebUIColab/StableDiffusionWebUI.ipynb" target="_blank" rel="nofollow"><img src="https://github.com/PR0LAPSE/StableDiffusionWebUIColab/raw/main/src/short_url.svg" alt="короткая ссылка"></a></p>
# --->
# <p><b><font size='3'>Браузерный графический интерфейс для Стабильной Диффузии</font></b></strong> | Основано на <a href="https://github.com/AUTOMATIC1111/stable-diffusion-webui">AUTOMATIC1111</a></p>
#
# <font size="3em">Тут могут помочь:&ensp;<font>
# <sub><a href="https://t.me/stabdiff"><img src="https://telegram.org/img/t_logo.svg" alt="обратная связь в telegram" width="18px"/></a>
# &ensp;
# <a href="https://2ch.hk/ai/"><img src="https://files.catbox.moe/n2obzw.svg" height="18px"/></a></sub>
#
# <hr>
# <!---
# <a href="https://www.google.com/intl/ru/chrome/dev/"><img src="https://files.catbox.moe/hkg6yy.svg" width="330px"></a><br><a href="https://dl.google.com/tag/s/appguid%3D%7B401C381F-E0DE-4B85-8BD8-3F3F14FBDA57%7D%26iid%3D%7BCBBF41EA-4997-3691-E1A6-323A7F02AD44%7D%26lang%3Dru%26browser%3D4%26usagestats%3D0%26appname%3DGoogle%2520Chrome%2520Dev%26needsadmin%3Dprefers%26ap%3D-arch_x64-statsdef_1%26installdataindex%3Dempty/update2/installers/ChromeSetup.exe">win64</a> | <a href="https://dl.google.com/tag/s/appguid%3D%7B401C381F-E0DE-4B85-8BD8-3F3F14FBDA57%7D%26iid%3D%7BCBBF41EA-4997-3691-E1A6-323A7F02AD44%7D%26lang%3Dru%26browser%3D4%26usagestats%3D0%26appname%3DGoogle%2520Chrome%2520Dev%26needsadmin%3Dprefers%26ap%3D-arch_x86-statsdef_1%26installdataindex%3Dempty/update2/installers/ChromeSetup.exe">win32</a> | <a href="https://dl.google.com/linux/direct/google-chrome-unstable_current_amd64.deb">linux (deb)</a> | <a href="https://dl.google.com/dl/linux/direct/google-chrome-unstable_current_x86_64.rpm">linux (rpm)</a> | <a href="https://dl.google.com/chrome/mac/universal/dev/googlechromedev.dmg">macos</a>

# %% [markdown]
# <details>
# <summary><font size='4'><big>👈Cписок изменений</big></font> <small>(нажми чтобы развернуть)</small></summary>
#
# <p>21.02.2023:</p>
# <ol>
# <li>Изменена ячейка установки: все опции и настройки в одном виджете вместе с поиском и множественным выбором моделей.</li>
# <li>Ячейка докачики моделей теперь качает параллельно, в теории - 20 моделей будут качаться как одна. Рандомный баг с размещением модели не в нужную папку тоже исправлен.</li>
# <li>В ячейке перезапуска (впрочем, как и в запуске через ячейку установки) добавлены новые аргументы для старта вебуи: --no-hashing и --opt-channelslast (для "свежей" версии вебуи).</li>
# </ol>
# <p>20.02.2023:</p>
# <ol>
# <li>Добавлена ячейка чтобы разложить по полочкам модели/лоры/внедрения/гиперсети/т.п. на гуглодиске</li>
# </ol>
# <p>16.02.2023:</p>
# <ol>
# <li>Добавлено расширение и отпруненые модели ControlNet.</li>
# </ol>
# <p>07.02.2023:</p>
# <ol>
# <li>Изменена ячейка <a href="#scrollTo=MTex_2fJwYjn">выбора и скачивания нескольких моделей</a>: теперь компактно и наглядно.</li>
# <li>Для совместимости с мобильными устройствами, чтобы браузер не усыплял вкладку с колабом, во время генерации, добавлено бесконечное проигрывание тишины. На мобильном трафике/скорости работы/заряде аккума это никак не отразится. Дектоп-пользователи, не пугайтесь если заметите визуальные симптомы проигрывания звука на вкладке (индикатор громкости и т.п.), звука слышно не будет, но это не позволит усыплять вкладку с колабом.</li>
# </ol>
# <p>03.02.2023:</p>
# <ol>
# <li>Модели разбиты на категории, чтобы было проще ориентироваться.</li>
# <li>Категории и модели отсортированы в алфавитном порядке, чтобы никому не было обидно.</li>
# <li>Удалена ссылка на loca.lt (скорее всего на всегда, надоел) - у них постоянно стал падать сервер.</li>
# </ol>
# <p>02.02.2023:</p>
# <ol>
# <li>Удалена ячейка переобъявления переменных: переменные теперь должны хранится на диске, и не пропадать после крашей.</li>
# <li>Удалена ячейка сброса рантайма ("если что-то пошло не так"), ее функцию выполняет ячейка фикса RAM.</li>
# </ol>
# <p>31.01.2023:</p>
# <ol>
# <p>01.02.2023:</p>
# <ol>
# <li>Добавлены новые аниме-модели из семейства <a href="https://huggingface.co/andite/yohan-diffusion">Yohan Diffusion</a> (скачиваются все при выборе опции): Cocoa, Butter, Latte, Yohan-Diffusion</li>
# <li>"Фикс" пережора памяти немного изменен, и должен убивать любой проблемный процесс</li>
# </ol>
# <p>31.01.2023:</p>
# <ol>
# <li>Обновлен WebUI. Теперь можно всегда выбирать между самой свежей и наиболее проверенной старой версией. В случае проблем с новыми коммитами Автоматика - можно переключиться на старую ветку. Тем не менее по функционалу версии не идентичны.</li>
# <li>Добавлены новые модели апскейла ESRGAN в дефолтную установку (ничего выбирать не нужно).</li>
# <li>Добавлены/обновлены дополнения.</li>
# <li>Добавлена модель Instruct pix2pix и дополнение для работы с ней. Работает строго на отдельной вкладке своего расширения и только в свежих версиях А1111</li>
# <li>Добавлены LORA-модели: PhotoVintage, ArtisticJinskyStyle, SilverjowStyle, Seiji_Shingen_idol-master</li>
# <li>Добавлены в дефолтную установку внедрения для <b>негативных</b> промптов:
# <ul><li>bad_prompt_version2.pt</li>
# <li>bad_quality.pt</li>
# <li>bad-artist.pt</li>
# <li>bad-hands-3.pt</li>
# <li>bad-hands-5.pt</li>
# <li>bad-image.pt</li>
# <li>bad-image-9600.pt</li>
# <li>bad-image-v2-11000.pt</li>
# <li>bad-image-v2-27000.pt</li>
# <li>bad-image-v2-39000.pt</li>
# <li>NegLowRes-2400.pt</li>
# <li>negprompt5.pt</li>
# <li>vile_prompt3.pt</li>
# </ul>
# </li>
# <li>После обновления пока не работает ссылка через гугл, временно убрана</li>
# </ol>
# <p>29.01.2023</p>
# <ol><li>Добавлены новые модели:<ul>
# <li><a href="https://huggingface.co/andite/pastel-mix">PastelMix</a></li>
# <li><a href="https://civitai.com/models/1221/anime-pencil-diffusion">AnimePencil</a></li>
# </ul></li>
# <li>Обновлены/дополнены модели: DreamShaper(обновлен до v3.3.2), GrapefruitHentaiModel(будут скачены все версии), HassanBlend_v1_5_12<ul>
# </ol>
# <p>26.01.2023:</p>
# <ol>
# <li>Фикс ошибки loca.lt "404" при перезапуске</li>
# <li>Добавлена еще одна ссылка - на клаудфлару (т.к. локалт и нгрок в последнее время работают не очень)</li>
# <li>Обновился xformers. Его, кстати можно включить/выключить в любое время, без переустановки - в ячейке переобъявления переменных.</li>
# </ol>
# <p>25.01.2023</p>
# <ol>
# <li>Переделана шапка WebUI: ширина списка выбора моделей уменьшена, добавлен выбор VAE, переключатель комплектных VAE модели, выбор гиперсетей и ползунок их влияния, ползунок Skip Clip, переключатель для отключения вывода картинок в WebUI (полезно, чтобы не зависал наглухо интерфейс при пакетной генерации, например). <b>Все эти быстрые настройки теперь будут не в верху страницы, а внизу.</b></li>
# <li>Все доступные VAE (vae-ft-mse, vae-ft-ema, novelai-vae, kl-f8-anime, kl-f8-anime2, kl-f8-trinart_characters) теперь скачиваются и устанавливаются по дефолту без твоего выбора. Выбрать какую модель VAE использовать или не использовать можно прямо в шапке WebUI</li>
# <li>Модель апскейла LDSR теперь тоже устанавливается без твоего выбора. Времени это занимает 8-14 секунд, в отличии от установки через WebUI с мегабитной скоростью. Пользоваться конечно не обязательно. Модели Lolipop, SwinIR, Nickelback, FoolhardyRemacri, 4xESRGAN - по прежнему скачиваются и могут быть использованы.</li>
# <li>Добавлена новые модели:
# <ul><li>s4w3d0ff_Blend</li>
# <li>GalaxyTimemachines</li>
# <li>GenericFemaleMix</li>
# <li>ColoringBook</li>
# </ul>
# </li>
# <li>Loca.lt вернулся, ссылка на него будет там где и была (стабильность сервиса под вопросом, но вроде работает)</li>
# </ol>
# <p>24.01.2023</p>
# <ol><li>Убраны описания переменных (опций при установке) по максимуму под спойлеры. Желающие могут продолжать чтение, развернув нужный спойлер.</li>
# <li>Прогресс-бар снова отображается при генерации в WebUI</li>
# <li>Темная тема WebUI принудительно по умолчанию (отключить можно в строке браузера)</li>
# <li>Убран Loca.lt, поскольку их сервис - всё (не работают домены и сертификат истек). Возможно это не навсегда.</li>
# <li>Даунгрейд Gradio (v3.9 стабильнее)</li>
# <li>Добавлены новые модели:
# <ul><li>Clarity (+ Inpaiting)</li>
# </ul>
# </li>
# </ol>
# <p>23.01.2023</p>
# <ol><li>Дополнены описания (по возможности) для всех местных моделей</li>
# <li>Вкладка в WebUI с описаниями (возможно потом будет удалена, т.к некрасиво, и муторно дополнять в будущем)</li>
# </ol>
# <p>22.01.2023</p>
# <ol><li>Добавлены новые модели:
# <ul><li>SPYBG_Toolkit</li>
# <li>BstaberElysium_Anime</li>
# </ul>
# </li>
# </ol>
# <p>18.01.2023</p>
# <ol><li>Добавлена новые модели:
# <ul><li>WaifuDiffusion_v1_4 c VAE</li>
# <li>Anything_v4_0 c VAE</li>
# <li>Anything_v4_5 c VAE</li>
# </ul>
# </li>
# </ol>
# <p>17.01.2023</p>
# <ol><li>Модель Anything_v3 дополнена моделью Anything_v3_better_vae</li>
# <li>Добавлены новые модели:<ul>
# <li>MosaicArt v2.1</li>
# <li>vectorArt</li>
# <li>OldJourney</li>
# <li>classicNegative_v2_1</li>
# <li>classicNegative_v1_5</li>
# </ul>
# <li>Исправлена модель AIroticArtsPenis</li></ol>
# <p>16.01.2023</p>
# <ol><li>Добавлены новые модели:<ul>
# <li>artErosAErosATribute_aEros дополнена: artErosAErosATribute_NoVAE-inpainting и artErosAErosATribute_NoVAE</li>
# <li>ProtoGenDragonX59</li>
# <li>ProtoGenInfinityX86</li>
# <li>Babes</li>
# <li>DreamShaper</li>
# <li>Futagen_v2</li>
# <li>DanMumford_Style</li>
# </ul></li></ol>
# <p>15.01.2023</p>
# <ol>
# <li>Добавлен <a href="#scrollTo=i63BG0ZlGNpP">альтернативный</a> прунер</li>
# <li>Добавлены и обновлены модели:</li>
# <ul><li>ATitanStrawBerry</li>
# <li>PFG</li>
# <li>YiffyMix</li>
# <li>Any222Trinart</li>
# <li>ChinaBerry_nofix_f222_v1_4_pt2</li>
# <li>realisticHASDX</li>
# <li>GrapefruitHentaiModelv2_3</li>
# <li>uberrealistic_mix_PFG_URPM_Openjourney</li>
# <li>Radiant_v3</li>
# <li>PowerfulMix_v2</li>
# <li>Дополнены все OrangeMix:
#   <ul>
# 	<li>AbyssOrangeMix</li>
# 	<li>AbyssOrangeMix2</li>
# 	<li>BloodOrangeMix</li>
# 	<li>EerieOrangeMix</li>
# 	<li>EerieOrangeMix2</li>
# 	<li>ElyOrangeMix</li>
# 	<li>OrangeMixs_All (скачает все 22 оранжмикса в папку моделей, около 45Гб)</li></li>
#   </ul>
# </ul></ol>
# <p>14.01.2023</p>
# <ol>
# <li>Добавлена <a href="#scrollTo=wsUrVIhnstui">ячейка</a> обратного конвертора из safetensors в старый формат ckpt. Это требуется для прунинга, поскольку сейфтензорс его напрямую не поддерживает, конвертируем его в ckpt, <a href="#scrollTo=heHty0pzVYjw">пруним</a>, <a href="#scrollTo=QuW09EK-mIvg">конвертируем обратно</a> в сейфтензорс.</li>
# <li>Добавлена <a href="#scrollTo=w_29ofOEGng_">ячейка</a> перемонтирования/размнонтирования гуглодиска. Нужна, если решил покачать модели на гуглодиск или что-то перекинуть, но забыл поставить галочку в ячейке установки. Размонтирование полезно, когда в папке гуглодиска внутри колаба файлы видны, но на самом гуглодиске они не появляются или возникают любые другие ошибки с файловыми операциями через гуглодиск (например, когда качал напрямую много крупных файлов). Размонтирование сбрасывает кэш гуглодиска в колабе. Однако, монтирование из этой ячейки не применяет настроек для сохранения генерируемых картинок на гуглодиск и пути до папки с моделями! Это нужно делать только во время установки (или изменить настройки/аргументы запуска вручную и перезапустить вебинтерфейс).</li>
# <li>Улучшен <a href="#scrollTo=heHty0pzVYjw">прунер</a> моделек, теперь можно сразу прунить и конвертировать в сейфтензорс, а исходные толстые ckpt будут удаляться(опционально). Прунер конвертирует как папками так и поштучно.</li>
# <li>Добавлены 24 новые модели (всего 124 не считая дополнительных):
# <ul>
# <li>AbyssOrangeMix2_hard</li>
# <li>AbyssOrangeMix2_nsfw</li>
# <li>Creepy_Diffusion</li>
# <li>PostApocalypse_v1</li>
# <li>img2img_PaintingGenerator</li>
# <li>protogenNovaX80</li>
# <li>vintedois-diffusion-v01</li>
# <li>macroDiffusion_10</li>
# <li>reonArgondiansStyle</li>
# <li>woopwoopPhoto_12 (может содержать ♂️)</li>
# <li>RPG_v2 (<a href="https://huggingface.co/Anashel/rpg/resolve/main/RPG-Guide-v2.1.pdf">руководство пользователя</a>)</li>
# <li>Plat_v1_3</li>
# <li>_8528Diffusion_final_v05</li>
# <li>Timeless_v1</li>
# <li>ModelShoot_v1</li>
# <li>Wavy_fusion_v1</li>
# <li>Portrait_Plus</li>
# <li>DaddyDiffusion_v1 (♂️)</li>
# <li>Homoerotic_v2 (♂️)</li>
# <li>TwinkDiffusion_v2 (♂️)</li>
# <li>AIroticArtsPenis (♂️)</li>
# <li>некоторые из представленных моделей могут и будут пропагандировать гомосексуализм</li>
# </ul>
# </ol>
# <p>13.01.2023</p>
# <ol>
# <li>Мелкие фиксы: проверка путей и ссылок в ячейке загрузки нескольких моделей, альтернативный вход в случае ошибки в ячейке выгрузки моделей на huggingface, добавлена конвертация на CPU для safetensors если на GPU выходит ошибка.</li>
# <li>Модель апскейла LDSR заменена на новый формат</li>
# <li>Новые модели, ссылки на которые ты прислал:</li>
# <ul>
# <li>SynthwavePunk_v2</li>
# <li>Protogen_X53_Photorealism</li>
# <li>uberRealisticPornMer_urpMv12 со своей inpaiting-моделью (обновление с v11)</li>
# </ul>
# </ol>
# <p>12.01.2023:</p>
# <ol>
# <li>В основм мелкие фиксы (для гуглодиска, скачивания моделей, проверку путей)</li>
# <li>Обновлена и дополнена русская локализация ВебУИ. Пожалуйста, больше не тащите мою локализацию на гитхабы. Все что тут в колабе - чисто для анонов, а не для всех этих прочих.</li>
# <li>В новом интерфейсе (который ставился до этого с xformers) возвращен внешний вид сэмплеров и пакетной генерации как в старом интерфейсе.</li>
# <li>Ngrok должен снова работать. Вариант с xformers использует более свежие зависимости - там проблем быть не должно, без xformers ставится более старый gradio (он влияет и на ngrok) - по первым тестам вроде работает. Если вдруг когда-то перестанет работать генерация - просто используйте ссылку на Gradio. Localt - работает плохо.</li>
# </ol>
# <p>11.01.2023:</p>
# <ol>
# <li>Обновлены, подвергнуты пруну, перекодированы все модели. Теперь загрузка должна быть быстрее.</li>
# <li>Попытка пофиксить баги в следсвии сырых обнов автоматика1111 (и судя по нерабочим переменным - колаба)</li>
# <li>Версия с xformers ставится с откатом на вчерашний коммит 50fb20c</li>
# <li>Ngrok и Loca.lt пока не работают, Gradio - работает штатно.</li>
# </ol>
# <p>09.01.2023:</p>
# <ol>
# <li>Для тех кто не подключает гуглодиск по тем или иным причинам, переработана <a href="#scrollTo=V-2LlLHZPgoB">ячейка скачивания архива</a> сгенерированных картинок: теперь архив можно не только скачать средсвами колаба(что бывает мучительно), но и быстро получить ссылку на скачивание с сервера anonfiles(или одного из его аналогичных саттелитов). И по мелочи: архив создается с нормальным именем формата <code>SD_полная-дата_текущее-время.zip</code>.</li>
# <li>Добавлена <a href="#scrollTo=k98WImeXH5pK">ячейка распаковки архивов</a>. Полезно при работе с паками картинок, внедрений, моделей апскела, и чего угодно. Поддерживаются все форматы архивов, за исключением совсем уж редко встречающихся (arc, liz, zst..)</li>
# <li>Добавлена <a href="#scrollTo=ZsbbtJSUSdJ9">ячейка запаковки</a> произвольных папок/файлов в архив, который потом можно закинуть на гуглодиск, или выгрузить на обменник.</li>
# <li>Для этого добавлена <a href="#scrollTo=zVmDZeIAIcja">ячейка выгрузки</a> произвольных файлов на обменники, внизу указаны лимиты на размеры файлов для каждого. Catbox.moe часто говнится, запрещая api-запросы с ip колаба, надежнее использовать Pixeldrain, Gofiles, Transfer.sh и т.п. Модели по прежнему лучше выгружать через <a href="#scrollTo=j7N-__N4f9uY">ячейку для huggingface</a>, который дает прямые ссылки и не ограничивает размер и время хранения.</li>
# <li>Починена загрузка по кастомной ссылке в ячейке выбора нескольких моделей.</li>
# </ol>
# <p>08.01.2023:</p>
# <ol>
# <li>Добавлена опция подгрузки твоих моделей с гуглодиска, использование моделей только с гуглодиска, и скачивание моделей в свой гуглодиск. Отмечая соответствующие галочки, ты можешь пропустить скачивание моделей в колаб, а использовать свою коллекцию на гуглодиске. Если укажешь неправильный путь до папки с моделями на гуглодиске, будет использован дефолный путь до моделек, будь внимателен.</li>
# <li>Добавлена <a href="#scrollTo=14ZlsjXHUD4I">ячейка</a> переобъявления важных для запуска переменных, чтобы не начинать все сначала когда колаб крашнулся или после <a href ="#scrollTo=v2EGkiE4wsY-">сброса</a>.</li>
# <li>Добавлена <a href="#scrollTo=62QDyjXtYHjF">ячейка</a> удобной загрузки моделек с civitai.com, достаточно указать ссылку на страницу с моделью и папку куда грузить. Поддерживаются NSFW-модели. Если указана неверная папка или она не существует, модель загрузится в папку моделей SD WebUI по умолчанию: <code>/content/stable-diffusion-webui/models/Stable-diffusion</code></li>
# <li>Подправлена ячейка прунинга моделей, теперь есть пакетная обработка и автонейминг выходных файлов.</li>
# <li>Подправлена ячейка выгрузки на huggingface (вариант до 5Гб): если была пакетная выгрузка, в конце отобразятся прямые ссылки на все файлы.</li>
# <li>По твоей рекомендации добавлены новые модели (всего на сегодня их 100 штук [не считая допов типа inpaiting для 1.5 и 2.1]):
# <ul>
# <li>HassanBlend1.5</li>
# <li>BackgroundsDiffusion</li>
# <li>BerryCandy20_v2 (<a href ="https://mega.nz/folder/FlJAmZxb#-157b8UA9DlmF-YIfXKgvA">подробнее</a>)</li>
# <li>aloeVeraSSimpMaker3K_simpMaker3K1</li>
# <li>artErosAErosATribute_aEros</li>
# <li>dreamlikediffusion</li>
# <li>epicDiffusion</li>
# <li>uberRealisticPornMer_urpMv11</li>
# </ul>
# </li>
# </ol>
# <p>07.01.2023:</p>
# <ol>
# <li>Добавлены модели v2.1 (v2.0 ставить не стал). Для работы SDv2.1 нужен xformers, так что галочку с него не снимаем! Версия 768px имеет нативное разрешение 768х768, так что ставить меньше (например 512) - не нужно (будет жмыхнутое мыло). После запуска сам руками в левом верхнем углу WebUI выбери модель для генерации, по дефолту может подхватится модель inpaiting (ее нужно выбирать для вкладки изо-в-изо). Поскольку поддержка новых версий теперь реализована нормально, то можешь собирать и присылать модели и миксы на базе v2(.1)</li>
# <li>По твоему совету добавлены новые модели:
# <ul>
# <li>dreamlikePhotoRealV2</li>
# <li>HASDX</li>
# <li>elldrethSLucidMix_v10</li>
# <li>hAS3Dkx11_3Dkx11</li>
# <li>RealEldenApocalypse_AnalogSexKnoll_4CandyPureSimp+FEET</li>
# <li>protogenX3_4</li>
# </ul>
# </li>
# </ol>
# <p>06.01.2023:</p>
# <ol>
# <li>Отправка сгенерированных картинок на другие вкладки(изо-в-изо, апскейл, и т.д.) снова работают</li>
# <li>Объединение установки, подключения гуглодиска и запуска в одну ячейку. Теперь нужно поставить нужные галочки и нажать один раз запуск. По завершению установки - будет аудиоуведомление, перед запускам WebUI - тоже. Можно запустить и идти пить чай.</li>
# <li>По твоей просьбе добавлены новые модели:
# <ul>
# <li>analog-diffusion</li>
# <li>Protogen_x5.8_Rebuilt</li>
# <li>protogenV22Anime_22</li>
# <li>BloodNightOrangeMix</li>
# <li>ElyOrangeMix</li>
# <li>AbyssOrangeMix</li>
# <li>MMDv1-18</li>
# </ul>
# </li>
# <li>Добавлена <a href="#scrollTo=3yZXlc_hvzAF">ячейка</a> для пакетной конвертации в safetensors (NovelAI и некоторые модели на ее основе вызывают переполнение всей RAM)</li>
# <li>Автоматика разбанили на жидхабе, откат на старый репозиторий</li>
# </ol>
# <p>05.01.2023:</p>
# <ol>
# <li>Добавлена <a href="#scrollTo=otsDSY8bCdVN">ячейка</a> для прунинга больших моделей с целью уменьшения их размера</li>
# <li>Добавлена <a href="#scrollTo=QuW09EK-mIvg">ячейка</a> для конвертации ckpt в новый формат моделей safetensors</li>
# <li>Модель Anything_Berrymix.ckpt (7.2 Гб) заменена на Anything_Berrymix-pruned.ckpt (3.85 Гб)</li>
# <li>В связи с баном Автоматика1111 на жидхабе, переезд на <a href="https://gitgud.io/AUTOMATIC1111/stable-diffusion-webui.git">новую</a> репу (новый хостинг очень медленный, установка будет дольше), и откат на <a href="https://web.archive.org/web/20230101173248if_/https://codeload.github.com/AUTOMATIC1111/stable-diffusion-webui/zip/refs/heads/master">архив</a> репозитория за 01.01 (для варианта без xformers)</li>
# <li>В связи с баном аккаунта Автоматик1111, отвалились и пока не восстановились следующие дополнения:<br />эстетичные градиенты <a href="https://github.com/AUTOMATIC1111/stable-diffusion-webui-aesthetic-gradients">https://github.com/AUTOMATIC1111/stable-diffusion-webui-aesthetic-gradients</a>;<br />подстановочные знаки <a href="https://github.com/AUTOMATIC1111/stable-diffusion-webui-wildcards">https://github.com/AUTOMATIC1111/stable-diffusion-webui-wildcards</a>;<br />просмтор токенизации промпта <a href="https://github.com/AUTOMATIC1111/stable-diffusion-webui-tokenizer">https://github.com/AUTOMATIC1111/stable-diffusion-webui-tokenizer</a>;<br />каталог расширений и установка из вебинтерфейса, естественно тоже уничтожены.</li>
# <li>обновлены некоторые преинсталированные <a href="https://huggingface.co/utnah/LDSR/blob/main/zavisimosti">зависимости</a> для варианта с xformers</li>
# </ol>
# <p>04.01.2023:</p>
# <ol>
# <li>фикс для gradio</li>
# <li>откат webui на состояние 02.01</li>
# <li>ускоритель Xformers снова работает<sup>*</sup><br /><sup>*</sup><small>учитывай, что с ним могут конфликтовать какие-то дополнения, а так же увеличивается энтропия.</small></li>
# </ol>
# <p>24.09.2022</p>
# <ol><li>Начало</li></ol>
# </details>

# %% [markdown]
# <!---
#
#
# ---
#
# <details>
#   <summary><big>👈 <font color='#d23434'>Внимание! В последнее время участились баны аккаунтов</font></big> (нажми чтобы развернуть)</summary>
# <p>По словам реддиторов и некотоых анонов, последнее время участились баны аккаунтов из-за «злоупотреблений» колабом.<br>Причины? - Диффузоры зaeбaли гугл генерацией своих картинок круглосуточно терабайтами.<br>Попытаться этого избежать можно:<br>
# • не запускать несколько копий колаба одновременно под разными учётками с одного IP.<br>
# • не генерировать NSFW с глубоко допубертатными лолями младенческого возраста(младенец - до 7 лет, если что), свастоны и прочую неодобрительную символику и контент (гугл не только проверяет картинки, но и читает названия файлов - в котором твой промпт),<br>
# • при смене аккаунта помнить, что гугл может читать не только куки и IP, но и локалсторадж, и прочие отпечатоки браузера(временную зону ПК, id установленных расширений браузера и т.д.) - так что детектить тебя не составляет труда во всех твоих фейках;<br><font size='3' color='#e8630b'>ВАЖНО: при любом раскладе Гугл не отправляет досье на тебя в ближайше от твоего дома отделение полиции, можешь расслабиться.</font><p>
# Тут можно посоветовать использовать отдельный браузер, который всегда работает в режиме инкогнито и ничего не сохраняет после закрытия, vpn, блокировщики canvas/dom или иные расширения для спуффинга отпечатков браузера.</p><p>Если не планируется генерация Гитлера в окружении СС-цев, совокупляющихся с нагими младенцами - то без задней мысли подключай гуглодиск и смело генерируй свое аниме и копродедов.</p><hr>
# </details>
# --->
#
# <!---
# <b>Слишком много букав и кнопочек?</b> [Попробуй упрощенную версию](https://colab.research.google.com/drive/1xspncncuwztQYt7GXj9Kavp1ql6p3mng#scrollTo=jnXUwtACCHOy) или [эту версию](https://colab.research.google.com/drive/1kfwm6YK_kY5aLf_nX1iM_RujS94a7W7C#scrollTo=dNaggHpybFoQ)
# -->
# <a href="https://rentry.org/SD_guide_by_Kuroi_Mato_O"><!--<img src="https://files.catbox.moe/3ihq4v.svg" /><img src="https://files.catbox.moe/vupl39.svg" /><img src="https://files.catbox.moe/rcan0a.svg" />--><img src="https://files.catbox.moe/6ce3mj.svg" /></a>
# <details>
#    <summary><big><big>👈 <font color='#e14f4f'>Как пользоваться</font></big></big> (это спойлер, нажми на меня чтобы развернуть) </summary>
#   <!-- <summary><big><big>👈</big></big><img src='https://files.catbox.moe/959qv0.png' height="16em" />(это спойлер, нажми на меня чтобы развернуть) </summary>--->
# <sup><sup><b><big><big>Чтобы запусть ячейку нужно нажать вот такую кнопочку &#160;&#160;&#160;&#160;&#160;</big></big></b></sup></sup><img src="https://files.catbox.moe/mvz8ke.svg" width="70px"/><br><img src="https://files.catbox.moe/5y3iw3.svg" width="360px"/>
#
#
# <blockquote>
# Во-первых - читай внимательно все что написано, Во-вторых, в ячейке установки и запуска - установи нужные тебе галочки и выбери нужную модель, все параметры подписаны и пояснены, главное прочитай буковки. Один раз сделаешь - второй уже на автомате. Если планируешь использовать сразу несколько моделей, сними галочку &quot;запустить_сразу&quot;, проскроль до ячейки с выбором нескольких моделей, скачай нужные, и потом запусти WebUI из ячейки запуска/перезапуска
# </blockquote>
#
#
#
#
#
#
# <blockquote>
# <p>В конце вывода ячейки запуска читай внимательно текст, ищи там ссылку вида типа:<br><code>https://0bf89138a7c4877f.gradio.app/</code> или для Ngrok: <code>http://e402-34-126-159-209.ngrok.io</code> и переходи по ней, нажимай кнопку &quot;Visit site&quot;. Так же будет ссылка типа <code>cool-brooms-admire-23-251-149-142.loca.lt</code>. <em>См. скриншот:</em></p>
# </blockquote>
#
# <big><font color='#FF4500'>Скриншот где искать ссылки: </font></big>
#   <img src="https://files.catbox.moe/wrq2pc.svg">
#
# <p>Все три ссылки - это один и тот же WebUI, который просто тунеллируется с локального ip колаба до твоего браузера с помощью реверсивных прокси от этих трех провайдеров.</p>
# <p>Можешь поработать через Ngrok и Gradio и LocalIT, посмотреть что будет стабильнее для тебя. Для Ngrok нужен свой личный токен, <a href="https://ngrok.com/signup">зарегистрируйся</a> у них на сайте и получи свой <a href="https://dashboard.ngrok.com/get-started/your-authtoken">тoкен</a> (никому его не давай и не показывай, иначе по нему можно будет зайти в твой WebUI). Если своего токена у тебя нет - будет попытка использовать общественный, что конечно не очень надежно, поэтому потрать 15 секунд и заведи свой, это бесплатно.</p>
# <p>Имхо, проще сразу создавать картинки прямо на гуглодиске, а не сохранять по одной. Впрочем, это не обязательно, тогда и доступ к диску колабу можешь не давать. Если не подключаешь гуглодиск, внизу есть ячейка для скачивания картинок архивом.</p>
# <p>Если завис ВебУИ - презагружай вкладку с ним (не эту, не с колабом!) или перезапускай, бывает отваливается gradio, у некоторых стабильнее работает ngrok.io. Повлиять на отвалы/зависания реверсивных прокси-туннелей со стороны этого колаба нельзя (в основном, все проблемы с ними - чисто сетевые проблемы).</p>
#
# <blockquote><p>
# В случае ошибок, останавливай ячейку и перезапускай снова, если это не помогло - выполни ниже ячейку &quot;фикс утечки памяти | <a href="#scrollTo=lSrj3ztA60Eh">перезапуск среды выполнения</a>&quot; и запускай снова ячейку запуска WebUI. Если проблема не решается, выполни ячейку &quot;<a href="#scrollTo=WVZzS4nAhy77">удалить и сбросить среду выполнения</a>&quot;, и перезагружай эту страницу (жесткая перезгрузка: <code>Ctrl+Shift+R</code>) или <code>Shift+F5</code>. Если ничего не помогает - попробуй написать <a href="https://t.me/colabSDbot">боту</a>, <b>но обязательно прикрепи скриншот ошибки или текстом вывод ячейки с ошибкой</b>.</p>
# </blockquote>
#
# <b>По умолчанию, вместе с моделями устанавливаются несколько VAE, которые доступны в низу WebUI в выпадающем списке.</b><br>
# VAE - тонко настроенный вариационный автоэнкодер, немного улучшает качество генерации, особенно гамму, по дефолту идет при установке стандартной SD модели, но может быть полезен для других моделей на ее основе, например, сделанных через Dreambooth (а это большинство самопальных моделек, которые не создавались через нативное обучение).<br><font color='#0aa93f'><b>Обрати внимание, что в данном случае VAE автоматически не подхватятся при запуске, в отличии от тех, которые идут со своими моделями. Эти VAE нужно выбирать самостоятельно</font></b>
#
# По умолчанию скачивается модель апскейла LDSR, а также модели для ESRGAN, а именно: Lolipop, SwinIR, Nickelback, FoolhardyRemacri, 4xESRGAN и немного других, которые могут подтянуться автоматически. Все эти апскейлеры достпупны на странице настроек и на странице апскейла/исправления лиц.
#
# <hr>
# <h3>Плезные горячие клавиши:<h3>
#
# <code>Ctrl+M+.</code> перезапустить среду выполнения
#
# <code>Ctrl+Shift+Enter</code> запустить только выделенный код (полезно чтобы не выполнять всю ячейку)
#
# <code>Ctrl+Shift+R</code> - перезагрузить страницу, сбросив кэши
#
# Другие горячие клавиши (можно назначить самому): <code>Ctrl+M+H</code>
#
#
# <b>Выше была преамбула, непосредственно работа начинается с ячейки <code>Установка зависимостей и моделей | Подключение гуглодиска | Запуск</code> ниже.</b>
# </details>
#
# <br>
# <img src="https://telegram.org/img/t_logo.svg" alt="обратная связь в telegram" width="26"/>&ensp;<big><big><sup> <a href="https://t.me/colabSDbot"> сообщить об ошибке боту</a> <small><small><font color='#808080'>(делай скриншот ошибки)</font></small></small></sup></big></big><hr>

# %% [markdown]
# <details><summary><a href="https://openuserjs.org/scripts/Kuroi_mato_O/fixed_TOC_for_colab">Юзерскрипт для быстрой навигации</a></summary><img src="https://files.catbox.moe/qawiz8.png"></details>
# <br/>
#
# <details>
#   <summary><font size="3">JS-коды для консоли браузера, которые будут автоматически нажимать кнопку повторного подключения при бездействии.</summary>
# <p>Открывай консоль разработчика в браузере (Ctrl+Shift+J - хромиумподобные или Ctrl+Shift+K - фаерфоксоподобные):
# <img src="https://telegra.ph/file/fc25b681ea1900e042919.png" />
# код можно скопировать, заменить 60000 на 120 для проверки и нажать Enter, если увидишь что кнопка быстро нажимается - код рабочий, обновляй страницу и используй код без изменений:</p>
# <pre>
# function ClickConnect() {
#   console.log('Working')
#   document
#     .querySelector('#top-toolbar > colab-connect-button')
#     .shadowRoot.querySelector('#connect')
#     .click()
# }
#
# setInterval(ClickConnect, 60000)
# </pre>
# <pre>
# function ClickConnect(){
#     console.log("Working");
#     document.querySelector("colab-toolbar-button#connect").click()
# }
# setInterval(ClickConnect,60000)
# </pre>
# <pre>
# function ClickConnect(){
#   console.log("Connnect Clicked - Start");
#   document.querySelector("#top-toolbar > colab-connect-button").shadowRoot.querySelector("#connect").click();
#   console.log("Connnect Clicked - End");
# };
# setInterval(ClickConnect, 60000)
# </pre>
# <pre>
# function ClickConnect(){
#     console.log("Working");
#     document.querySelector("colab-connect-button").click()
# }
# setInterval(ClickConnect,60000)
# </pre>
# <pre>
#  function ClickConnect(){
#    btn = document.querySelector("colab-toolbar-button")
#    if (btn != null){
#      console.log("Clicked on the connect button");
#      btn.click()
#      }
#
#    btn = document.getElementById('connect')
#    if (btn != null){
#      console.log("Clicked on the reconnect button");
#      btn.click()
#      }
#   }
#
# setInterval(ClickConnect,60000)
# </pre>
# К сожалению, напрямую из колаба уже не работают. Работают из консоли до сих пор нормально, а так же из них можно сделать user.js. Если перестали работать, значит гугл переименовал  id кнопки, зайди в исходный код страницы и подсмотри новый id, обнови id в скрипте.
# </details>
# <br/>
# <details><summary>быстрые ссылки</summary>
# <ul>
# <li><a href="#scrollTo=10iWu8h1UTvQ">установка и запуск</a></li>
# <li><a href="#scrollTo=MTex_2fJwYjn">выбор и установка нескольких моделей</a></li>
# <li><a href="#scrollTo=R-xAdMA5wxXd">запуск/перезапуск</a></li>
# <li><a href="#scrollTo=V-2LlLHZPgoB">скачивание архива с картинками</a></li>
# <li><a href="#scrollTo=w_29ofOEGng_">подключение/переподключение/сброс кэша гуглодиска</a></li>
# <li><a href="#scrollTo=TuwHDqutjgZd">массовая загрузка по прямым ссылкам</a></li>
# <li><a href="#scrollTo=62QDyjXtYHjF">загрузчик моделей с civitai.com</a></li>
# <li><a href="#scrollTo=VirGjpcNCCKX">скачивание с торрентов</a></li>
# <li><a href="#scrollTo=heHty0pzVYjw">прунинг и конвертация моделей</a></li>
# <li><a href="#scrollTo=j7N-__N4f9uY">выгрузка моделей на HuggingFace</a></li>
# <li><a href="#scrollTo=zVmDZeIAIcja">выгрузка на файлообменники</a></li>
# <li><a href="#scrollTo=k98WImeXH5pK">запаковка/распаковка архивов</a></li>
# <li><a href="#scrollTo=Oh37kTko2shA">операции с папками/файлами/симлинками</a></li>
# </ul></details>

# %%
#@title 🆑 удалить и сбросить среду выполнения { display-mode: "form" }
#@markdown <sup>◀=| нажать кнопку самоуничтожения
from google.colab import runtime
runtime.unassign()

# %%
#@title 📁 Файловый менеджер { display-mode: "form" }
import os
import os.path
if not os.path.exists("/usr/local/lib/python3.8/dist-packages/imjoy_elfinder"):
  # !pip -q install imjoy-elfinder
from IPython.display import HTML
import threading
from google.colab import output
from imjoy_elfinder.app import main
from IPython.display import clear_output
from google.colab.output import serve_kernel_port_as_window
from google.colab.output import eval_js
output.clear()
threading.Thread(target=main, args=[["--root-dir=/content", "--port=8765"]]).start()
#output.serve_kernel_port_as_iframe(8765, height='620')
#google.colab.serve_kernel_port_as_window(8765)
# !sleep 1
output.clear()
flink = eval_js( "google.colab.kernel.proxyPort(" + str(8765) + ")" )
display(HTML(f'<a href="{flink}" target="_blank" style="text-decoration:none;"><h2 style="color: #c06f0e;">📁ссылка на файловый менеджер<h2></a>'))

# %%
#@title <img src='https://files.catbox.moe/3uju7d.svg' height='30px'> фикс утечки памяти | перезапуск среды выполнения { display-mode: "form" }
#@markdown <sup>◀=| нажать
import os
import os.path
if os.path.exists("/content/stable-diffusion-webui"):
  print("\033[1;31mВНИМАНИЕ!\nПосле выполнения этой ячейки произойдет перезапуск среды выполнения!\n\033[1;34m")
else:
  print("\033[1;36mПосле выполнения этой ячейки произойдет перезапуск среды выполнения.")

#!for pid in $(ps -ef | grep -v "awk" | awk '/ipykernel_launcher/ {print $2}'); do kill -9 $pid; done
# !sleep 5
# !kill $(ps aux | sort -rnk 4 | awk 'NR>1{print $2; exit}')
exit()

# %%
#@title <img height="20px" src="https://kstatic.googleusercontent.com/files/d57b24106c34c7e50ef3d98423b94ddaf35ad2da73a9b9d4d12f52dbb9dd4c08c2957f6255ab8690d5ef0b32cff8287e09577d05e479d263e872160c4c9e8363"> перенос моделей СД, внедрений, гиперсетей, НиРа, ВАЭ, моделей апскейлеров и т.п. { display-mode: "form" }
#@markdown <details><summary>как это должно выглядеть</summary><img width="350px" src="https://files.catbox.moe/sdm9mi.png"></details>
import os
import os.path
import glob
import shutil
import ipywidgets as widgets
import requests
from IPython.display import display, HTML, clear_output
from google.colab import drive

sdmodels = widgets.Checkbox(value=False, description='Stable-diffusion').add_class("sdmodels")
sdmodels_path = widgets.Text(value="", placeholder='путь до папки с моделями на гуглодиске').add_class("sdmodels_path")
sd_item = widgets.HBox([sdmodels, sdmodels_path]).add_class("item")
def sdmodels_check(change):
  if sdmodels.value == True:
    sdmodels_path.layout.display = 'flex'
  if sdmodels.value == False:
    sdmodels_path.layout.display = 'none'
    sdmodels_path.value = ''
sdmodels_path.layout.display = 'none'
sdmodels.observe(sdmodels_check, names='value')

vaemodels = widgets.Checkbox(value=False, description='VAE').add_class("vaemodels")
vaemodels_path = widgets.Text(value="", placeholder='путь до папки с VAE на гуглодиске').add_class("vaemodels_path")
vae_item = widgets.HBox([vaemodels, vaemodels_path]).add_class("item")
def vaemodels_check(change):
  if vaemodels.value == True:
    vaemodels_path.layout.display = 'flex'
  if vaemodels.value == False:
    vaemodels_path.layout.display = 'none'
    vaemodels_path.value = ''
vaemodels_path.layout.display = 'none'
vaemodels.observe(vaemodels_check, names='value')

embeddingsmodels = widgets.Checkbox(value=False, description='внедрения').add_class("embeddingsmodels")
embeddingsmodels_path = widgets.Text(value="", placeholder='путь до папки с embeddings на гуглодиске').add_class("embeddingsmodels_path")
embeddings_item = widgets.HBox([embeddingsmodels, embeddingsmodels_path]).add_class("item")
def embeddingsmodels_check(change):
  if embeddingsmodels.value == True:
    embeddingsmodels_path.layout.display = 'flex'
  if embeddingsmodels.value == False:
    embeddingsmodels_path.layout.display = 'none'
    embeddingsmodels_path.value = ''
embeddingsmodels_path.layout.display = 'none'
embeddingsmodels.observe(embeddingsmodels_check, names='value')

hypernetworksmodels = widgets.Checkbox(value=False, description='гиперсети').add_class("hypernetworksmodels")
hypernetworksmodels_path = widgets.Text(value="", placeholder='путь до папки с hypernetworks на гуглодиске').add_class("hypernetworksmodels_path")
hypernetworks_item = widgets.HBox([hypernetworksmodels, hypernetworksmodels_path]).add_class("item")
def hypernetworksmodels_check(change):
  if hypernetworksmodels.value == True:
    hypernetworksmodels_path.layout.display = 'flex'
  if hypernetworksmodels.value == False:
    hypernetworksmodels_path.layout.display = 'none'
    hypernetworksmodels_path.value = ''
hypernetworksmodels_path.layout.display = 'none'
hypernetworksmodels.observe(hypernetworksmodels_check, names='value')

loramodels = widgets.Checkbox(value=False, description='LORA').add_class("loramodels")
loramodels_path = widgets.Text(value="", placeholder='путь до папки с LORA на гуглодиске').add_class("loramodels_path")
lora_item = widgets.HBox([loramodels, loramodels_path]).add_class("item")
def loramodels_check(change):
  if loramodels.value == True:
    loramodels_path.layout.display = 'flex'
  if loramodels.value == False:
    loramodels_path.layout.display = 'none'
    loramodels_path.value = ''
loramodels_path.layout.display = 'none'
loramodels.observe(loramodels_check, names='value')

esrganmodels = widgets.Checkbox(value=False, description='ESRGAN').add_class("esrganmodels")
esrganmodels_path = widgets.Text(value="", placeholder='путь до папки с ESRGAN на гуглодиске').add_class("esrganmodels_path")
esrgan_item = widgets.HBox([esrganmodels, esrganmodels_path]).add_class("item")
def esrganmodels_check(change):
  if esrganmodels.value == True:
    esrganmodels_path.layout.display = 'flex'
  if esrganmodels.value == False:
    esrganmodels_path.layout.display = 'none'
    esrganmodels_path.value = ''
esrganmodels_path.layout.display = 'none'
esrganmodels.observe(esrganmodels_check, names='value')

realesrganmodels = widgets.Checkbox(value=False, description='RealESRGAN').add_class("realesrganmodels")
realesrganmodels_path = widgets.Text(value="", placeholder='путь до папки с RealESRGAN на гуглодиске').add_class("realesrganmodels_path")
realesrgan_item = widgets.HBox([realesrganmodels, realesrganmodels_path]).add_class("item")
def realesrganmodels_check(change):
  if realesrganmodels.value == True:
    realesrganmodels_path.layout.display = 'flex'
  if realesrganmodels.value == False:
    realesrganmodels_path.layout.display = 'none'
    realesrganmodels_path.value = ''
realesrganmodels_path.layout.display = 'none'
realesrganmodels.observe(realesrganmodels_check, names='value')

swinirmodels = widgets.Checkbox(value=False, description='SwinIR').add_class("swinirmodels")
swinirmodels_path = widgets.Text(value="", placeholder='путь до папки с SwinIR на гуглодиске').add_class("swinirmodels_path")
swinir_item = widgets.HBox([swinirmodels, swinirmodels_path]).add_class("item")
def swinirmodels_check(change):
  if swinirmodels.value == True:
    swinirmodels_path.layout.display = 'flex'
  if swinirmodels.value == False:
    swinirmodels_path.layout.display = 'none'
    swinirmodels_path.value = ''
swinirmodels_path.layout.display = 'none'
swinirmodels.observe(swinirmodels_check, names='value')

run = widgets.Button(description='переместить ❯', button_style='success').add_class("run")

def run_button_click(b):
  clear_output()
  if not os.path.exists('/content/gdrive/MyDrive/'):
    try:
      drive.mount('/content/drive', force_remount=True)
    except:
      print(f'\033[1;31mпользователь отменил подключение гуглодиска\033[0m')
  if os.path.exists('/content/gdrive/MyDrive/'):
    if os.path.exists('/content/gdrive/MyDrive/models'):
      os.makedirs("/content/gdrive/MyDrive/SD/models/Stable-diffusion", exist_ok=True)
      if str(os.listdir('/content/gdrive/MyDrive/models')) != '[]':
        for file in glob.glob("/content/gdrive/MyDrive/models/*.ckpt"):
          os.replace(file, "/content/gdrive/MyDrive/SD/models/Stable-diffusion/"+os.path.basename(file))
        for file in glob.glob("/content/gdrive/MyDrive/models_old/*.safetensors"):
          os.replace(file, "/content/gdrive/MyDrive/SD/models/Stable-diffusion/"+os.path.basename(file))
      print('в папке /content/gdrive/MyDrive/models/ были найдены *.safetensors/.*ckpt и перемещены в /content/gdrive/MyDrive/SD/models/Stable-diffusion')
      if str(os.listdir('/content/gdrive/MyDrive/models')) == '[]':
        os.rmdir('/content/gdrive/MyDrive/models')
      else:
        try:
          os.rename("/content/gdrive/MyDrive/models", "/content/gdrive/MyDrive/models_old")
        except:
          for g in os.listdir('/content/gdrive/MyDrive/models'):
            shutil.move('/content/gdrive/MyDrive/models/'+g, "/content/gdrive/MyDrive/models_old")
            os.rmdir('/content/gdrive/MyDrive/models')
        print('в папке /content/gdrive/MyDrive/models/ были найдены какие-то файлы не относящиеся к SD-моделям или вложенные папки, все это перемещено в /content/gdrive/MyDrive/models_old - разбери это вручную')
    if sdmodels.value == True and sdmodels_path.value.strip():
      if '/content/gdrive/MyDrive/' not in sdmodels_path.value:
        sdmodels_path.value = f'/content/gdrive/MyDrive/{sdmodels_path.value}'
      if not os.path.exists(sdmodels_path.value):
        print(f'\033[1;31mпуть до моделей\033[1;34m {sdmodels_path.value} \033[1;31mуказан неверно\033[0m')
      else:
        for file in glob.glob(f"{sdmodels_path.value}/*.ckpt"):
          os.replace(file, "/content/gdrive/MyDrive/SD/models/Stable-diffusion/"+os.path.basename(file))
        for file in glob.glob(f"{sdmodels_path.value}/*.safetensors"):
          os.replace(file, "/content/gdrive/MyDrive/SD/models/Stable-diffusion/"+os.path.basename(file))
        if str(os.listdir(sdmodels_path.value)) == '[]':
          os.rmdir(sdmodels_path.value)
        if str(os.listdir(sdmodels_path.value)) != '[]':
          print(f'файлы sd-моделей перемещены, но в исходной папке {sdmodels_path.value} остались какие-то файлы, разбери их вручную')
    else:
      None
    if vaemodels.value == True and vaemodels_path.value.strip():
      if '/content/gdrive/MyDrive/' not in vaemodels_path.value:
        vaemodels_path.value = f'/content/gdrive/MyDrive/{vaemodels_path.value}'
      if not os.path.exists(vaemodels_path.value):
        print(f'\033[1;31mпуть до vae\033[1;34m {vaemodels_path.value} \033[1;31mуказан неверно\033[0m')
      else:
        for file in glob.glob(f"{vaemodels_path.value}/*.ckpt"):
          os.replace(file, "/content/gdrive/MyDrive/SD/models/VAE/"+os.path.basename(file))
        for file in glob.glob(f"{vaemodels_path.value}/*.pt"):
          os.replace(file, "/content/gdrive/MyDrive/SD/models/VAE/"+os.path.basename(file))
        for file in glob.glob(f"{vaemodels_path.value}/*.safetensors"):
          os.replace(file, "/content/gdrive/MyDrive/SD/models/VAE/"+os.path.basename(file))
        if str(os.listdir(vaemodels_path.value)) == '[]':
          os.rmdir(vaemodels_path.value)
        if str(os.listdir(vaemodels_path.value)) != '[]':
          print(f'файлы vae-моделей перемещены, но в исходной папке {vaemodels_path.value} остались какие-то файлы, разбери их вручную')
    else:
      None
    if embeddingsmodels.value == True and embeddingsmodels_path.value.strip():
      if '/content/gdrive/MyDrive/' not in embeddingsmodels_path.value:
        embeddingsmodels_path.value = f'/content/gdrive/MyDrive/{embeddingsmodels_path.value}'
      if not os.path.exists(embeddingsmodels_path.value):
        print(f'\033[1;31mпуть до моделей\033[1;34m {embeddingsmodels_path.value} \033[1;31mуказан неверно\033[0m')
      else:
        for file in glob.glob(f"{embeddingsmodels_path.value}/*.bin"):
          os.replace(file, "/content/gdrive/MyDrive/SD/embeddings/"+os.path.basename(file))
        for file in glob.glob(f"{embeddingsmodels_path.value}/*.pt"):
          os.replace(file, "/content/gdrive/MyDrive/SD/embeddings/"+os.path.basename(file))
        for file in glob.glob(f"{embeddingsmodels_path.value}/*.png"):
          os.replace(file, "/content/gdrive/MyDrive/SD/embeddings/"+os.path.basename(file))
        if str(os.listdir(embeddingsmodels_path.value)) == '[]':
          os.rmdir(embeddingsmodels_path.value)
        if str(os.listdir(embeddingsmodels_path.value)) != '[]':
          print(f'файлы внедрений перемещены, но в исходной папке {embeddingsmodels_path.value} остались какие-то файлы, разбери их вручную')
    else:
      None
    if hypernetworksmodels.value == True and hypernetworksmodels_path.value.strip():
      if '/content/gdrive/MyDrive/' not in hypernetworksmodels_path.value:
        hypernetworksmodels_path.value = f'/content/gdrive/MyDrive/{hypernetworksmodels_path.value}'
      if not os.path.exists(hypernetworksmodels_path.value):
        print(f'\033[1;31mпуть до моделей\033[1;34m {hypernetworksmodels_path.value} \033[1;31mуказан неверно\033[0m')
      else:
        for file in glob.glob(f"{hypernetworksmodels_path.value}/*.pt"):
          os.replace(file, "/content/gdrive/MyDrive/SD/models/hypernetworks/"+os.path.basename(file))
        if str(os.listdir(hypernetworksmodels_path.value)) == '[]':
          os.rmdir(hypernetworksmodels_path.value)
        if str(os.listdir(hypernetworksmodels_path.value)) != '[]':
          print(f'файлы гиперсетей перемещены, но в исходной папке {hypernetworksmodels_path.value} остались какие-то файлы, разбери их вручную')
    else:
      None
    if loramodels.value == True and loramodels_path.value.strip():
      if '/content/gdrive/MyDrive/' not in loramodels_path.value:
        loramodels_path.value = f'/content/gdrive/MyDrive/{loramodels_path.value}'
      if not os.path.exists(loramodels_path.value):
        print(f'\033[1;31mпуть до моделей\033[1;34m {loramodels_path.value} \033[1;31mуказан неверно\033[0m')
      else:
        for file in glob.glob(f"{loramodels_path.value}/*.pt"):
          os.replace(file, "/content/gdrive/MyDrive/SD/models/Lora/"+os.path.basename(file))
        for file in glob.glob(f"{loramodels_path.value}/*.ckpt"):
          os.replace(file, "/content/gdrive/MyDrive/SD/models/Lora/"+os.path.basename(file))
        for file in glob.glob(f"{loramodels_path.value}/*.safetensors"):
          os.replace(file, "/content/gdrive/MyDrive/SD/models/Lora/"+os.path.basename(file))
        if str(os.listdir(loramodels_path.value)) == '[]':
          os.rmdir(loramodels_path.value)
        if str(os.listdir(loramodels_path.value)) != '[]':
          print(f'файлы Lora перемещены, но в исходной папке {loramodels_path.value} остались какие-то файлы, разбери их вручную')
    else:
      None
    if esrganmodels.value == True and esrganmodels_path.value.strip():
      if '/content/gdrive/MyDrive/' not in esrganmodels_path.value:
        esrganmodels_path.value = f'/content/gdrive/MyDrive/{esrganmodels_path.value}'
      if not os.path.exists(esrganmodels_path.value):
        print(f'\033[1;31mпуть до моделей\033[1;34m {esrganmodels_path.value} \033[1;31mуказан неверно\033[0m')
        for file in glob.glob(f"{loramodels_path.value}/*.pth"):
          os.replace(file, "/content/gdrive/MyDrive/SD/models/ESRGAN/"+os.path.basename(file))
        if str(os.listdir(esrganmodels_path.value)) == '[]':
          os.rmdir(esrganmodels_path.value)
        if str(os.listdir(esrganmodels_path.value)) != '[]':
          print(f'файлы ESRGAN перемещены, но в исходной папке {esrganmodels_path.value} остались какие-то файлы, разбери их вручную')
    else:
      None
    if realesrganmodels.value == True and realesrganmodels_path.value.strip():
      if '/content/gdrive/MyDrive/' not in realesrganmodels_path.value:
        realesrganmodels_path.value = f'/content/gdrive/MyDrive/{realesrganmodels_path.value}'
      if not os.path.exists(realesrganmodels_path.value):
        print(f'\033[1;31mпуть до моделей\033[1;34m {realesrganmodels_path.value} \033[1;31mуказан неверно\033[0m')
        for file in glob.glob(f"{loramodels_path.value}/*.pth"):
          os.replace(file, "/content/gdrive/MyDrive/SD/models/RealESRGAN/"+os.path.basename(file))
        if str(os.listdir(realesrganmodels_path.value)) == '[]':
          os.rmdir(realesrganmodels_path.value)
        if str(os.listdir(realesrganmodels_path.value)) != '[]':
          print(f'файлы RealESRGAN перемещены, но в исходной папке {realesrganmodels_path.value} остались какие-то файлы, разбери их вручную')
    else:
      None
    if swinirmodels.value == True and swinirmodels_path.value.strip():
      if '/content/gdrive/MyDrive/' not in swinirmodels_path.value:
        swinirmodels_path.value = f'/content/gdrive/MyDrive/{swinirmodels_path.value}'
      if not os.path.exists(swinirmodels_path.value):
        print(f'\033[1;31mпуть до моделей\033[1;34m {swinirmodels_path.value.value} \033[1;31mуказан неверно\033[0m')
        for file in glob.glob(f"{swinirmodels_path.value}/*.pth"):
          os.replace(file, "/content/gdrive/MyDrive/SD/models/SwinIR/"+os.path.basename(file))
        if str(os.listdir(swinirmodels_path.value)) == '[]':
          os.rmdir(swinirmodels_path.value)
        if str(os.listdir(swinirmodels_path.value)) != '[]':
          print(f'файлы SwinIR перемещены, но в исходной папке {swinirmodels_path.value} остались какие-то файлы, разбери их вручную')
    else:
      None
    if sdmodels_path.value.strip() or vaemodels_path.value.strip() or embeddingsmodels_path.value.strip() or hypernetworksmodels_path.value.strip() or loramodels_path.value.strip() or esrganmodels_path.value.strip() or realesrganmodels_path.value.strip() or swinirmodels_path.value.strip():
      print('задание выполнено!')
    else:
      if os.path.exists('/content/gdrive/MyDrive/'):
        root_path = '/content/gdrive/MyDrive/SD/models'
        folders = ['Stable-diffusion','ESRGAN', 'hypernetworks', 'Lora', 'RealESRGAN', 'SwinIR', 'VAE']
        for folder in folders:
          os.makedirs(os.path.join(root_path,folder), exist_ok=True)
        os.makedirs('/content/gdrive/MyDrive/SD/embeddings', exist_ok=True)
  else:
    print('сперва нужно примонтировать гуглодиск!')

run.on_click(run_button_click)

gdrivefolders_css = requests.get("https://github.com/PR0LAPSE/StableDiffusionWebUIColab/raw/main/src/gdrivefolders_widget_css").text
display(HTML(f'''
{gdrivefolders_css}
'''))

actions_header = HTML('<h2 id="header">структурирование файлов моделей на гуглодиске</h2><h3>для подтягивания в колаб через симлинки</h3><p id="description">отметь галочками нужные типы моделей, которые ты хранишь на гуглодиске, и после - укажи до них путь вида <code>/content/gdrive/MyDrive/папка</code> либо <code>папка</code></p>')

display(actions_header)
checkboxes_of_models = widgets.VBox([sd_item, vae_item, embeddings_item, hypernetworks_item, lora_item, esrgan_item, realesrgan_item, swinir_item]).add_class("items")
display(checkboxes_of_models)
display(run)

# %% [markdown]
# ---

# %% [markdown]
# чтобы остановить выполнение кода в виджетовых ячейках: `Ctrl+M+I` или в меню: `Среда выполнения → Прервать выполнение кода`

# %%
#@title  { display-mode: "form" }
#@markdown <img height="22px" src="https://files.catbox.moe/im26b0.svg">
'''
в сундуке — заяц, в зайце — утка,
в утке — яйцо, в яйце — игла

ячейка разделена на вложенные файлики
для ускорения запуска (не выполнения, а запуска, из-за построчной проверки кода гуглом).
в противном случае - холодный старт от 1,5 минуты
'''

# сброс сохраненных переменных на диске
# %store -z
# %cd /content
# задать чекпоинты автоматика
commit_new =  "ea9bd9fc7409109adcd61b897abc2c8881161256"
commit_stable = "52f6e94338f31c286361802b08ee5210b8244141"
# %store commit_new
# %store commit_stable

clear_out = True # очищать вывод? (False)
def clear():
  if clear_out:
    clear_output()

import os
import os.path
from google.colab import output as cou
from google.colab import drive
import re
from re import search
import subprocess
from subprocess import getoutput
import threading
from IPython.display import HTML, Javascript, display, clear_output
from ipython_genutils.py3compat import builtin_mod
import ipywidgets as widgets
import requests
import glob
import time
from datetime import timedelta
import distutils.dir_util
from IPython.utils import capture
import multiprocessing
import random
import string
from tqdm import tqdm
import concurrent.futures
from concurrent.futures import ThreadPoolExecutor, as_completed
import pickle

# проверка рантайма и завершение, если лимит GPU исчерпан на аккаунте
nsmi = getoutput('nvidia-smi')
if "NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running." in nsmi:
  display(HTML('https://github.com/PR0LAPSE/StableDiffusionWebUIColab/raw/main/src/warn'))
  # !sleep 5
  print("завершение...")
  # !sleep 5
  from google.colab import runtime
  runtime.unassign()


# файл с переменными
# просмотр/редактирование: https://is.gd/1var_ipynb
# !wget -q https://github.com/PR0LAPSE/StableDiffusionWebUIColab/raw/main/src/1_var.ipynb -P /content/.config
# %run /content/.config/1_var.ipynb


# загрузчик моделей
# просмотр/редактирование: https://is.gd/21models_ipynb
# файл с моделями: https://is.gd/22models_ipynb
# !wget -q https://github.com/PR0LAPSE/StableDiffusionWebUIColab/raw/main/src/2_1_models.ipynb -P /content/.config
# %run /content/.config/2_1_models.ipynb


# создание виджетов для установки
# просмотр/редактирование: https://is.gd/3installation_ipynb
# !wget -q https://github.com/PR0LAPSE/StableDiffusionWebUIColab/raw/main/src/3_installation.ipynb -P /content/.config
# %run /content/.config/3_installation.ipynb


#начальное состояние доп.опций и действия по клику на них
gfolder.layout.display = 'none'
gdrive_models.layout.display = 'none'
gdrive_only.layout.display = 'none'
gdrive_only.layout.display = 'none'
gdrive_models.observe(gd_path, names='value')
gdrive.observe(gdrive_mount, names='value')
gdrive_only.observe(only_gdrive, names='value')
close_button.on_click(on_close_button_click)
#download_button.on_click(on_download_click) - кнопка скачать не нужна, все на кнопке продолжить
apply.on_click(apply_button_click)
# очистить вывод перед показом виджетов
clear()
# пауза 3-10сек (чтобы после очистки корректно отработал css)
# !sleep 3
# отображение элементов виджетов в порядке сверху вниз
display(m)
display(HTML('<h2 id="setup_header">настройки</h2>'))
display(checkpoint)
display(gd_set, additions, webuiargs)
display(model_header)
display(search_and_button, tab)
display(filtered_checkboxes, close_button)
display(apply)
#скрыть кнопку "скачать" в виджете моделей
display(HTML('<style>.dl_button {display: none}</style>'))
#внедрение css
setup_css()
cou.eval_js(f'new Audio("{gh}start_widget.mp3").play()') #оповещение о загрузке виджета

# %% [markdown]
# ---

# %%
#@title докачать модели{ display-mode: "form" }
#@markdown <a href="https://teletype.in/@stablediffusion/models_for_colab"><img height="24px" src="https://files.catbox.moe/wq11dz.svg"></a> <br>
# %store -r
# %cd /content/stable-diffusion-webui/models/Stable-diffusion

clear_out = True # очищать вывод? (False)
def clear():
  if clear_out:
    clear_output()

import os.path
from google.colab import output as cou
from IPython.display import HTML, display
import ipywidgets as widgets
from IPython.display import clear_output
import requests
# папки указаны в исполняемом файле
# !cd /content/stable-diffusion-webui/models/Stable-diffusion
cou.clear()
try:
  print(ok)
except NameError:
  # файл с переменными
  # просмотр/редактирование: https://is.gd/1var_ipynb
  # !wget -q https://github.com/PR0LAPSE/StableDiffusionWebUIColab/raw/main/src/1_var.ipynb -P /content/.config
  # %run /content/.config/1_var.ipynb
  cou.clear()

# загрузчик моделей
# просмотр/редактирование: https://is.gd/21models_ipynb
# файл с моделями: https://is.gd/22models_ipynb
# !wget -q https://github.com/PR0LAPSE/StableDiffusionWebUIColab/raw/main/src/2_1_models.ipynb -P /content/.config
# %run /content/.config/2_1_models.ipynb

download_button.on_click(on_download_click)
close_button.on_click(on_close_button_click)
setup_css()
# !sleep 3
display(search_and_button, tab)
display(filtered_checkboxes, close_button)

# %%
#@title запуск/перезапуск { display-mode: "form" }
#@markdown <details><summary><font color='#c89c26' size='3' face="Verdana"><b>👈 Прочитать подробнее</b></font></summary>Получить <b>свой</b> токен для ngrok можешь <a href="https://dashboard.ngrok.com/get-started/your-authtoken">тут</a> |  Если токен ngrok не будет указан в поле выше, ngrok в 99% все равно запустится - будет использован ч҉у҉ж҉о҉й токен.<br><code>--no-half-vae</code> это дополнительный аргумент запуска, позволяющий избежать черных квадратов при генерации (запрещает перевод vae в режим 16-bit floats)<br>⚠️ <font color='#32CD32'>После того как <strong>все прогрузится</strong>, ищи сылки типа</font>: <br> <code>cool-brooms-admire-23-251-149-142.loca.lt</code> или <code>0bf89138a7c4877f.gradio.app</code> или <code>e402-34-126-159-209.ngrok.io</code><br>И переходи по ссылкам. Gradio - дефольный, но бывает зависает. Пробуй Ngrok или LokalIt<br><details><summary><font color="#c89c26">где искать и какие ссылки? </font></summary><img src="https://files.catbox.moe/wrq2pc.svg" width="70%"></details><b><font color='#32CD32'>Рекомендую использовать ngrok.</font></b> Работа через gradio сопряжена с частыми зависаниями и потерей коннекта при пакетной генерации. loca.lt - иногда чуточку лучше. Ngrok тоже не идеален, но он более стабилен.<br>Если возникают проблемы с подгрузкой жирных моделей (ema-full, non-pruned, которые под 7 гигов) - это из-за нехватки памяти на бесплатном тарифе колаба. <a href="#scrollTo=otsDSY8bCdVN">Воспользуйся прунингом</a>, чтобы уменьшить размер. Прунинг никак не сказывается на качестве генерации, картинки будут идентичные 100% (проверенно Аноном).</details>

ngrok_token = "\u0442\u0432\u043E\u0439_\u0442\u043E\u043A\u0435\u043D" #@param {type:"string"}
# %store -d xformers
xformers = True #@param {type:"boolean"}
# %store xformers
# %store -d no_half_vae
no_half_vae = False #@param {type:"boolean"}
# %store no_half_vae
#@markdown [как составить промпт и список художников](https://teletype.in/@stablediffusion/artists_for_prompts) | [о настройках генерации](https://teletype.in/@stablediffusion/samplers_steps)
#@markdown <details><summary>быстрые ссылки</summary><ul><li><a href="#scrollTo=10iWu8h1UTvQ">установка и запуск</a></li><li><a href="#scrollTo=MTex_2fJwYjn">выбор и установка нескольких моделей</a></li><li><a href="#scrollTo=R-xAdMA5wxXd">запуск/перезапуск</a></li><li><a href="#scrollTo=V-2LlLHZPgoB">скачивание архива с картинками</a></li><li><a href="#scrollTo=w_29ofOEGng_">подключение/переподключение/сброс кэша гуглодиска</a></li><li><a href="#scrollTo=TuwHDqutjgZd">массовая загрузка по прямым ссылкам</a></li><li><a href="#scrollTo=62QDyjXtYHjF">загрузчик моделей с civitai.com</a></li><li><a href="#scrollTo=VirGjpcNCCKX">скачивание с торрентов</a></li><li><a href="#scrollTo=heHty0pzVYjw">прунинг и конвертация моделей</a></li><li><a href="#scrollTo=j7N-__N4f9uY">выгрузка моделей на HuggingFace</a></li><li><a href="#scrollTo=zVmDZeIAIcja">выгрузка на файлообменники</a></li><li><a href="#scrollTo=k98WImeXH5pK">запаковка/распаковка архивов</a></li><li><a href="#scrollTo=Oh37kTko2shA">операции с папками/файлами/симлинками</a></li></ul></details>

try:
  print(ok)
except NameError:
  # !wget -q https://github.com/PR0LAPSE/StableDiffusionWebUIColab/raw/main/src/1_var.ipynb -P /content/.config
  # %run /content/.config/1_var.ipynb

# %cd /content/stable-diffusion-webui
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
# !sleep 3
#проигрывание аудио для влияния на подсознание
cou.eval_js("var audio = new Audio('https://files.catbox.moe/zt1h9u.wav'); audio.addEventListener('ended', function() { audio.currentTime = 0; audio.play(); }, false); audio.play();")

# !find /content/ -name "*.safetensors" -type f -size +1900M -exec mv {} /content/stable-diffusion-webui44/models/Stable-diffusion/ \;
# !find /content/stable-diffusion-webui/ -name "*.safetensors" -type f -size +1900M -exec mv {} /content/stable-diffusion-webui44/models/Stable-diffusion/ \;

clear_output()

#Установка токена ngrok
ngrok_share = cfg+'cfg'
freetoken = open(ngrok_share).read().split('\n')
sharetoken = random.choice(list(freetoken))
ngrok_token_value = ngrok_token
xformers_value = xformers
no_half_vae_value = no_half_vae
if not ngrok_token_value or len(ngrok_token_value) < 48 or len(ngrok_token_value) > 51:
  ngrok = f'--ngrok {sharetoken} --ngrok-region eu'
else:
  ngrok = f'--ngrok {ngrok_token_value} --ngrok-region eu'
if xformers_value == True:
  xf = '--xformers'
if xformers_value == False:
  xf = '--opt-split-attention'
if no_half_vae_value == True:
  nhv = '--no-half-vae'
if no_half_vae_value == False:
  nhv = ''
if checkpoint_value == "new":
  gq = '--gradio-queue --disable-console-progressbars --no-hashing --opt-channelslast'
if checkpoint_value == "legacy":
  gq = ''
ckpt_dir = "/content/stable-diffusion-webui/models/Stable-diffusion"
if booru_value == True:
  deepdanbooru_arg = "--deepdanbooru"
if booru_value == False:
  deepdanbooru_arg = ""
default_args = f"--disable-safe-unpickle --enable-insecure-extension-access --share {deepdanbooru_arg} --gradio-img2img-tool editor --theme dark --ckpt-dir {ckpt_dir}"
cmdargs = f'{default_args} {gq} {xf} {nhv} {ngrok}'
#with capture.capture_output() as stored_variables:
#  %store cmdargs
saved_vars = open(f'{cfg}saved_vars', 'wb')
pickle.dump(xf, saved_vars)
pickle.dump(nhv, saved_vars)
pickle.dump(gq, saved_vars)
pickle.dump(deepdanbooru_arg, saved_vars)
pickle.dump(default_args, saved_vars)
saved_vars.close()
print("\033[1;36mВнимание! Если интерфейсе не отображается генерация, просто используй ссылку на Gradio!\033[0m \n")
print("\033[1;34mПереходить по ссылкам можно после полной прогрузки, ожидай сообщения.\033[0m")
flara()
with open('/content/stable-diffusion-webui/clfr.txt', 'r') as flare:
  print("\033[01;38;05;112m⯈\033[0m Ссылка на Флару: " + flare.read())
#from google.colab.output import serve_kernel_port_as_window
#from google.colab.output import eval_js
#print("\033[01;38;05;112m⯈\033[0m Ссылка на Гугл:", eval_js( "google.colab.kernel.proxyPort(" + str(7860) + ")" ))
print("")
#Собственно запуск

# в последней версии автоматик добавил аргументы: --no-hashing, можно использовать вместе с --lowram
# !python /content/stable-diffusion-webui/webui.py $cmdargs
if os.path.exists("/content/gdrive/MyDrive/SD/styles.csv"):
  # !cp -f /content/stable-diffusion-webui/styles.csv /content/gdrive/MyDrive/SD/styles.csv
display(HTML('/content/.config/end'))

# %% [markdown]
# ---

# %%
#@title Переподключение, сброс кэша гуглодиска { display-mode: "form" }
#@markdown <center><img src='https://kstatic.googleusercontent.com/files/d57b24106c34c7e50ef3d98423b94ddaf35ad2da73a9b9d4d12f52dbb9dd4c08c2957f6255ab8690d5ef0b32cff8287e09577d05e479d263e872160c4c9e8363' /></center>
#@markdown Гуглодиск монтируется по пути: /content/gdrive/MyDrive<br>Если к аккаунту подключен "общий диск", он находится в папке: /content/drive/Shareddrives (например: <n>/con<n>tent</n>/<n>drive</n>/<n>Share</n><n>ddrives</n>/<n>Vasya</n>)
режим = "\u043F\u0440\u0438\u043C\u043E\u043D\u0442\u0438\u0440\u043E\u0432\u0430\u0442\u044C" #@param ["примонтировать", "размонтировать"]

from google.colab import drive
drive.mount._DEBUG = False
if режим == "примонтировать":
  drive.mount('/content/drive', force_remount=True)
  print('гуглодиск примонтирован')
elif режим == "размонтировать":
  try:
    drive.flush_and_unmount()
  except ValueError:
    pass
  # !rm -rf /root/.config/Google/DriveFS
  print('гуглодиск размонтирован')
#@markdown Можно примонтировать гуглодиск, если забыл сделать это ранее. Размонтирование необходимо в случае проблем с гуглодиском (в гуглодиске не появляются отправленные с колаба файлы и т.п.)<br>Подключение гуглодиска в этой ячейке не меняет настройки сохранения картинок и папку моделей!
#@markdown <center> <a href="#scrollTo=gnzJeBa5OYO3">🔝</a>&emsp;<a href="#scrollTo=R-xAdMA5wxXd">🚀</a></center>
#@markdown <details><summary>быстрые ссылки</summary><ul><li><a href="#scrollTo=10iWu8h1UTvQ">установка и запуск</a></li><li><a href="#scrollTo=MTex_2fJwYjn">выбор и установка нескольких моделей</a></li><li><a href="#scrollTo=R-xAdMA5wxXd">запуск/перезапуск</a></li><li><a href="#scrollTo=V-2LlLHZPgoB">скачивание архива с картинками</a></li><li><a href="#scrollTo=w_29ofOEGng_">подключение/переподключение/сброс кэша гуглодиска</a></li><li><a href="#scrollTo=TuwHDqutjgZd">массовая загрузка по прямым ссылкам</a></li><li><a href="#scrollTo=62QDyjXtYHjF">загрузчик моделей с civitai.com</a></li><li><a href="#scrollTo=VirGjpcNCCKX">скачивание с торрентов</a></li><li><a href="#scrollTo=heHty0pzVYjw">прунинг и конвертация моделей</a></li><li><a href="#scrollTo=j7N-__N4f9uY">выгрузка моделей на HuggingFace</a></li><li><a href="#scrollTo=zVmDZeIAIcja">выгрузка на файлообменники</a></li><li><a href="#scrollTo=k98WImeXH5pK">запаковка/распаковка архивов</a></li><li><a href="#scrollTo=Oh37kTko2shA">операции с папками/файлами/симлинками</a></li></ul></details>

# %% [markdown]
# ---

# %%
#@title 💾 Создание и скачивание архива со всеми картинками { display-mode: "form" }
#@markdown <details><summary><font color='#c89c26' size='3' face="Verdana"><b>👈 Прочитать описание</b></font></summary><strong>Cкачивание напрямую на ПК, минуя гуглодиск или получение ссылки с архивом всех картинок</strong>: это очень полезно, если ты не монтируешь гуглодиск в colab. Имей в виду, что прямое скачивание, которе тут предлагается, средствами colab - оно очень медленное, а самое печальное - если файлик не маленький, то загрузка вообще будет прерываться, вызывая боль и мучения. Поэтому в качестве альтернативы - воспользуйся очень быстрой выгрузкой архива на anonfiles или его саттелиты по своему вкусу, потом просто гораздо быстрее и без нервов скачаешь.<br><strong>Прежде чем запустить скачивание архива в этой ячейке, ячейка с WebUI должна быть остановлена.</strong> (потом можно будет ее запустить снова, если требуется)</details>
что_сделать_после_архивирования = "\u0432\u044B\u0433\u0440\u0443\u0437\u0438\u0442\u044C \u0438 \u043F\u043E\u043B\u0443\u0447\u0438\u0442\u044C \u0441\u0441\u044B\u043B\u043A\u0443" #@param ["сразу скачать", "выгрузить и получить ссылку"]
файлопомойка = "anonfiles.com" #@param ["anonfiles.com", "openload.cc", "bayfiles.com", "lolabits.se", "vshare.is", "upvid.cc", "hotfile.io", "rapidshare.nu", "filechan.org", "letsupload.cc", "share-online.is", "megaupload.nz", "myfile.is"]
import datetime
from datetime import datetime
from datetime import date
import pytz
from pytz import timezone
now = datetime.now(pytz.timezone('Europe/Moscow'))
filename = "SD_" + now.strftime("%d%m%Y_%H%M%S") + ".zip"
!7z a -tzip -mx=4 "{filename}" /content/output
output.clear()
if что_сделать_после_архивирования == "сразу скачать":
  print('скачивание архива начнется автоматически...\nбраузер может заблокировать загрузку, не забудь выдать разрешения')
  from google.colab import files
  files.download(filename)
if что_сделать_после_архивирования == "выгрузить и получить ссылку":
  import requests
  url = f'https://api.{файлопомойка}/upload'
  x = requests.post(url, files = {'file': open(filename,'rb')},)
  print("\033[01;38;05;46m Твоя ссылка: " + x.json()["data"]["file"]["url"]["full"])

#@markdown <center> <a href="#scrollTo=gnzJeBa5OYO3">🔝</a>&emsp;<a href="#scrollTo=R-xAdMA5wxXd">🚀</a></center>
#@markdown <details><summary>быстрые ссылки</summary><ul><li><a href="#scrollTo=10iWu8h1UTvQ">установка и запуск</a></li><li><a href="#scrollTo=MTex_2fJwYjn">выбор и установка нескольких моделей</a></li><li><a href="#scrollTo=R-xAdMA5wxXd">запуск/перезапуск</a></li><li><a href="#scrollTo=V-2LlLHZPgoB">скачивание архива с картинками</a></li><li><a href="#scrollTo=w_29ofOEGng_">подключение/переподключение/сброс кэша гуглодиска</a></li><li><a href="#scrollTo=TuwHDqutjgZd">массовая загрузка по прямым ссылкам</a></li><li><a href="#scrollTo=62QDyjXtYHjF">загрузчик моделей с civitai.com</a></li><li><a href="#scrollTo=VirGjpcNCCKX">скачивание с торрентов</a></li><li><a href="#scrollTo=heHty0pzVYjw">прунинг и конвертация моделей</a></li><li><a href="#scrollTo=j7N-__N4f9uY">выгрузка моделей на HuggingFace</a></li><li><a href="#scrollTo=zVmDZeIAIcja">выгрузка на файлообменники</a></li><li><a href="#scrollTo=k98WImeXH5pK">запаковка/распаковка архивов</a></li><li><a href="#scrollTo=Oh37kTko2shA">операции с папками/файлами/симлинками</a></li></ul></details>

# %% [markdown]
# ---

# %% [markdown]
# #👈 Загрузка моделей с сайтов и торрентов

# %%
#@title  Скачивание моделек с civitai.com{ vertical-output: true, display-mode: "form" }
import requests
import os
import base64
import random
from tqdm import tqdm
from bs4 import BeautifulSoup
url = "https://civitai.com/models/2661/uber-realistic-porn-merge-urpm" #@param {type:"string"}
куда_скачать = "/content/gdrive/MyDrive/models" #@param {type:"string"}
dlpath = куда_скачать
defpath = "/content/stable-diffusion-webui/models/Stable-diffusion"
if not куда_скачать or "content" not in куда_скачать:
  print(f"папка загрузки указана некорректно, модель будет загружена в папку моделей по умолчанию:")
  dlpath = defpath
if not os.path.exists(куда_скачать ):
  print(f"указанная папка не существует, модель будет загружена в папку моделей по умолчанию:")
  dlpath = defpath
# %cd {dlpath}
pref = random.randint(1,2)
cookie_url = f'https://is.gd/ckjson{pref}'
cookies_list = requests.get(cookie_url).json()
cookies = {cookie["name"]: cookie["value"] for cookie in cookies_list}

response = requests.get(url, cookies=cookies)
soup = BeautifulSoup(response.content, "html.parser")
link_elements = soup.select("a[href^='/api/download/models/']")

link_element = link_elements[0]
download_url = "https://civitai.com" + link_element.get("href")

response = requests.get(download_url, headers={"Referer": url}, cookies=cookies, stream=True)
headers = response.headers
file_name = headers["Content-Disposition"].split("=")[1]
file_name = file_name.strip("\"")
print("Начинается скачивание...")
with tqdm(total=int(headers["Content-Length"]), unit="B", unit_scale=True) as pbar:
    with open(file_name, "wb") as file:
        for chunk in response.iter_content(chunk_size=1024):
            file.write(chunk)
            pbar.update(1024)
with open(file_name, "rb") as f:
    content = f.read(4)
content_base64 = base64.b64encode(content).decode("utf-8")
if content_base64 == "AAEAAQ==":
    new_file_name = os.path.splitext(file_name)[0] + ".safetensor"
    os.rename(file_name, new_file_name)
elif content_base64 == "RGF0YQ==":
    new_file_name = os.path.splitext(file_name)[0] + ".ckpt"
    os.rename(file_name, new_file_name)
print("\nЗагрузка завершена!")

#@markdown <center> <a href="#scrollTo=gnzJeBa5OYO3">🔝</a>&emsp;<a href="#scrollTo=R-xAdMA5wxXd">🚀</a></center>
#@markdown <details><summary>быстрые ссылки</summary><ul><li><a href="#scrollTo=10iWu8h1UTvQ">установка и запуск</a></li><li><a href="#scrollTo=MTex_2fJwYjn">выбор и установка нескольких моделей</a></li><li><a href="#scrollTo=R-xAdMA5wxXd">запуск/перезапуск</a></li><li><a href="#scrollTo=V-2LlLHZPgoB">скачивание архива с картинками</a></li><li><a href="#scrollTo=w_29ofOEGng_">подключение/переподключение/сброс кэша гуглодиска</a></li><li><a href="#scrollTo=TuwHDqutjgZd">массовая загрузка по прямым ссылкам</a></li><li><a href="#scrollTo=62QDyjXtYHjF">загрузчик моделей с civitai.com</a></li><li><a href="#scrollTo=VirGjpcNCCKX">скачивание с торрентов</a></li><li><a href="#scrollTo=heHty0pzVYjw">прунинг и конвертация моделей</a></li><li><a href="#scrollTo=j7N-__N4f9uY">выгрузка моделей на HuggingFace</a></li><li><a href="#scrollTo=zVmDZeIAIcja">выгрузка на файлообменники</a></li><li><a href="#scrollTo=k98WImeXH5pK">запаковка/распаковка архивов</a></li><li><a href="#scrollTo=Oh37kTko2shA">операции с папками/файлами/симлинками</a></li></ul></details>

# %%
#@title  массовая загрузка моделей и т.п. по прямым ссылкам { vertical-output: true, display-mode: "form" }
import os
wg = "/content/.config/wget"
#@markdown нужно указать произвольный путь загрузки, если указанная папка не будет найдена - она создастся.
папка = "/content/stable-diffusion-webui/models/Stable-diffusion" #@param {type:"string"}
#@markdown <hr width="50%"> ссылки должны быть прямые, все поля заполнять не обязательно
ссылка_1 = "" #@param {type:"string"}
ссылка_2 = "" #@param {type:"string"}
ссылка_3 = "" #@param {type:"string"}
ссылка_4 = "" #@param {type:"string"}
ссылка_5 = "" #@param {type:"string"}
ссылка_6 = "" #@param {type:"string"}
ссылка_7 = "" #@param {type:"string"}
ссылка_8 = "" #@param {type:"string"}
ссылка_9 = "" #@param {type:"string"}
ссылка_10 = "" #@param {type:"string"}
if os.path.exists(wg):
  # !rm {wg}
# !touch {wg}
with open(wg, 'r+') as addurl:
  addurl.seek(0, os.SEEK_END)
  addurl.write(f"{ссылка_1}" + "\n" + f"{ссылка_2}" + "\n" + f"{ссылка_3}" + "\n" + f"{ссылка_4}" + "\n" + f"{ссылка_5}" + "\n" + f"{ссылка_6}" + "\n" + f"{ссылка_7}" + "\n" + f"{ссылка_8}" + "\n" + f"{ссылка_9}" + "\n" + f"{ссылка_10}" + "\n")
print("\033[1;34mначинаю загрузку...\033[1;36m")
# !wget --content-disposition -q --show-progress -i {wg} -P "{папка}"
# !rm {wg}
print("\033[1;32mзагрузка завершена!\033[0m")

#@markdown <center> <a href="#scrollTo=gnzJeBa5OYO3">🔝</a>&emsp;<a href="#scrollTo=R-xAdMA5wxXd">🚀</a></center>
#@markdown <details><summary>быстрые ссылки</summary><ul><li><a href="#scrollTo=10iWu8h1UTvQ">установка и запуск</a></li><li><a href="#scrollTo=MTex_2fJwYjn">выбор и установка нескольких моделей</a></li><li><a href="#scrollTo=R-xAdMA5wxXd">запуск/перезапуск</a></li><li><a href="#scrollTo=V-2LlLHZPgoB">скачивание архива с картинками</a></li><li><a href="#scrollTo=w_29ofOEGng_">подключение/переподключение/сброс кэша гуглодиска</a></li><li><a href="#scrollTo=TuwHDqutjgZd">массовая загрузка по прямым ссылкам</a></li><li><a href="#scrollTo=62QDyjXtYHjF">загрузчик моделей с civitai.com</a></li><li><a href="#scrollTo=VirGjpcNCCKX">скачивание с торрентов</a></li><li><a href="#scrollTo=heHty0pzVYjw">прунинг и конвертация моделей</a></li><li><a href="#scrollTo=j7N-__N4f9uY">выгрузка моделей на HuggingFace</a></li><li><a href="#scrollTo=zVmDZeIAIcja">выгрузка на файлообменники</a></li><li><a href="#scrollTo=k98WImeXH5pK">запаковка/распаковка архивов</a></li><li><a href="#scrollTo=Oh37kTko2shA">операции с папками/файлами/симлинками</a></li></ul></details>

# %%
#@title <big>libtorrent</big> { display-mode: "form" }

import os
import time
from google.colab import output
if подключить_гуглодиск:
  from google.colab import output
  from google.colab import drive
  drive.mount('/content/gdrive')
  # !sleep 2
if not os.path.exists("/usr/share/doc/python3-libtorrent/copyright"):
  print ("сначала нужно установить торрент-клиент.\n установка...")
  # !python -m pip install jedi>=0.10 --quiet
  # !python -m pip install --upgrade pip setuptools wheel --quiet
  # !python -m pip install lbry-libtorrent --quiet
  # !apt install -qq python3-libtorrent --quiet
  # !rm '/content/=0.10'
  output.clear()
  print("установка клиента завершена")
else:
  # !sleep 1

import ipywidgets as widgets
import libtorrent as lt
from threading import Thread

ses = lt.session()
ses.listen_on(6881, 6891)
downloads = []

# !sleep 1
#@markdown чтобы скачать на гуглодиск, сначала примонтируй его, если этого не сделал ранее, или укажи другую папку для загрузки
подключить_гуглодиск = False #@param {type:"boolean"}
куда_качать = "/content/drive/My Drive/Torrent" #@param {type:"string"}
#@markdown Поставь галочку, если нужно после запуска выбрать файлы .torrent с компьютера:
torrent_файл = False #@param {type:"boolean"}
#@markdown Или вставь magnet-ссылку:


# выбрать торрент файлы?
if torrent_файл:
  from google.colab import files

  source = files.upload()
  if not source:                         
    print ('Нечего скачивать...')
    print ('Ты либо загрузи torrent-файлы, либо сними галочку и укажи magnet-ссылку')
    print ('попробуй еще раз')
    exit
  else:
    params = {
        "save_path": f"{куда_качать}",
        "ti": lt.torrent_info(list(source.keys())[0]),
    }
    downloads.append(ses.add_torrent(params))
    print ('ГОТОВО !!!')
else:
  from numpy import empty
  import libtorrent as lt
  import time
  import datetime
  ses = lt.session()
  ses.listen_on(6881, 6891)
  params = {
      'save_path': f'{куда_качать}',
      }
  link = "magnet:?xt=urn:btih:ED295B74E820777FF1E5C84B6657CB2AEB539AE1&tr=http%3A%2F%2Fbt3.t-ru.org%2Fann%3Fmagnet&dn=%D0%9C%D0%B8%D1%85%D0%B0%D0%B8%D0%BB%20%D0%91%D0%B5%D0%B9%D0%BB%D1%8C%D0%BA%D0%B8%D0%BD%20-%20%D0%A1%D0%B5%D1%80%D0%B8%D1%8F%20%D0%BA%D0%BD%D0%B8%D0%B3%20%22%D0%A1%D0%B5%D0%BA%D1%81-%D0%BB%D0%B8%D0%BA%D0%B1%D0%B5%D0%B7%22%20%D0%BF%D0%BE%20%D0%B3%D0%BE%D0%BC%D0%BE%D1%81%D0%B5%D0%BA%D1%81%D1%83%D0%B0%D0%BB%D1%8C%D0%BD%D0%BE%D1%81%D1%82%D0%B8%20%D0%B8%20%D1%81%D0%B5%D0%BA%D1%81%D0%BE%D0%BB%D0%BE%D0%B3%D0%B8%D0%B8%20%5B2006-2009%2C%20DOC%5D" #@param {type:"string"}

  if not link:                         
      print ('Ты не ввел магнет-ссылку !!!')
      exit
  if "magnet:?xt=urn:btih" not in link:
    print ('Это не магнет-ссылка !!!')
    print ('Либо вставь нормальную магнет-ссылку, либо отметь галочку и запусти и загрузи торрент-файлы.')
    exit
  else:
    handle = lt.add_magnet_uri(ses, link, params)
    ses.start_dht()

    begin = time.time()
    print(datetime.datetime.now())

    print ('Получаю метаданные...')
    while (not handle.has_metadata()):
      time.sleep(1)
    print ('Запускаю загрузку...')

    while (handle.status().state != lt.torrent_status.seeding):
        s = handle.status()
        state_str = ['очередь', 'проверка', 'получение метаданных', \
                'идет скачивание', 'готово', 'раздача', 'распределение']
        print ('%.2f%% (загрузка: %.1f kb/s отдача: %.1f kB/s пиры: %d) %s ' % \
                (s.progress * 100, s.download_rate / 1000, s.upload_rate / 1000, \
                s.num_peers, state_str[s.state]))
        time.sleep(5)

    end = time.time()
    print("ГОТОВО!")

    print("Затрачено времени: ",int((end-begin)//60),"min :", int((end-begin)%60), "sec")


#@markdown Обрати внимание: путь до папки загрузок приведен для примера (если подключен гуглодиск, допустим)! Это не путь до папки с моделями в колабе!

#@markdown Путь до стандартной папки с моделями: `/content/stable-diffusion-webui/models/Stable-diffusion`
#@markdown Торент может содержать вложенные папки и т.п., поэтому скачать лучше куда-то, а потом непосредственно файл можели перетянуть в папку где лежат все модели:
#@markdown <b><font color='forestgreen' size='2'><details><summary>скрин где найти тут папку</summary> <img src='https://files.catbox.moe/4pi0d7.png' /></details>


#@markdown <center> <a href="#scrollTo=gnzJeBa5OYO3">🔝</a>&emsp;<a href="#scrollTo=R-xAdMA5wxXd">🚀</a></center>
#@markdown <details><summary>быстрые ссылки</summary><ul><li><a href="#scrollTo=10iWu8h1UTvQ">установка и запуск</a></li><li><a href="#scrollTo=MTex_2fJwYjn">выбор и установка нескольких моделей</a></li><li><a href="#scrollTo=R-xAdMA5wxXd">запуск/перезапуск</a></li><li><a href="#scrollTo=V-2LlLHZPgoB">скачивание архива с картинками</a></li><li><a href="#scrollTo=w_29ofOEGng_">подключение/переподключение/сброс кэша гуглодиска</a></li><li><a href="#scrollTo=TuwHDqutjgZd">массовая загрузка по прямым ссылкам</a></li><li><a href="#scrollTo=62QDyjXtYHjF">загрузчик моделей с civitai.com</a></li><li><a href="#scrollTo=VirGjpcNCCKX">скачивание с торрентов</a></li><li><a href="#scrollTo=heHty0pzVYjw">прунинг и конвертация моделей</a></li><li><a href="#scrollTo=j7N-__N4f9uY">выгрузка моделей на HuggingFace</a></li><li><a href="#scrollTo=zVmDZeIAIcja">выгрузка на файлообменники</a></li><li><a href="#scrollTo=k98WImeXH5pK">запаковка/распаковка архивов</a></li><li><a href="#scrollTo=Oh37kTko2shA">операции с папками/файлами/симлинками</a></li></ul></details>

# %% [markdown]
# # 👈 Прунинг и конвертация моделей

# %%
#@title Проверка смещения тензоров модели { display-mode: "form" }
модель = "/content/aloeVeraSSimpMaker3K_simpMaker3K1-ema-fp16.safetensors" #@param {type:"string"}
import torch
import safetensors.torch
import os.path
import sys
if __name__ == "__main__":
    checkpoint_file = модель
    device = 'cpu'
    ext = os.path.splitext(checkpoint_file)

    if ext[-1] == ".safetensors":
        checkpoint = safetensors.torch.load_file(checkpoint_file, device=device)
    elif ext[-1] == ".ckpt":
        checkpoint = torch.load(checkpoint_file,  map_location=torch.device(device))
    else:
        raise Exception("файл модели должен быть с расширением ckpt или safetensors")

    if 'state_dict' in checkpoint:
        checkpoint = checkpoint['state_dict']

    print(checkpoint['cond_stage_model.transformer.text_model.embeddings.position_ids'])

# %%
#@title Pruning (уменьшение размера модели) { display-mode: "form" }
#@markdown Прунинг - удаление из раздутых больших моделей лишней информации для обучения, позволяя уменьшить размер готового файла в двое. Заметных глазу изменений при генерации не происходит. Данный вариант создает ema-only модели. В ячейке ниже, по мимо этого, можно удалить из модели больше данных и сделать float16 вариант.
путь_до_модели = "/content/Anything_Berrymix.ckpt" #@param {type:"string"}
import os
if not os.path.exists("/content/prune-ckpt.py"):
  from google.colab import output
  # !wget -nv --show-progress https://github.com/prettydeep/Dreambooth-SD-ckpt-pruning/raw/main/prune-ckpt.py
  output.clear()
else:
  # !sleep 1
# !python prune-ckpt.py --ckpt {путь_до_модели}

#@markdown <center> <a href="#scrollTo=gnzJeBa5OYO3">🔝</a>&emsp;<a href="#scrollTo=R-xAdMA5wxXd">🚀</a></center>
#@markdown <details><summary>быстрые ссылки</summary><ul><li><a href="#scrollTo=10iWu8h1UTvQ">установка и запуск</a></li><li><a href="#scrollTo=MTex_2fJwYjn">выбор и установка нескольких моделей</a></li><li><a href="#scrollTo=R-xAdMA5wxXd">запуск/перезапуск</a></li><li><a href="#scrollTo=V-2LlLHZPgoB">скачивание архива с картинками</a></li><li><a href="#scrollTo=w_29ofOEGng_">подключение/переподключение/сброс кэша гуглодиска</a></li><li><a href="#scrollTo=TuwHDqutjgZd">массовая загрузка по прямым ссылкам</a></li><li><a href="#scrollTo=62QDyjXtYHjF">загрузчик моделей с civitai.com</a></li><li><a href="#scrollTo=VirGjpcNCCKX">скачивание с торрентов</a></li><li><a href="#scrollTo=heHty0pzVYjw">прунинг и конвертация моделей</a></li><li><a href="#scrollTo=j7N-__N4f9uY">выгрузка моделей на HuggingFace</a></li><li><a href="#scrollTo=zVmDZeIAIcja">выгрузка на файлообменники</a></li><li><a href="#scrollTo=k98WImeXH5pK">запаковка/распаковка архивов</a></li><li><a href="#scrollTo=Oh37kTko2shA">операции с папками/файлами/симлинками</a></li></ul></details>

# %%
#@title Прунинг моделей (с поддержкой v2)
import os
from os import path
from pathlib import Path
import enum
from google.colab import output
if not os.path.exists("/content/stable-diffusion-prune/prune.py"):
  from google.colab import output
  # %cd /content/
  # !git clone https://github.com/saftle/stable-diffusion-prune
  output.clear()
  print("Установка зависимостей...")
  #если ModuleNotFoundError:
    #!pip -q install -r https://github.com/AUTOMATIC1111/stable-diffusion-webui/raw/master/requirements.txt
  output.clear()
#@markdown Сперва нужно указать путь до исходной модели (для пруна одиночного файла) или папки с моделями (для пакетной обработки)
источник = "/content/stable-diffusion-webui/models/Stable-diffusion/radiantV3_radiantV3.ckpt" #@param {type:"string"}
добавлять_суффиксы_к_имени = True #@param {type:"boolean"}
удалить_исходник = True #@param {type:"boolean"}
сконвертировать_в_safetensors = True #@param {type:"boolean"}
#@markdown Галочками нужно отметить параметры прунинга:<br>
#@markdown `fp16 - конвертировать в float16` <br> `ema - оставить только EMA данные` <br> `no_clip - удалить веса CLIP` <br> `no_vae - удалить веса VAE` <br> `no_depth - удалить данные глубины (для моделей v2)` <br> `no_unet - удалить веса UNet`
fp16 = True #@param {type:"boolean"}
ema = False #@param {type:"boolean"}
no_clip = False #@param {type:"boolean"}
no_vae = False #@param {type:"boolean"}
no_depth = False #@param {type:"boolean"}
no_unet = False #@param {type:"boolean"}

if сконвертировать_в_safetensors:
  if not os.path.exists("/usr/local/lib/python3.8/dist-packages/safetensors"):
    # !pip -q install safetensors
    output.clear()
  if not os.path.exists("/usr/local/lib/python3.8/dist-packages/pytorch_lightning"):
    # !pip -q install pytorch-lightning
    output.clear()
  if not os.path.exists("/usr/local/lib/python3.8/dist-packages/torchsde"):
    # !pip -q install torchsde
    output.clear()
  if not os.path.exists("/usr/local/lib/python3.8/dist-packages/pandas"):
    # !pip -q install pandas
    output.clear()

if fp16:
  flpnt16 = "--fp16"
  f16 = "_fp16"
if not fp16:
  flpnt16 = ""
  f16 = ""

if ema:
  exmovaver = "--ema"
  em = "_ema"
if not ema:
  exmovaver = ""
  em = ""

if no_clip:
  clip = "--no-clip"
  clp = "_no-clip"
if not no_clip:
  clip = ""
  clp = ""

if no_vae:
  vae = "--no-vae"
  nv = "_no-vae"
if not no_vae:
  vae = ""
  nv = ""

if no_depth:
  depth = "--no-depth"
  nd = "_no-depth"
if not no_depth:
  depth = ""
  nd = ""

if no_unet:
  unet = "--no-unet"
  nu = "_no-unet"
if not no_unet:
  unet = ""
  nu = ""
ckptpath = Path(источник)
folderpath = os.path.dirname(источник) + "/"
if добавлять_суффиксы_к_имени:
  suff = f16 + em + clp + nv + nd + nu
else:
  suff = "_temp"
extention = os.path.splitext(источник)[-1]
outputname = folderpath + ckptpath.stem + suff + extention
input_type = os.path.isfile(источник)
# Обработка одиночного файла
if input_type:
  print("\033[01;38;05;136mПрунинг модели...")
  # !python /content/stable-diffusion-prune/prune.py {flpnt16} {exmovaver} {clip} {vae} {depth} {unet} "{источник}" "{outputname}"
  print("\033[01;38;05;34mГотово!")
  class SIZE_UNIT(enum.Enum):
    BYTES = 1
    KB = 2
    MB = 3
    GB = 4
  def convert_size(size_in_bytes, unit):
    if unit == SIZE_UNIT.KB:
        return size_in_bytes/1024
    elif unit == SIZE_UNIT.MB:
        return size_in_bytes/(1024*1024)
    elif unit == SIZE_UNIT.GB:
        return size_in_bytes/(1024*1024*1024)
    else:
        return size_in_bytes
  def get_file_size(file_name, size_type = SIZE_UNIT.BYTES ):
    size = os.path.getsize(file_name)
    return convert_size(size, size_type)
  size_in = get_file_size(источник, SIZE_UNIT.GB)
  size_out = get_file_size(outputname, SIZE_UNIT.GB)
  print('Размер новой модели:', round(size_out, 2) ,  'Гб!\nА размер исходной:  ', round(size_in, 2),  'Гб!')
  if удалить_исходник:
    # !rm "{источник}"
  if not добавлять_суффиксы_к_имени:
    rename = outputname.replace("_temp", "")
    os.rename(outputname, rename)
    outputname = rename
  if сконвертировать_в_safetensors:
    sftname = path.splitext(outputname)[0]
    import torch
    from safetensors.torch import save_file
    try:
      weights = torch.load(f"{outputname}")["state_dict"]
      save_file(weights, f"{sftname}.safetensors")
      # !rm {outputname}
    except RuntimeError:
      print("сконвертировать на GPU не получилось!\nконвертирую на CPU")
      weights = torch.load(f"{исходная_ckpt}", map_location=torch.device('cpu'))["state_dict"]
      save_file(weights, f"{sfname}.safetensors")
      # !rm {outputname}
    except ValueError:
      print(f'\033[38;05;143mМодель {f} содержит код NovelAI, колаб возможно крашнется из-за нехватки памяти!\033[0m')
      with torch.no_grad():
        weights = torch.load(f"{outputname}")["state_dict"]
        weights.pop("state_dict")
        sft = f"{outputname.replace('.ckpt', '')}.safetensors"
        print(f'Пытаюсь сохранить {sft}...')
        save_file(weights, sft)
        print(f'Успешно сохранил {sft}')
        # !rm {outputname}
    except KeyError:
      with torch.no_grad():
        weights = torch.load(f"{outputname}")
        sft = f"{outputname.replace('.ckpt', '')}.safetensors"
        print(f'Пытаюсь сохранить {sft}...')
        save_file(weights, sft)
        print(f'Успешно сохранил {sft}')
        # !rm {outputname}
    except Exception as er:
      print(f'\033[01;38;05;167mОшибка конвертации: {er}\033[0m')
# Обработка папки   
if not input_type:
  print("пакетный прунинг")
  ckptfiles = os.listdir(источник)
  for f in ckptfiles:
    if f.lower().endswith('.ckpt'):
      inputckpt = источник + "/" + f
      ext = os.path.splitext(inputckpt)[-1]
      outckpt = источник + "/" + os.path.splitext(f)[0] + suff + ext
      print(f"\033[01;38;05;136mВыполняется сжатие: \033[01;38;05;38m{f}\033[m")
      # !python /content/stable-diffusion-prune/prune.py {flpnt16} {exmovaver} {clip} {vae} {depth} {unet} "{inputckpt}" "{outckpt}"
      class SIZE_UNIT(enum.Enum):
        BYTES = 1
        KB = 2
        MB = 3
        GB = 4
      def convert_size(size_in_bytes, unit):
        if unit == SIZE_UNIT.KB:
            return size_in_bytes/1024
        elif unit == SIZE_UNIT.MB:
            return size_in_bytes/(1024*1024)
        elif unit == SIZE_UNIT.GB:
            return size_in_bytes/(1024*1024*1024)
        else:
            return size_in_bytes
      def get_file_size(file_name, size_type = SIZE_UNIT.BYTES ):
        size = os.path.getsize(file_name)
        return convert_size(size, size_type)
      size_in = get_file_size(inputckpt, SIZE_UNIT.GB)
      size_out = get_file_size(outckpt, SIZE_UNIT.GB)
      print('Размер новой модели:', round(size_out, 2) ,  'Гб!\nА размер исходной:  ', round(size_in, 2),  'Гб!')
      if удалить_исходник:
        # !rm {inputckpt}
      if not добавлять_суффиксы_к_имени:
        renamemodel = outckpt.replace("_temp", "")
        os.rename(outckpt, renamemodel)
        outckpt = renamemodel
      if сконвертировать_в_safetensors:
        sftname = path.splitext(outckpt)[0]
        import torch
        from safetensors.torch import save_file
        try:
          weights = torch.load(f"{outckpt}")["state_dict"]
          save_file(weights, f"{sftname}.safetensors")
          # !rm {outckpt}
        except RuntimeError:
          print("сконвертировать на GPU не получилось!\nконвертирую на CPU")
          weights = torch.load(f"{исходная_ckpt}", map_location=torch.device('cpu'))["state_dict"]
          save_file(weights, f"{sfname}.safetensors")
          # !rm {outckpt}
        except ValueError:
          print(f'\033[38;05;143mМодель {f} содержит код NovelAI, колаб возможно крашнется из-за нехватки памяти!\033[0m')
          with torch.no_grad():
            weights = torch.load(f"{outckpt}")["state_dict"]
            weights.pop("state_dict")
            sft = f"{outckpt.replace('.ckpt', '')}.safetensors"
            print(f'Пытаюсь сохранить {sft}...')
            save_file(weights, sft)
            print(f'Успешно сохранил {sft}')
            # !rm {outckpt}
        except KeyError:
          with torch.no_grad():
            weights = torch.load(f"{outckpt}")
            sft = f"{outckpt.replace('.ckpt', '')}.safetensors"
            print(f'Пытаюсь сохранить {sft}...')
            save_file(weights, sft)
            print(f'Успешно сохранил {sft}')
            # !rm {outckpt}
        except Exception as er:
          print(f'\033[01;38;05;167mОшибка конвертации: {er}\033[0m')

        print("\033[01;38;05;34mМодель сохранена в safetensors")
      continue
  print("---------------------------\n\033[01;38;05;34mВсё!")

#@markdown <center> <a href="#scrollTo=gnzJeBa5OYO3">🔝</a>&emsp;<a href="#scrollTo=R-xAdMA5wxXd">🚀</a></center>
#@markdown <details><summary>быстрые ссылки</summary><ul><li><a href="#scrollTo=10iWu8h1UTvQ">установка и запуск</a></li><li><a href="#scrollTo=MTex_2fJwYjn">выбор и установка нескольких моделей</a></li><li><a href="#scrollTo=R-xAdMA5wxXd">запуск/перезапуск</a></li><li><a href="#scrollTo=V-2LlLHZPgoB">скачивание архива с картинками</a></li><li><a href="#scrollTo=w_29ofOEGng_">подключение/переподключение/сброс кэша гуглодиска</a></li><li><a href="#scrollTo=TuwHDqutjgZd">массовая загрузка по прямым ссылкам</a></li><li><a href="#scrollTo=62QDyjXtYHjF">загрузчик моделей с civitai.com</a></li><li><a href="#scrollTo=VirGjpcNCCKX">скачивание с торрентов</a></li><li><a href="#scrollTo=heHty0pzVYjw">прунинг и конвертация моделей</a></li><li><a href="#scrollTo=j7N-__N4f9uY">выгрузка моделей на HuggingFace</a></li><li><a href="#scrollTo=zVmDZeIAIcja">выгрузка на файлообменники</a></li><li><a href="#scrollTo=k98WImeXH5pK">запаковка/распаковка архивов</a></li><li><a href="#scrollTo=Oh37kTko2shA">операции с папками/файлами/симлинками</a></li></ul></details>

# %%
#@title Альтернативный прунер, если с другими не получилось { display-mode: "form" }
моделька = "/content/new/Radiant_v3.ckpt" #@param {type:"string"}
import os
from google.colab import output
if not os.path.exists("/content/pruner/prune-ckpt.py"):
  # !wget -nv https://github.com/pesser/stable-diffusion/raw/main/scripts/prune-ckpt.py -P /content/pruner
try:
    import fire 
except ImportError:
    # !pip -q install fire
try:
    import torch-fidelity
except ImportError:
    # !pip -q torch-fidelity
try:
    import einops 
except ImportError:
    # !pip -q install einops
output.clear()
try:
  # !python /content/pruner/prune-ckpt.py {моделька} --keep_only_ema
except KeyError:
  print("не получилось, попробуем другой метод...")
  if not os.path.exists("/content/pruner/prune_ckpt.py"):
    # !wget -nv https://github.com/PR0LAPSE/StableDiffusionWebUIColab/raw/main/src/prune_ckpt.py -P /content/pruner
    # !python /content/pruner/prune_ckpt.py {моделька} --keep_only_ema
    print("УСПЕХ!")
except Exception as er:
  print(f"Ошибка: {er} \nВозможно стоит попробовать метод через слияние модели самой с собой с 0 смешиванием через ВебУИ Автоматик111 с опцией fp16")
#@markdown Некоторые заковыристые миксы, которые содержат хрен пойми какие модели, в том числе с кодом из НовелАИ, по нескольку раз перемиксованные, не получается отпрунить стандартными методами. Этот вариант может иногда помочь (сбрасывает состояние оптимизатора и не-ЕМА веса), после него полученую модель нужно будет пропустить через обычный прунер, для получения fp16 и safensor.

#@markdown <center> <a href="#scrollTo=gnzJeBa5OYO3">🔝</a>&emsp;<a href="#scrollTo=R-xAdMA5wxXd">🚀</a></center>
#@markdown <details><summary>быстрые ссылки</summary><ul><li><a href="#scrollTo=10iWu8h1UTvQ">установка и запуск</a></li><li><a href="#scrollTo=MTex_2fJwYjn">выбор и установка нескольких моделей</a></li><li><a href="#scrollTo=R-xAdMA5wxXd">запуск/перезапуск</a></li><li><a href="#scrollTo=V-2LlLHZPgoB">скачивание архива с картинками</a></li><li><a href="#scrollTo=w_29ofOEGng_">подключение/переподключение/сброс кэша гуглодиска</a></li><li><a href="#scrollTo=TuwHDqutjgZd">массовая загрузка по прямым ссылкам</a></li><li><a href="#scrollTo=62QDyjXtYHjF">загрузчик моделей с civitai.com</a></li><li><a href="#scrollTo=VirGjpcNCCKX">скачивание с торрентов</a></li><li><a href="#scrollTo=heHty0pzVYjw">прунинг и конвертация моделей</a></li><li><a href="#scrollTo=j7N-__N4f9uY">выгрузка моделей на HuggingFace</a></li><li><a href="#scrollTo=zVmDZeIAIcja">выгрузка на файлообменники</a></li><li><a href="#scrollTo=k98WImeXH5pK">запаковка/распаковка архивов</a></li><li><a href="#scrollTo=Oh37kTko2shA">операции с папками/файлами/симлинками</a></li></ul></details>

# %%
#@title Конвертор 🥒ckpt в 🤗safetensors (пакетный и одиночный режим)
папка_ckpt = "/content/stable-diffusion-webui/models/Stable-diffusion/" #@param {type:"string"}
import os
from os import path
from google.colab import output
if not os.path.exists("/usr/local/lib/python3.8/dist-packages/safetensors"):
  # !pip -q install safetensors
  output.clear()
if not os.path.exists("/usr/local/lib/python3.8/dist-packages/pytorch_lightning"):
  # !pip -q install pytorch-lightning
  output.clear()
if not os.path.exists("/usr/local/lib/python3.8/dist-packages/torchsde"):
  # !pip -q install torchsde
  output.clear()
if not os.path.exists("/usr/local/lib/python3.8/dist-packages/pandas"):
  # !pip -q install pandas
  output.clear()
import torch
from safetensors.torch import save_file
# %cd {папка_ckpt}
files = os.listdir()
for f in files:
  if f.lower().endswith('.ckpt'):
    print(f'Загружаю {f}...')
    fn = f"{f.replace('.ckpt', '')}.safetensors"
    if fn in files:
      print(f'\033[38;05;136mПропуск, поскольку {fn} уже существует.\033[0m')
      continue
    if "novelai" in fn:
      try:
        with torch.no_grad():
          weights = torch.load(f)["state_dict"]
          weights.pop("state_dict")
          fn = f"{f.replace('.ckpt', '')}.safetensors"
          print(f'Пытаюсь сохранить {fn}...')
          save_file(weights, fn)
          print(f'Успешно сохранил {fn}')
          continue
      except RuntimeError:
        with torch.no_grad():
          weights = torch.load(f, map_location=torch.device('cpu'))["state_dict"]
          weights.pop("state_dict")
          fn = f"{f.replace('.ckpt', '')}.safetensors"
          print(f'Пытаюсь сохранить {fn}...')
          save_file(weights, fn)
          print(f'Успешно сохранил {fn}')
          continue
    try:
      with torch.no_grad():
        weights = torch.load(f)["state_dict"]
        fn = f"{f.replace('.ckpt', '')}.safetensors"
        print(f'Сохраняю {fn}...')
        save_file(weights, fn)
    except EOFError:
      print(f'\033[01;38;05;167mФайл {f} поврежден, недокачан, или не является файлом модели!\033[0m')
    except KeyError:
      # !sleep 3
      with torch.no_grad():
        weights = torch.load(f)
        fn = f"{f.replace('.ckpt', '')}.safetensors"
        print(f'Пытаюсь сохранить {fn}...')
        save_file(weights, fn)
    except ValueError:
      # !sleep 3
      print(f'\033[38;05;143mМодель {f} содержит код NovelAI, сейчас колаб крашнется из-за нехватки памяти!\033[0m')
      with torch.no_grad():
        weights = torch.load(f)["state_dict"]
        weights.pop("state_dict")
        fn = f"{f.replace('.ckpt', '')}.safetensors"
        print(f'Пытаюсь сохранить {fn}...')
        save_file(weights, fn)
        print(f'Успешно сохранил {fn}')
    except RuntimeError:
      with torch.no_grad():
        weights = torch.load(f, map_location=torch.device('cpu'))["state_dict"]
        fn = f"{f.replace('.ckpt', '')}.safetensors"
        print(f'Пытаюсь сохранить {fn}...')
        save_file(weights, fn)
        print(f'Успешно сохранил {fn}')
    except Exception as ex:
      print(f'\033[01;38;05;167mОшибка конвертации {f}: {ex}\033[0m')
print('\033[38;05;34mГотово!\033[0m')
# %cd /content/

#@markdown <center> <a href="#scrollTo=gnzJeBa5OYO3">🔝</a>&emsp;<a href="#scrollTo=R-xAdMA5wxXd">🚀</a></center>
#@markdown <details><summary>быстрые ссылки</summary><ul><li><a href="#scrollTo=10iWu8h1UTvQ">установка и запуск</a></li><li><a href="#scrollTo=MTex_2fJwYjn">выбор и установка нескольких моделей</a></li><li><a href="#scrollTo=R-xAdMA5wxXd">запуск/перезапуск</a></li><li><a href="#scrollTo=V-2LlLHZPgoB">скачивание архива с картинками</a></li><li><a href="#scrollTo=w_29ofOEGng_">подключение/переподключение/сброс кэша гуглодиска</a></li><li><a href="#scrollTo=TuwHDqutjgZd">массовая загрузка по прямым ссылкам</a></li><li><a href="#scrollTo=62QDyjXtYHjF">загрузчик моделей с civitai.com</a></li><li><a href="#scrollTo=VirGjpcNCCKX">скачивание с торрентов</a></li><li><a href="#scrollTo=heHty0pzVYjw">прунинг и конвертация моделей</a></li><li><a href="#scrollTo=j7N-__N4f9uY">выгрузка моделей на HuggingFace</a></li><li><a href="#scrollTo=zVmDZeIAIcja">выгрузка на файлообменники</a></li><li><a href="#scrollTo=k98WImeXH5pK">запаковка/распаковка архивов</a></li><li><a href="#scrollTo=Oh37kTko2shA">операции с папками/файлами/симлинками</a></li></ul></details>

# %%
#@title Конвертор 🥒ckpt в 🤗safetensors для базовых моделей (одиночный режим)
#@markdown После конвертации модель в новом формате будет лежать рядом с исходной в той же папке. [GUI-вариант](https://github.com/diStyApps/Safe-and-Stable-Ckpt2Safetensors-Conversion-Tool-GUI#downloads) для Windows/Linux.
исходная_ckpt = "/content/stable-diffusion-webui/models/Stable-diffusion/model.ckpt" #@param {type:"string"}
from google.colab import output
import os
from os import path

ckpt_name = path.basename(r'$исходная_ckpt')
sfname = path.splitext(исходная_ckpt)[0]

if not os.path.exists("/usr/local/lib/python3.8/dist-packages/safetensors"):
  # !pip -q install safetensors
  output.clear()
else:
  None

if not os.path.exists("/usr/local/lib/python3.8/dist-packages/pytorch_lightning"):
  # !pip -q install pytorch-lightning
  output.clear()
else:
  None

if not os.path.exists("/usr/local/lib/python3.8/dist-packages/torchsde"):
  # !pip -q install torchsde
  output.clear()
else:
  None

if not os.path.exists("/usr/local/lib/python3.8/dist-packages/pandas"):
  # !pip -q install pandas
  output.clear()
else:
  None

print("\033[01;38;05;136mКонвертирую...\033[")
import torch
from safetensors.torch import save_file
try:
  weights = torch.load(f"{исходная_ckpt}")["state_dict"]
  save_file(weights, f"{sfname}.safetensors")
  print("\033[01;38;05;34mГотово!")
except KeyError:
  print("модель содержит код NAI, с этим могут быть проблемы!\nконвертирую другим способом (протестируй потом работоспособность модели)")
  weights = torch.load(f"{исходная_ckpt}", map_location=torch.device('cpu'))
  save_file(weights, f"{sfname}.safetensors")
  print("\033[01;38;05;34mГотово!")
except RuntimeError:
  print("сконвертировать на GPU не получилось!\nконвертирую на CPU (протестируй потом работоспособность модели)")
  weights = torch.load(f"{исходная_ckpt}", map_location=torch.device('cpu'))["state_dict"]
  save_file(weights, f"{sfname}.safetensors")
  print("\033[01;38;05;34mГотово!")
except FileNotFoundError:
  print("указан неверный путь!")
except Exception as er:
  print(f"Ошибка: {er}")


#@markdown <center> <a href="#scrollTo=gnzJeBa5OYO3">🔝</a>&emsp;<a href="#scrollTo=R-xAdMA5wxXd">🚀</a></center>
#@markdown <details><summary>быстрые ссылки</summary><ul><li><a href="#scrollTo=10iWu8h1UTvQ">установка и запуск</a></li><li><a href="#scrollTo=MTex_2fJwYjn">выбор и установка нескольких моделей</a></li><li><a href="#scrollTo=R-xAdMA5wxXd">запуск/перезапуск</a></li><li><a href="#scrollTo=V-2LlLHZPgoB">скачивание архива с картинками</a></li><li><a href="#scrollTo=w_29ofOEGng_">подключение/переподключение/сброс кэша гуглодиска</a></li><li><a href="#scrollTo=TuwHDqutjgZd">массовая загрузка по прямым ссылкам</a></li><li><a href="#scrollTo=62QDyjXtYHjF">загрузчик моделей с civitai.com</a></li><li><a href="#scrollTo=VirGjpcNCCKX">скачивание с торрентов</a></li><li><a href="#scrollTo=heHty0pzVYjw">прунинг и конвертация моделей</a></li><li><a href="#scrollTo=j7N-__N4f9uY">выгрузка моделей на HuggingFace</a></li><li><a href="#scrollTo=zVmDZeIAIcja">выгрузка на файлообменники</a></li><li><a href="#scrollTo=k98WImeXH5pK">запаковка/распаковка архивов</a></li><li><a href="#scrollTo=Oh37kTko2shA">операции с папками/файлами/симлинками</a></li></ul></details>

# %%
#@title Конвертор 🤗safetensors в 🥒ckpt (пакетный и одиночный режим){ display-mode: "form" }
#!pip -q install jax[cpu] flax accelerate transformers ftfy OmegaConf torch safetensors git+https://github.com/huggingface/diffusers
try:
    import jax 
except ImportError:
    # !pip -q install jax[cpu]
try:
    import flax
except ImportError:
    # !pip -q install flax
try:
    import accelerate
except ImportError:
    # !pip -q install accelerate
try:
    import transformers
except ImportError:
    # !pip -q install transformers
try:
    import ftfy
except ImportError:
    # !pip -q install ftfy
try:
    import omegaconf
except ImportError:
    # !pip -q install omegaconf
try:
    import torch
except ImportError:
    # !pip -q install torch
try:
    import safetensors
except ImportError:
    # !pip -q install safetensors
try:
    import diffusers
except ImportError:
    # !pip -q install git+https://github.com/huggingface/diffusers
except AttributeError:
  print('требуется другая версия Pillow/PIL.\nна свой страх и риск, можешь переустановить:\n\033[1;36m!pip install Pillow==7.1.2\n!pip install PIL\n!pip install image\033[0m/nили скопировать ячейку в пустрой блокнот без GPU')
import os
from pathlib import Path
import numpy as np
from diffusers import FlaxStableDiffusionPipeline, StableDiffusionPipeline
import torch
from safetensors.torch import save_file, load_file
safetensors = "/content/AbyssOrangeMix" #@param {type:"string"}
удалить_исходник = True #@param {type:"boolean"}
input_type = os.path.isfile(safetensors)
if input_type:
  #ckpt_name = Path(safetensors).stem + ".ckpt"
  ckpt_path = os.path.splitext(safetensors)[0]  + ".ckpt"
  weights = load_file(f"{safetensors}", device="cpu")
  torch.save(weights, ckpt_path)
  if удалить_исходник:
    # !rm {safetensors}
  print("готово!")
if not input_type:
  print("пакетная конвертация")
  #%cd {safetensors}
  stfiles = os.listdir(safetensors)
  for f in stfiles:
    if f.lower().endswith('.safetensors'):
      inputsf = safetensors + "/" + f
      ckpt_path = os.path.splitext(inputsf)[0]  + ".ckpt"
      weights = load_file(f"{inputsf}", device="cpu")
      torch.save(weights, ckpt_path)
      print(f"сохранен: {ckpt_path}")
      if удалить_исходник:
        # !rm {inputsf}
    continue
  print("готово!")
#@markdown Конвертор нужен, чтобы отпрунить модель, а safetensors пока не поддерживает прунинг. Берем большой сейфтензор, конвертируем в старый формат, <a href="#scrollTo=heHty0pzVYjw">пруним</a> по вкусу, <a href="#scrollTo=QuW09EK-mIvg">конвертируем обратно</a> в сейфтензорс

#@markdown <center> <a href="#scrollTo=gnzJeBa5OYO3">🔝</a>&emsp;<a href="#scrollTo=R-xAdMA5wxXd">🚀</a></center>
#@markdown <details><summary>быстрые ссылки</summary><ul><li><a href="#scrollTo=10iWu8h1UTvQ">установка и запуск</a></li><li><a href="#scrollTo=MTex_2fJwYjn">выбор и установка нескольких моделей</a></li><li><a href="#scrollTo=R-xAdMA5wxXd">запуск/перезапуск</a></li><li><a href="#scrollTo=V-2LlLHZPgoB">скачивание архива с картинками</a></li><li><a href="#scrollTo=w_29ofOEGng_">подключение/переподключение/сброс кэша гуглодиска</a></li><li><a href="#scrollTo=TuwHDqutjgZd">массовая загрузка по прямым ссылкам</a></li><li><a href="#scrollTo=62QDyjXtYHjF">загрузчик моделей с civitai.com</a></li><li><a href="#scrollTo=VirGjpcNCCKX">скачивание с торрентов</a></li><li><a href="#scrollTo=heHty0pzVYjw">прунинг и конвертация моделей</a></li><li><a href="#scrollTo=j7N-__N4f9uY">выгрузка моделей на HuggingFace</a></li><li><a href="#scrollTo=zVmDZeIAIcja">выгрузка на файлообменники</a></li><li><a href="#scrollTo=k98WImeXH5pK">запаковка/распаковка архивов</a></li><li><a href="#scrollTo=Oh37kTko2shA">операции с папками/файлами/симлинками</a></li></ul></details>

# %%
#@title Конвертер моделей pytorch .bin в .ckpt { display-mode: "form" }

#@markdown нужно указать путь до папки с файлами модели формата питорч, а не просто файла .bin!

#@markdown <details><summary><font color=red>как должно выглядить <u>содержимое</u> папки</font></summary><img src='https://dl.uploadgram.me/6373cae8820b1h?dl' height='500' /></details>

#@markdown [пример такой модели](https://huggingface.co/lambdalabs/sd-image-variations-diffusers/tree/main) - скачивать нужно всю папку, и вот такая папка указывается в параметрах, именно вся эта папка будет сконвертированна в один файлик модели с расширением .ckpt, пригодным для WebUI

#@markdown Если папку с моделью ты еще не скачал самостоятельно на гуглодиск, можешь вставить ссылку на репозиторий модели в поле ниже, тогда модель временно скачается в колаб и сконвертируется автоматически в ckpt куда ты укажешь, указывать дополнительно путь до нее будет не нужно, если указана ссылка на модель - поле пути до папки модели будет проигнорированно.

#@markdown Корректная ссылка должна выглядить только так: `https://huggingface.co/Юзер_Нейм/Модель_Нейм` а репозиторий должен быть открытым с доступом без всяких подтверждений лицензионных соглашений. В противном случае - скачайте папку вручную.

#@markdown Если будешь указывать путь до своей папки - ссылку удали из ее поля

ссылка_на_репозиторий_модели = "https://huggingface.co/IfanSnek/JohnDiffusion" #@param {type:"string"}

#@markdown  <hr>
# !git clone {ссылка_на_репозиторий_модели}
import os
import os.path
from google.colab import output
from IPython.display import clear_output
папка_модели_питорч = "/content/JohnDiffusion" #@param {type:"string"}
куда_сохранить_ckpt = "/content/" #@param {type:"string"}
if not ссылка_на_репозиторий_модели or "huggingface.co" not in ссылка_на_репозиторий_модели:
  ckpt_name = os.path.basename(f"{папка_модели_питорч}")
  scrpath = "/content/.config/converter/ckptconverter.py"
  # !curl -s -L --create-dirs -o {scrpath} https://github.com/PR0LAPSE/StableDiffusionWebUIColab/raw/main/src/ckptconverter.py
  # !python {scrpath} --model_path={папка_модели_питорч} --checkpoint_path={куда_сохранить_ckpt}/{ckpt_name}.ckpt
  if os.path.exists(куда_сохранить_ckpt+'/' + ckpt_name + '.ckpt'):
      output.clear()
      print("[1;32mВСЁ! модель в формате ckpt успешно создана.")
      print(куда_сохранить_ckpt+'/' + ckpt_name + '.ckpt')
      output.eval_js('new Audio("https://dl.uploadgram.me/6374ad94c98a5h?dl").play()')
  else:
      print("[1;31mчто-то пошло не так...")
      output.eval_js('new Audio("https://dl.uploadgram.me/6374ad9346cc1h?dl").play()')
else:
  # !git lfs install
  output.clear()
  # !cd /content
  output.clear()
  # !git clone {ссылка_на_репозиторий_модели}
  output.clear()
  ckpt_name = '/'.join(ссылка_на_репозиторий_модели.split('/')[-1:])
  папка_модели_питорч = f"/content/{ckpt_name}"
  scrpath = "/content/.config/converter/ckptconverter.py"
  # !curl -s -L --create-dirs -o {scrpath} https://github.com/PR0LAPSE/StableDiffusionWebUIColab/raw/main/src/ckptconverter.py
  # !python {scrpath} --model_path={папка_модели_питорч} --checkpoint_path={куда_сохранить_ckpt}/{ckpt_name}.ckpt
  if os.path.exists(куда_сохранить_ckpt+'/' + ckpt_name + '.ckpt'):
    # !rm -rf /content/{ckpt_name}
    output.clear()
    print("[1;32mВСЁ! модель в формате ckpt успешно создана.")
    print(куда_сохранить_ckpt+'/' + ckpt_name + '.ckpt')
    output.eval_js('new Audio("https://dl.uploadgram.me/6374ad94c98a5h?dl").play()')
  else:
    # !rm -rf /content/{ckpt_name}
    print("[1;31mчто-то пошло не так...")
    output.eval_js('new Audio("https://dl.uploadgram.me/6374ad9346cc1h?dl").play()')

#@markdown <center> <a href="#scrollTo=gnzJeBa5OYO3">🔝</a>&emsp;<a href="#scrollTo=R-xAdMA5wxXd">🚀</a></center>
#@markdown <details><summary>быстрые ссылки</summary><ul><li><a href="#scrollTo=10iWu8h1UTvQ">установка и запуск</a></li><li><a href="#scrollTo=MTex_2fJwYjn">выбор и установка нескольких моделей</a></li><li><a href="#scrollTo=R-xAdMA5wxXd">запуск/перезапуск</a></li><li><a href="#scrollTo=V-2LlLHZPgoB">скачивание архива с картинками</a></li><li><a href="#scrollTo=w_29ofOEGng_">подключение/переподключение/сброс кэша гуглодиска</a></li><li><a href="#scrollTo=TuwHDqutjgZd">массовая загрузка по прямым ссылкам</a></li><li><a href="#scrollTo=62QDyjXtYHjF">загрузчик моделей с civitai.com</a></li><li><a href="#scrollTo=VirGjpcNCCKX">скачивание с торрентов</a></li><li><a href="#scrollTo=heHty0pzVYjw">прунинг и конвертация моделей</a></li><li><a href="#scrollTo=j7N-__N4f9uY">выгрузка моделей на HuggingFace</a></li><li><a href="#scrollTo=zVmDZeIAIcja">выгрузка на файлообменники</a></li><li><a href="#scrollTo=k98WImeXH5pK">запаковка/распаковка архивов</a></li><li><a href="#scrollTo=Oh37kTko2shA">операции с папками/файлами/симлинками</a></li></ul></details>

# %% [markdown]
# #👈 Выгрузка моделей на HuggingFace

# %%
#@title Выгрузка моделей/файлов до 5 Гб { display-mode: "form" }
HuggingFace_токен = "****************************************" #@param {type:"string"}
источник = "\u043F\u0430\u043F\u043A\u0430" #@param ["\u043F\u0430\u043F\u043A\u0430", "\u0444\u0430\u0439\u043B"]
что_загрузить = "/content/\u043A\u0430\u043A\u043E\u0439-\u0442\u043E/\u0444\u0430\u0439\u043B.safetensors" #@param {type:"string"}
репозиторий = "\u044E\u0437\u0435\u0440\u043D\u0435\u0439\u043C/\u0440\u0435\u043F\u043E\u0437\u0438\u0442\u043E\u0440\u0438\u0439" #@param {type:"string"}
#@markdown Токент нужно получить [здесь](https://huggingface.co/settings/tokens). При создании токена нужно указать **Role : Write**. <details><summary>скрин создания токена</summary><img src="https://dl.uploadgram.me/6373ee91cbbe5h?dl" height='300px'></details><br> В качестве источника можно указать путь до одного файла модели, или путь до папки с несколькими файлами - все содержимое папки будет отправленно в указанный репозиторий. В поле "репозиторий" нужно вписать твой юзернейм на HuggingFace и имя репозитория через слеш. Если репозитория еще нет - его <a href='https://huggingface.co/new'>нужно создать</a>, он должен быть публичным, чтобы загружаемые файлы потом были доступны по прямым ссылкам. Если в источнике будет файл недопустимого размера (больше 5 гигов) - загрузка даже не начнется, т.к. от дураков стоит проверка на размер файла, без этого случилось переполнение памяти и крах колаба. Для огромных файлов более 5гб нужно использовать ячейку ниже.  
import os
if not os.path.exists("/usr/local/lib/python3.8/dist-packages/huggingface_hub"):
  from google.colab import output
  # !pip install huggingface_hub==0.11.1
  output.clear()

if not HuggingFace_токен or len(HuggingFace_токен) < 36 or "hf_" not in HuggingFace_токен:
  print("Токен указан неверно. Получить токен можно тут: https://huggingface.co/settings/tokens")
else:
  try:
    from huggingface_hub import login
    login(f'{HuggingFace_токен}', add_to_git_credential=True)
  #except ImportError:
    #print('автоматический вход не удался, попробуй сейчас войти сам')
    #from huggingface_hub import notebook_login
    #notebook_login()
  except ValueError:
    print('\033[01;38;05;167mНеверный токен!')
  except Exception as er:
    print(f'\033[01;38;05;167mЧто-то пошло не так. Ошибка: {er}\033[0m \nПробуем прописать токен вручную...')
    if not os.path.exists('/root/.huggingface/token'):
      # !mkdir /root/.huggingface/
      # !touch /root/.huggingface/token
    tw = open("/root/.huggingface/token", "w+")
    tw.write(HuggingFace_токен)
    tw.close()

# !sleep 1

import enum
class SIZE_UNIT(enum.Enum):
   BYTES = 1
   KB = 2
   MB = 3
   GB = 4
def convert_unit(size_in_bytes, unit):
   if unit == SIZE_UNIT.KB:
       return size_in_bytes/1024
   elif unit == SIZE_UNIT.MB:
       return size_in_bytes/(1024*1024)
   elif unit == SIZE_UNIT.GB:
       return size_in_bytes/(1024*1024*1024)
   else:
       return size_in_bytes
import os
def get_file_size(file_name, size_type = SIZE_UNIT.BYTES ):
   size = os.path.getsize(file_name)
   return convert_unit(size, size_type)
file_path = что_загрузить
size = get_file_size(file_path, SIZE_UNIT.GB)
if size > 4.999:
  print('Размер модели : ', size ,  'Гб!\nЭто очень большой размер для данного метода загрузки.\nВоспользуйся методом в ячейке ниже, он предназначен для загрузки файлов более 5Гб.')
else:
  if not что_загрузить or not репозиторий:
    print("Не указан репозиторий или файл/папка для загрузки")
  if источник == "файл":
    from pathlib import Path
    p = Path(f"{что_загрузить}")
    print(p.name)
    print("жди, идет загрузка...")
    from huggingface_hub import HfApi
    api = HfApi()
    api.upload_file(
        path_or_fileobj=f"{что_загрузить}",
        path_in_repo=(p.name),
        repo_id=f"{репозиторий}",
        repo_type="model",
    )
  elif источник == "папка":
    print("жди, идет загрузка...")
    from huggingface_hub import HfApi
    api = HfApi()
    api.upload_folder(
        folder_path=f"{что_загрузить}",
        repo_id=f"{репозиторий}",
        repo_type="model",
    )
  if источник == "папка":
    print(f"загрузка завершена!\nтвои файлы тут: https://huggingface.co/{репозиторий}/tree/main \nвот прямые ссылки на модели:")
    from pathlib import Path
    dlfolder = Path(f"{что_загрузить}")
    for file_name in dlfolder.rglob('*.*'): 
      print(f"https://huggingface.co/{репозиторий}/resolve/main/{file_name.name}\n")
  if источник == "файл":
    filename = os.path.basename(f'{что_загрузить}')
    print(f"загрузка завершена!\nтвои файлы тут: https://huggingface.co/{репозиторий}/tree/main \nпрямая ссылка на модель: https://huggingface.co/{репозиторий}/resolve/main/{filename} ")

#@markdown <center> <a href="#scrollTo=gnzJeBa5OYO3">🔝</a>&emsp;<a href="#scrollTo=R-xAdMA5wxXd">🚀</a></center>
#@markdown <details><summary>быстрые ссылки</summary><ul><li><a href="#scrollTo=10iWu8h1UTvQ">установка и запуск</a></li><li><a href="#scrollTo=MTex_2fJwYjn">выбор и установка нескольких моделей</a></li><li><a href="#scrollTo=R-xAdMA5wxXd">запуск/перезапуск</a></li><li><a href="#scrollTo=V-2LlLHZPgoB">скачивание архива с картинками</a></li><li><a href="#scrollTo=w_29ofOEGng_">подключение/переподключение/сброс кэша гуглодиска</a></li><li><a href="#scrollTo=TuwHDqutjgZd">массовая загрузка по прямым ссылкам</a></li><li><a href="#scrollTo=62QDyjXtYHjF">загрузчик моделей с civitai.com</a></li><li><a href="#scrollTo=VirGjpcNCCKX">скачивание с торрентов</a></li><li><a href="#scrollTo=heHty0pzVYjw">прунинг и конвертация моделей</a></li><li><a href="#scrollTo=j7N-__N4f9uY">выгрузка моделей на HuggingFace</a></li><li><a href="#scrollTo=zVmDZeIAIcja">выгрузка на файлообменники</a></li><li><a href="#scrollTo=k98WImeXH5pK">запаковка/распаковка архивов</a></li><li><a href="#scrollTo=Oh37kTko2shA">операции с папками/файлами/симлинками</a></li></ul></details>

# %%
#@title Выгрузка файлов больше 5 гб { display-mode: "form" }
HuggingFace_токен = "\u0442\u0432\u043E\u0439 \u0442\u043E\u043A\u0435\u043D" #@param {type:"string"}
username = "\u044E\u0437\u0435\u0440\u043D\u0435\u0439\u043C"  #@param {type:"string"}
LFS_репозиторий = "\u0440\u0435\u043F\u043E\u0437\u0438\u0442\u043E\u0440\u0438\u0439" #@param {type:"string"}
что_выгружаем = "/content/models/my_biggest_model.safetensors" #@param {type:"string"}
#@markdown можно указать файл или целую папку с файлами. Если это папка - будет загружено все ее содержимое в репозиторий, но не сама папка, если не поставлена опция "сохранить структуру".
сохранить_структуру = False #@param {type:"boolean"}
#@markdown Копировать в папку репозитория или переместить? Перемещение быстрее, но исходные файлы с диска колаба удалятся, переместившись в папку репы. 
файлы_с_диска = "\u043F\u0435\u0440\u0435\u043C\u0435\u0449\u0430\u0435\u043C" #@param ["копируем", "перемещаем"]


import os
if not os.path.exists("/usr/local/lib/python3.8/dist-packages/huggingface_hub"):
  from google.colab import output
  # !pip install huggingface_hub==0.11.1
  output.clear()
if not HuggingFace_токен or len(HuggingFace_токен) < 36 or "hf_" not in HuggingFace_токен:
  print("Токен указан неверно. Получить токен можно тут: https://huggingface.co/settings/tokens")
else:
  try:
    from huggingface_hub import login
    login(f'{HuggingFace_токен}', add_to_git_credential=True)
  #except ImportError:
    #print('автоматический вход не удался, попробуй сейчас войти сам')
    #from huggingface_hub import notebook_login
    #notebook_login()
  except ValueError:
    print('\033[01;38;05;167mНеверный токен!')
  except Exception as er:
    print(f'\033[01;38;05;167mЧто-то пошло не так. Ошибка: {er}\033[0m \nПробуем прописать токен вручную...')
    if not os.path.exists('/root/.huggingface/token'):
      # !mkdir /root/.huggingface/
      # !touch /root/.huggingface/token
    tw = open("/root/.huggingface/token", "w+")
    tw.write(HuggingFace_токен)
    tw.close()

# !sleep 1

# !git lfs install --skip-smudge

# !git -c filter.lfs.smudge= clone https://huggingface.co/{username}/{LFS_репозиторий}

if сохранить_структуру:
  if файлы_с_диска == "копируем":
    # !cp -f -i -R {что_выгружаем} /content/{LFS_репозиторий}
  elif файлы_с_диска == "перемещаем":
    # !mv -f -i {что_выгружаем} /content/{LFS_репозиторий}
if not сохранить_структуру:
  if файлы_с_диска == "копируем":
    # !cp -f -i -R -t /content/{LFS_репозиторий} {что_выгружаем}
  elif файлы_с_диска == "перемещаем":
    # !mv -f -i -t /content/{LFS_репозиторий} {что_выгружаем}

from huggingface_hub import Repository
repo = Repository(local_dir=f"/content/{LFS_репозиторий}")
# !huggingface-cli lfs-enable-largefiles /content/{LFS_репозиторий}

# !sleep 2

#запустить выгрузку
repo.push_to_hub(commit_message="upload with huggingface-cli")
# !sleep 1
print(f"загрузка завершена!\nтвои файлы тут: https://huggingfce.co/{username}/{LFS_репозиторий}/tree/main")

#@markdown <center> <a href="#scrollTo=gnzJeBa5OYO3">🔝</a>&emsp;<a href="#scrollTo=R-xAdMA5wxXd">🚀</a></center>
#@markdown <details><summary>быстрые ссылки</summary><ul><li><a href="#scrollTo=10iWu8h1UTvQ">установка и запуск</a></li><li><a href="#scrollTo=MTex_2fJwYjn">выбор и установка нескольких моделей</a></li><li><a href="#scrollTo=R-xAdMA5wxXd">запуск/перезапуск</a></li><li><a href="#scrollTo=V-2LlLHZPgoB">скачивание архива с картинками</a></li><li><a href="#scrollTo=w_29ofOEGng_">подключение/переподключение/сброс кэша гуглодиска</a></li><li><a href="#scrollTo=TuwHDqutjgZd">массовая загрузка по прямым ссылкам</a></li><li><a href="#scrollTo=62QDyjXtYHjF">загрузчик моделей с civitai.com</a></li><li><a href="#scrollTo=VirGjpcNCCKX">скачивание с торрентов</a></li><li><a href="#scrollTo=heHty0pzVYjw">прунинг и конвертация моделей</a></li><li><a href="#scrollTo=j7N-__N4f9uY">выгрузка моделей на HuggingFace</a></li><li><a href="#scrollTo=zVmDZeIAIcja">выгрузка на файлообменники</a></li><li><a href="#scrollTo=k98WImeXH5pK">запаковка/распаковка архивов</a></li><li><a href="#scrollTo=Oh37kTko2shA">операции с папками/файлами/симлинками</a></li></ul></details>

# %% [markdown]
# # 👈 Выгрузка файлов на файлообменники

# %%
#@title Загрузка на файлообменники типа anonfiles до 20 Гб на 1 файл
import requests
Cервер = "filechan.org" #@param ["anonfiles.com", "openload.cc", "bayfiles.com", "lolabits.se", "vshare.is", "upvid.cc", "hotfile.io", "rapidshare.nu", "filechan.org", "letsupload.cc", "share-online.is", "megaupload.nz", "myfile.is"]
url = f'https://api.{Cервер}/upload'
Файл = "/content/drive/MyDrive/my_willy.7z" # @param {type: "string"}
x = requests.post(url, files = {'file': open(Файл,'rb')},)
print("\033[01;38;05;46m Твоя ссылка: " + x.json()["data"]["file"]["url"]["full"])
#@markdown <center> <a href="#scrollTo=gnzJeBa5OYO3">🔝</a>&emsp;<a href="#scrollTo=R-xAdMA5wxXd">🚀</a></center>
#@markdown <details><summary>быстрые ссылки</summary><ul><li><a href="#scrollTo=10iWu8h1UTvQ">установка и запуск</a></li><li><a href="#scrollTo=MTex_2fJwYjn">выбор и установка нескольких моделей</a></li><li><a href="#scrollTo=R-xAdMA5wxXd">запуск/перезапуск</a></li><li><a href="#scrollTo=V-2LlLHZPgoB">скачивание архива с картинками</a></li><li><a href="#scrollTo=w_29ofOEGng_">подключение/переподключение/сброс кэша гуглодиска</a></li><li><a href="#scrollTo=TuwHDqutjgZd">массовая загрузка по прямым ссылкам</a></li><li><a href="#scrollTo=62QDyjXtYHjF">загрузчик моделей с civitai.com</a></li><li><a href="#scrollTo=VirGjpcNCCKX">скачивание с торрентов</a></li><li><a href="#scrollTo=heHty0pzVYjw">прунинг и конвертация моделей</a></li><li><a href="#scrollTo=j7N-__N4f9uY">выгрузка моделей на HuggingFace</a></li><li><a href="#scrollTo=zVmDZeIAIcja">выгрузка на файлообменники</a></li><li><a href="#scrollTo=k98WImeXH5pK">запаковка/распаковка архивов</a></li><li><a href="#scrollTo=Oh37kTko2shA">операции с папками/файлами/симлинками</a></li></ul></details>

# %%
#@title Выгрузка на разные файлообменники { display-mode: "form" }
import os
import subprocess
import json
try:
  if not os.path.exists('/content/.config/go-ul_linux_x64'):
    # !wget -P /content/.config https://github.com/bunnykek/go-upload/releases/download/tag/go-ul_linux_x64
    # !chmod 755 /content/.config/go-ul_linux_x64
    from google.colab import output
    output.clear()
  else:
    # !chmod 755 /content/.config/go-ul_linux_x64
    output.clear()
except Exception as er:
  print('Ошибка: ', er)
# !sleep 1
файлообменник = "pixeldrain" #@param ['catbox', 'fileio', 'filemail', 'gofile', 'krakenfiles', 'letsupload', 'mixdrop', 'pixeldrain', 'racaty', 'transfersh', 'uguu', 'wetransfer', 'workupload', 'zippyshare']
файл_для_выгрузки = "/content/output.zip" #@param {type:"string"}
filehost, infile = файлообменник, файл_для_выгрузки
message = "Файл: {0}\nСсылка: {2}"
cwd = '/content/.config/'
def upload(filehost:str, filePath: str):
    subprocess.Popen(["./go-ul_linux_x64", filehost,
                     '-f', infile, '-j', 'response.json'], 
                     cwd=cwd).wait()
    response = json.load(open(cwd+'response.json'))
    if not response['jobs'][-1]['ok']:
        print(f"{response['jobs'][-1]['error_text']}")
    else:
        print(message.format(response['jobs'][-1]['filename'], filehost, response['jobs'][-1]['url']))
upload(filehost, infile)
#@markdown обменник       | лимит  |ǀ|   обменник   | лимит
#@markdown ---------------|--------||---------------|---------------
#@markdown Catbox         | 200 MB |ǀ|  pixeldrain  | 10 GB 
#@markdown file.io        | 2 GB   |ǀ|  Racaty      | 10 GB 
#@markdown Filemail       | 5 GB   |ǀ|  transfer.sh | unlim
#@markdown Gofile         | unlim  |ǀ|  Uguu        | 128 MB
#@markdown KrakenFiles    | 1 GB   |ǀ|  WeTransfer  | 2 GB 
#@markdown LetsUpload.io  | 10 GB  |ǀ|  workupload  | 2 GB
#@markdown MixDrop        | unlim  |ǀ|  zippyshare  | 500 MB 

#@markdown <center> <a href="#scrollTo=gnzJeBa5OYO3">🔝</a>&emsp;<a href="#scrollTo=R-xAdMA5wxXd">🚀</a></center>
#@markdown <details><summary>быстрые ссылки</summary><ul><li><a href="#scrollTo=10iWu8h1UTvQ">установка и запуск</a></li><li><a href="#scrollTo=MTex_2fJwYjn">выбор и установка нескольких моделей</a></li><li><a href="#scrollTo=R-xAdMA5wxXd">запуск/перезапуск</a></li><li><a href="#scrollTo=V-2LlLHZPgoB">скачивание архива с картинками</a></li><li><a href="#scrollTo=w_29ofOEGng_">подключение/переподключение/сброс кэша гуглодиска</a></li><li><a href="#scrollTo=TuwHDqutjgZd">массовая загрузка по прямым ссылкам</a></li><li><a href="#scrollTo=62QDyjXtYHjF">загрузчик моделей с civitai.com</a></li><li><a href="#scrollTo=VirGjpcNCCKX">скачивание с торрентов</a></li><li><a href="#scrollTo=heHty0pzVYjw">прунинг и конвертация моделей</a></li><li><a href="#scrollTo=j7N-__N4f9uY">выгрузка моделей на HuggingFace</a></li><li><a href="#scrollTo=zVmDZeIAIcja">выгрузка на файлообменники</a></li><li><a href="#scrollTo=k98WImeXH5pK">запаковка/распаковка архивов</a></li><li><a href="#scrollTo=Oh37kTko2shA">операции с папками/файлами/симлинками</a></li></ul></details>

# %% [markdown]
# # 👈 Распаковка и запаковка архивов разных форматов

# %%
#@title Распаковка архивов { display-mode: "form" }
import os
import pathlib
from pathlib import Path 
файл_архива = "/content/xenopus_laevis.rar"  # @param {type:"string"}
куда_распаковать = "/content/gdrive/MyDrive/"  # @param {type:"string"}
создать_подпапку = True #@param {type:"boolean"}
#@markdown Если папка не существует - она будет создана, а если не указать место распаковки, архив распакуется в папку /content/распаковка
пароль = "" #@param {type:"string"}
subfolder = os.path.basename(файл_архива).split('.')[0]
arctype = pathlib.Path(f'{файл_архива}').suffix
if пароль:
  passADD = f'-P {пароль}'
else:
  passADD = ''
if not куда_распаковать:
  куда_распаковать = "/content/распаковка"
if создать_подпапку:
  extract_path = куда_распаковать + "/" + subfolder
if not создать_подпапку:
  extract_path = куда_распаковать
def raspakovka():
  if "rar" in arctype or "RAR" in arctype:
    os.makedirs(extract_path, exist_ok=True)
    # !unrar -y x "{файл_архива}" "{extract_path}" {passADD} -o
  else:
    os.makedirs(extract_path, exist_ok=True)
    !7z -y -bt x "{файл_архива}" -o"{extract_path}" {passADD}
if "liz" in arctype or "LIZ" in arctype or "zst" in arctype or "ZST" in arctype or "ace" in arctype or "ACE" in arctype:
    print("\033[01;38;05;167mТип архива \033[01;38;05;178m" + arctype + "\033[01;38;05;167m не поддерживается!\033[39m")
else:
  raspakovka()
#@markdown <center> <a href="#scrollTo=gnzJeBa5OYO3">🔝</a>&emsp;<a href="#scrollTo=R-xAdMA5wxXd">🚀</a></center>
#@markdown <details><summary>быстрые ссылки</summary><ul><li><a href="#scrollTo=10iWu8h1UTvQ">установка и запуск</a></li><li><a href="#scrollTo=MTex_2fJwYjn">выбор и установка нескольких моделей</a></li><li><a href="#scrollTo=R-xAdMA5wxXd">запуск/перезапуск</a></li><li><a href="#scrollTo=V-2LlLHZPgoB">скачивание архива с картинками</a></li><li><a href="#scrollTo=w_29ofOEGng_">подключение/переподключение/сброс кэша гуглодиска</a></li><li><a href="#scrollTo=TuwHDqutjgZd">массовая загрузка по прямым ссылкам</a></li><li><a href="#scrollTo=62QDyjXtYHjF">загрузчик моделей с civitai.com</a></li><li><a href="#scrollTo=VirGjpcNCCKX">скачивание с торрентов</a></li><li><a href="#scrollTo=heHty0pzVYjw">прунинг и конвертация моделей</a></li><li><a href="#scrollTo=j7N-__N4f9uY">выгрузка моделей на HuggingFace</a></li><li><a href="#scrollTo=zVmDZeIAIcja">выгрузка на файлообменники</a></li><li><a href="#scrollTo=k98WImeXH5pK">запаковка/распаковка архивов</a></li><li><a href="#scrollTo=Oh37kTko2shA">операции с папками/файлами/симлинками</a></li></ul></details>

# %%
#@title Создать архив
import os
from pathlib import Path
имя_архива = "sdwui"  # @param {type:"string"}
что_архивировать = "/content/stable-diffusion-webui"  # @param {type:"string"}
пароль = "" #@param {type:"string"}
#@markdown пароль можно не заполнять.<br><small>готовый файл архива будет лежать рядом с иходной папкой/файлом<small>
сжатие = "\u0431\u044B\u0441\u0442\u0440\u043E (zip)" #@param ["быстро (zip)", "хорошо (7z)"]
archpath = Path(что_архивировать)
dirpath = str(archpath.parent) + "/"
if not os.path.exists(что_архивировать):
  print("Источник указан неверно, архивировать нечего...")
else:
  if сжатие == "быстро (zip)":
    if пароль:
      !7z a -p{пароль} -tzip -mx=4 "{имя_архива}.zip" {что_архивировать}
    else:
      !7z a -tzip -mx=4 "{имя_архива}.zip" {что_архивировать}
    print(f"\033[01;38;05;178mВот полный путь до архива:\033[01;38;05;110m {dirpath}{имя_архива}.7z\033[39m")
  elif сжатие == "хорошо (7z)":
    if пароль:
      !7z a -mhe=on -p{пароль} -t7z -m0=lzma2 -mx=9 -mfb=64 -md=1024m -ms=on "{имя_архива}.7z" {что_архивировать}
    else:
      !7z a -t7z -m0=lzma2 -mx=9 -mfb=64 -md=1024m -ms=on "{имя_архива}.7z" {что_архивировать}
    print(f"\033[01;38;05;178mВот полный путь до архива:\033[01;38;05;110m {dirpath}{имя_архива}.7z\033[39m")

#@markdown <center> <a href="#scrollTo=gnzJeBa5OYO3">🔝</a>&emsp;<a href="#scrollTo=R-xAdMA5wxXd">🚀</a></center>
#@markdown <details><summary>быстрые ссылки</summary><ul><li><a href="#scrollTo=10iWu8h1UTvQ">установка и запуск</a></li><li><a href="#scrollTo=MTex_2fJwYjn">выбор и установка нескольких моделей</a></li><li><a href="#scrollTo=R-xAdMA5wxXd">запуск/перезапуск</a></li><li><a href="#scrollTo=V-2LlLHZPgoB">скачивание архива с картинками</a></li><li><a href="#scrollTo=w_29ofOEGng_">подключение/переподключение/сброс кэша гуглодиска</a></li><li><a href="#scrollTo=TuwHDqutjgZd">массовая загрузка по прямым ссылкам</a></li><li><a href="#scrollTo=62QDyjXtYHjF">загрузчик моделей с civitai.com</a></li><li><a href="#scrollTo=VirGjpcNCCKX">скачивание с торрентов</a></li><li><a href="#scrollTo=heHty0pzVYjw">прунинг и конвертация моделей</a></li><li><a href="#scrollTo=j7N-__N4f9uY">выгрузка моделей на HuggingFace</a></li><li><a href="#scrollTo=zVmDZeIAIcja">выгрузка на файлообменники</a></li><li><a href="#scrollTo=k98WImeXH5pK">запаковка/распаковка архивов</a></li><li><a href="#scrollTo=Oh37kTko2shA">операции с папками/файлами/симлинками</a></li></ul></details>

# %% [markdown]
# # 👈 Операции с файлами/папками

# %%
#@title копирование, перемещение, создание символьных ссылок, очистка папок, удаление
import os
import pathlib
from pathlib import Path
откуда = "/content/a" #@param {type:"string"}
куда = "/content/b/c" #@param {type:"string"}
что_делать = "\u0441\u043E\u0437\u0434\u0430\u0442\u044C \u0441\u0438\u043C\u043B\u0438\u043D\u043A\u0438 \u043D\u0430 \u0432\u0441\u0435 \u0441\u043E\u0434\u0435\u0440\u0436\u0438\u043C\u043E\u0435 \u043F\u0430\u043F\u043A\u0438 \u0438\u043B\u0438 \u0444\u0430\u0439\u043B \u0432 \u0434\u0440\u0443\u0433\u043E\u0439 \u043F\u0430\u043F\u043A\u0435" #@param ["копировать только содержимое папки или файл", "копировать файл или папку с ее содержимым в другую папку", "переместить только содержимое папки или файл в другую папку", "переместить папку или файл в другую папку", "создать симлинки на все содержимое папки или файл в другой папке", "создать симлинк на папку или файл в другой папке", "удалить содержимое папки или файл", "удалить папку или файл"]
#@markdown Важно задать источник и тип операции, а если выходная папка не существует - она будет создана, если это возможно. Файлы могут быть перезаписаны, если существуют в месте назначения!
if что_делать == "копировать только содержимое папки или файл":
  if not os.path.exists(откуда):
    print("\033[1;31mисточник указан не верно - он не существует\033[0m")
  else:
    if os.path.isdir(откуда):
      if not os.path.exists(куда):
        if not os.path.isdir(куда):
            os.makedirs(куда)
        else:
          print("\033[1;31mзадай другое имя выходной папки!\n\033[01;38;05;208mимеется файл с точно таким же именем, что не допустимо в линукс!\033[0m")
        print("\033[1;34mкопирование содержимого папки...\033[0m")
        # !cp -v -H -r "{откуда}"/* -t "{куда}"
        print("\033[1;32mкопирование завершено\033[0m")
    else:
      if os.path.isfile(куда):
        print("\033[1;31mзадай другое имя выходной папки!\n\033[01;38;05;208mимеется файл с точно таким же именем, что не допустимо в линукс!\033[0m")
      else:
        print("\033[1;34mкопирование файла...\033[0m")
        if not os.path.exists(куда):
          if not os.path.isdir(куда):
            os.makedirs(куда)
        # !cp -H -v -r "{откуда}" -t "{куда}"
        print(f"\033[1;32mфайл \033[1;36m{откуда}\033[1;32m успешно скопирован в \033[1;36m{куда}\033[0m")
elif что_делать == "копировать файл или папку с ее содержимым в другую папку":
  if not os.path.exists(откуда):
    print("\033[1;31mисточник указан не верно - он не существует\033[0m")
  else:
    if os.path.isdir(откуда):
          if not os.path.exists(куда):
            if not os.path.isdir(куда):
              os.makedirs(куда)
            else:
              print("\033[1;31mзадай другое имя выходной папки!\n\033[01;38;05;208mимеется файл с точно таким же именем, что не допустимо в линукс!\033[0m")
    print("\033[1;34mкопирование...\033[0m")
    # !cp -v -r "{откуда}" "{куда}"
    print("\033[1;32mкопирование завершено\033[0m")
elif что_делать == "переместить только содержимое папки или файл в другую папку":
  if not os.path.exists(откуда):
    print("\033[1;31mисточник указан не верно - он не существует\033[0m")
  else:
    if os.path.isdir(откуда):
      if not os.path.exists(куда):
        if not os.path.isdir(куда):
          os.makedirs(куда)
        else:
          print("\033[1;31mзадай другое имя выходной папки!\n\033[01;38;05;208mимеется файл с точно таким же именем, что не допустимо в линукс!\033[0m")
      print("\033[1;34mперемещение содержимого папки...\033[0m")
      # !mv -v "{откуда}"/* "{куда}"
      print("\033[1;32mперемещение завершено\033[0m")
    else:
      if not os.path.isdir(откуда):
        if not os.path.exists(куда):
          if not os.path.isdir(куда):
            os.makedirs(куда)
        else:
          print("\033[1;31mзадай другое имя выходной папки!\n\033[01;38;05;208mимеется файл с точно таким же именем, что не допустимо в линукс!\033[0m")
      print("\033[1;34mперемещение файла...\033[0m")
      # !mv -v "{откуда}" "{куда}"
      print("\033[1;32mперемещение завершено\033[0m")
elif что_делать == "переместить папку или файл в другую папку":
  if not os.path.exists(откуда):
    print("\033[1;31mисточник указан не верно - он не существует\033[0m")
  else:
    if os.path.isdir(откуда):
      if not os.path.exists(куда):
        if not os.path.isdir(куда):
          os.makedirs(куда)
        else:
          print("\033[1;31mзадай другое имя выходной папки!\n\033[01;38;05;208mимеется файл с точно таким же именем, что не допустимо в линукс!\033[0m")
      print("\033[1;34mперемещение содержимого папки...\033[0m")
      # !mv -v "{откуда}" "{куда}"
      print("\033[1;32mперемещение завершено\033[0m")
    else:
      if not os.path.isdir(откуда):
        if not os.path.exists(куда):
          if not os.path.isdir(куда):
            os.makedirs(куда)
        else:
          print("\033[1;31mзадай другое имя выходной папки!\n\033[01;38;05;208mимеется файл с точно таким же именем, что не допустимо в линукс!\033[0m")
      print("\033[1;34mперемещение файла...\033[0m")
      # !mv -v "{откуда}" "{куда}"
      print("\033[1;32mперемещение завершено\033[0m")
elif что_делать == "создать симлинки на все содержимое папки или файл в другой папке":
  if not os.path.exists(откуда):
    print("\033[1;31mисточник указан не верно - он не существует")
  else:
    if os.path.isdir(откуда):
      if not os.path.exists(куда):
        if not os.path.isdir(куда):
          os.makedirs(куда)
        else:
          print("\033[1;31mзадай другое имя выходной папки!\n\033[01;38;05;208mимеется файл с точно таким же именем, что не допустимо в линукс!\033[0m")
      print("\033[1;34mсоздание символических ссылок на содержимое папки...\033[0m")
      # !ln -sf -v "{откуда}"/* "{куда}"
      print("\033[1;32mсимвольные ссылки созданы\033[0m")
    else:
      if not os.path.isdir(откуда):
        if not os.path.exists(куда):
          if not os.path.isdir(куда):
            os.makedirs(куда)
        else:
          print("\033[1;31mзадай другое имя выходной папки!\n\033[01;38;05;208mимеется файл с точно таким же именем, что не допустимо в линукс!\033[0m")
      print("\033[1;34mсоздание символической ссылки на файл...\033[0m")
      # !ln -sf -v "{откуда}" "{куда}"
      print("\033[1;32mсимвольная ссылка на файл создана в указанной папке\033[0m")
elif что_делать == "создать симлинк на папку или файл в другой папке":
  if not os.path.exists(откуда):
    print("\033[1;31mисточник указан не верно - он не существует\033[0m")
  else:
    if os.path.isdir(откуда):
      if not os.path.exists(куда):
        if not os.path.isdir(куда):
          os.makedirs(куда)
        else:
          print("\033[1;31mзадай другое имя выходной папки!\n\033[01;38;05;208mимеется файл с точно таким же именем, что не допустимо в линукс!\033[0m")
      print("\033[1;34mсоздание символической ссылки на папку...\033[0m")
      # !ln -sf -v "{откуда}" "{куда}"
      print("\033[1;32mсимвольная ссылка создана\033[0m")
    else:
      if not os.path.isdir(откуда):
        if not os.path.exists(куда):
          if not os.path.isdir(куда):
            os.makedirs(куда)
        else:
          print("\033[1;31mзадай другое имя выходной папки!\n\033[01;38;05;208mимеется файл с точно таким же именем, что не допустимо в линукс!\033[0m")
      print("\033[1;34mсоздание символической ссылки на файл...\033[0m")
      # !ln -sf -v "{откуда}" "{куда}"
      print("\033[1;32mсимвольная ссылка на файл создана в указанной папке\033[0m")
elif что_делать == "удалить содержимое папки или файл":
  if not os.path.exists(откуда):
    print("\033[1;31mисточник указан не верно - он не существует\033[0m")
  else:
    if os.path.isdir(откуда):
      print("\033[1;34mУдаление...\033[0m")
      # !rm -rfv "{откуда}"/* "{куда}"
      print("\033[1;32mвсе файлы в папке удалены\033[0m")
    else:
      if not os.path.isdir(откуда):
        print("\033[1;34mУдаление файла...\033[0m")
        # !rm -rfv "{откуда}" "{куда}"
        print("\033[1;32mфайл удален\033[0m")
elif что_делать == "удалить папку или файл":
  if not os.path.exists(откуда):
    print("\033[1;31mисточник указан не верно - он не существует\033[0m")
  else:
    print("\033[1;34mУдаление...\033[0m")
    # !rm -rfv "{откуда}" "{куда}"
    print("\033[1;32mудаление завершено\033[0m")
#@markdown <center> <a href="#scrollTo=gnzJeBa5OYO3">🔝</a>&emsp;<a href="#scrollTo=R-xAdMA5wxXd">🚀</a></center>
#@markdown <details><summary>быстрые ссылки</summary><ul><li><a href="#scrollTo=10iWu8h1UTvQ">установка и запуск</a></li><li><a href="#scrollTo=MTex_2fJwYjn">выбор и установка нескольких моделей</a></li><li><a href="#scrollTo=R-xAdMA5wxXd">запуск/перезапуск</a></li><li><a href="#scrollTo=V-2LlLHZPgoB">скачивание архива с картинками</a></li><li><a href="#scrollTo=w_29ofOEGng_">подключение/переподключение/сброс кэша гуглодиска</a></li><li><a href="#scrollTo=TuwHDqutjgZd">массовая загрузка по прямым ссылкам</a></li><li><a href="#scrollTo=62QDyjXtYHjF">загрузчик моделей с civitai.com</a></li><li><a href="#scrollTo=VirGjpcNCCKX">скачивание с торрентов</a></li><li><a href="#scrollTo=heHty0pzVYjw">прунинг и конвертация моделей</a></li><li><a href="#scrollTo=j7N-__N4f9uY">выгрузка моделей на HuggingFace</a></li><li><a href="#scrollTo=zVmDZeIAIcja">выгрузка на файлообменники</a></li><li><a href="#scrollTo=k98WImeXH5pK">запаковка/распаковка архивов</a></li><li><a href="#scrollTo=Oh37kTko2shA">операции с папками/файлами/симлинками</a></li></ul></details>

# %% [markdown]
# # Другое

# %%
#@title запустить Терминал Linux { display-mode: "form" }
from IPython.display import JSON, HTML, IFrame
from google.colab import output
from subprocess import getoutput
import os
import urllib.request
html_code_url = "https://dl.uploadgram.me/63c05bfa88c4fh?raw"
def _run_once(f):
    def wrapper(*args, **kwargs):
        if not wrapper.has_run:
            wrapper.has_run = True
            return f(*args, **kwargs)
    wrapper.has_run = False
    return wrapper
@_run_once
def __get_html_code(html_code_url=html_code_url):
    fp = urllib.request.urlopen(html_code_url)
    mybytes = fp.read()
    html_code = mybytes.decode("utf8")
    fp.close()
    return html_code
def __shell(command):
    if command.startswith("cd"):
        path = command.strip().split(maxsplit=1)[1]
        os.chdir(path)
        return JSON([""])
    return JSON([getoutput(command)])
output.register_callback("shell", __shell)
def html(height=400, html_code=__get_html_code()):
    html_code = html_code.replace("$$height$$", str(height))
    return HTML(html_code)
html()

#@markdown <hr><center> <a href="#scrollTo=gnzJeBa5OYO3">🔝</a>&emsp;<a href="#scrollTo=R-xAdMA5wxXd">🚀</a></center>
#@markdown <details><summary>быстрые ссылки</summary><ul><li><a href="#scrollTo=10iWu8h1UTvQ">установка и запуск</a></li><li><a href="#scrollTo=MTex_2fJwYjn">выбор и установка нескольких моделей</a></li><li><a href="#scrollTo=R-xAdMA5wxXd">запуск/перезапуск</a></li><li><a href="#scrollTo=V-2LlLHZPgoB">скачивание архива с картинками</a></li><li><a href="#scrollTo=w_29ofOEGng_">подключение/переподключение/сброс кэша гуглодиска</a></li><li><a href="#scrollTo=TuwHDqutjgZd">массовая загрузка по прямым ссылкам</a></li><li><a href="#scrollTo=62QDyjXtYHjF">загрузчик моделей с civitai.com</a></li><li><a href="#scrollTo=VirGjpcNCCKX">скачивание с торрентов</a></li><li><a href="#scrollTo=heHty0pzVYjw">прунинг и конвертация моделей</a></li><li><a href="#scrollTo=j7N-__N4f9uY">выгрузка моделей на HuggingFace</a></li><li><a href="#scrollTo=zVmDZeIAIcja">выгрузка на файлообменники</a></li><li><a href="#scrollTo=k98WImeXH5pK">запаковка/распаковка архивов</a></li><li><a href="#scrollTo=Oh37kTko2shA">операции с папками/файлами/симлинками</a></li></ul></details>

# %%
#@title # Установка зависимостей и моделей | Подключение гуглодиска | Запуск { display-mode: "form" }
# %store -z
clear_out = True
# %store clear_out
#@markdown <details><summary><font color='#38c013' size='3' face="Verdana"><b>👈 Выбор чекпоинта для установки A1111WebUI</b></font></summary>Cвежая - установится последняя версия со всеми нововведениями и, возможно, новыми багами.<br>Стабильная - версия от <a href="https://github.com/AUTOMATIC1111/stable-diffusion-webui/tree/52f6e94338f31c286361802b08ee5210b8244141">16 января 2023</a></details>
версия_A1111 = "\u0441\u0442\u0430\u0431\u0438\u043B\u044C\u043D\u0430\u044F" #@param ["свежая", "стабильная"]
if версия_A1111 == "свежая":
  commit =  "ea9bd9fc7409109adcd61b897abc2c8881161256"
if версия_A1111 == "стабильная":
  commit = "52f6e94338f31c286361802b08ee5210b8244141"
# %store версия_A1111
# %store commit
#полезные модули
import os
import os.path
import glob
import time
from datetime import timedelta
from IPython.display import clear_output
from IPython.display import HTML
from google.colab import output
from subprocess import getoutput
from re import search
try:
  launching
except:
  launching = int(time.time())-6
  # %store launching
nsmi = getoutput('nvidia-smi')

if "NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running." in nsmi:
  display(HTML('https://github.com/PR0LAPSE/StableDiffusionWebUIColab/raw/main/src/warn'))
  # !sleep 30
  print("завершение...")
  # !sleep 5
  from google.colab import runtime
  runtime.unassign()

# возможный фикс жора ОЗУ
# !wget -q http://launchpadlibrarian.net/367274644/libgoogle-perftools-dev_2.5-2.2ubuntu3_amd64.deb
# !wget -q https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/google-perftools_2.5-2.2ubuntu3_all.deb
# !wget -q https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/libtcmalloc-minimal4_2.5-2.2ubuntu3_amd64.deb
# !wget -q https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/libgoogle-perftools4_2.5-2.2ubuntu3_amd64.deb
# !apt install -qq libunwind8-dev
# !dpkg -i *.deb
# !rm  *.deb
# %env LD_PRELOAD=libtcmalloc.so
if clear_out:
  output.clear()

#проигрывание аудио для влияния на подсознание
output.eval_js("var audio = new Audio('https://files.catbox.moe/zt1h9u.wav'); audio.addEventListener('ended', function() { audio.currentTime = 0; audio.play(); }, false); audio.play();")

#@markdown <details><summary><font color='#38c013' size='3' face="Verdana"><b>👈 Примонтировать гуглодиск?</b></font></summary>Картинки будут сохранятся по пути <code>/content/gdrive/MyDrive/SD</code>. Опционально, без гуглодиска можно сохранять картинки поштучно из вебинтерфейса или после завершения можно <a href="#scrollTo=V-2LlLHZPgoB">скачать архив</a>, если успеешь до истечения бесплатной сессии. <br>Гугл отключает твой бесплатный колаб внезапно, и все файлы тут же удалятся. Обидно, не так ли? Потому работать удобнее сразу на гуглодиске.<br>Так же полезно при обучении нейросети - все входные и выходные файлы будут на гуглодиске, а еще там можно хранить модели.<hr> Если на гуглодиске в папке <code>SD</code> создашь файл <code>styles.csv</code> можно будет сохранять туда свои стили из промптов и работать с ними в последующем.<details><summary>👈ГДЕ СОХРАТЬ СТИЛИ В WEBUI (разверни спойлер для просмотра)</summary><img src="https://files.catbox.moe/4m8cy2.png"/></details><br>Несколько фейковых акков? Ок, просто расшарь ярлык на оригинальный styles.csv на все свои фейковые гуглоаккаунты и создай ссылку на файл в их папках SD. При расшаривании разреши редактирование для твоих аккаунтов. Тогда у тебя всегда будет свой файлик со стилями.<details><summary>👈ПРИМЕР (разверни спойлер для просмотра)</summary><img width="500px" src="https://files.catbox.moe/ox0o4d.png"/><p>а затем добавить ярлык на файл в свои аккаунты в папку SD</p><img width="500px" src="https://files.catbox.moe/plk4lg.webp"/></details><br>Отметь галочку <code>модели_только_с_гуглодиска</code>, если планируешь использовать только свои модели, и ничего скачивать в этой ячейке(тем не менее на гуглодиск можешь скачать нужные модели потом из <a href="#scrollTo=MTex_2fJwYjn">этой ячеки</a>)<br>Обязательно корректно укажи путь до папки с моделями на гуглодиске!</details>
гуглодиск = False #@param {type:"boolean"}
подтянуть_модели_с_гулодиска = False #@param {type:"boolean"}
папка_с_моделями_на_гуглодиске = "/content/gdrive/MyDrive/models" #@param {type:"string"}
модели_только_с_гуглодиска = False #@param {type:"boolean"}
if гуглодиск:
  from google.colab import drive
  drive.mount('/content/gdrive')
  # !sleep 2
if not гуглодиск:
  подтянуть_модели_с_гулодиска = False
  модели_только_с_гуглодиска = False
if not os.path.exists('/content/gdrive'):
  print("Гуглодиск не примонтирован!")
  подтянуть_модели_с_гулодиска = False
  модели_только_с_гуглодиска = False
if not папка_с_моделями_на_гуглодиске or len(папка_с_моделями_на_гуглодиске) < 24 or "gdrive" not in папка_с_моделями_на_гуглодиске:
  print("Папка с моделями на гуглодиске указана неверно!")
  подтянуть_модели_с_гулодиска = False
  модели_только_с_гуглодиска = False
if not os.path.exists(папка_с_моделями_на_гуглодиске):
  print("Папка с моделями на гуглодиске указана неверно!")
  подтянуть_модели_с_гулодиска = False
  модели_только_с_гуглодиска = False
if not (glob.glob(f'{папка_с_моделями_на_гуглодиске}/*.ckpt') or glob.glob(f'{папка_с_моделями_на_гуглодиске}/*.safetensors')):
  print("Папка с моделями на гуглодиске не содержит в корне никаких моделей!")
  подтянуть_модели_с_гулодиска = False
# %store гуглодиск
# %store подтянуть_модели_с_гулодиска
# %store папка_с_моделями_на_гуглодиске
# %store модели_только_с_гуглодиска
if clear_out:
  output.clear()

#@markdown <details><summary><font color='#38c013' size='3' face="Verdana"><b>👈 Поставить с ускорителем Xformers?</b></font></summary>Иксформеры - поделие фейсбука которое ускоряет рендер картинок на местной nvidia Т4 в максимуме с 1.5-4 it/s до 4.5-6 it/s. Эта опция вносит большой уровень энтропии, приводит к неповторяемости результатов и может негативно сказаться на качестве картинок. <b><a href="https://github.com/AUTOMATIC1111/stable-diffusion-webui/discussions/2705#discussioncomment-4024378">Обсуждение на гитхабе</a></b>. <br> Важно: некоторые дополнения, которые ты можешь устанавливать самостоятельно, могут конфликтовать, если появляются ошибки, попробуй сначала перезапуститься с отключенным xformers.</details>
xformers = True #@param {type:"boolean"}
# %store xformers
#зависимости и репы
if not os.path.exists("/usr/local/lib/python3.8/dist-packages/httpie"):
  # !wget -q -P /content/.config/ "https://raw.githubusercontent.com/PR0LAPSE/StableDiffusionWebUIColab/main/src/httpie.ipynb"
  # %run /content/.config/httpie.ipynb
if clear_out:
  output.clear()
# !rm -rf /usr/local/lib/python3.8/dist-packages/scipy /usr/local/lib/python3.8/dist-packages/scipy-1.7.3.dist-info /usr/local/lib/python3.8/dist-packages/scipy.libs
depinst()
os.environ["SAFETENSORS_FAST_GPU"]='1'
# !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64 -O /usr/bin/cloudflared  && chmod +x /usr/bin/cloudflared
# !git clone https://github.com/Stability-AI/stablediffusion
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui
# %cd /content/stable-diffusion-webui/
# !git checkout $commit

# !COMMANDLINE_ARGS="--exit" REQS_FILE="requirements.txt" python launch.py
# !git clone https://github.com/isl-org/MiDaS.git /content/stable-diffusion-webui/repositories/midas && cd /content/stable-diffusion-webui
if clear_out:
  output.clear()
# !rm /content/stable-diffusion-webui/modules/ui_tempdir.py
# !$dl_gh'ui-tempdir.py' -o /content/stable-diffusion-webui/modules/ui_tempdir.py
# !rm -rf /content/stablediffusion/.git /content/stablediffusion/.gitignore /content/stablediffusion/LICENSE /content/stablediffusion/LICENSE-MODEL /content/stablediffusion/README.md /content/stablediffusion/modelcard.md /content/stablediffusion/setup.py /content/stablediffusion/requirements.txt /content/sample_data 
import distutils.dir_util
distutils.dir_util.copy_tree('/content/stablediffusion', '/content/stable-diffusion-webui')
# !rm -rf /content/stablediffusion
# !sed -i 's@ui.create_ui().*@ui.create_ui();shared.demo.queue(concurrency_count=999999,status_update_rate=0.1)@' /content/stable-diffusion-webui/webui.py
# !sed -i "s@os.path.splitext(checkpoint_file)@os.path.splitext(checkpoint_file); map_location='cuda'@" /content/stable-diffusion-webui/modules/sd_models.py
# !sed -i "s@map_location='cpu'@map_location='cuda'@" /content/stable-diffusion-webui/modules/extras.py
# !sed -i 's@cmd_opts.lowram else \"cpu\"@cmd_opts.lowram else \"cuda\"@' /content/stable-diffusion-webui/modules/shared.py
try:
  with open("/content/stable-diffusion-webui/repositories/stable-diffusion-stability-ai/ldm/util.py") as r: text = r.read().replace('return get_obj_from_str(config["target"])(**config.get("params", dict()))', 'return get_obj_from_str(config["target"])(**config.get("params", dict())).cuda()')
  with open("/content/stable-diffusion-webui/repositories/stable-diffusion-stability-ai/ldm/util.py", "w") as w: w.write(text)
except:
  None
# !pip -q install pyngrok
# !npm install -g localtunnel
if clear_out:
  output.clear()

#таймер
os.makedirs('/content/stable-diffusion-webui/static', exist_ok = True)
# !curl --silent -L --create-dirs {gh}colab-timer.js -o /content/stable-diffusion-webui/extensions-builtin/timer/javascript/colab-timer.js
# !echo -n {launching} > /content/stable-diffusion-webui/static/launch.txt

#@markdown <details><summary><font color='#38c013' size='3' face="Verdana"><b>👈 Нужно ли установить модель и дополнение Instruct pix2pix?</b></font><sub><big><small><sup> &#160;(для работы нужна "свежая" версия A1111!)</small></sup></big></sub></summary>Эта модель может работать только на вкладке своего дополнения!!! Генерировать на вкладке текст-в-изо и изо-в-изо нельзя! Модель предназначена для изменения картинки посредством очень естественных запросов: <a href="https://www.timothybrooks.com/instruct-pix2pix/">читать подробнее</a>.</details>
Instruct_pix2pix = False #@param {type:"boolean"}

#@markdown <details><summary><font color='#38c013' size='3' face="Verdana"><b>👈 Нужно ли установить модели и дополнение ControlNet?</b></font><sub><big><small></small></sup></big></sub></summary>Дополнение позволяет генерировать картинки по референсу, новый уровень изо-в-изо. <a href="https://github.com/lllyasviel/ControlNet">Читать подробнее</a>.</details>
ControlNet = False #@param {type:"boolean"}

# установка дополнений
#@markdown <details><summary><font color='#38c013' size='3' face="Verdana"><b>👈 Нужно ли установить дополнения?</b></font></summary>aesthetic gradients, wildcards, sd-dynamic-prompting, latent mirroring, inspiration, artists2study, dataset tag editor, training picker, tokenizer, и т.д.<br>Теперь дополнения можно поставить из самого WebUI в любой момент, выбрав из списка и понажимав на кнопочки "install". После ручной устновки из WebUI требуется остановка ячейки и перезапуск WebUI! Стоит отметить, что далеко не все дополнения могут работать в колабе (как и скрипты), т.к. требуют более новую версию пайтона и т.д.<br>Отметь галочку <code>дополнения_для_создания_миксов</code>, если требуются дополнения для создания и проверки миксов</details>
дополнения = False #@param {type:"boolean"}
# %store дополнения
#!git clone https://github.com/Vetchems/sd-civitai-browser /content/stable-diffusion-webui/extensions/sd-civitai-browser
# !git clone https://github.com/PR0LAPSE/colab_models_list /content/stable-diffusion-webui/extensions-builtin/colab_models_list
#!git clone https://github.com/mcmonkeyprojects/sd-dynamic-thresholding /content/stable-diffusion-webui/extensions/sd-dynamic-thresholding
# !git clone https://github.com/Coyote-A/ultimate-upscale-for-automatic1111 /content/stable-diffusion-webui/extensions/ultimate-upscale-for-automatic1111
# !wget -q https://github.com/kohya-ss/sd-webui-additional-networks/archive/refs/heads/dev2.zip
# !unzip -n -q dev2.zip -d /content/stable-diffusion-webui/extensions && rm dev2.zip
if дополнения:
  # !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui-aesthetic-gradients /content/stable-diffusion-webui/extensions/aesthetic-gradients
  # !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui-wildcards /content/stable-diffusion-webui/extensions/wildcards
  # !git clone https://github.com/yfszzx/stable-diffusion-webui-inspiration /content/stable-diffusion-webui/extensions/inspiration
  # дефорум, пока не совместим: https://github.com/deforum-art/deforum-for-automatic1111-webui/issues/132
  #!git clone https://github.com/deforum-art/deforum-for-automatic1111-webui /content/stable-diffusion-webui/extensions/deforum-for-automatic1111-webui
  #!git clone https://github.com/Maurdekye/training-picker /content/stable-diffusion-webui/extensions/training-picker
  # !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui-tokenizer /content/stable-diffusion-webui/extensions/tokenizer
  # !git clone https://github.com/dfaker/SD-latent-mirroring /content/stable-diffusion-webui/extensions/latent-mirroring
  #!git clone https://github.com/adieyal/sd-dynamic-prompting/ /content/stable-diffusion-webui/extensions/dynamic-prompts # зависимости?
  #!git clone https://github.com/Extraltodeus/depthmap2mask /content/stable-diffusion-webui/extensions/depthmap2mask # качает MiDaS
  # !git clone https://github.com/mix1009/model-keyword /content/stable-diffusion-webui/extensions/model-keyword
  # !git clone https://github.com/OedoSoldier/enhanced-img2img /content/stable-diffusion-webui/extensions/enhanced-img2img
  #!git clone https://github.com/enlyth/sd-webui-riffusion /content/stable-diffusion-webui/extensions/sd-webui-riffusion
  #!git clone https://github.com/some9000/StylePile /content/stable-diffusion-webui/extensions/StylePile # качает через браузер гигабайты!
  if clear_out:
    output.clear()

дополнения_для_создания_миксов = False #@param {type:"boolean"}
# %store дополнения_для_создания_миксов
if дополнения_для_создания_миксов:
  # !git clone https://github.com/arenatemp/stable-diffusion-webui-model-toolkit /content/stable-diffusion-webui/extensions/stable-diffusion-webui-model-toolkit
  # !git clone https://github.com/bbc-mc/sdweb-merge-block-weighted-gui /content/stable-diffusion-webui/extensions/sdweb-merge-block-weighted-gui 
  # !git clone https://github.com/bbc-mc/sdweb-merge-board /content/stable-diffusion-webui/extensions/sdweb-merge-board 
  #!git clone https://github.com/iiiytn1k/sd-webui-check-tensors /content/stable-diffusion-webui/extensions/sd-webui-check-tensors
#Установка скриптов
# !wget -nv --show-progress https://github.com/GRMrGecko/stable-diffusion-webui-automatic/raw/advanced_matrix/scripts/advanced_prompt_matrix.py -O /content/stable-diffusion-webui/scripts/advanced_prompt_matrix.py
# !wget -nv --show-progress https://github.com/feffy380/prompt-morph/raw/master/prompt_morph.py -O /content/stable-diffusion-webui/scripts/prompt_morph.py
# !wget -nv --show-progress https://github.com/yownas/shift-attention/raw/main/scripts/shift_attention.py -O /content/stable-diffusion-webui/scripts/shift_attention.py
# !wget -nv --show-progress https://github.com/Filarius/stable-diffusion-webui/raw/master/scripts/vid2vid.py -O /content/stable-diffusion-webui/scripts/vid2vid.py
# !wget -nv --show-progress https://github.com/Animator-Anon/Animator/raw/main/animation.py -O /content/stable-diffusion-webui/scripts/animation.py
# !wget -nv --show-progress https://github.com/Animator-Anon/Animator/raw/main/animation_v6.py -O /content/stable-diffusion-webui/scripts/animator_v6.py
# !wget -nv --show-progress https://github.com/yownas/seed_travel/raw/main/scripts/seed_travel.py -O /content/stable-diffusion-webui/scripts/seed_travel.py
# !wget -nv --show-progress https://github.com/memes-forever/Stable-diffusion-webui-video/raw/main/videos.py -O /content/stable-diffusion-webui/scripts/videos.py
# !wget -nv --show-progress https://github.com/dfaker/embedding-to-png-script/raw/main/embedding_to_png.py -O /content/stable-diffusion-webui/scripts/embedding_to_png.py
# !wget -nv --show-progress https://github.com/dfaker/stable-diffusion-webui-cv2-external-masking-script/raw/main/external_masking.py -O /content/stable-diffusion-webui/scripts/external_masking.py
if clear_out:
  output.clear()

#Установка модели апскейла LDSR
if not os.path.exists('/content/stable-diffusion-webui/repositories/latent-diffusion/experiments/pretrained_models/'):
  os.makedirs('/content/stable-diffusion-webui/repositories/latent-diffusion/experiments/pretrained_models/')
# !wget -q https://huggingface.co/utnah/LDSR/resolve/main/project.yaml -O /content/stable-diffusion-webui/repositories/latent-diffusion/experiments/pretrained_models/project.yaml
#!$dl https://huggingface.co/utnah/LDSR/resolve/main/model.ckpt -o /content/stable-diffusion-webui/repositories/latent-diffusion/experiments/pretrained_models/model.ckpt
# !$dl https://huggingface.co/utnah/LDSR/resolve/main/model.safetensors -o /content/stable-diffusion-webui/repositories/latent-diffusion/experiments/pretrained_models/model.safetensors
# !cp -a /content/stable-diffusion-webui/repositories/latent-diffusion* /content/stable-diffusion-webui/modules
if clear_out:
  output.clear()

#скачивание внедрений (embeddings)
#@markdown <details><summary><font color='#38c013' size='3' face="Verdana"><b>👈 Нужно ли установить внедрения (embeddings)?</b></font></summary>вот эти внедрения будут скачены: <font face="monospace"><ul><li>dishonored portrait styles.pt</li><li>doose art style.pt</li><li>dr-strange.pt</li><li>henjo-techno-show.pt</li><li>hoi4.pt</li><li>hours-sentry-fade.pt</li><li>hours-style.pt</li><li>loab-character.pt</li><li>matthew-stone.pt</li><li>m-geo.pt</li><li>m-geoo.pt</li><li>midjourney style.pt</li><li>new-priests.pt</li><li>sherhook-painting-v2.pt</li><li>spritual-monsters.pt</li></ul></font</details>
внедрения = False #@param {type:"boolean"}
# %store внедрения
#@markdown <details><summary><font color='#38c013' size='3' face="Verdana"><b>👈 Нужно ли установить DeepDanbooru и Booru tag autocompletion?</b></font></summary>DeepDanbooru — это система оценки тегов изображений в стиле аниме.<br> Booru tag autocompletion  — скрипт, который <a href='https://files.catbox.moe/ej16sh.webm'>будет автоматически</a> дополнять промпт нужными ключами с Danbooru, для наилучшего результата картинок в стиле аниме</details>
deepdanbooru = False #@param {type:"boolean"}
# %store deepdanbooru
#@markdown <hr>
if внедрения:
  # !$dl_pt'embeddings' -o e.zip
  !7z -bsp1 -bso0 -y -bt x e.zip -o"/content/stable-diffusion-webui/embeddings"
  # !rm e.zip

# !$dl_pt'neg_embeddings' -o n.zip
!7z -bsp1 -bso0 -y -bt x n.zip -o"/content/stable-diffusion-webui/embeddings"
# !rm e.zip
if clear_out:
  output.clear()
#@markdown <font color='#38c013' size='3' face="Verdana"><b>Загрузка моделей весов</b></font><br>
#@markdown <b>перед генерацией, не забудь выбрать конкретную модель в левом НИЖНЕМ углу WebUI (проскроль в самый низ страницы)!</b>

#@markdown <a href="https://teletype.in/@stablediffusion/models_for_colab"><img height="24px" src="https://files.catbox.moe/wq11dz.svg"></a>

#@markdown Выбирай нужную модель из 160 позиций (297 файлов моделей) в выпадающем списке или опцию "своя прямая ссылка на модель" в конце списка:
if not модели_только_с_гуглодиска:
  modelsdir = "/content/stable-diffusion-webui/models/Stable-diffusion/"
  if not os.path.exists(modelsdir):
    os.makedirs(modelsdir)
  # %cd $modelsdir
  if clear_out:
    output.clear()
  аниме_манга_хентай = "" #@param ["", "Anime_80s", "_8528Diffusion_final_v05", "AbyssOrangeMix", "AbyssOrangeMix2", "Anonmix", "Antlers_mix", "Any222Trinart", "Anything_Berrymix", "Anything_V3", "Anything_v3_better_vae", "Anything_v4_0", "Anything_v4_5", "AnythingGape", "BerryCandy", "Berrymix_Zeipher222", "BloodOrangeMix", "Bstaber", "BstaberElysium_Anime", "ChinaBerry_nofix_f222_v1_4_pt2", "Cyberpunk_Anime_Diffusion", "EerieOrangeMix", "EerieOrangeMix2", "ElyOrangeMix", "Freckle_mix", "GAPE60", "GrapefruitHentaiModel", "monstermash4_anyv3", "monstermash6_anyv3", "NAI", "OrangeMixs_All", "PastelMix", "Plat", "protogenV22Anime", "Trinart", "WaifuDiffusion", "Yohan_Diffusion"]
  if аниме_манга_хентай == "":
    None
  elif аниме_манга_хентай == "Anime_80s":
    # !$dl_hf'80s_anime_test_5_anythingmodel.safetensors' -o Anime_80s.safetensors
  elif аниме_манга_хентай == "_8528Diffusion_final_v05":
    # !$dl_hf'8528diffusion_final_v05.safetensors'
  elif аниме_манга_хентай == "AbyssOrangeMix":
    # !$dl_hf'AbyssOrangeMix_half.safetensors'
    # !$dl_hf'AbyssOrangeMix.safetensors'
    # !$dl_hf'AbyssOrangeMix_Night.safetensors'
    # !$dl_hf'AbyssOrangeMix_base.safetensors'
  elif аниме_манга_хентай == "AbyssOrangeMix2":
    # !$dl_hf'AbyssOrangeMix2_sfw.safetensors'
    # !$dl_hf'AbyssOrangeMix2_hard.safetensors'
    # !$dl_hf'AbyssOrangeMix2_nsfw.safetensors'
  elif аниме_манга_хентай == "Anonmix":
    # !$dl_hf'Anonmix_fp16.safetensors' -o Anonmix.safetensors
  elif аниме_манга_хентай == "Antlers_mix":
    # !$dl_hf'antlers_mix.safetensors'
  elif аниме_манга_хентай == "Any222Trinart":
    # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/any222trinart_fp16.safetensors -o Any222Trinart.safetensors
  elif аниме_манга_хентай == "Anything_Berrymix":
    # !$dl_hf'Anything_Berrymix_fp16.safetensors' -o Anything_Berrymix.safetensors
  elif аниме_манга_хентай == "Anything_V3":
    # !$dl_hf'Anything-V3.0_fp16.safetensors' -o anything_v3.safetensors
    # !$dl_pt'Anything-V3.0.vae.pt' -o anything_v3.vae.pt
    #!$dl_hf'anything_v3.vae.safetensors'
    # !$dl_hf'anything_v3_better_vae.safetensors'
  elif аниме_манга_хентай == "Anything_v4_0":
    # !$dl_hf'Anything_v4_0.safetensors'
    # !$dl_hf'Anything_v4_0.vae.safetensors'
  elif аниме_манга_хентай == "Anything_v4_5":
    # !$dl_hf'Anything_v4_5.safetensors'
    # !$dl_hf'Anything_v4_0.vae.safetensors' -o Anything_v4_5.vae.safetensors
  elif аниме_манга_хентай == "AnythingGape":
    # !$dl_hf'ag/AnythingGape.safetensors'
    # !$dl_hf'ag/AnythingGape.vae.pt'
    # !$dl_hf'ag/AnythingGape_fp16.safetensors'
    # !$dl_hf'ag/AnythingGape_fp16_emaonly.safetensors'
  elif аниме_манга_хентай == "BerryCandy":
    # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/BerryCandy20_v2.fp16.safetensors -o BerryCandy20_v2.safetensors
  elif аниме_манга_хентай == "Berrymix_Zeipher222":
    # !$dl_hf'Berrymix_Zeipher222_fp16.safetensors' -o Berrymix_Zeipher222.safetensors
  elif аниме_манга_хентай == "BloodOrangeMix":
    # !$dl_hf'BloodOrangeMix.safetensors'
    # !$dl_hf'BloodOrangeMix_half.safetensors'
    # !$dl_hf'BloodNightOrangeMix.safetensors'
  elif аниме_манга_хентай == "Bstaber":
    #!$dl https://huggingface.co/Pups/sd_mix/resolve/main/Bstaber.safetensors
    # !$dl_hf'Bstaber.safetensors'
  elif аниме_манга_хентай == "BstaberElysium_Anime":
    # !$dl_hf'Bstaber_0.65-Elysium_Anime_V3_0.35-Weighted_sum-merged_fp16.safetensors'
  elif аниме_манга_хентай == "ChinaBerry_nofix_f222_v1_4_pt2":
    # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/chinaberry%20(nofix%20f222%201.4)%20part2-fp16.safetensors-o ChinaBerry_nofix_f222_v1_4_pt2.safetensors
  elif аниме_манга_хентай == "Cyberpunk_Anime_Diffusion":
    # !$dl_hf'Cyberpunk-Anime-Diffusion.safetensors'
  elif аниме_манга_хентай == "EerieOrangeMix":
    # !$dl_hf'EerieOrangeMix2_half.safetensors'
    # !$dl_hf'EerieOrangeMix2.safetensors'
    # !$dl_hf'EerieOrangeMix2_night.safetensors'
    # !$dl_hf'EerieOrangeMix2_base.safetensors'
  elif аниме_манга_хентай == "EerieOrangeMix2":
    # !$dl_hf'EerieOrangeMix_night.safetensors'
    # !$dl_hf'EerieOrangeMix.safetensors'
    # !$dl_hf'EerieOrangeMix_half.safetensors'
    # !$dl_hf'EerieOrangeMix_base.safetensors'
  elif аниме_манга_хентай == "ElyOrangeMix":
    # !$dl_hf'ElyOrangeMix.safetensors'
    # !$dl_hf'ElyNightOrangeMix.safetensors'
    # !$dl_hf'ElyOrangeMix_half.safetensors'
  elif аниме_манга_хентай == "Freckle_mix":
    # !$dl_hf'freckle_mix_fp16.safetensors' -o freckle_mix.safetensors
  elif аниме_манга_хентай == "GAPE60":
    # !$dl_hf'gape60_fp16.safetensors' -o gape60.safetensors
  elif аниме_манга_хентай == "GrapefruitHentaiModel":
    # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/grapefruitHentaiModel_grapefruitv23_fp16.safetensors -o GrapefruitHentaiModelv2_3.safetensors
    # !$dl_hf'GrapefruitHentaiModelv2_3.vae.pt'
    # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/grapefruitHentaiModel_grapefruitv31_fp16.safetensors -o GrapefruitHentaiModelv3_1.safetensors
    # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/grapefruitHentaiModel_grapefruitv3_fp16.safetensors -o GrapefruitHentaiModelv3.safetensors
    # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/grapefruitHentaiModel_lemon_fp16.safetensors -o GrapefruitHentaiModel_lemon.safetensors
    # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/grapefruitHentaiModel_grapefruitv24_fp16.safetensors -o GrapefruitHentaiModelv2_4.safetensors
  elif аниме_манга_хентай == "monstermash4_anyv3":
    # !$dl_pt'monstermash4+anyv3.safetensors' -o monstermash4_anyv3.safetensors
  elif аниме_манга_хентай == "monstermash6_anyv3":
    # !$dl_pt'monstermash6+anyv3.safetensors' -o monstermash6_anyv3.safetensors
  elif аниме_манга_хентай == "NAI":
    # !$dl_hf'novelai_fp16.safetensors' -o novelai.safetensors
    # !$dl_pt'novelai.vae.pt'
  elif аниме_манга_хентай == "OrangeMixs_All":
    # !$dl_hf'ElderOrangeMix.safetensors'
    # !$dl_hf'AbyssOrangeMix_half.safetensors'
    # !$dl_hf'AbyssOrangeMix.safetensors'
    # !$dl_hf'AbyssOrangeMix_Night.safetensors'
    # !$dl_hf'AbyssOrangeMix_base.safetensors'
    # !$dl_hf'AbyssOrangeMix2_sfw.safetensors'
    # !$dl_hf'AbyssOrangeMix2_hard.safetensors'
    # !$dl_hf'AbyssOrangeMix2_nsfw.safetensors'
    # !$dl_hf'BloodOrangeMix.safetensors'
    # !$dl_hf'BloodOrangeMix_half.safetensors'
    # !$dl_hf'BloodNightOrangeMix.safetensors'
    # !$dl_hf'EerieOrangeMix2_half.safetensors'
    # !$dl_hf'EerieOrangeMix2.safetensors'
    # !$dl_hf'EerieOrangeMix2_night.safetensors'
    # !$dl_hf'EerieOrangeMix2_base.safetensors'
    # !$dl_hf'EerieOrangeMix_night.safetensors'
    # !$dl_hf'EerieOrangeMix.safetensors'
    # !$dl_hf'EerieOrangeMix_half.safetensors'
    # !$dl_hf'EerieOrangeMix_base.safetensors'
    # !$dl_hf'ElyOrangeMix.safetensors'
    # !$dl_hf'ElyNightOrangeMix.safetensors'
    # !$dl_hf'ElyOrangeMix_half.safetensors'
  elif аниме_манга_хентай == "PastelMix":
    # !$dl https://huggingface.co/andite/pastel-mix/resolve/main/pastelmix-better-vae-fp16.safetensors -o Pastelmix_betterVAE.safetensors
  elif аниме_манга_хентай == "Plat":
    #!$dl_hf'Plat_v1_3.safetensors'
    # !$dk https://huggingface.co/p1atdev/pd-archive/resolve/main/plat-v1-3-1-fp16.safetensors -o Plat_v1_3_1.safetensors
    # !$dl https://huggingface.co/p1atdev/pd-archive/resolve/main/plat-v1-3-0.yaml -o Plat_v1_3_1.yaml
    # !$dl https://huggingface.co/hakurei/waifu-diffusion-v1-4/resolve/main/vae/kl-f8-anime2.ckpt -o Plat_v1_3_1.vae.pt
  elif аниме_манга_хентай == "protogenV22Anime":
    # !$dl_pt'protogenV22Anime_22_fp16.safetensors' -o protogenV22Anime.safetensors
  elif аниме_манга_хентай == "Trinart":
    # !$dl_hf'trinart2.safetensors'
  elif аниме_манга_хентай == "WaifuDiffusion":
    # !$dl_hf'WaifuDiffusion_v1_4.safetensors'
    # !$dl_hf'WaifuDiffusion_v1_4.yaml'
    # !$dl_hf'WaifuDiffusion_v1_4.vae.safetensors'
    # !$dl_hf'WaifuDiffusion_v1_4.vae.yaml'
    # !$dl_hf'wd-v1-3_fp16.safetensors' -o WaifuDiffusion.safetensors
  elif аниме_манга_хентай == "Yohan_Diffusion":
    # !$dl_hf'Cocoa.safetensors'
    # !$dl_hf'Butter.safetensors'
    # !$dl_hf'Latte.safetensors'
    # !$dl_hf'yohan-diffusion.safetensors'

  вектор_и_лайнарт = "" #@param ["", "AnimePencil", "App_Icons", "ColoringBook", "vectorArt"]
  if вектор_и_лайнарт == "":
    None
  elif вектор_и_лайнарт == "AnimePencil":
    # !$dl_hf'anime-pencil-diffusion-v4.safetensors'
  elif вектор_и_лайнарт == "App_Icons":
    # !$dl_hf'App_Icons.safetensors'
  elif вектор_и_лайнарт == "ColoringBook":
    # !$dl_hf'ColoringBook.safetensors'
    # !$dl_hf'ColoringBook.yaml' -q
  elif вектор_и_лайнарт == "vectorArt":
    # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/vectorArt_vectorArtBeta.safetensors -o vectorArt.safetensors
    # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/vectorArt_vectorArtBeta.yaml -o vectorArt.yaml

  женские_модели = "" #@param ["", "artErosAErosATribute_aEros", "Babes", "bkdbj", "F222", "GenericFemaleMix", "HassanBlend", "pyros_blowjob", "RealEldenApocalypse_AnalogSexKnoll_4CandyPureSimp_FEET", "uberRealisticPornMer_urpMv12"]
  if женские_модели == "":
    None
  elif женские_модели == "artErosAErosATribute_aEros":
    # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/artErosAErosATribute_aErosCkpt-ema-fp16.safetensors -o artErosAErosATribute_aEros.safetensors
    # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/artErosAerosATribute_aerosINPAINTINGNovae-inpainting_fp16.safetensors -o artErosAErosATribute_NoVAE-inpainting.safetensors.safetensors
    # !$dl_hf'artErosAErosATribute_NoVAE.safetensors'
  elif женские_модели == "Babes":
    # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/babes_babes11_fp16.safetensors -o Babes.safetensors
    # !$dl https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.ckpt -o Babes.vae.pt
    #!$dl_hf'Babes.vae.safetensors'
  elif женские_модели == "bkdbj":
    # !$dl_hf'bkdbj_fp16.safetensors' -o bkdbj.safetensors
  elif женские_модели == "F222":
    # !$dl_hf'f222_fp16.safetensors' -o f222.safetensors
  elif женские_модели == "GenericFemaleMix":
    # !$dl_hf'GenericFemaleMix_v2-1.safetensors'
  elif женские_модели == "HassanBlend":
    #!$dl_hf'HassanBlend1.5.safetensors'
    # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/hassanblend1512And_hassanblend1512_fp16.safetensors -o HassanBlend1_5_12.safetensors
    # !$dl_hf'HassanBlend_1.4_fp16.safetensors' -o HassanBlend_v1_4.safetensors
    # !$dl_hf'HassansBlend_1.2_fp16.safetensors' -o HassanBlend_v1_2.safetensors
  elif женские_модели == "pyros_blowjob":
    # !$dl_hf'pbj_v1.safetensors'
  elif женские_модели == "RealEldenApocalypse_AnalogSexKnoll_4CandyPureSimp_FEET":
    # !$dl_hf'realEldenApocalypseA_realEldenApocalypseAsexKnoll4CandyPureSimpFeet-ema.fp16.safetensors' -o RealEldenApocalypse_AnalogSexKnoll_4CandyPureSimp_FEET.safetensors
  elif женские_модели == "uberRealisticPornMer_urpMv12":
    # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/uberRealisticPornMerge_urpmv12.safetensors -o uberRealisticPornMer_urpMv12.safetensors
    # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/uberRealisticPornMerge_urpmv12Inpainting-inpainting_fp16.safetensors -o uberRealisticPornMer_urpMv12-inpainting.safetensors

  игры_и_кино = "" #@param ["", "Black_Souls", "Bloodborne", "Borderlands", "DarkSouls", "DiscoElysium_style", "EldenRing_style", "GalaxyTimemachines", "Hogwarts_Legacy", "pokemon", "ProtoGenDragonX59", "protogenX3_4", "Starsector_Portrait", "TronLegacy_style"]
  if игры_и_кино == "":
    None
  elif игры_и_кино == "Black_Souls":
    # !$dl_hf'Black_Souls.safetensors'
  elif игры_и_кино == "Bloodborne":
    # !$dl_hf'Bloodborne_Style.safetensors'
  elif игры_и_кино == "Borderlands":
    # !$dl_hf'borderlands.safetensors'
  elif игры_и_кино == "DarkSouls":
    # !$dl_hf'DarkSouls_Style.safetensors'
  elif игры_и_кино == "DiscoElysium_style":
    # !$dl_hf'discoElysium-pruned.safetensors' -o discoelysium_style.safetensors
  elif игры_и_кино == "EldenRing_style":
    # !$dl_hf'eldenring-v2-pruned.safetensors' -o elden_ring_style.safetensors
  elif игры_и_кино == "GalaxyTimemachines":
    # !$dl_hf'GalaxyTimemachines_v3_Inpainting.safetensors'
  elif игры_и_кино == "Hogwarts_Legacy":
    # !$dl_hf'HogLegStyle-v2.4.safetensors' -o HogLeg_Style.safetensors
  elif игры_и_кино == "pokemon":
    # !$dl_hf'pokemon_fp16.safetensors' -o pokemon.safetensors
  elif игры_и_кино == "ProtoGenDragonX59":
    # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/protogenDragon_protogenX59_fp16.safetensors -o ProtoGenDragonX59.safetensors
  elif игры_и_кино == "protogenX3_4":
    # !$dl_hf'protogenX3.4-fp16-ema.safetensors' -o protogenX3_4.safetensors
  elif игры_и_кино == "Starsector_Portrait":
    # !$dl_hf'starsectorportrait.safetensors'
    # !$dl_pt'HN_ssportrait.pt' -o /content/stable-diffusion-webui/models/hypernetworks/HN_ssportrait.pt
  elif игры_и_кино == "TronLegacy_style":
    # !$dl_hf'Tron-Legacy-Style-trnlgcy.safetensors' -o trnlgcy.safetensors

  космос_и_техника = "" #@param ["", "EpicSpaceMachine", "James_Webb_Cosmos", "nousr_robot", "ProtoGenInfinityX86"]
  if космос_и_техника == "":
    None
  elif космос_и_техника == "EpicSpaceMachine":
    # !$dl_hf'EpicSpaceMachine.safetensors'
  elif космос_и_техника == "James_Webb_Cosmos":
    # !$dl_hf'JWST-Deep-Space.safetensors'
  elif космос_и_техника == "nousr_robot":
    # !$dl_hf'robo-diffusion-v2-base.safetensors' -o nousr_robot.safetensors
  elif космос_и_техника == "ProtoGenInfinityX86":
    # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/protogenInfinity_protogenX86.safetensors -o ProtoGenInfinityX86.safetensors

  крипота = "" #@param ["", "blotmon", "Creepy_Diffusion", "newhorrorfantasy_style", "rotten_zombie"]
  if крипота == "":
    None
  elif крипота == "blotmon":
    # !$dl_hf'blotmon-v1-5000.safetensors' -o blotmon.safetensors
  elif крипота == "Creepy_Diffusion":
    # !$dl_hf'creepy-diffusion.safetensors'
  elif крипота == "newhorrorfantasy_style":
    # !$dl_hf'newhorrorfantasy_style.safetensors'
  elif крипота == "rotten_zombie":
    # !$dl_hf'RottingZombie_person.safetensors'

  макро = "" #@param ["", "macroDiffusion", "Microscopic"]
  if макро == "":
    None
  elif макро == "Microscopic":
    # !$dl_hf'Microscopic_v1_fp16.safetensors' -o Microscopic.safetensors
  elif макро == "macroDiffusion":
    # !$dl_hf'macroDiffusion_10.safetensors'

  мемные = "" #@param ["", "chkn_петухи", "ГигаЧэд", "hyperpreg__round_belly", "Pepe"]
  if мемные == "":
    None
  elif мемные == "chkn_петухи":
    # !$dl_hf'chkn.safetensors'
  elif мемные == "ГигаЧэд":
    # !$dl_hf'gigachad_2000.safetensors' -o gigachad.safetensors
  elif мемные == "hyperpreg__round_belly":
    # !$dl_hf'hyperpreg__round_belly.safetensors'
  elif мемные == "Pepe":
    # !$dl_hf'pepestylev2_2200.safetensors' -o pepestyle_person.safetensors

  мужские_модели = "" #@param ["", "AIroticArtsPenis", "DaddyDiffusion", "Homoerotic", "TwinkDiffusion", "UncutPenises"]
  if мужские_модели == "":
    None
  elif мужские_модели == "AIroticArtsPenis":
    # !$dl_hf'airoticartsPenis.safetensors' -o airoticartsPenis_v1-inpainting.safetensors
  elif мужские_модели == "TwinkDiffusion":
    # !$dl_hf'twinkdiffusionv2.safetensors'
  elif мужские_модели == "Homoerotic":
    # !$dl_hf'homoerotic_v2.safetensors'
  elif мужские_модели == "DaddyDiffusion":
    # !$dl_hf'daddyDiffusion_v1.safetensors'
  elif мужские_модели == "UncutPenises":
    # !$dl_hf'unctpns_fp16.safetensors' -o uncut-penis.safetensors

  мультипликация = "" #@param ["", "Arcane_style", "Archer_style", "Classic_Disney_style", "megaPals", "Modern_Disney_style", "SpiderVerse_style"]
  if мультипликация == "":
    None
  elif мультипликация == "Arcane_style":
    # !$dl_hf'arcane-diffusion-v3.safetensors' -o arcane_style.safetensors
  elif мультипликация == "Archer_style":
    # !$dl_hf'archer-v1.safetensors' -o archer_style.safetensors
  elif мультипликация == "Classic_Disney_style":
    # !$dl_hf'classicAnim-v1.safetensors' -o classic_disney_style.safetensors
  elif мультипликация == "megaPals":
    # !$dl_hf'megaPals.safetensors'
  elif мультипликация == "Modern_Disney_style":
    # !$dl_hf'moDi-v1-pruned.safetensors' -o modern_disney_style.safetensors
  elif мультипликация == "SpiderVerse_style":
    # !$dl_hf'spiderverse-v1-pruned.safetensors' -o spiderverse_style.safetensors

  общего_назначения = "" #@param ["", "elldrethSLucidMix", "epicDiffusion", "MMD", "RealisticVision", "SD_v2_1", "SD_v1_5", "SD_v1_5_full", "SD_v1_4", "Vintedois_Diffusion", "Wavy_fusion"]
  if общего_назначения == "":
    None
  elif общего_назначения == "elldrethSLucidMix":
    # !$dl_hf'elldrethSLucidMix_v10-ema-fp16.safetensors' -o elldrethSLucidMix_v10.safetensors
  elif общего_назначения == "epicDiffusion":
    # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/epicDiffusion_epicDiffusion10.safetensors -o epicDiffusion.safetensors
  elif общего_назначения == "MMD":
    # !$dl_pt'MMDv1-18_fp16.safetensors' -o MMDv1_18.safetensors
  elif общего_назначения == "RealisticVision":
    # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/realisticVisionV12_v12_fp16.safetensors -o RealisticVision.safetensors
  elif общего_назначения == "SD_v2_1":
    # !$dl_hf'SDv2_1_768.yaml' --quiet
    # !$dl_hf'SDv2_1_512.yaml' --quiet
    # !$dl_hf'SDv2_1_512_inpaiting.yaml' --quiet
    # !$dl_hf'SDv2_1_512.safetensors'
    # !$dl_hf'SDv2_1_512_inpaiting.safetensors'
    # !$dl_hf'SDv2_1_768.safetensors'
    # !sed -i 's@def load_state_dict(checkpoint_path: str, map_location.*@def load_state_dict(checkpoint_path: str, map_location="cuda"):@' /usr/local/lib/python3.8/dist-packages/open_clip/factory.py
  elif общего_назначения == "SD_v1_5":
    # !$dl_hf'sd-v1-5_fp16.safetensors' -o sd-v1-5.safetensors
    # !$dl_pt'sd-v1-5.vae.pt'
    #!$dl_hf'sd-v1-5.vae.safetensors'
    # !$dl_hf'sd-v1-5.inpainting_fp16.safetensors' -o sd-v1-5.inpainting.safetensors
    # !$dl_pt'sd-v1-5.inpainting.vae.pt'
    #!$dl_hf'sd-v1-5.inpainting.vae.safetensors'
  elif общего_назначения == "SD_v1_5_full":
    # !$dl_hf'v1-5-ema.safetensors'
    # !$dl_pt'sd-v1-5.vae.pt' -o v1-5-ema.vae.pt
  elif общего_назначения == "SD_v1_4":
    # !$dl_hf'sd-v1-4_fp16.safetensors' -o sd-v1-4.safetensors
  elif общего_назначения == "Vintedois_Diffusion":
    # !$dl_hf'vintedois-diffusion-v01.safetensors'
  elif общего_назначения == "Wavy_fusion":
    # !$dl https://huggingface.co/wavymulder/wavyfusion/resolve/main/wa-vy-fusion_1.0.safetensors -o Wavy_fusion_v1.safetensors

  пиксельарт = "" #@param ["", "All_In_1_Pixel", "MinecraftRTX", "Pixel_Art", "pixel_landscape"]
  if пиксельарт == "":
    None
  elif пиксельарт == "All_In_1_Pixel":
    # !$dl_hf'Public-Prompts-Pixel-Model.safetensors' -o all_in_one_PixelModel.safetensors
  elif пиксельарт == "MinecraftRTX":
    # !$dl_hf'BlockWorldRTX.safetensors'
  elif пиксельарт == "Pixel_Art":
    # !$dl_hf'Pixel_Art.safetensors'
  elif пиксельарт == "pixel_landscape":
    # !$dl_hf'16-bit-landscape_PublicPrompts.safetensors' -o 16bit_landscape.safetensors

  трехмерная_графика = "" #@param ["", "aloeVeraSSimpMaker3K_simpMaker3K1", "hAS3Dkx11_3Dkx11", "microworld", "PFG", "PostApocalypse", "Redshift", "RPG", "SPYBG_Toolkit"]
  if трехмерная_графика == "":
    None
  elif трехмерная_графика == "Redshift":
    # !$dl_hf'redshift-diffusion-v1.safetensors' -o redshift.safetensors
  elif трехмерная_графика == "hAS3Dkx11_3Dkx11":
    # !$dl_hf'hAS3Dkx11_3Dkx11.safetensors'
  elif трехмерная_графика == "PostApocalypse":
    # !$dl_hf'postapocalypse_v1.safetensors'
  elif трехмерная_графика == "PFG":
    # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/pfg_111Safetensors_fp16.safetensors -o PFG.safetensors
  elif трехмерная_графика == "microworld":
    # !$dl_hf'microworld.safetensors'
  elif трехмерная_графика == "aloeVeraSSimpMaker3K_simpMaker3K1":
    # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/aloeVeraSSimpMaker3K_simpMaker3K1-ema-fp16.safetensors -o aloeVeraSSimpMaker3K_simpMaker3K1.safetensors
  elif трехмерная_графика == "RPG":
    # !$dl_hf'RPG-v2.safetensors'
  elif трехмерная_графика == "SPYBG_Toolkit":
    # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/spybgsToolkitFor_v35.yaml -o SPYBG_Toolkit.yaml -q
    # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/spybgsToolkitFor_v35.safetensors -o SPYBG_Toolkit.safetensors

  фотореалистичные_общие = "" #@param ["", "Analog_diffusion", "Clarity", "classicNegative", "dreamlikePhotoReal", "ModelShoot", "Poolsuite", "Portrait_Plus", "PowerfulMix", "Protogen_X53_Photorealism", "Radiant", "realisticHASDX", "s4w3d0ff_Blend", "Timeless", "uberrealistic_mix_PFG_URPM_Openjourney", "woopwoopPhoto"]
  if фотореалистичные_общие == "":
    None
  elif фотореалистичные_общие == "Analog_diffusion":
    # !$dl https://huggingface.co/wavymulder/Analog-Diffusion/resolve/main/analog-diffusion-1.0.safetensors -o analog-diffusion.safetensors
  elif фотореалистичные_общие == "Clarity":
    # !$dl_hf'Clarity.safetensors'
    # !$dl_hf'Clarity.vae.pt'
    # !$dl_hf'Clarity-inpainting.safetensors'
  elif фотореалистичные_общие == "classicNegative":
    # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/classicnegative.safetensors
    # !$dl_hf'classicNegative768px.safetensors'
    # !$dl_hf'classicNegative768px.yaml'
  elif фотореалистичные_общие == "dreamlikePhotoReal":
    # !$dl_hf'dreamlikePhotoRealV2_dreamlikePhotoRealV2.safetensors' -o dreamlikePhotoRealV2.safetensors
  elif фотореалистичные_общие == "ModelShoot":
    # !$dl https://huggingface.co/wavymulder/modelshoot/resolve/main/modelshoot-1.0.safetensors -o ModelShoot_v1.safetensors
  elif фотореалистичные_общие == "Poolsuite":
    # !$dl_hf'poolsuite_step2010.safetensors'  -o poolsuite_style.safetensors
  elif фотореалистичные_общие == "Portrait_Plus":
    # !$dl https://huggingface.co/wavymulder/portraitplus/resolve/main/portrait%2B1.0.safetensors -o Portrait_Plus.safetensors
  elif фотореалистичные_общие == "PowerfulMix":
    # !$dl_hf'PowerfulMix_v2.safetensors'
  elif фотореалистичные_общие == "Protogen_X53_Photorealism":
    # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/protogenX53Photorealism_10_fp16.safetensors -o Protogen_X53_Photorealism.safetensors
  elif фотореалистичные_общие == "Radiant":
    # !$dl_hf'Radiant_v3.safetensors'
  elif фотореалистичные_общие == "realisticHASDX":
    # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/hasdx_realisticHASDX.safetensors -o realisticHASDX.safetensors
  elif фотореалистичные_общие == "s4w3d0ff_Blend":
    # !$dl_hf's4w3d0ff_Blend.safetensors'
  elif фотореалистичные_общие == "Timeless":
    # !$dl https://huggingface.co/wavymulder/timeless-diffusion/resolve/main/timeless-1.0.safetensors -o Timeless_v1.safetensors
  elif фотореалистичные_общие == "uberrealistic_mix_PFG_URPM_Openjourney":
    # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/uberrealistic_mix_PFG_URPM_Openjourney_fp16.safetensors -o uberrealistic_mix_PFG_URPM_Openjourney.safetensors
  elif фотореалистичные_общие == "woopwoopPhoto":
    # !$dl_hf'woopwoopPhoto_12.safetensors'

  фурри = "" #@param ["", "FurSlut", "YIFFY_EPOCH18", "YIFFY_GAPE", "YiffyMix", "Zack3D_Kinky"]
  if фурри == "":
    None
  elif фурри == "FurSlut":
    # !$dl_hf'furslut.safetensors'
  elif фурри == "YIFFY_EPOCH18":
    # !$dl_hf'yiffy-e18_fp16.safetensors' -o yiffy-e18.safetensors
  elif фурри == "YIFFY_GAPE":
    # !$dl_hf'gape22_yiffy15_fp16.safetensors' -o gape_yiffy.safetensors
  elif фурри == "YiffyMix":
    # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/yiffymix_yiffymix_fp16.safetensors -o YiffyMix.safetensors
  elif фурри == "Zack3D_Kinky":
    # !$dl_hf'Zack3D_Kinky-v1_fp16.safetensors' -o Zack3D_Kinky.safetensors

  футанари = "" #@param ["", "Futagen"]
  if футанари == "":
    None
  elif футанари == "Futagen":
    # !$dl_hf'Futagen_v2.safetensors'

  художественные = "" #@param ["", "Abstract_Swirls", "ATitanStrawBerry", "Babes", "BackgroundsDiffusion", "beeple", "Beksinski", "BubblyDubbly", "CALARTS", "Cats_Tabaxi", "Cthulhu_illithid", "DanMumford_Style", "DBWayneBarlowe_JM", "dreamlikediffusion", "DreamShaper", "HASDX", "img2img_PaintingGenerator", "Ложкин", "Midjourney", "MosaicArt", "OldJourney", "OpenJourney", "Protogen_Eclipse", "Protogen_X58_Rebuil", "protogenNovaX80", "reasonableDrink", "reonArgondiansStyle", "ssmoky", "SynthwavePunk", "Van_Gogh", "WiKiArt"]
  if художественные == "":
    None
  elif художественные == "Abstract_Swirls":
    # !$dl_hf'Abstract_Swirls.safetensors' -o AbstractSwirls.safetensors
  elif художественные == "ATitanStrawBerry":
    # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/ATitanStrawBerry_fp16.safetensors -o ATitanStrawBerry.safetensors
  elif художественные == "BackgroundsDiffusion":
    # !$dl_hf'sjh_style_fp16.safetensors' -o sjh_style.safetensors
  elif художественные == "beeple":
    # !$dl_hf'beeple.safetensors'
  elif художественные == "Beksinski":
    # !$dl_hf'beksinski-style.safetensors'
  elif художественные == "BubblyDubbly":
    # !$dl_hf'bubblydubbly_7k_fp16.safetensors' -o bubblydubbly_7k.safetensors
    # !$dl_hf'bubblydubbly_fp16.safetensors' -o bubblydubbly.safetensors
  elif художественные == "CALARTS":
    # !$dl_hf'CALARTS.safetensors'
  elif художественные == "Cats_Tabaxi":
    # !$dl_hf'tabaxi2500person.safetensors' -o tabaxi_person.safetensors
  elif художественные == "Cthulhu_illithid":
    # !$dl_hf'DnDAi-illithid_Person_fp16.safetensors' -o illithid_person.safetensors
  elif художественные == "DanMumford_Style":
    # !$dl_hf'DanMumford_Style.safetensors'
  elif художественные == "DBWayneBarlowe_JM":
    # !$dl_hf'DBWayneBarlowe_JM_fp16.safetensors' -o DBWayneBarlowe_JM.safetensors
  elif художественные == "dreamlikediffusion":
    # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/dreamlikediffusion1.0.safetensors -o dreamlikediffusion.safetensors
  elif художественные == "DreamShaper":
    #!$dl_hf'DreamShaper_v3_3.safetensors'
    # !$dl_hf'DreamShaper_v3_3.vae.pt' -o DreamShaper.vae.pt
    #!$dl_hf'DreamShaper_v3_3.vae.safetensors'
    # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/dreamshaper_332BakedVaeClipFix_fp16.safetensors -o DreamShaper.safetensors
  elif художественные == "HASDX":
    # !$dl_hf'HASDX-ema-fp16.safetensors' -o HASDX.safetensors
  elif художественные == "img2img_PaintingGenerator":
    # !$dl_hf'img2img_PaintingGenerator.safetensors'
  elif художественные == "Ложкин":
    # !$dl_hf'lozhkin.safetensors'
  elif художественные == "Midjourney":
    # !$dl_hf'mdjrny-v4_style.safetensors'
  elif художественные == "MosaicArt":
    # !$dl_hf'MosaicArt_v2.safetensors'
    # !$dl_hf'MosaicArt_v2.yaml'
  elif художественные == "OldJourney":
    # !$dl_hf'OldJourney.safetensors'
    # !$dl_hf'OldJourney.yaml'
  elif художественные == "OpenJourney":
    # !$dl_hf'mdjrny-v4_style-openjourney.safetensors'
  elif художественные == "Protogen_Eclipse":
    # !$dl_hf'protogenEclipse_protogenX74.safetensors'
  elif художественные == "Protogen_X58_Rebuil":
    # !$dl_pt'Protogen_x5.8_Rebuilt_pruned.safetensors' -o Protogen_X58_Rebuil.safetensors
  elif художественные == "protogenNovaX80":
    # !$dl_hf'protogenNovaX80.safetensors'
  elif художественные == "reasonableDrink":
    # !$dl_hf'reasonableDrink.safetensors'
  elif художественные == "reonArgondiansStyle":
    # !$dl_hf'reonArgondiansStyle.safetensors'
  elif художественные == "ssmoky":
    # !$dl_hf'ssmoky1_3000.safetensors' -o ssmoky.safetensors
  elif художественные == "SynthwavePunk":
    # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/synthwavepunk_v2.safetensors -o synthwavepunk_v2.safetensors
  elif художественные == "Van_Gogh":
    # !$dl_hf'lvngvncnt_Van-Gogh.safetensors'
  elif художественные == "WiKiArt":
    # !$dl_hf'sd-wikiart-v2.safetensors' -o wikiart_v2.safetensors



if not модели_только_с_гуглодиска:
  if подтянуть_модели_с_гулодиска:
    # !ln -s "{папка_с_моделями_на_гуглодиске}"/* /content/stable-diffusion-webui/models/Stable-diffusion/

if clear_out:
  output.clear()
# !sleep 2
#@markdown <details><summary><font color='#c89c26' size='3' face="Verdana"><b>👈 Дополнительные опции</b></font></summary><li><a href="#scrollTo=MTex_2fJwYjn">Ячейка</a> для скачивания нескольких моделей (Перед запуском WebUI).</li><li>Нужная модель доступна через торрент? <a href="#scrollTo=CD4q5amW7Oib">Ячейка</a> для скачивания торрентов.</li><li><a href="https://t.me/colabSDbot">Если пришлешь в тг-бот</a> ссылку/торрент на очень нужную модель, ее можно будет добавить в меню выбора моделей.</li><li>Скаченные откуда-то модели, можешь удобно выгрузить на HuggingFace <a href="#scrollTo=wsS_furff9uY">в этой ячейке</a>, чтобы всегда иметь прямые ссылки на свои модели с максимальной скоростью загрузки.</li><li>Нашел модель, но она не в формате .ckpt, а в каких-то .bin-файлах? <a href="#scrollTo=du5Xt_kv7Gd9">В этой ячейке</a> можешь сконвертировать diffusers-модели в нормальный формат и получить ckpt-файлик.</li><li><a href="#scrollTo=heHty0pzVYjw">уменьшить размер модели</a></li><li><a href="#scrollTo=3yZXlc_hvzAF">сконвертировать в safetensors</a></li><li><a href="#scrollTo=wsUrVIhnstui">сконвертировать в ckpt</a></li><li>Другие модели можно найти <a href="https://teletype.in/@stablediffusion/models_for_SD">на этой странице</a>.</li></details>

#@markdown <details><summary><font color='#38c013' size='3' face="Verdana"><b>👈 Установить гиперсети?</b></font></summary><font color='red'>Внимание: гиперсети не работают с установленным Xformers!</font> Будет установлен небольшой пак гиперсетей, для экспериментов, и чтобы понять как они работают, прежде чем создавать свои. Данные гиперсети можно использовать, например, с анимечными и фуррийными моделями, чтобы получить различные результаты.<details><summary>список гиперсетей из пака</summary><img src='https://files.catbox.moe/fq5y8h.png' width='640px'/></details><details><summary>что это такое?</summary>Гиперсеть - дополнительный слой визуализации после основной модели. Гиперсеть обучает модель не новым изображениям, а перестраивает вектора, так чтобы определенные токены ассоциировались с каким-то новым понятием. Например нейросеть не знает что такое <i>пролапс</i> - гиперсеть укажет что это "<i>красная глянцевая прямая кишка из анального сфинктера, плотная, набухшая, что-то среднее между красной колбасой и бутоном розы</i>". При условии что модель нейросети хорошо знает все эти понятия по отдельности - гиперсеть может сопоставить их с новым термином - <i>пролапс</i>, который можно будет использовать в промпте. Более подробно можешь <a href='https://bennycheung.github.io/stable-diffusion-training-for-embeddings#:~:text=Hypernetwork,-Hypernetwork%3A%20An%20additional'>почитать в статье</a>.</details></details>
гиперсети = False #@param {type:"boolean"}
# %store гиперсети
#@markdown <details><summary><font color='808080' size='3' face="Verdana"><b>👈 Установить дополнительные модели ESRGAN?</b></font></summary>Будет установлен огромнейший пак из 110 моделей Real-ESRGAN. Тебе это совершенно не нужно для генерации и апскейла сгенерированных картинок! Для этого нужные модели скачиваются по дефолту. <details><summary>а нaxyя?</summary>А данная опция нужна только для апскейла/исправления плохих, шакальных картинок из интернета, в основном фотографий очень низкого качества. Все это это может быть полезно для подготовки обучающего датасета, когда есть много нужных картинок, но они не лучшего качества, очень старые и т.п. Например, хочется обучить нейросетку чему-то из 90-х прошлого века или нулевых, но все фотки того времени в интернете зашакалены, или вообще от них остались одни превьюшки на сайтах-галереях. Этот пак именно для этого и больше ни для чего. Предполагается тщательный ручной подбор конкретной модели под определенную картинку, потом доводка результатов в фотошопе, посредством сложения наиболее удачных частей картинки от разных моделей (например кожу лучше восстановила одна модель, волосы - другая, текстуру одежды - третья, природу на заднем плане - четвертая, кота сидящего рядом - стодесятая модель, а небо - восьмидесятая).</details></details>
модели_ESRGAN = False #@param {type:"boolean"}
# %store модели_ESRGAN

#@markdown <details><summary><font color='#38c013' size='3' face="Verdana"><b>👈 Запустить WebUI сразу после установки?</b></font></summary>Получить <b>свой</b> токен для ngrok можешь <a href="https://dashboard.ngrok.com/get-started/your-authtoken">тут</a> |  Если токен ngrok не будет указан в поле выше, ngrok в 99% все равно запустится - будет использован ч҉у҉ж҉о҉й токен.<br><code>--no-half-vae</code> это дополнительный аргумент запуска, позволяющий избежать черных квадратов при генерации (запрещает перевод vae в режим 16-bit floats)<br>⚠️ <font color='#32CD32'>После того как <strong>все прогрузится</strong>, ищи сылки типа</font>: <br> <code>cool-brooms-admire-23-251-149-142.loca.lt</code> или <code>0bf89138a7c4877f.gradio.app</code> или <code>e402-34-126-159-209.ngrok.io</code><br>И переходи по ссылкам. Gradio - дефольный, но бывает зависает. Пробуй Ngrok или LokalIt<br><details><summary><font color="#c89c26">где искать и какие ссылки? </font></summary><img src="https://files.catbox.moe/wrq2pc.svg" width="70%"></details><b><font color='#32CD32'>Рекомендую использовать ngrok.</font></b> Работа через gradio сопряжена с частыми зависаниями и потерей коннекта при пакетной генерации. loca.lt - иногда чуточку лучше. Ngrok тоже не идеален, но он более стабилен.<br>Если возникают проблемы с подгрузкой жирных моделей (ema-full, non-pruned, которые под 7 гигов) - это из-за нехватки памяти на бесплатном тарифе колаба. <a href="#scrollTo=otsDSY8bCdVN">Воспользуйся прунингом</a>, чтобы уменьшить размер. Прунинг никак не сказывается на качестве генерации, картинки будут идентичные 100% (проверенно Аноном).</details>
запустить_сразу = True #@param {type:"boolean"}
# %store запустить_сразу
ngrok_token = "\u0442\u0432\u043E\u0439_\u0442\u043E\u043A\u0435\u043D" #@param {type:"string"}
no_half_vae = False #@param {type:"boolean"}
# %store no_half_vae
#@markdown [как составить промпт и список художников](https://teletype.in/@stablediffusion/artists_for_prompts) | [о настройках генерации](https://teletype.in/@stablediffusion/samplers_steps)
#@markdown <details><summary>быстрые ссылки</summary><ul><li><a href="#scrollTo=10iWu8h1UTvQ">установка и запуск</a></li><li><a href="#scrollTo=MTex_2fJwYjn">выбор и установка нескольких моделей</a></li><li><a href="#scrollTo=R-xAdMA5wxXd">запуск/перезапуск</a></li><li><a href="#scrollTo=V-2LlLHZPgoB">скачивание архива с картинками</a></li><li><a href="#scrollTo=w_29ofOEGng_">подключение/переподключение/сброс кэша гуглодиска</a></li><li><a href="#scrollTo=TuwHDqutjgZd">массовая загрузка по прямым ссылкам</a></li><li><a href="#scrollTo=62QDyjXtYHjF">загрузчик моделей с civitai.com</a></li><li><a href="#scrollTo=VirGjpcNCCKX">скачивание с торрентов</a></li><li><a href="#scrollTo=heHty0pzVYjw">прунинг и конвертация моделей</a></li><li><a href="#scrollTo=j7N-__N4f9uY">выгрузка моделей на HuggingFace</a></li><li><a href="#scrollTo=zVmDZeIAIcja">выгрузка на файлообменники</a></li><li><a href="#scrollTo=k98WImeXH5pK">запаковка/распаковка архивов</a></li><li><a href="#scrollTo=Oh37kTko2shA">операции с папками/файлами/симлинками</a></li></ul></details>
#локализация и настройки
# !$dl_gh'localization.json' -o /content/stable-diffusion-webui/localizations/localization.json
# !$dl_gh'config.json' -o /content/stable-diffusion-webui/config.json
# !$dl_gh'ui-config.json' -o /content/stable-diffusion-webui/ui-config.json

# если забыл выбрать хоть одну модель, чтобы небыло ошибки запуска: скачивание самой общей модели
if запустить_сразу:
  # !rm '/content/stable-diffusion-webui/models/Stable-diffusion/Put Stable Diffusion checkpoints here.txt'
  with os.scandir('/content/stable-diffusion-webui/models/Stable-diffusion') as check_models:
    if any(check_models):
      None
    else:
      # !$dl https://huggingface.co/Pups/sdtensors/resolve/main/epicDiffusion_epicDiffusion10.safetensors -o /content/stable-diffusion-webui/models/Stable-diffusion/epicDiffusion.safetensors


if deepdanbooru:
  # !git clone "https://github.com/DominikDoom/a1111-sd-webui-tagcomplete.git" /content/stable-diffusion-webui/extensions/tag-autocomplete
  if not os.path.exists('/content/stable-diffusion-webui/tmp'):
    os.makedirs('/content/stable-diffusion-webui/tmp')
  tagacp = "/content/stable-diffusion-webui/tmp/tagAutocompletePath.txt"
  # !touch $tagacp
  with open(tagacp, 'a') as ta:
    ta.write("extensions/a1111-sd-webui-tagcomplete/tags")

if clear_out:
  output.clear()

# скачивание VAE
# %cd /content/stable-diffusion-webui/models/VAE/
# !$dl https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.ckpt -o vae-ft-mse.ckpt
# !$dl https://huggingface.co/stabilityai/sd-vae-ft-ema-original/resolve/main/vae-ft-ema-560000-ema-pruned.ckpt -o vae-ft-ema.ckpt
# !$dl_hf'kl-f8-trinart_characters.pt' -o kl-f8-trinart_characters.ckpt
# !$dl_hf'nivelai-vae.pt' -o novelai-vae.ckpt
# !$dl_hf'kl-f8-anime.pt' -o kl-f8-anime.ckpt
# !$dl_hf'kl-f8-anime2.pt' -o kl-f8-anime2.ckpt
# %cd /content/stable-diffusion-webui/

if Instruct_pix2pix:
  if версия_A1111 == "стабильная":
    print("\033[01;38;05;208mInstruct Pix2Pix модель и расширение не будут установленны,\nпотому что ты не выбрал свежую версию A1111!\033[0m")
    output.eval_js(f'new Audio("{gh}pixwarn.mp3").play()')
  else:
    # !git clone https://github.com/Klace/stable-diffusion-webui-instruct-pix2pix /content/stable-diffusion-webui/extensions/stable-diffusion-webui-instruct-pix2pix
    # !$dl_hf'instruct_pix2pix.safetensors' -o /content/stable-diffusion-webui/models/Stable-diffusion/instruct_pix2pix.safetensors
    # !ln -s /content/stable-diffusion-webui/models/VAE/vae-ft-mse.ckpt /content/stable-diffusion-webui/models/Stable-diffusion/instruct_pix2pix.vae.pt

if ControlNet:
  dlcn = "wget -nv -t 10 --show-progress --progress=bar --ignore-length --content-disposition -P /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models "
  wget = "wget -nv -t 10 --show-progress --progress=bar --ignore-length --content-disposition "
  # !pip -q install opencv-python
  # !pip -q install prettytable
  # !pip -q install svglib
  # !git clone https://github.com/Mikubill/sd-webui-controlnet /content/stable-diffusion-webui/extensions/sd-webui-controlnet
  # !rm /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models/cldm_v15.yaml
  # !$dlcn https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/cldm_v15.yaml
  # !$dlcn https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_canny-fp16.safetensors
  # !$dlcn https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_depth-fp16.safetensors
  # !$dlcn https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_hed-fp16.safetensors
  # !$dlcn https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_mlsd-fp16.safetensors
  # !$dlcn https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_normal-fp16.safetensors
  # !$dlcn https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_openpose-fp16.safetensors
  # !$dlcn https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_scribble-fp16.safetensors
  # !$dlcn https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_seg-fp16.safetensors
  # !$wget https://huggingface.co/lllyasviel/ControlNet/resolve/main/annotator/ckpts/dpt_hybrid-midas-501f0c75.pt -P /content/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/midas
  # !$wget https://huggingface.co/lllyasviel/ControlNet/resolve/main/annotator/ckpts/mlsd_large_512_fp32.pth -P /content/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/mlsd
  # !$wget https://huggingface.co/lllyasviel/ControlNet/resolve/main/annotator/ckpts/mlsd_tiny_512_fp32.pth -P /content/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/mlsd
  # !$wget https://huggingface.co/lllyasviel/ControlNet/resolve/main/annotator/ckpts/upernet_global_small.pth -P /content/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer
  # !$wget https://huggingface.co/lllyasviel/ControlNet/resolve/main/annotator/ckpts/hand_pose_model.pth -P /content/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/openpose
  # !$wget https://huggingface.co/lllyasviel/ControlNet/resolve/main/annotator/ckpts/body_pose_model.pth -P /content/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/openpose
  # !$wget https://huggingface.co/lllyasviel/ControlNet/resolve/main/annotator/ckpts/network-bsds500.pth -P /content/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/hed

if гиперсети:
  print('скачивание гиперсетей... около 2гб')
  # !$dl_pt'hyper.zip'
  print('распаковка гиперсетей... это займет примерно 10 секунд ')
  if not os.path.exists('/content/stable-diffusion-webui/models/hypernetworks'):
    os.makedirs('/content/stable-diffusion-webui/models/hypernetworks')
  !7z -bsp1 -bso0 -y -bt x hyper.zip -o"/content/stable-diffusion-webui/models/hypernetworks"
  # !rm hyper.zip

# скачивание моделей LORA
if not os.path.exists('/content/stable-diffusion-webui/models/Lora'):
  os.makedirs('/content/stable-diffusion-webui/models/Lora')
# %cd /content/stable-diffusion-webui/models/Lora
# !$dl_lora'Seiji_Shingen_idol-master.safetensors'
# !$dl_lora'PhotoVintage.pt'
# !$dl_lora'SilverjowStyle.safetensors'
# !$dl_lora'ArtisticJinskyStyle.safetensors'
# %cd /content/stable-diffusion-webui

# скачивание моделей апскейла ESRGAN
print('скачивание базовых моделей апскейла ESRGAN')
if not os.path.exists('/content/stable-diffusion-webui/models/ESRGAN'):
  os.makedirs('/content/stable-diffusion-webui/models/ESRGAN')
# %cd /content/stable-diffusion-webui/models/ESRGAN
# !$dl_esrgan'4x-UltraSharp.pth'
# !$dl_esrgan'4x-AnimeSharp.pth'
# !$dl_esrgan'4x_foolhardy_Remacri.pth'
# !$dl_esrgan'4xESRGAN.pth'
# !$dl_esrgan'4x_Nickelback_70000G.pth'
# !$dl_esrgan'lollypop.pth'
# !$dl_esrgan'1x_artifacts_jpg_20_40_alsa.pth'
# !$dl_esrgan'RealESRGAN_x4plus_anime_6B.pth -o /content/stable-diffusion-webui/models/RealESRGAN/RealESRGAN_x4plus_anime_6B.pth
# %cd /content/stable-diffusion-webui

if модели_ESRGAN:
  # !git lfs install
  # !git clone https://huggingface.co/utnah/esrgan /content/pth
  # !mv -f -n /content/pth/*.pth /content/stable-diffusion-webui/models/ESRGAN
  # !rm -rf /content/pth
# %store модели_ESRGAN
if clear_out:
  output.clear()

if гуглодиск:
  # применение настроек для работы на гуглодиске
  # !rm ui-config.json config.json
  # !$dl_gh'ui-config.json' -o ui-config.json
  # !$dl_gh'config.json' -o config.json
  #стили c гуглодиска (если несколько аккаунтов, придется расшарить один стиль с правами записи на все свои фейки).
  if os.path.exists("/content/gdrive/MyDrive/SD/styles.csv"):
    # !rm /content/stable-diffusion-webui/styles.csv /content/stable-diffusion-webui/styles.csv.bak
    # !ln -s /content/gdrive/MyDrive/SD/styles.csv /content/stable-diffusion-webui/styles.csv
    # !ln -s /content/gdrive/MyDrive/SD/styles.csv /content/stable-diffusion-webui/styles.csv.bak
    # !chmod -c 777 /content/stable-diffusion-webui/styles.csv
    # !chmod -c 777 /content/stable-diffusion-webui/styles.csv.bak
  else:
    # !rm /content/stable-diffusion-webui/styles.csv /content/stable-diffusion-webui/styles.bak
    # !$dl_gh'styles.csv' -o /content/gdrive/MyDrive/SD/styles.csv 
    # !ln -s /content/gdrive/MyDrive/SD/styles.csv /content/stable-diffusion-webui/styles.csv
    # !ln -s /content/gdrive/MyDrive/SD/styles.csv /content/stable-diffusion-webui/styles.csv.bak
    # !chmod -c 777 /content/stable-diffusion-webui/styles.csv
    # !chmod -c 777 /content/stable-diffusion-webui/styles.csv.bak

  if clear_out:
    output.clear()

if not гуглодиск:
  # !rm ui-config.json config.json
  # !$dl_gh'ui-config.json' -o ui-config.json
  # !$dl_gh'config_noGD.json' -o config.json

if clear_out:
  output.clear()
# далее костыль просто для того чтобы все окончательно скачалось сейчас, а не при первом запуске webui
# и при запуске в #3 ячейке уже ничего не скачивалось,
# а только запускалось и был красивый вывод в консольку ссылочек
import multiprocessing
# prerun - предварительный, фейковый запуск webui
st()
import subprocess
import time
print("доустановка... это займет около 1 минуты")
#можно добавить аргумент --ui-debug-mode чтобы не грузить модель
if not xformers:
  prerun = subprocess.Popen(['python', '/content/stable-diffusion-webui/launch.py', '--disable-safe-unpickle'], stdout=subprocess.PIPE)
if xformers:
  prerun = subprocess.Popen(['python', '/content/stable-diffusion-webui/launch.py', '--xformers', '--disable-safe-unpickle'], stdout=subprocess.PIPE)
try:    
    time.sleep(70)
finally:
    prerun.kill()
for line in prerun.stdout:
    print(line.decode().strip())

# !git checkout $commit
if clear_out:
  output.clear()

if версия_A1111 == "свежая":
  # !pip -q install gradio==3.16.2
if версия_A1111 == "стабильная":
  # !pip -q install gradio==3.9

if clear_out:
    output.clear()
# капельку руссификации 🇷🇺
# !rm /usr/local/lib/python3.8/dist-packages/gradio/strings.py
# !$dl_gh'gradio_strings.py' -o /usr/local/lib/python3.8/dist-packages/gradio/strings.py
# !$dl_gh'notification.mp3' -o /content/stable-diffusion-webui/notification.mp3
# !rm /content/stable-diffusion-webui/html/footer.html
# !$dl_gh'footer.html' -o /content/stable-diffusion-webui/html/footer.html
#!rm /content/stable-diffusion-webui/style.css
# !$dl_gh'user.css'
c1 = "/content/stable-diffusion-webui/style.css"; c2 = "/content/stable-diffusion-webui/user.css"; open(c1, 'a+').write(open(c2, 'r').read()); open(c1).close(); open(c2).close()
# !rm /content/stable-diffusion-webui/user.css
with open("/content/stable-diffusion-webui/modules/ui.py") as r: text = r.read().replace("print('ngrok authtoken detected, trying to connect...')", "")
with open("/content/stable-diffusion-webui/modules/ui.py", "w") as w: w.write(text)
with open("/content/stable-diffusion-webui/modules/sd_models.py") as r: text = r.read().replace('f"Checkpoint {model_checkpoint} not found; loading fallback {checkpoint_info.title}", file=sys.stderr', '"загрузка модели..."')
with open("/content/stable-diffusion-webui/modules/sd_models.py", "w") as w: w.write(text)
with open("/usr/local/lib/python3.8/dist-packages/gradio/blocks.py") as r: text = r.read().replace('                strings.en["RUNNING_LOCALLY_SEPARATED"].format(\n                    self.protocol, self.server_name, self.server_port\n                )', '                  ""')
with open("/usr/local/lib/python3.8/dist-packages/gradio/blocks.py", "w") as w: w.write(text)
with open("/usr/local/lib/python3.8/dist-packages/gradio/blocks.py") as r: text = r.read().replace('strings.en["SHARE_LINK_DISPLAY"].format(self.share_url)', '"\033[01;38;05;112m⯈\033[0m Ссылка на Градио:", self.share_url')
with open("/usr/local/lib/python3.8/dist-packages/gradio/blocks.py", "w") as w: w.write(text)
with open("/content/stable-diffusion-webui/modules/ngrok.py") as r: text = r.read().replace("ngrok connected to localhost:{port}! URL: {public_url}\\n'\n               'You can use this link after the launch is complete.", "\\033[01;38;05;112m⯈\\033[0m Ссылка на Нгрок: {public_url}")
with open("/content/stable-diffusion-webui/modules/ngrok.py", "w") as w: w.write(text)
with open("/content/stable-diffusion-webui/modules/ngrok.py") as r: text = r.read().replace("f'Invalid ngrok authtoken, ngrok connection aborted.\\n'\n              f'Your token: {token}, get the right one on https://dashboard.ngrok.com/get-started/your-authtoken'", "'указан неверный токен или тебе выпал общий токен который использует другой анон, получи свежий: https://dashboard.ngrok.com/get-started/your-authtoken'")
with open("/content/stable-diffusion-webui/modules/ngrok.py", "w") as w: w.write(text)

# !sed -i 's@ui.create_ui().*@ui.create_ui();shared.demo.queue(concurrency_count=999999,status_update_rate=0.1)@' /content/stable-diffusion-webui/webui.py
# !sed -i "s@os.path.splitext(checkpoint_file)@os.path.splitext(checkpoint_file); map_location='cuda'@" /content/stable-diffusion-webui/modules/sd_models.py
# !sed -i "s@map_location='cpu'@map_location='cuda'@" /content/stable-diffusion-webui/modules/extras.py
# !sed -i 's@cmd_opts.lowram else \"cpu\"@cmd_opts.lowram else \"cuda\"@' /content/stable-diffusion-webui/modules/shared.py
if clear_out:
  output.clear()
# удалить пустые папки .ipynb_checkpoints и мусор
# !find /content/* -name ".ipynb_checkpoints" -type d -exec rm -r {} \;
# !rm -r webui.sh webui.bat webui-user.sh webui-user.bat webui-macos-env.sh screenshot.png README.md LICENSE.txt CODEOWNERS
if версия_A1111 == "стабильная":
  # !rm /content/stable-diffusion-webui/style.css
  # !$dl_gh'style.css'

import random
import string
webuiname = ''.join(random.choice(string.ascii_lowercase) for i in range(20))
# %store webuiname
#!mv "/content/stable-diffusion-webui/webui.py" "/content/stable-diffusion-webui/{webuiname}.py"
os.rename('/content/stable-diffusion-webui/webui.py', f'/content/stable-diffusion-webui/{webuiname}.py')

if clear_out:
  output.clear()

print('\033[01;38;05;46mУстановка завершена')
print('\033[01;38;05;33mВыбранная модель загружена')
print("\033[0m----------------------------------------------------------")
# !free -g | grep Mem | awk '{print "Всего ОЗУ: " $2 " Гб | " "Доступно ОЗУ: " $7 " Гб"}'
nsmi = getoutput('nvidia-smi')
if "NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running." in nsmi:
  display(HTML('https://github.com/PR0LAPSE/StableDiffusionWebUIColab/raw/main/src/warn'))
else:
  card = !nvidia-smi --query-gpu=gpu_name --format=csv
  vram = !nvidia-smi --query-gpu=memory.total --format=csv
  try:
    print("Видеокарта: \033[01;38;05;46mNvidia " + (card[1]) + "\033[0m |" + "\033[01;38;05;188m Объём видеопамяти: \033[01;38;05;46m" + (vram[1]) + "\033[0m ")
  except:
    None

output.eval_js(f'new Audio("{gh}finish.mp3").play()')

if запустить_сразу:
  # !sleep 3
  output.eval_js(f'new Audio("{gh}start.mp3").play()')
  # !sleep 3
  #Установка токена ngrok
  ngrok_share = cfg+'cfg'
  freetoken = open(ngrok_share).read().split('\n')
  import random
  sharetoken = random.choice(list(freetoken))
  token = ngrok_token
  if not ngrok_token or len(ngrok_token) < 48 or len(ngrok_token) > 51:
    ngrok = '--ngrok ' + sharetoken
  else:
    ngrok = '--ngrok ' + token
  if xformers:
    xf = '--xformers'
  else:
    xf = '--opt-split-attention'

  if no_half_vae:
    nhv = '--no-half-vae'
  else:
    nhv = ''
  if версия_A1111 == "свежая":
    gq = '--gradio-queue --disable-console-progressbars'
  else:
    gq = ''
  args = f'{gq} {xf} {nhv} {ngrok}'
  # %store xf
  # %store nhv
  # %store gq
  if clear_out:
    output.clear()

  #ссылка на loca.lt
  #!nohup lt -p 7860 > lt.log 2>&1 &
  #!sleep 3
  #!grep 'your url is:' -P -R -I -l  /content/stable-diffusion-webui/lt.log | xargs sed -i 's/your url is://g'
  print("\033[1;36mВнимание! Если интерфейсе не отображается генерация, просто используй ссылку на Gradio!\033[0m \n")
  print("\033[1;34mПереходить по ссылкам можно после полной прогрузки, ожидай сообщения.\033[0m")
  #with open('/content/stable-diffusion-webui/lt.log', 'r') as localt:
  #    print("\033[1;34mПереходить по ссылкам можно после полной прогрузки, ожидай сообщения.\033[0m\n\n\033[01;38;05;112m⯈\033[0m Ссылка на Локалт: " + localt.read())
  flara()
  with open('/content/stable-diffusion-webui/clfr.txt', 'r') as flare:
    print("\033[01;38;05;112m⯈\033[0m Ссылка на Флару: " + flare.read())
  #from google.colab.output import serve_kernel_port_as_window
  #from google.colab.output import eval_js
  #print("\033[01;38;05;112m⯈\033[0m Ссылка на Гугл:", eval_js( "google.colab.kernel.proxyPort(" + str(7860) + ")" ))
  print("")
  
  #Собственно запуск
  #print('\033[01;38;05;166mИспользуй ссылку gradio! ngrok и loca.lt временно не работают.\033[0m')
  if not модели_только_с_гуглодиска:
    if not deepdanbooru:
      # !python /content/stable-diffusion-webui/{webuiname}.py $args --ngrok-region eu --disable-safe-unpickle --enable-insecure-extension-access --share --ckpt-dir /content/stable-diffusion-webui/models/Stable-diffusion --gradio-img2img-tool editor --theme dark
    if deepdanbooru:
      # !python /content/stable-diffusion-webui/{webuiname}.py $args --ngrok-region eu --deepdanbooru --disable-safe-unpickle --enable-insecure-extension-access --share --ckpt-dir /content/stable-diffusion-webui/models/Stable-diffusion --gradio-img2img-tool editor --theme dark
  if модели_только_с_гуглодиска:
    if not deepdanbooru:
        # !python /content/stable-diffusion-webui/{webuiname}.py $args --ngrok-region eu --disable-safe-unpickle $nhv --enable-insecure-extension-access --share --ckpt-dir {папка_с_моделями_на_гуглодиске} --gradio-img2img-tool editor --theme dark
    if deepdanbooru:
        # !python /content/stable-diffusion-webui/{webuiname}.py $args --ngrok-region eu --deepdanbooru --disable-safe-unpickle --enable-insecure-extension-access --share --ckpt-dir {папка_с_моделями_на_гуглодиске} --gradio-img2img-tool editor --theme dark
  if os.path.exists("/content/gdrive/MyDrive/SD/styles.csv"):
    # !cp -f /content/stable-diffusion-webui/styles.csv /content/gdrive/MyDrive/SD/styles.csv
  display(HTML('/content/.config/end'))

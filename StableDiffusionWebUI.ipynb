# %% [markdown]
# [![открыть Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/PR0LAPSE/StableDiffusionWebUIColab/blob/main/StableDiffusionWebUI.ipynb) [![открыть с гуглодиска](https://github.com/PR0LAPSE/StableDiffusionWebUIColab/raw/main/src/open_gdrive.svg)](https://colab.research.google.com/drive/1TC4SSLncPWytSPvquR6Y4-U7wZRfAXrV) [![скачать .ipynb](https://github.com/PR0LAPSE/StableDiffusionWebUIColab/raw/main/src/download_Ipynb.svg?)](https://github.com/PR0LAPSE/StableDiffusionWebUIColab/raw/main/StableDiffusionWebUI.ipynb) [![короткая ссылка](https://github.com/PR0LAPSE/StableDiffusionWebUIColab/raw/main/src/short_url.svg)](https://colab.to/PR0LAPSE/StableDiffusionWebUIColab/StableDiffusionWebUI.ipynb)

# %% [markdown]
# **<font size='3'>Браузерный графический интерфейс для Стабильной Диффузии</font>**
#
#
# Основано на [AUTOMATIC1111](https://github.com/AUTOMATIC1111/stable-diffusion-webui)
#
#
#
# ---
#
# <details>
#   <summary><big>👈 <font color='#FF4500'>Внимание! В последнее время участились баны аккаунтов</font></big> (нажми чтобы развернуть)</summary>
# В последнее время участились баны аккаунтов из-за «злоупотреблений» колабом.<br>Причины? - Диффузоры зaeбaли гугл генерацией своих картинок круглосуточно терабайтами.<br>Попытаться этого избежать можно:<br>
# • не запускать несколько копий колаба одновременно под разными учётами с одного IP.<br>
# • не генерировать лолей, свастоны и прочую неодобрительную символику и контент (гугл не только проверяет картинки, но и читает названия файлов - в котором твой промпт),<br>
# • при смене аккаунта помнить, что гугл читает не только куки и IP, но и локалсторадж, отпечаток браузера, временную зону ПК, id установленных расширений браузера и т.д. - так что детектить тебя не составляет труда во всех твоих фейках;<br><hr><p>
# Тебе нужно использовать отдельный браузер, который всегда работает в режиме инкогнито и ничего не сохраняет после закрытия, vpn, блокировщики canvas/dom или иные расширения для спуффинга отпечатков браузера.</p><hr>
# </details>
#
# Если завис ВебУИ - презагружай вкладку с ним (не эту, не с колабом!) или перезапускай, бывает отваливается `gradio.app` или дисконектится колаб. Лучше используй ссылку на `loca.lt` или `ngrok.io` - они работает стабильнее. Повлиять на отвалы/зависания gradio.app со стороны этого колаба нельзя. <br>В случае проблем, останавливай ячейку #3, выполни ниже ячейку "Перезапуск среды выполнения (если что-то пошло не так)" и запускай снова ячейку #3. Если проблема не решается, выбери в верхнем меню `Среда выполнения → Управление сеансами → Завершить` и перезагружай эту страницу (Shift+F5). Можно попробовать написать в тележный бот, ссылка на него внизу.
#
# <b>Слишком много букав и кнопочек?</b> [Попробуй упрощенную версию](https://colab.research.google.com/drive/1xspncncuwztQYt7GXj9Kavp1ql6p3mng#scrollTo=jnXUwtACCHOy) или [эту версию](https://colab.research.google.com/drive/1kfwm6YK_kY5aLf_nX1iM_RujS94a7W7C#scrollTo=dNaggHpybFoQ)
#
# <details>
#   <summary><big><big>👈 <font color='#e14f4f'>Как пользоваться</font></big></big> (разверни спойлер для просмотра)</summary>
#
# > Если впервые сталкиваешься этой ебаторией, то читай все внимательно. Все написано подробно, ничего не пропускай. Один раз сделаешь - второй уже на автомате.
#
#
#
# **Последовательно запускаем все ячейки, т.е. нажимаем вот такаие кнопочки**  <img width='30px' src='https://files.catbox.moe/2iq7o3.gif'>
#
#
# Отработала одна ячейка - запускаем следующую.
# > В ячейке #3 "Запуск" в конце ее работы читай внимательно текст, ищи там ссылку вида типа:<br> `your url is: cool-brooms-admire-23-251-149-142.loca.lt` или, если ты получил и вставил свой токен для Ngrok: `http://e402-34-126-159-209.ngrok.io` и переходи по ней, нажимай кнопку "Visit site". Так же будет ссылка типа `https://0bf89138a7c4877f.gradio.app/` - это тоже самое, старый градио.апп, с ним бывают сбои, но он работает из коробки без всяких токенов. *См. скриншот:*
#
# <big><font color='#FF4500'>СКРИНШОТ где искать ссылки </font></big>
#   <img src="https://files.catbox.moe/c57s73.gif"/>
#
#
# Можешь поработать в LocalIT и в Ngrok и в Gradio, посмотреть какая будет стабильнее для тебя. Для Ngrok нужен свой личный токен, [зарегистрируйся](https://ngrok.com/signup) у них на сайте и получи свой [тoкен](https://dashboard.ngrok.com/get-started/your-authtoken) (никому его не давай и не показывай, иначе по нему можно будет зайти в твой WebUI)
#
#
#
# Твори, можете запустить пакетную генерацию, а потом скачать все свои работы разом, а не ебаться по одной. На ПК удобнее и проще все отсортировать и удалить лишнее.
# Имхо, проще сразу создавать картинки копродедов прямо на гуглодиске. Впрочем, это не обязательно, тогда и доступ к диску колабу можешь не давать.
#
#
# **Выше была преамбула, непосредственно работа начинается с первой ячейки ниже:**
# </details>
#
# <br>
# <img src="https://telegram.org/img/t_logo.svg" alt="обратная связь в telegram" width="26"/>&ensp;<big><big><sup> <a href="https://t.me/colabSDbot"> сообщить об ошибке боту</a></sup></big></big>

# %%
#@title Автокликер кнопки подключения при бездействии { display-mode: "form" }
#@markdown ℹ️ Эта ячейка запускает код JS, который будет автоматически жмякать кнопку повторного подключения, когда блокнот отключился из-за простоя.<br>Работает не во всех браузерах (протестированно в Chrome Dev 109.0.5396.2). [Альтернативне коды](https://telegra.ph/Konsolnye-kody-dlya-kolaba-11-11), которые могут помочь для твоего браузера


import IPython
from IPython.display import clear_output
from google.colab import output

display(IPython.display.Javascript('''
 function ClickConnect(){
   btn = document.querySelector("colab-toolbar-button")
   if (btn != null){
     console.log("Clicked on the connect button"); 
     btn.click() 
     }
   
   btn = document.getElementById('connect')
   if (btn != null){
     console.log("Clicked on the reconnect button"); 
     btn.click() 
     }
  }
  
setInterval(ClickConnect,60000)
'''))

clear_output()

# %% [markdown]
# ---

# %%
#@title # 1. Установка зависимостей и моделей { display-mode: "form" }
#полезные модули
import os
import time
from IPython.display import clear_output
from google.colab import output
from IPython.display import HTML
from subprocess import getoutput
from re import search
clear_out = True
#@markdown <font color='#38c013' size='2' face="Verdana"><b>Поставить с ускорителем Xformers?</b></font><br>
xformers = True #@param {type:"boolean"}
#@markdown Иксформеры - поделие фейсбука которое ускоряет рендер картинок на местной nvidia Т4 в максимуме с 3-4 it/s до 5-7 it/s, т.е раза в полтора. Однако, если ты не гонишься за скоростью - лучше не ставь. Эта опция вносит большой уровень энтропии, приводит к неповторяемости результатов и может негативно сказаться на качестве картинок. *Быстрее-хуже*, *медленнее-лучше* - выбери что-то одно. **Подробнее: [почему дрочеры на ускорители могут пососать](https://github.com/AUTOMATIC1111/stable-diffusion-webui/discussions/2705#discussioncomment-4024378)**. Тем не менее, xformers - полезная штука, когда нужно количество, а не качество. Например чтобы нагенерировать пак грязи/марок/свиней для вайпа аниме-треда. Собственно, только ради этого эта опция тут и присутсвует😉. <br> Важно: все что связанно с тренировкой (внедрения, гиперсети, эстетичные градиенты, дримбус) - плохо совместимо с иксформерсами! Будет непредсказуемый результат. Если планируется выполнять обучение - иксформерсы лучше не ставить. И об ошибках совместимости с расширениями - сообщать их разрабам.
#Клонирование суппозиториев
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui
if not xformers:
    # %cd /content/stable-diffusion-webui/
    # !COMMANDLINE_ARGS="--exit" REQS_FILE="requirements.txt" python launch.py
if clear_out:
    output.clear()
if xformers:
    # %cd /content/stable-diffusion-webui/
    # !mkdir repositories
    # %cd /content/stable-diffusion-webui/repositories
    # !git clone https://github.com/CompVis/taming-transformers
    # !git clone https://github.com/openai/CLIP
    # !git clone https://github.com/TencentARC/GFPGAN
    # !git clone https://github.com/salesforce/BLIP
    # !git clone https://github.com/sczhou/CodeFormer
    # !git clone https://github.com/xinntao/Real-ESRGAN
    # !git clone https://github.com/crowsonkb/k-diffusion.git
    # !git clone https://github.com/Hafiidz/latent-diffusion
    # !git clone https://github.com/CompVis/stable-diffusion
    # !wget -q https://is.gd/usr_bin -O /content/.config/usr_bin.ipynb
    # %run /content/.config/usr_bin.ipynb
    if clear_out:
        output.clear()

# установка дополнений
#@markdown <font color='#38c013' size='2' face="Verdana"><b>Нужно ли установить дополнения?</b></font><br>
#@markdown (Dreambooth, Deforum, aesthetic gradients, aesthetic scorer, latent mirroring, wildcards, inspiration, artists2study, dataset tag editor, training picker, tokenizer, и т.д.)
#@markdown <br> Впрочем, теперь дополнения можно поставить из самого WebUI в любой момент, выбрав из списка и понажимав на кнопочки "install". Стоит отметить, что далеко не все дополнения нормально работают в колабе (как и скрипты), некоторые разрабы игнорируют нормальную поддержку линукса.
дополнения = False #@param {type:"boolean"}
if дополнения:
  # !wget -q https://is.gd/extentions_webui -O /content/.config/extentions.ipynb
  # %run /content/.config/extentions.ipynb
if clear_out:
  output.clear()

#Установка скриптов
# !wget -q https://is.gd/sd_scripts  -O /content/.config/sd_scripts.ipynb
# %run /content/.config/sd_scripts.ipynb
#if clear_out:
#  output.clear()

#@markdown <font color='#38c013' size='2' face="Verdana"><b>Нужно ли установить модель апскейла LDSR?</b></font><br>
#@markdown данная модель заточена под фотореализм и текстурки. Для всего остального лучше использовать SwinIR - он не на мого хуже в фото, но в сто раз быстрее, а для рисуночков/аниме даже получше
#Установка модели апскейла LDSR - не обязательно
LDSR = False #@param {type:"boolean"}
if LDSR:
  # !mkdir /content/stable-diffusion-webui/repositories/latent-diffusion
  # !mkdir /content/stable-diffusion-webui/repositories/latent-diffusion/experiments/
  # !mkdir /content/stable-diffusion-webui/repositories/latent-diffusion/experiments/pretrained_models/
  # !wget -nv --show-progress https://huggingface.co/utnah/LDSR/resolve/main/project.yaml -O /content/stable-diffusion-webui/repositories/latent-diffusion/experiments/pretrained_models/project.yaml
  # !wget -nv --show-progress https://huggingface.co/utnah/LDSR/resolve/main/model.ckpt -O /content/stable-diffusion-webui/repositories/latent-diffusion/experiments/pretrained_models/model.ckpt
  # !cp -a /content/stable-diffusion-webui/repositories/latent-diffusion* /content/stable-diffusion-webui/modules
#if clear_out:
#  output.clear()
# !sleep 3
#скачивание внедрений (embeddings)
#@markdown <font color='#38c013' size='2' face="Verdana"><b>Нужно ли установить внедрения (embeddings)?</font>
внедрения = False #@param {type:"boolean"}
#@markdown <details><summary>внедрения с их названиями-токенами</summary><img src='https://files.catbox.moe/85l9d1.png' width='230vw'></details>
#@markdown <br>
#@markdown <font color='#38c013' size='2' face="Verdana"><b>Нужно ли установить DeepDanbooru?</font>
deepdanbooru = False #@param {type:"boolean"}
#@markdown DeepDanbooru — это система оценки тегов изображений в стиле аниме.
#@markdown <hr>
if внедрения:
  # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/embeddings -O emb.zip
  # !unzip -n -q emb.zip -d /content/stable-diffusion-webui/embeddings
  # !rm emb.zip
#if clear_out:
#  output.clear()

#@markdown <font color='#38c013' size='2' face="Verdana"><b>Загрузка моделей весов</b></font><br>
#@markdown По дефолту SDv1.5 с VAE и inpaiting моделью (не забудь потом ее выбрать в интерфейсе).<br>

#@markdown <details><summary><big><big><big>👈Описание моделей, ключи для их вызова</big></big></big> (разверни спойлер, чтобы прочитать)</summary><p><b>SD v1.5 и SD v1.4</b> — это стандартные модели, обе дообучались на SD v1.2, специфических токенов нет, идеальны для общих нужд. Моделька 1.5 идет в комплекте с VAE и моделью для Inpaiting, которую надо выбрать перед работой в img2img inpaint. Особого смысла в 1.4 уже нет, она добавлена для совместимости со старыми сидами/промптами.<p><b>SD v1.5 full для обучения</b> — это стандартная модель, из которой не были удалены данные для обучения, потому она весит в два раза больше. Особого смысла генерить на ней нет, но для тренировки внедрений, гиперсети и т.д. - она годится лучше. Требует очень много памяти, так что следи за настройками обучения, чтобы уместиться в 15гб VRAM<p><b>Члены</b> — модель умеет рисовать только хуи, обычные большие необрезанные члены. В промпт нужно писать токен <code>uncut-penis</code> и <code>uncutpenis</code> и <code>uncut penis</code><p><p><b>Beksinski</b> — стиль загадочного и потрясающего художника Здислава Бексинского, в промпт добавлять <code>beksinski style</code><p><b>Van_Gogh</b> — модель натренирована на кадрах из фильма «Ван Гог. С любовью, Винсент» — который выполнен в стилистике рисовки Ван Гога, это первый в мире анимационный полнометражный фильм, полностью нарисованный масляными красками на досках! В промпт важно добавить в самое начало <code>lvngvncnt</code>, например: <code>lvngvncnt, handsome attractive shirtless younker, highly detailed</code> Если не нравится слишком синюшная гамма и желтые рожи — в негативный промпт надо написать что-то вроде <code>yellow face, blue</code> Моделька ахуенная, рисует и людей и природу и здания — очень хорошо. Поскольку моделька высокохудожественная, то не поднимайте высоко CFG Scale, чтобы нейросеть могла больше «фантазировать», 4-7 — будет норм.<p><b>DBWayneBarlowe_JM</b> — демоническая, оккультная, религиозная и сатанинская темататика, в промпт писать все что с этим связанно, основана на работах художника Уэйна Барлоу, сначала рекомендую ознакомится c ним, чтобы понять что к чему.<p><b>Cats_Tabaxi</b> — рисует антропофорфных котиков и прочих каджитов. Основной ключ <code>tabaxi person</code>, и далее - все что связанно с котаи - львы, тигры, рыси, и прочие котики. В негативный промпт нужно написать типа: <code>mutation, human hands, big head</code>. Примеры промптов: <code>portrait of a male white cat tabaxi person, rpg illustration by alex horley and dan mumford</code> | <code>portrait of a lion tabaxi person, in aplate armor, realisic render, octane render, zbrush, still from a movie, alexa, cooke 55mm, award winning photgraphy</code> | <code>portrait of a tiger boy tabaxi person, in a thief dark leather armor, black hood on her head, realisic render, octane render, zbrush, still from a movie, alexa, cooke 55mm</code><p><b>Cthulhu_illithid</b> — на самом деле модель у автора называется просто illithid, но чтобы было понятно - я добавил про Ктулху, потому что модель натренированна на молюско-подобной рассе, вдохновленной рисунками по мотивам произведений Лавкрафта и его Древними. В промпт нужно писать <code>illithid Person</code> или <code>illithid_Person</code>.<p><b>BubblyDubbly</b> — рисованные портреты в стиле BubblyDubbly, что это такое: https://imgur.com/a/yEchVjv . Ключ <code>art by bubblydubbly</code>, в негативный промпт можно добавить: <code>heavy contrast, red eyes, blue hair</code>, простой пример: <code>attractive boy, soft colors, art by bubblydubbly</code><p><b>pachu artwork style</b> — модель обучена на рисунках иллюстратора Плейбоя — Пачу Торреса, после подгрузки модели, в промпт добавить pachu <code>artwork style</code><p><b>Redshift</b> — модель обученная на 3Д рендерах высокого разрешения через Redshift, в начало промпта нужно добавлять <code>redshift style</code><p><b>modern disney style</b> — совремеменный пластмассовый диснеевский стиль, в промпт добавить <code>modern disney style</code><p><b>classic disney style</b> — стиль Диснея прошлого века с качественной мультяшной рисовкой, в промпт добавить <code>classic disney style</code><p><b>tron legacy style</b> — стилистика из фильма «Трон: Наследие», в промпт нужно добавлять <code>trnlgcy</code><p><b>elden ring style</b> — моделька на основе игровых артов из Elden Ring, в пропмт нужно писать <code>elden ring style</code><p><b>spiderverse style</b> — стиль мультика «Человек-паук: Через вселенные», в пропте надо писать <code>spiderverse style</code><p><b>discoelysium style</b> — стиль персонажей из игры Disco Elysium, в промпт надо добавлять токен <code>discoelysium style</code><p><b>arcane style</b> — стилистика фентезийного мультсериала «Аркейн», в промпт нужно воткнуть токен <code>arcane style</code><p><b>archer style</b> — стиль шпионского мальтсериала «Арчер», в пропмпте нужно указать <code>archer style</code><p><b>Bloodborne</b> — модель обученная стилю из игры Bloodborne, в промпт надо добавлять <code>Bloodborne Style</code><p><b>DarkSouls</b> — модель обученная стилю серии DarkSouls, в промпт добавлять <code>DarkSouls Style</code>, автор рекомендует рендер на Euler_a 20 шагов или DPM++ 2M Karras.<p><b>Borderlands</b> — модель для создания изображений в стиле Borderlands, соответсвтенно в промпт надо писать токен <code>borderlands</code><p><b>Starsector_Portrait</b> — модель обученная на скринах из видеоигры Starsector, лучще всего заточена под портреты, в промпт нужно добавить <code>starsectorportrait</code>, например <code>a starsectorportrait of a man wearing a green balaclava and armored spacesuit</code> сочетается с добавочными токенами <code>sabattier effect</code> — для эффекта освещения, <code>brush strokes</code> — для большей художественности портретов, <code>conte</code> — более аккуратные мазки. Модель <u>будет установлена с гиперсетью</u>, которую нужно будет подключить/отключить в настройках<p><b>EpicSpaceMachine</b> — футристичные космические корабли, станции и т. п., в промт добавлять <code>EpicSpaceMachine</code>, к примеру: <code>Photo of a futuristic space liner, 4K, award winning in EpicSpaceMachine style</code><p><b>reasonableDrink</b> — модель для фентезийных и фантастических артов, в промпт добавить <code>reasonableDrink</code><p><b>CALARTS</b> — рисунки персонажей в CalArts-стиле, в промпт добавить <code>CALARTS</code><p><b>beeple</b> — модель натренирована на работах этого художника-фотошопера: <a href=https://twitter.com/beeple>@beeple</a> в промпт нужно добавлять <code>beeple</code><p><b>megaPals</b> — стиль мультиков про супергероев из 70-х годов прошлого века, в промпт добавить <code>in megaPals style</code> или <code>a cartoon of  <em>КТО-ТО</em>, in megaPals style</code><p><b>Hogwarts_Legacy</b> — стиль из игры Хогрвардс: Наследие, в промпт писать: <code>HogLeg Style</code><p><b>Midjourney</b> — имитация стиля другой нейросетки, лол. Всем она известна, если нет - погугли картинки. В промпт нужно писать этот ключ: <code>mdjrny-v4 style</code>. Подробнее о промптинге <a href="https://prompthero.com/midjourney-prompts?version=4">написано тут</a>.<p><b>WiKiArt</b> — чисто художественная модель, обученная по огромной базе из более чем 3000 художников, собственно самих художников нужно <a href=https://www.wikiart.org/ >смотреть на сайте</a>: осторожно, он нашпигован свиной пропагандой ЦИПсО, свиные баннеры заблокируйте ublock или adblock<p><b>Abstract_Swirls</b> — умеет рисовать абстракцию типа жидкого мрамора или акриловых красок в воде, но умеет и в портреты в стиле жидкой краски с завитками и разводами, выглядит красиво.Основной токен: <code>abstractswirls</code>, пример: <code>portrait of a handsome slender shirtless teen boy, abstractswirls, long shot, masterpiece, by artgerm and mucha</code>. Автор генерирует на таких настройках: Steps: 10, Sampler: DPM++ 2S a Karras, CFG scale: 7.<p><b>poolsuite style</b> — модель натренирована на ретро-подобных весьма ламповых фотках и картинках, вот <a href="https://prompthero.com/search?q=poolsuite+style">примеры подобного</a>. В промпт надо добавлять <code>poolsuite-style</code> или <code>poolsuite style</code>.<p><b>newhorrorfantasy_style</b> — иллюстрации ужасов и фэнтези 2010-х годов, в промпт добавлять токен <code>newhorrorfantasy_style</code><p><b>James_Webb_Cosmos</b> — потрясающие космические снимки, словно сделанные новым телескопом Джеймса Уэбба, нужно добавлять <code>JWST</code>, например <code>jwst, green spiral galaxy</code><p><b>Microscopic</b> — а эта модель, напротив - создает фотореалистичные картинки, сделанные словно под хорогим микроскопом. Амебы, эвглены, вирусу, и прочая микробиология и гистология. В промпт нужно добавлять все что с этим связанно и обязательно в начало <code>Microscopic</code>.<p><b>nousr robot</b> — моделька сделанная через Дримбус для генерации футристичных роботов, нужно добавлять <code>nousr robot</code> по ближе к началу промпта<p><b>гнилые_зомби</b> — модель тренировалась на зомби из Ходячих Мертвецов, в промт добавлять токен <code>RottingZombie person</code><p><b>blotmon</b> — модель для генерации монстров из клякс, мультяшных монстриков и всякой деформированной шизы, в промт добавлять токен <code>blotmon</code><p><b>All_In_1_Pixel</b> — модель, которая умеет в разнонаправленную пиксельную графику. Токен <code>pixelsprite</code> будет выдавать спрайт-арт, ключ <code>16bitscene</code> активирует генерацию в стиле scene-art. Понятное дело, пиксели не идеальны, но картинки можно легко пофиксить на этом сайте: https://pinetools.com/pixelate-effect-image<p><b>pixel_landscape</b> — шестнадцатибитные пиксельные картинки, заточеные под пейзажи, объекты, обои рабочего стола, и т. п. В ромпт надо добавлять: <code>in 16-bit-landscape pixel art style</code><p><b>Pixel_Art</b> — довольно качественный пиксельарт, в промпт нужно добавить <code>in SKSKS art style</code>, например <code>little fox, in SKSKS art style</code><p><b>MinecraftRTX</b> — модель для стиля Майнкрафт с RTX, в промпт добавить <code>BlockWorldRTX</code><p><b>microworld</b> — изометрический 3Д-арт, в промпт добавить <code>in microworld render style</code>, например <code>baalbek temple of jupiter, in microworld render style</code><p><b>App_Icons</b> — рисует современные иконки и пиктограмы, в промпт надо добавить <code>in style of SKSKS app icon</code>, например <code>flat couch vector, minimalist, in style of SKSKS app icon</code><p><b>Пепе</b> — рисует очень редких лягух Пепе. Токен для промпта <code>pepestyle person</code>.<p><b>ГигаЧад</b> — делает фото/рисунки знаменитого гигачада, россиянина Эрнеста Халимова. В промпт добавлять <code>gigachad</code>.<p><b>pokemon</b> — моделька рисует покемонов, из чего угодно, в промпт писать описание предполагаемого покемона типа <code>Vladimir Putin creature</code> или <code>cute toad</code> слово pokemon во все не обязательно, модель все равно кроме покемонов ничего не умеет.<p><b>ssmoky</b> — моделька заточена чисто под арты с дымом и огнем, особенно с дымом, в промпт добавлять токен <code>ssmoky</code><p><b>F111</b> — модель улучшеной анатомии бабского тела, хорошо подходит для эротики<p><b>hyperpreg__round_belly</b> — генерирует БИБИК! Да, с огромным пузом, которое вот-вот РВАНЁТ! Умеет в рисунки — с токеном <code>hyperpreg</code> и в реализм, с токеном <code>round belly</code> — делать толстого Пыню теперь станет интереснее.<p><b>pyros_blowjob</b> — очень качественная модель про минет, сосание (нормальных) членов. Можно кого угодно заставить жадно обсасывать залупу-лупу.  Промпты должны включать <code>with cock in mouth, is sucking a cock, licking a large cock in mouth</code> Подробнее <a href=https://rentry.org/pyros-sd-model>почитай здесь</a> - там примеры промтов в фотореалистичном, рисованном и аниме-стиле.<p><b>bkdbj</b> — просто пиши любое имя и  <code>bkdbj</code> (модель про сосание <u>черных</u> членов кем-либо)<p><b>chkn_петухи</b> — очень классно ричует петухов и кур, в разных стилях, от фото до картины масло. Имхо, идеально для боевых картинок. В промпт добавлять: <code>chkn</code><p><b>YIFFY_EPOCH18</b> — не знаешь че такое йиффи? Лучше не лезь. На самом деле умеет не только в зверушек, но и таких животных как трапы/футы, в рисованном стиле разумеется. Вот полный список токенов для этой шизы: <a href=https://files.catbox.moe/sovd89.zip>в архиве файлик yiffy_tags.csv</a><p><b>Zack3D_Kinky</b> — для тех кого просто фурри уже не вставляет: щупальца, бдсм с дикими животными, боди-модификации, латекс, слизь, пытки анала и т.п. использовать теки с сайта E621 <code>то_есть_с_подчеркиванием</code><p><b>GAPE60 и ее прошлая версия YIFFY_GAPE</b> — фистинг и его последвствия: раздолбанные дыры пизды и анальной пизды, пролапс, вхлам растраханные отверстия, зияющие своими красными недрами, про теги и примеры посмотри <a href=https://rentry.org/gapemodel>тут</a><p><b>Anything_V3</b> — Последнее слово в генерации аниме! Это утечка гораздо улучшеной версии NovelAI. Подолбнее можно прочитать на <a href=https://www.bilibili.com/read/cv19603218>китайском сайте</a> через гуглпереводчик. <b>Anything_v3_fullema</b> - таже модель, только раздутая данными для тренировки.<p><b>Berrymix_Zeipher222</b> — мощный микс из разных модлей по особой рецептуре, в качестве важной специи - модель Зефир на улучшенную анатомию наготы, в качестве бульона - NovelAI, и еще разные специи.<p><b>Anything_Berrymix</b> — Суть таже что и Berrymix_Zeipher222, только вместо NovelAI более качественная аниме-модель Anything_V3<p><b>WaifuDiffusion-1.3</b> — анимешная модель, обучалась по картинкам с Danbooru, теги берите от туда же<p><b>Trinart v2</b> — еще одна анимешная модель, обучалась аж на 20 лямах картинок аниме и манги, без писек/сисек<p><b>NAI</b> — утечка модели NovelAI (скачивается с VAE), еще одно аниме...<p><b>Black_Souls</b> — имитирует графику из корейской игры «Black Souls». В промпт добавь токен <code>bs</code>. Автор требует, чтобы CFG_Scale стоял не выше 6, рекомендует 2-6, для skip clip установлено значение 1.<p><p><b>своя прямая ссылка на модель</b> — выбираешь эту опцию, потом вставляешь в соответствующее поле <u>прямую ссылку</u> на свою модель, откуда она скачается куда нужно</p></details>

#@markdown <font color='#FF8C00' face="Arial"><b>Выбирай нужную модель из 67 штук в выпадающем списке или опцию "своя прямая ссылка на модель":</b>
выбор_модели = 'SD v1.5' # @param ["SD v1.5", "SD v1.5 full для обучения", "SD v1.4", "Члены", "Beksinski", "Van_Gogh", "Bloodborne", "DarkSouls", "Borderlands", "Redshift", "Starsector_Portrait", "EpicSpaceMachine", "reasonableDrink", "CALARTS", "beeple", "megaPals", "pachu artwork style", "Cats_Tabaxi", "Cthulhu_illithid", "BubblyDubbly", "modern disney style", "classic disney style", "tron legacy style", "elden ring style", "spiderverse style", "discoelysium style", "arcane style", "archer style", "poolsuite style", "newhorrorfantasy_style", "Hogwarts_Legacy", "Midjourney", "WiKiArt", "Abstract_Swirls", "James_Webb_Cosmos", "Microscopic", "nousr robot", "гнилые_зомби", "blotmon", "All_In_1_Pixel", "16bit_landscape", "Pixel_Art", "MinecraftRTX", "microworld", "App_Icons", "DBWayneBarlowe_JM", "Пепе", "ГигаЧад", "pokemon", "ssmoky", "F111", "pyros_blowjob", "bkdbj", "hyperpreg__round_belly", "chkn_петухи", "YIFFY_EPOCH18", "Zack3D_Kinky", "GAPE60", "YIFFY15_GAPE", "Anything_V3", "Anything_v3_fullema", "WaifuDiffusion-1.3", "Berrymix_Zeipher222", "Anything_Berrymix", "Trinart v2", "NAI", "Black_Souls", "своя прямая ссылка на модель"]
if выбор_модели == 'SD v1.5':
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/sd-v1-5.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/sd-v1-5.ckpt
    # !sleep 2
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/sd-v1-5.vae.pt -O /content/stable-diffusion-webui/models/Stable-diffusion/sd-v1-5.vae.pt
    # !sleep 2
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/sd-v1-5.inpainting.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/sd-v1-5.inpainting.ckpt
    # !sleep 2
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/sd-v1-5.inpainting.vae.pt -O /content/stable-diffusion-webui/models/Stable-diffusion/sd-v1-5.inpainting.vae.pt
elif выбор_модели == 'SD v1.5 full для обучения':
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/sd-v1-5.full.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/sd-v1-5.full.ckpt
elif выбор_модели == 'SD v1.4':
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/sd-v1-4.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/sd-v1-4.ckpt
elif выбор_модели == 'pachu artwork style':
    # !wget -nv --show-progress https://huggingface.co/ProGamerGov/Pachu-Diffusion/resolve/main/pachu_artwork_style_v1_iter8000.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/pachu_artwork_style.ckpt
elif выбор_модели == 'modern disney style':
    # !wget -nv --show-progress https://huggingface.co/nitrosocke/mo-di-diffusion/resolve/main/moDi-v1-pruned.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/modern_disney_style.ckpt
elif выбор_модели == 'classic disney style':
    # !wget -nv --show-progress https://huggingface.co/nitrosocke/classic-anim-diffusion/resolve/main/classicAnim-v1.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/classic_disney_style.ckpt
elif выбор_модели == 'tron legacy style':
    # !wget -nv --show-progress https://huggingface.co/dallinmackay/Tron-Legacy-diffusion/resolve/main/Tron-Legacy-Style-trnlgcy.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/trnlgcy.ckpt
elif выбор_модели == 'elden ring style':
    # !wget -nv --show-progress https://huggingface.co/nitrosocke/elden-ring-diffusion/resolve/main/eldenring-v2-pruned.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/elden_ring_style.ckpt
elif выбор_модели == 'spiderverse style':
    # !wget -nv --show-progress https://huggingface.co/nitrosocke/spider-verse-diffusion/resolve/main/spiderverse-v1-pruned.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/spiderverse_style.ckpt
elif выбор_модели == 'discoelysium style':
    # !wget -nv --show-progress https://huggingface.co/nitrosocke/disco-elysium/resolve/main/discoElysium-pruned.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/discoelysium_style.ckpt
elif выбор_модели == 'arcane style':
    # !wget -nv --show-progress https://huggingface.co/nitrosocke/Arcane-Diffusion/resolve/main/arcane-diffusion-v3.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/arcane_style.ckpt
elif выбор_модели == 'archer style':
    # !wget -nv --show-progress https://huggingface.co/nitrosocke/archer-diffusion/resolve/main/archer-v1.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/archer_style.ckpt
elif выбор_модели == 'poolsuite style':
    # !wget -nv --show-progress https://huggingface.co/prompthero/poolsuite-diffusion/resolve/main/poolsuite_step2010.ckpt  -O /content/stable-diffusion-webui/models/Stable-diffusion/poolsuite_style.ckpt
elif выбор_модели == 'newhorrorfantasy_style':
    # !wget -nv --show-progress https://huggingface.co/elRivx/sd-newhorrorfantasy_style/resolve/main/newhorrorfantasy_style.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/newhorrorfantasy_style.ckpt
elif выбор_модели == 'nousr robot':
    # !wget -nv --show-progress https://huggingface.co/nousr/robo-diffusion/resolve/main/models/robo-diffusion-v1.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/nousr_robot.ckpt
elif выбор_модели == 'pokemon':
    # !wget -nv --show-progress https://huggingface.co/justinpinkney/pokemon-stable-diffusion/resolve/main/ema-only-epoch%3D000142.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/pokemon.ckpt
elif выбор_модели == 'blotmon':
    # !wget -nv --show-progress https://huggingface.co/guumaster/blot-monster-diffusion/resolve/main/blotmon-v1-5000.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/blotmon.ckpt
elif выбор_модели == 'ssmoky':
    # !wget -nv --show-progress https://huggingface.co/guumaster/smoke-diffusion/resolve/main/ssmoky1_3000.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/ssmoky.ckpt
elif выбор_модели == 'YIFFY_EPOCH18':
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/yiffy-e18.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/yiffy-e18.ckpt
elif выбор_модели == 'WiKiArt':
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/sd-wikiart-v2.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/wikiart.ckpt
elif выбор_модели == 'Zack3D_Kinky':
    # !wget -nv --show-progress https://huggingface.co/Zack3D/Zack3D_Kinky-v1/resolve/main/Zack3D_Kinky-v1.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/kinky.ckpt
elif выбор_модели == 'GAPE60':
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/gape60.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/gape60.ckpt
elif выбор_модели == 'YIFFY15_GAPE':
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/gape22_yiffy15.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/gape_yiffy.ckpt
elif выбор_модели == 'hyperpreg__round_belly':
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/hyperpreg__round_belly.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/hyperpreg__round_belly.ckpt
elif выбор_модели == 'WaifuDiffusion-1.3':
    # !wget -nv --show-progress https://huggingface.co/hakurei/waifu-diffusion-v1-3/resolve/main/wd-v1-3-float32.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/waifu.ckpt
elif выбор_модели == 'NAI':
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/novelai.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/novelai.ckpt
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/novelai.vae.pt -O /content/stable-diffusion-webui/models/Stable-diffusion/novelai.vae.pt
elif выбор_модели == 'Anything_V3':
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/Anything-V3.0-pruned-fp32.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/anything_v3.ckpt
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/Anything-V3.0.vae.pt -O /content/stable-diffusion-webui/models/Stable-diffusion/anything_v3.vae.pt
elif выбор_модели == 'Anything_v3_fullema':
    # !wget -nv --show-progress https://huggingface.co/utnah/big_ckpt/resolve/main/Anything_v3_fullema.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/Anything_v3_fullema.ckpt
    # !wget -nv --show-progress https://huggingface.co/utnah/big_ckpt/resolve/main/Anything_v3_fullema.vae.pt -O /content/stable-diffusion-webui/models/Stable-diffusion/Anything_v3_fullema.vae.pt
elif выбор_модели == 'Trinart v2':
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/trinart2.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/trinart2.ckpt
elif выбор_модели == 'DBWayneBarlowe_JM':
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/DBWayneBarlowe_JM.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/DBWayneBarlowe_JM.ckpt
elif выбор_модели == 'F111':
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/f111.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/f111.ckpt
elif выбор_модели == 'Beksinski':
    # !wget -nv --show-progress https://huggingface.co/s3nh/beksinski-style-stable-diffusion/resolve/main/model.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/beksinski.ckpt
elif выбор_модели == 'Van_Gogh':
    # !wget -nv --show-progress https://huggingface.co/dallinmackay/Van-Gogh-diffusion/resolve/main/Van-Gogh-Style-lvngvncnt-v2.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/Van_Gogh.ckpt
elif выбор_модели == 'Bloodborne':
    # !wget -nv --show-progress https://huggingface.co/Guizmus/Bloodborne/resolve/main/BloodborneStyle-v1.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/Bloodborne.ckpt
elif выбор_модели == 'DarkSouls':
    # !wget -nv --show-progress https://huggingface.co/Guizmus/DarkSoulsDiffusion/resolve/main/DarkSoulsStyle-v1.2.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/DarkSouls.ckpt
elif выбор_модели == 'Borderlands':
    # !wget -nv --show-progress https://huggingface.co/PublicPrompts/borderlands/resolve/main/borderlands.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/borderlands.ckpt
elif выбор_модели == 'Redshift':
    # !wget -nv --show-progress https://huggingface.co/nitrosocke/redshift-diffusion/resolve/main/redshift-diffusion-v1.ckptt -O /content/stable-diffusion-webui/models/Stable-diffusion/redshift.ckpt
elif выбор_модели == 'Starsector_Portrait':
    # !wget -nv --show-progress https://huggingface.co/Severian-Void/Starsector-Portraits/resolve/main/models/starsectorportrait_v2.1_SD1.5.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/starsector_portrait.ckpt
    # !curl -L --create-dirs https://huggingface.co/Severian-Void/Starsector-Portraits/resolve/main/hypernetworks/HN_ssportrait_v2_1.5_13431.pt -o /content/stable-diffusion-webui/models/hypernetworks/HN_ssportrait.pt
elif выбор_модели == 'EpicSpaceMachine':
    # !wget -nv --show-progress https://huggingface.co/rabidgremlin/sd-db-epic-space-machine/resolve/main/EpicSpaceMachine.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/EpicSpaceMachine.ckpt
elif выбор_модели == 'reasonableDrink':
    # !wget -nv --show-progress https://huggingface.co/elRivx/reasonableDrink/resolve/main/reasonableDrink.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/reasonableDrink.ckpt
elif выбор_модели == 'CALARTS':
    # !wget -nv --show-progress https://huggingface.co/PublicPrompts/CALARTS/resolve/main/CALARTS.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/CALARTS.ckpt
elif выбор_модели == 'beeple':
    # !wget -nv --show-progress https://huggingface.co/riccardogiorato/beeple-diffusion/resolve/main/beeple.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/beeple.ckpt
elif выбор_модели == 'megaPals':
    # !wget -nv --show-progress https://huggingface.co/elRivx/megaPals/resolve/main/megaPals.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/megaPals.ckpt
elif выбор_модели == '16bit_landscape':
    # !wget -nv --show-progress https://huggingface.co/PublicPrompts/16-bit-landscape_PublicPrompts/resolve/main/16-bit-landscape_PublicPrompts.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/16bit_landscape.ckpt
elif выбор_модели == 'Pixel_Art':
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/Pixel_Art.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/Pixel_Art.ckpt
elif выбор_модели == 'MinecraftRTX':
    # !wget -nv --show-progress https://huggingface.co/rabidgremlin/sd-db-block-world-rtx/resolve/main/BlockWorldRTX.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/MinecraftRTX.ckpt
elif выбор_модели == 'microworld':
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/microworld.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/microworld.ckpt
elif выбор_модели == 'App_Icons':
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/App_Icons.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/App_Icons.ckpt
elif выбор_модели == 'bkdbj':
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/bkdbj.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/bkdbj.ckpt
elif выбор_модели == 'Berrymix_Zeipher222':
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/Berrymix_Zeipher222.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/Berrymix_Zeipher222.ckpt
elif выбор_модели == 'Anything_Berrymix':
    # !wget -nv --show-progress https://huggingface.co/utnah/big_ckpt/resolve/main/Anything_Berrymix.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/Anything_Berrymix.ckpt
elif выбор_модели == 'pyros_blowjob':
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/pbj_v1.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/pyros_blowjob.ckpt
elif выбор_модели == 'Пепе':
    # !wget -nv --show-progress https://huggingface.co/SpiteAnon/Pepestyle/resolve/main/pepestylev2_2200.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/pepestyle_person.ckpt
elif выбор_модели == 'ГигаЧад':
    # !wget -nv --show-progress https://huggingface.co/SpiteAnon/gigachad-diffusion/resolve/main/gigachad_2000.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/gigachad.ckpt
elif выбор_модели == 'James_Webb_Cosmos':
    # !wget -nv --show-progress https://huggingface.co/dallinmackay/JWST-Deep-Space-diffusion/resolve/main/JWST-Deep-Space.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/JWST.ckpt
elif выбор_модели == 'Midjourney':
    # !wget -nv --show-progress https://huggingface.co/prompthero/midjourney-v4-diffusion/resolve/main/mdjrny-v4.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/mdjrny-v4_style.ckpt
elif выбор_модели == 'Cats_Tabaxi':
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/tabaxi2500person.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/cat_tabaxi_person.ckpt
elif выбор_модели == 'Cthulhu_illithid':
    # !wget -nv --show-progress 'https://huggingface.co/VTTRPGResources/DnDAi-illithid_Person/resolve/main/DnDAi%20-%20illithid_Person.ckpt' -O /content/stable-diffusion-webui/models/Stable-diffusion/illithid_person.ckpt
elif выбор_модели == 'BubblyDubbly':
    # !wget -nv --show-progress https://huggingface.co/Marre-Barre/bubblydubbly/resolve/main/bubblydubbly_7k.ckpt  -O /content/stable-diffusion-webui/models/Stable-diffusion/bubblydubbly_7k.ckpt
    # !wget -nv --show-progress https://huggingface.co/Marre-Barre/bubblydubbly/resolve/main/bubblydubbly.ckpt  -O /content/stable-diffusion-webui/models/Stable-diffusion/bubblydubbly.ckpt
elif выбор_модели == 'Microscopic':
    # !wget -nv --show-progress https://huggingface.co/Fictiverse/Stable_Diffusion_Microscopic_model/resolve/main/Microscopic_v1.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/Microscopic.ckpt
elif выбор_модели == 'гнилые_зомби':
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/RottingZombie_person.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/RottingZombie_person.ckpt
elif выбор_модели == 'Black_Souls':
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/Black_Souls.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/Black_Souls.ckpt
elif выбор_модели == 'All_In_1_Pixel':
    # !wget -nv --show-progress https://huggingface.co/PublicPrompts/All-In-One-Pixel-Model/resolve/main/Public-Prompts-Pixel-Model.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/all_in_one_pixel_model.ckpt
elif выбор_модели == 'Abstract_Swirls':
    # !wget -nv --show-progress https://huggingface.co/coder119/Abstract_Swirls_Diffusion/resolve/main/Abstract_Swirls.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/abstractswirls.ckpt
elif выбор_модели == 'chkn_петухи':
    # !wget -nv --show-progress https://huggingface.co/fake4325634/chkn/resolve/main/chkn.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/chkn.ckpt
elif выбор_модели == 'Hogwarts_Legacy':
    # !wget -nv --show-progress https://huggingface.co/Guizmus/Experiments/resolve/main/HogLegStyle-v2.4.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/HogLeg_Style.ckpt
elif выбор_модели == 'Члены':
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/unctpns.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/uncut-penis.ckpt
elif выбор_модели == 'своя прямая ссылка на модель':
    своя_ссылка = "https://твоя-ссылка.на/свою/модель.ckpt" #@param {type:"string"}
    # !wget {своя_ссылка} -O /content/stable-diffusion-webui/models/Stable-diffusion/my_model.ckpt

# !ls -la /content/stable-diffusion-webui/models/Stable-diffusion/*.ckpt

if clear_out:
  output.clear()
# !sleep 2
#@markdown - [Ячейка](#scrollTo=rcAPPhbyhx3t) для скачивания нескольких моделей (Перед запуском WebUI). 
#@markdown - Нужная модель доступна через торрент? [Ячейка](#scrollTo=CD4q5amW7Oib) для скачивания торрентов.
#@markdown - [Если пришлешь в тг-бот](https://t.me/colabSDbot) ссылку/торрент на очень нужную модель, ее можно будет добавить в меню выбора моделей.
#@markdown - Скаченные откуда-то модели, можешь удобно выгрузить на HuggingFace [в этой ячейке](#scrollTo=LsKdhWiFdTOq), чтобы всегда иметь прямые ссылки на свои модели с максимальной скоростью загрузки.
#@markdown - Нашел модель, но она не в формате .ckpt, а в каких-то .bin-файлах? [В этой ячейке](#scrollTo=du5Xt_kv7Gd9) можешь сконвертировать diffusers-модели в нормальный формат и получить ckpt-файлик.
#@markdown - Другие модели можно найти [на этой странице](https://teletype.in/@stablediffusion/models_for_SD).
#фиксы
if xformers:
    # !wget -q https://is.gd/fix_webui -O /content/.config/fix_webui.ipynb
    # %run /content/.config/fix_webui.ipynb
if not xformers:
  # !wget -q https://is.gd/russian_only -O /content/.config/localisation.ipynb
  # %run /content/.config/localisation.ipynb
# %cd /content
#принудительно выбор версии pytorch для совместимости (Автоматик уже сам пофиксил)
#!pip install pytorch-lightning==1.7.7

#Установка ngrok в качестве более стабильной альтернативы gradio
# !pip install pyngrok
#Настройка pyngrok на наш порт
# %cd /content/stable-diffusion-webui
# !npm install -g localtunnel
# !nohup lt -p 7860 > lt.log 2>&1 &

# настройка вебуи
if xformers:
    # !COMMANDLINE_ARGS="--exit" REQS_FILE="requirements.txt" python launch.py --disable-safe-unpickle --exit
    # !wget -q https://github.com/DagnyT/hardnet/raw/master/pretrained/train_liberty_with_aug/checkpoint_liberty_with_aug.pth -O /root/.cache/torch/hub/checkpoints/checkpoint_liberty_with_aug.pth


if deepdanbooru:
  # !pip install git+https://github.com/KichangKim/DeepDanbooru.git@edf73df4cdaeea2cf00e9ac08bd8a9026b7a7b26

# проверка и установка обновленных зависимостей (на всякий случай, для изменившихся модулей/расширений)
# !pip install -r https://github.com/AUTOMATIC1111/stable-diffusion-webui/raw/master/requirements.txt
if clear_out:
  output.clear()
# далее костыль просто для того чтобы все окончательно скачалось сейчас, а не при первом запуске webui
# и при запуске в #3 ячейке уже ничего не скачивалось,
# а только запускалось и был красивый вывод в консольку (да, это только для красоты)
import multiprocessing
import time
# prerun - предварительный, фейковый запуск webui
def prerun():
  # %cd /content/stable-diffusion-webui
  print("доустановка... это займет около 1 минуты")
  # !python /content/stable-diffusion-webui/webui.py --disable-safe-unpickle --enable-insecure-extension-access --opt-split-attention --ckpt-dir /content/stable-diffusion-webui/models/Stable-diffusion    

if __name__ == '__main__':
  p = multiprocessing.Process(target=prerun)
  p.start()
  p.join(70)

  if p.is_alive():
    print("\n завершение...")
    p.kill()
    # p.terminate()
    p.join()

# конец
if clear_out:
  output.clear()
  
print('\033[01;38;05;46mУстановка завершена')
print('\033[01;38;05;33mВыбранная модель загружена')
print("\033[0m----------------------------------------------------------")
# !free -g | grep Mem | awk '{print "Всего ОЗУ: " $2 " Гб | " "Доступно ОЗУ: " $7 " Гб"}'
import os
from subprocess import getoutput
nsmi = getoutput('nvidia-smi')
if "NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running." in nsmi:
    print('\033[01;38;05;242mColab запущен без видеоускорителя \033[0m')
else:
  card = !nvidia-smi --query-gpu=gpu_name --format=csv
  vram = !nvidia-smi --query-gpu=memory.total --format=csv
  print("Видеокарта: \033[01;38;05;46mNvidia " + (card[1]) + "\033[0m |" + "\033[01;38;05;188m Объём видеопамяти: \033[01;38;05;46m" + (vram[1]) + "\033[0m ")

from google.colab import output
output.eval_js('new Audio("https://files.catbox.moe/60v2d2.mp3").play()')

# %%
#@title #2. Подключение гуглодиска <br><small><small>опционально, без гуглодиска после завершения можно [скачать архив](#scrollTo=V-2LlLHZPgoB), если успеешь до истечения бесплатной сессии</small></small>
#@markdown для сохранений по пути `/content/gdrive/MyDrive/SD` если хотим, чтобы картинки СРАЗУ создавались в папке гуглодиска, чтобы их потом не скачивать.<br>И чтобы картинки не пропали когда внезапно Гугл отключит твой бесплатный колаб: файловая система в колабе не надежна, в том смысле, что гугл в любой момент может схлопнуть работающий колаб и все файлы тут же удаляться. Обидно, не так ли? Потому работать удобнее сразу на гуглодиске.<br>Так же полезно при обучении нейросети - все входные и выходные файлы будут на гуглодиске.<hr> Если на гуглодиске в папке `SD` создашь файл `styles.csv` можно будет сохранять туда свои стили из промптов и работать с ними в последующем.<details><summary>👈ГДЕ СОХРАТЬ СТИЛИ В WEBUI (разверни спойлер для просмотра)</summary><img src="https://files.catbox.moe/4m8cy2.png"/></details><br>Несколько фейковых акков? Ок, просто расшарь ярлык на оригинальный styles.csv на все свои фейковые гуглоаккаунты и создай ссылку на файл в их папках SD. При расшаривании разреши редактирование для твоих аккаунтов. Тогда у тебя всегда будет свой файлик со стилями.<details><summary>👈ПРИМЕР (разверни спойлер для просмотра)</summary><img width="500px" src="https://files.catbox.moe/ox0o4d.png"/><p>а затем добавить ярлык на файл в свои аккаунты в папку SD</p><img width="500px" src="https://files.catbox.moe/plk4lg.webp"/></details><br>
import os
from google.colab import output
from google.colab import drive
drive.mount('/content/gdrive')

# !sleep 2
# применение настроек для работы на гуглодиске
# %cd /content/stable-diffusion-webui
# !rm ui-config.json
# !wget -q https://is.gd/ui_config -O ui-config.json
# !rm config.json
# !wget -q https://is.gd/config_wGD -O config.json

#стили c гуглодиска (если несколько аккаунтов, придется расшарить один стиль с правами записи на все свои фейки).
if os.path.exists("/content/gdrive/MyDrive/SD/styles.csv"):
  # !rm /content/stable-diffusion-webui/styles.csv
  # !rm /content/stable-diffusion-webui/styles.csv.bak
  # !ln -s /content/gdrive/MyDrive/SD/styles.csv /content/stable-diffusion-webui/styles.csv
  # !ln -s /content/gdrive/MyDrive/SD/styles.csv /content/stable-diffusion-webui/styles.csv.bak
  # !chmod -c 777 /content/stable-diffusion-webui/styles.csv
  # !chmod -c 777 /content/stable-diffusion-webui/styles.csv.bak
else:
  # !rm /content/stable-diffusion-webui/styles.csv
  # !rm /content/stable-diffusion-webui/styles.bak
  # !wget -q https://pst.klgrth.io/paste/7k85j/download -O /content/gdrive/MyDrive/SD/styles.csv 
  # !ln -s /content/gdrive/MyDrive/SD/styles.csv /content/stable-diffusion-webui/styles.csv
  # !ln -s /content/gdrive/MyDrive/SD/styles.csv /content/stable-diffusion-webui/styles.csv.bak
  # !chmod -c 777 /content/stable-diffusion-webui/styles.csv
  # !chmod -c 777 /content/stable-diffusion-webui/styles.csv.bak

output.clear()

print('[1;32m Гуглодиск подключен')
from google.colab import output
output.eval_js('new Audio("https://files.catbox.moe/5vthn3.mp3").play()')

# %%
#@title #3. Погнали! | Эта ячейка запускает WebUI после всех приготовлений выше { display-mode: "form" }
import os

ngrok_token = "вставь сюда свой токен ngrok" #@param {type:"string"}

#@markdown Получить <b>свой</b> токен для ngrok можешь [тут](https://dashboard.ngrok.com/get-started/your-authtoken) |  Если токен ngrok не будет указан в поле выше, ngrok в 99% все равно запустится - будет использован ч҉у҉ж҉о҉й токен

#@markdown ⚠️ <font color='#32CD32'>После того как **все прогрузится**, ищи сылки типа</font>: <br> `cool-brooms-admire-23-251-149-142.loca.lt` или `0bf89138a7c4877f.gradio.app` или `e402-34-126-159-209.ngrok.io`<br>И переходи по ссылкам. Gradio - дефольный, но бывает зависает. Пробуй Ngrok или LokalIt
#@markdown <br><details><summary><font color='gold'>где искать и какие ссылки? </font></summary><img src="https://files.catbox.moe/c57s73.gif" width='1000px'/></details>
#@markdown <b><font color='#32CD32'>Рекомендую использовать ngrok.</font></b> Работа через gradio сопряжена с частыми зависаниями и потерей коннекта при пакетной генерации. loca.lt - иногда чуточку лучше. Ngrok тоже не идеален, но он более стабилен.

#@markdown 👉 [как составить промпт и список художников](https://teletype.in/@stablediffusion/artists_for_prompts) | [о настройках генерации](https://teletype.in/@stablediffusion/samplers_steps) 👈

#ссылка на LocalTunel (loca.lt)
with open('/content/stable-diffusion-webui/lt.log', 'r') as testwritefile:
    print(testwritefile.read())

# !sleep 2

#Установка токена ngrok
ngrok_share = '/content/.config/cfg'
freetoken = open(ngrok_share).read().split('\n')
import random
sharetoken = random.choice(list(freetoken))
token = ngrok_token
if not ngrok_token or len(ngrok_token) < 48 or len(ngrok_token) > 51:
  ngrok = '--ngrok ' + sharetoken
else:
  ngrok = '--ngrok ' + token

#Собственно запуск
if not deepdanbooru:
  # !python /content/stable-diffusion-webui/webui.py --disable-safe-unpickle --enable-insecure-extension-access --share --gradio-debug --opt-split-attention --ckpt-dir /content/stable-diffusion-webui/models/Stable-diffusion {ngrok} --ngrok-region eu
if deepdanbooru:
  # !python /content/stable-diffusion-webui/webui.py --deepdanbooru --disable-safe-unpickle --enable-insecure-extension-access --share --gradio-debug --opt-split-attention --ckpt-dir /content/stable-diffusion-webui/models/Stable-diffusion {ngrok} --ngrok-region eu
#конец

if os.path.exists("/content/gdrive/MyDrive/SD/styles.csv"):
  # !cp -f /content/stable-diffusion-webui/styles.csv /content/gdrive/MyDrive/SD/styles.csv
from IPython.display import HTML
end = '/content/.config/end'
HTML(end)

# %% [markdown]
# ---

# %%
#@title 💩 Перезапуск среды выполнения (если что-то пошло не так) { display-mode: "form" }
# от этого Колаб крашнется/ребутнется, это так и должно быть, ничего не пропадет, запускай ячейки дальше ниже
print('\033[31m Среда выполнения сброшена!')
print('\033[32m Можно перезапустить WebUI ячейке #3...')
from google.colab import output
output.eval_js('new Audio("https://files.catbox.moe/cgh6an.mp3").play()')
# !sleep 1
import os
os.kill(os.getpid(), 9)

# %%
#@title 💾 Создание и скачивание архива со всеми картинками { display-mode: "form" }
#@markdown **Cкачивание напрямую на ПК, минуя гуглодиск**: это нужно, если ты не захотел сразу работать на гуглодиске, после архивации - скачивание запустится автоматически.<br>

#@markdown **Прежде чем запустить скачивание архива в этой ячейке, предыдущая ячейка должна быть остановлена!** (потом можно будет ее запустить снова, если требуется)
# %cd /content/
# !zip -r /content/SD_Colab.zip /content/output
output.clear()
print('\033[35m скачивание архива начнется автоматически...')
from google.colab import files
files.download('/content/SD_Colab.zip')

# %% [markdown]
# ---

# %%
#@title Скачать несколько моделей { display-mode: "form" }
#@markdown <details><summary><big><big><big>👈Описание моделей, ключи для их вызова</big></big></big> (разверни спойлер, чтобы прочитать)</summary><p><b>SD v1.5 и SD v1.4</b> — это стандартные модели, обе дообучались на SD v1.2, специфических токенов нет, идеальны для общих нужд. Моделька 1.5 идет в комплекте с VAE и моделью для Inpaiting, которую надо выбрать перед работой в img2img inpaint. Особого смысла в 1.4 уже нет, она добавлена для совместимости со старыми сидами/промптами.<p><b>SD v1.5 full для обучения</b> — это стандартная модель, из которой не были удалены данные для обучения, потому она весит в два раза больше. Особого смысла генерить на ней нет, но для тренировки внедрений, гиперсети и т.д. - она годится лучше. Требует очень много памяти, так что следи за настройками обучения, чтобы уместиться в 15гб VRAM<p><b>Beksinski</b> — стиль загадочного и потрясающего художника Здислава Бексинского, в промпт добавлять <code>beksinski style</code><p><b>Van_Gogh</b> — модель натренирована на кадрах из фильма «Ван Гог. С любовью, Винсент» — который выполнен в стилистике рисовки Ван Гога, это первый в мире анимационный полнометражный фильм, полностью нарисованный масляными красками на досках! В промпт важно добавить в самое начало <code>lvngvncnt</code>, например: <code>lvngvncnt, handsome attractive shirtless younker, highly detailed</code> Если не нравится слишком синюшная гамма и желтые рожи — в негативный промпт надо написать что-то вроде <code>yellow face, blue</code> Моделька ахуенная, рисует и людей и природу и здания — очень хорошо. Поскольку моделька высокохудожественная, то не поднимайте высоко CFG Scale, чтобы нейросеть могла больше «фантазировать», 4-7 — будет норм.<p><b>DBWayneBarlowe_JM</b> — демоническая, оккультная, религиозная и сатанинская темататика, в промпт писать все что с этим связанно, основана на работах художника Уэйна Барлоу, сначала рекомендую ознакомится c ним, чтобы понять что к чему.<p><b>Cats_Tabaxi</b> — рисует антропофорфных котиков и прочих каджитов. Основной ключ <code>tabaxi person</code>, и далее - все что связанно с котаи - львы, тигры, рыси, и прочие котики. В негативный промпт нужно написать типа: <code>mutation, human hands, big head</code>. Примеры промптов: <code>portrait of a male white cat tabaxi person, rpg illustration by alex horley and dan mumford</code> | <code>portrait of a lion tabaxi person, in aplate armor, realisic render, octane render, zbrush, still from a movie, alexa, cooke 55mm, award winning photgraphy</code> | <code>portrait of a tiger boy tabaxi person, in a thief dark leather armor, black hood on her head, realisic render, octane render, zbrush, still from a movie, alexa, cooke 55mm</code><p><b>Cthulhu_illithid</b> — на самом деле модель у автора называется просто illithid, но чтобы было понятно - я добавил про Ктулху, потому что модель натренированна на молюско-подобной рассе, вдохновленной рисунками по мотивам произведений Лавкрафта и его Древними. В промпт нужно писать <code>illithid Person</code> или <code>illithid_Person</code>.<p><b>BubblyDubbly</b> — рисованные портреты в стиле BubblyDubbly, что это такое: https://imgur.com/a/yEchVjv . Ключ <code>art by bubblydubbly</code>, в негативный промпт можно добавить: <code>heavy contrast, red eyes, blue hair</code>, простой пример: <code>attractive boy, soft colors, art by bubblydubbly</code><p><b>pachu artwork style</b> — модель обучена на рисунках иллюстратора Плейбоя — Пачу Торреса, после подгрузки модели, в промпт добавить pachu <code>artwork style</code><p><b>Redshift</b> — модель обученная на 3Д рендерах высокого разрешения через Redshift, в начало промпта нужно добавлять <code>redshift style</code><p><b>modern disney style</b> — совремеменный пластмассовый диснеевский стиль, в промпт добавить <code>modern disney style</code><p><b>classic disney style</b> — стиль Диснея прошлого века с качественной мультяшной рисовкой, в промпт добавить <code>classic disney style</code><p><b>tron legacy style</b> — стилистика из фильма «Трон: Наследие», в промпт нужно добавлять <code>trnlgcy</code><p><b>elden ring style</b> — моделька на основе игровых артов из Elden Ring, в пропмт нужно писать <code>elden ring style</code><p><b>spiderverse style</b> — стиль мультика «Человек-паук: Через вселенные», в пропте надо писать <code>spiderverse style</code><p><b>discoelysium style</b> — стиль персонажей из игры Disco Elysium, в промпт надо добавлять токен <code>discoelysium style</code><p><b>arcane style</b> — стилистика фентезийного мультсериала «Аркейн», в промпт нужно воткнуть токен <code>arcane style</code><p><b>archer style</b> — стиль шпионского мальтсериала «Арчер», в пропмпте нужно указать <code>archer style</code><p><b>Bloodborne</b> — модель обученная стилю из игры Bloodborne, в промпт надо добавлять <code>Bloodborne Style</code><p><b>DarkSouls</b> — модель обученная стилю серии DarkSouls, в промпт добавлять <code>DarkSouls Style</code>, автор рекомендует рендер на Euler_a 20 шагов или DPM++ 2M Karras.<p><b>Borderlands</b> — модель для создания изображений в стиле Borderlands, соответсвтенно в промпт надо писать токен <code>borderlands</code><p><b>Starsector_Portrait</b> — модель обученная на скринах из видеоигры Starsector, лучще всего заточена под портреты, в промпт нужно добавить <code>starsectorportrait</code>, например <code>a starsectorportrait of a man wearing a green balaclava and armored spacesuit</code> сочетается с добавочными токенами <code>sabattier effect</code> — для эффекта освещения, <code>brush strokes</code> — для большей художественности портретов, <code>conte</code> — более аккуратные мазки. Модель <u>будет установлена с гиперсетью</u>, которую нужно будет подключить/отключить в настройках<p><b>EpicSpaceMachine</b> — футристичные космические корабли, станции и т. п., в промт добавлять <code>EpicSpaceMachine</code>, к примеру: <code>Photo of a futuristic space liner, 4K, award winning in EpicSpaceMachine style</code><p><b>reasonableDrink</b> — модель для фентезийных и фантастических артов, в промпт добавить <code>reasonableDrink</code><p><b>CALARTS</b> — рисунки персонажей в CalArts-стиле, в промпт добавить <code>CALARTS</code><p><b>beeple</b> — модель натренирована на работах этого художника-фотошопера: <a href=https://twitter.com/beeple>@beeple</a> в промпт нужно добавлять <code>beeple</code><p><b>megaPals</b> — стиль мультиков про супергероев из 70-х годов прошлого века, в промпт добавить <code>in megaPals style</code> или <code>a cartoon of  <em>КТО-ТО</em>, in megaPals style</code><p><b>Hogwarts_Legacy</b> — стиль из игры Хогрвардс: Наследие, в промпт писать: <code>HogLeg Style</code><p><b>Midjourney</b> — имитация стиля другой нейросетки, лол. Всем она известна, если нет - погугли картинки. В промпт нужно писать этот ключ: <code>mdjrny-v4 style</code>. Подробнее о промптинге <a href="https://prompthero.com/midjourney-prompts?version=4">написано тут</a>.<p><b>WiKiArt</b> — чисто художественная модель, обученная по огромной базе из более чем 3000 художников, собственно самих художников нужно <a href=https://www.wikiart.org/ >смотреть на сайте</a>: осторожно, он нашпигован свиной пропагандой ЦИПсО, свиные баннеры заблокируйте ublock или adblock<p><b>Abstract_Swirls</b> — умеет рисовать абстракцию типа жидкого мрамора или акриловых красок в воде, но умеет и в портреты в стиле жидкой краски с завитками и разводами, выглядит красиво.Основной токен: <code>abstractswirls</code>, пример: <code>portrait of a handsome slender shirtless teen boy, abstractswirls, long shot, masterpiece, by artgerm and mucha</code>. Автор генерирует на таких настройках: Steps: 10, Sampler: DPM++ 2S a Karras, CFG scale: 7.<p><b>poolsuite style</b> — модель натренирована на ретро-подобных весьма ламповых фотках и картинках, вот <a href="https://prompthero.com/search?q=poolsuite+style">примеры подобного</a>. В промпт надо добавлять <code>poolsuite-style</code> или <code>poolsuite style</code>.<p><b>newhorrorfantasy_style</b> — иллюстрации ужасов и фэнтези 2010-х годов, в промпт добавлять токен <code>newhorrorfantasy_style</code><p><b>James_Webb_Cosmos</b> — потрясающие космические снимки, словно сделанные новым телескопом Джеймса Уэбба, нужно добавлять <code>JWST</code>, например <code>jwst, green spiral galaxy</code><p><b>Microscopic</b> — а эта модель, напротив - создает фотореалистичные картинки, сделанные словно под хорогим микроскопом. Амебы, эвглены, вирусу, и прочая микробиология и гистология. В промпт нужно добавлять все что с этим связанно и обязательно в начало <code>Microscopic</code>.<p><b>nousr robot</b> — моделька сделанная через Дримбус для генерации футристичных роботов, нужно добавлять <code>nousr robot</code> по ближе к началу промпта<p><b>гнилые_зомби</b> — модель тренировалась на зомби из Ходячих Мертвецов, в промт добавлять токен <code>RottingZombie person</code><p><b>blotmon</b> — модель для генерации монстров из клякс, мультяшных монстриков и всякой деформированной шизы, в промт добавлять токен <code>blotmon</code><p><b>All_In_1_Pixel</b> — модель, которая умеет в разнонаправленную пиксельную графику. Токен <code>pixelsprite</code> будет выдавать спрайт-арт, ключ <code>16bitscene</code> активирует генерацию в стиле scene-art. Понятное дело, пиксели не идеальны, но картинки можно легко пофиксить на этом сайте: https://pinetools.com/pixelate-effect-image<p><b>pixel_landscape</b> — шестнадцатибитные пиксельные картинки, заточеные под пейзажи, объекты, обои рабочего стола, и т. п. В ромпт надо добавлять: <code>in 16-bit-landscape pixel art style</code><p><b>Pixel_Art</b> — довольно качественный пиксельарт, в промпт нужно добавить <code>in SKSKS art style</code>, например <code>little fox, in SKSKS art style</code><p><b>MinecraftRTX</b> — модель для стиля Майнкрафт с RTX, в промпт добавить <code>BlockWorldRTX</code><p><b>microworld</b> — изометрический 3Д-арт, в промпт добавить <code>in microworld render style</code>, например <code>baalbek temple of jupiter, in microworld render style</code><p><b>App_Icons</b> — рисует современные иконки и пиктограмы, в промпт надо добавить <code>in style of SKSKS app icon</code>, например <code>flat couch vector, minimalist, in style of SKSKS app icon</code><p><b>Пепе</b> — рисует очень редких лягух Пепе. Токен для промпта <code>pepestyle person</code>.<p><b>ГигаЧад</b> — делает фото/рисунки знаменитого гигачада, россиянина Эрнеста Халимова. В промпт добавлять <code>gigachad</code>.<p><b>pokemon</b> — моделька рисует покемонов, из чего угодно, в промпт писать описание предполагаемого покемона типа <code>Vladimir Putin creature</code> или <code>cute toad</code> слово pokemon во все не обязательно, модель все равно кроме покемонов ничего не умеет.<p><b>ssmoky</b> — моделька заточена чисто под арты с дымом и огнем, особенно с дымом, в промпт добавлять токен <code>ssmoky</code><p><b>F111</b> — модель улучшеной анатомии бабского тела, хорошо подходит для эротики<p><b>hyperpreg__round_belly</b> — генерирует БИБИК! Да, с огромным пузом, которое вот-вот РВАНЁТ! Умеет в рисунки — с токеном <code>hyperpreg</code> и в реализм, с токеном <code>round belly</code> — делать толстого Пыню теперь станет интереснее.<p><b>pyros_blowjob</b> — очень качественная модель про минет, сосание (нормальных) членов. Можно кого угодно заставить жадно обсасывать залупу-лупу.  Промпты должны включать <code>with cock in mouth, is sucking a cock, licking a large cock in mouth</code> Подробнее <a href=https://rentry.org/pyros-sd-model>почитай здесь</a> - там примеры промтов в фотореалистичном, рисованном и аниме-стиле.<p><b>bkdbj</b> — просто пиши любое имя и  <code>bkdbj</code> (модель про сосание <u>черных</u> членов кем-либо)<p><b>chkn_петухи</b> — очень классно ричует петухов и кур, в разных стилях, от фото до картины масло. Имхо, идеально для боевых картинок. В промпт добавлять: <code>chkn</code><p><b>YIFFY_EPOCH18</b> — не знаешь че такое йиффи? Лучше не лезь. На самом деле умеет не только в зверушек, но и таких животных как трапы/футы, в рисованном стиле разумеется. Вот полный список токенов для этой шизы: <a href=https://files.catbox.moe/sovd89.zip>в архиве файлик yiffy_tags.csv</a><p><b>Zack3D_Kinky</b> — для тех кого просто фурри уже не вставляет: щупальца, бдсм с дикими животными, боди-модификации, латекс, слизь, пытки анала и т.п. использовать теки с сайта E621 <code>то_есть_с_подчеркиванием</code><p><b>GAPE60 и ее прошлая версия YIFFY_GAPE</b> — фистинг и его последвствия: раздолбанные дыры пизды и анальной пизды, пролапс, вхлам растраханные отверстия, зияющие своими красными недрами, про теги и примеры посмотри <a href=https://rentry.org/gapemodel>тут</a><p><b>Anything_V3</b> — Последнее слово в генерации аниме! Это утечка гораздо улучшеной версии NovelAI. Подолбнее можно прочитать на <a href=https://www.bilibili.com/read/cv19603218>китайском сайте</a> через гуглпереводчик. <b>Anything_v3_fullema</b> - таже модель, только раздутая данными для тренировки.<p><b>Berrymix_Zeipher222</b> — мощный микс из разных модлей по особой рецептуре, в качестве важной специи - модель Зефир на улучшенную анатомию наготы, в качестве бульона - NovelAI, и еще разные специи.<p><b>Anything_Berrymix</b> — Суть таже что и Berrymix_Zeipher222, только вместо NovelAI более качественная аниме-модель Anything_V3<p><b>WaifuDiffusion-1.3</b> — анимешная модель, обучалась по картинкам с Danbooru, теги берите от туда же<p><b>Trinart v2</b> — еще одна анимешная модель, обучалась аж на 20 лямах картинок аниме и манги, без писек/сисек<p><b>NAI</b> — утечка модели NovelAI (скачивается с VAE), еще одно аниме...<p><b>Black_Souls</b> — имитирует графику из корейской игры «Black Souls». В промпт добавь токен <code>bs</code>. Автор требует, чтобы CFG_Scale стоял не выше 6, рекомендует 2-6, для skip clip установлено значение 1.</p></details>

#@markdown да, список длинный, в 2-3 колонки его не сделать, формы не поддерживают вложенность в markdown и т.д., может быть потом будет сделано через ipywidgets, но мне не нравится как выглядят виджеты ipywidgets при темной теме

#@markdown <big><big>галочками отметить нужные модели</big></big> (учитывая размер диска в колабе, около 40 гигов свободными):              
SDv1_5 = False #@param {type:"boolean"}
SDv1_5_full = False #@param {type:"boolean"}
SDv1_4 = False #@param {type:"boolean"}
Beksinski = False #@param {type:"boolean"}
Van_Gogh = False #@param {type:"boolean"}
Bloodborne = False #@param {type:"boolean"}
DarkSouls = False #@param {type:"boolean"}
Borderlands = False #@param {type:"boolean"}
Redshift = False #@param {type:"boolean"}
Starsector_Portrait = False #@param {type:"boolean"}
EpicSpaceMachine = False #@param {type:"boolean"}
reasonableDrink = False #@param {type:"boolean"}
CALARTS = False #@param {type:"boolean"}
beeple = False #@param {type:"boolean"}
megaPals = False #@param {type:"boolean"}
pachu_artwork_style = False #@param {type:"boolean"}
Cats_Tabaxi = False #@param {type:"boolean"}
Cthulhu_illithid = False #@param {type:"boolean"}
BubblyDubbly = False #@param {type:"boolean"}
modern_disney_style = False #@param {type:"boolean"}
classic_disney_style = False #@param {type:"boolean"}
tron_legacy_style = False #@param {type:"boolean"}
elden_ring_style = False #@param {type:"boolean"}
spiderverse_style = False #@param {type:"boolean"}
discoelysium_style = False #@param {type:"boolean"}
arcane_style = False #@param {type:"boolean"}
archer_style = False #@param {type:"boolean"}
poolsuite_style = False #@param {type:"boolean"}
newhorrorfantasy_style = False #@param {type:"boolean"}
Hogwarts_Legacy = False #@param {type:"boolean"}
Midjourney = False #@param {type:"boolean"}
WiKiArt = False #@param {type:"boolean"}
Abstract_Swirls = False #@param {type:"boolean"}
James_Webb_Cosmos = False #@param {type:"boolean"}
Microscopic = False #@param {type:"boolean"}
nousr_robot = False #@param {type:"boolean"}
гнилые_зомби = False #@param {type:"boolean"}
blotmon = False #@param {type:"boolean"}
All_In_1_Pixel = False #@param {type:"boolean"}
pixel_landscape = False #@param {type:"boolean"}
Pixel_Art = False #@param {type:"boolean"}
MinecraftRTX = False #@param {type:"boolean"}
microworld = False #@param {type:"boolean"}
App_Icons = False #@param {type:"boolean"}
DBWayneBarlowe_JM = False #@param {type:"boolean"}
Пепе = False #@param {type:"boolean"}
ГигаЧад = False #@param {type:"boolean"}
pokemon = False #@param {type:"boolean"}
ssmoky = False #@param {type:"boolean"}
F111 = False #@param {type:"boolean"}
pyros_blowjob = False #@param {type:"boolean"}
bkdbj = False #@param {type:"boolean"}
hyperpreg__round_belly = False #@param {type:"boolean"}
chkn_петухи = False #@param {type:"boolean"}
YIFFY_EPOCH18 = False #@param {type:"boolean"}
Zack3D_Kinky = False #@param {type:"boolean"}
GAPE60 = False #@param {type:"boolean"}
YIFFY_GAPE = False #@param {type:"boolean"}
Anything_V3 = False #@param {type:"boolean"}
Anything_v3_fullema = False #@param {type:"boolean"}
Berrymix_Zeipher222 = False #@param {type:"boolean"}
Anything_Berrymix = False #@param {type:"boolean"}
WaifuDiffusion = False #@param {type:"boolean"}
Trinart_v2 = False #@param {type:"boolean"}
NAI = False #@param {type:"boolean"}
Black_Souls = False #@param {type:"boolean"}

if SDv1_5:
    # !wget https://huggingface.co/utnah/ckpt/resolve/main/sd-v1-5.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/sd-v1-5.ckpt
    # !sleep 2
    # !wget https://huggingface.co/utnah/ckpt/resolve/main/sd-v1-5.vae.pt -O /content/stable-diffusion-webui/models/Stable-diffusion/sd-v1-5.vae.pt
    # !sleep 2
    # !wget https://huggingface.co/utnah/ckpt/resolve/main/sd-v1-5.inpainting.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/sd-v1-5.inpainting.ckpt
if SDv1_5_full:
    # !wget https://huggingface.co/utnah/ckpt/resolve/main/sd-v1-5.full.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/sd-v1-5.full.ckpt
if SDv1_4:
    # !wget https://huggingface.co/utnah/ckpt/resolve/main/sd-v1-4.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/sd-v1-4.ckpt
if pachu_artwork_style:
    # !wget https://huggingface.co/ProGamerGov/Pachu-Diffusion/resolve/main/pachu_artwork_style_v1_iter8000.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/pachu_artwork_style.ckpt
if modern_disney_style:
    # !wget https://huggingface.co/nitrosocke/mo-di-diffusion/resolve/main/moDi-v1-pruned.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/modern_disney_style.ckpt
if classic_disney_style:
    # !wget https://huggingface.co/nitrosocke/classic-anim-diffusion/resolve/main/classicAnim-v1.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/classic_disney_style.ckpt
if tron_legacy_style:
    # !wget https://huggingface.co/dallinmackay/Tron-Legacy-diffusion/resolve/main/Tron-Legacy-Style-trnlgcy.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/trnlgcy.ckpt
if elden_ring_style:
    # !wget https://huggingface.co/nitrosocke/elden-ring-diffusion/resolve/main/eldenring-v2-pruned.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/elden_ring_style.ckpt
if spiderverse_style:
    # !wget https://huggingface.co/nitrosocke/spider-verse-diffusion/resolve/main/spiderverse-v1-pruned.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/spiderverse_style.ckpt
if discoelysium_style:
    # !wget https://huggingface.co/nitrosocke/disco-elysium/resolve/main/discoElysium-pruned.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/discoelysium_style.ckpt
if arcane_style:
    # !wget https://huggingface.co/nitrosocke/Arcane-Diffusion/resolve/main/arcane-diffusion-v3.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/arcane_style.ckpt
if archer_style:
    # !wget https://huggingface.co/nitrosocke/archer-diffusion/resolve/main/archer-v1.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/archer_style.ckpt
if nousr_robot:
    # !wget https://huggingface.co/nousr/robo-diffusion/resolve/main/models/robo-diffusion-v1.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/nousr_robot.ckpt
if pokemon:
    # !wget https://huggingface.co/justinpinkney/pokemon-stable-diffusion/resolve/main/ema-only-epoch%3D000142.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/pokemon.ckpt
if blotmon:
    # !wget https://huggingface.co/guumaster/blot-monster-diffusion/resolve/main/blotmon-v1-5000.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/blotmon.ckpt
if ssmoky:
    # !wget https://huggingface.co/guumaster/smoke-diffusion/resolve/main/ssmoky1_3000.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/ssmoky.ckpt
if YIFFY_EPOCH18:
    # !wget https://huggingface.co/utnah/ckpt/resolve/main/yiffy-e18.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/yiffy-e18.ckpt
if poolsuite_style:
    # !wget https://huggingface.co/prompthero/poolsuite-diffusion/resolve/main/poolsuite_step2010.ckpt  -O /content/stable-diffusion-webui/models/Stable-diffusion/poolsuite_style.ckpt
if newhorrorfantasy_style:
    # !wget https://huggingface.co/elRivx/sd-newhorrorfantasy_style/resolve/main/newhorrorfantasy_style.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/newhorrorfantasy_style.ckpt
if WiKiArt:
    # !wget https://huggingface.co/utnah/ckpt/resolve/main/sd-wikiart-v2.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/wikiart.ckpt
if Zack3D_Kinky:
    # !wget https://huggingface.co/Zack3D/Zack3D_Kinky-v1/resolve/main/Zack3D_Kinky-v1.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/kinky.ckpt
if YIFFY_GAPE:
    # !wget https://huggingface.co/utnah/ckpt/resolve/main/gape22_yiffy15.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/gape_yiffy.ckpt
if hyperpreg__round_belly:
    # !wget https://huggingface.co/utnah/ckpt/resolve/main/hyperpreg__round_belly.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/hyperpreg__round_belly.ckpt
if WaifuDiffusion:
    # !wget https://huggingface.co/hakurei/waifu-diffusion-v1-3/resolve/main/wd-v1-3-float32.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/waifu.ckpt
if NAI:
    # !wget https://huggingface.co/utnah/ckpt/resolve/main/novelai.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/novelai.ckpt
    # !wget https://huggingface.co/utnah/ckpt/resolve/main/novelai.vae.pt -O /content/stable-diffusion-webui/models/Stable-diffusion/novelai.vae.pt
if Trinart_v2:
    # !wget https://huggingface.co/utnah/ckpt/resolve/main/trinart2.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/trinart2.ckpt
if DBWayneBarlowe_JM:
    # !wget https://huggingface.co/utnah/ckpt/resolve/main/DBWayneBarlowe_JM.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/DBWayneBarlowe_JM.ckpt
if F111:
    # !wget https://huggingface.co/utnah/ckpt/resolve/main/f111.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/f111.ckpt
if Beksinski:
    # !wget https://huggingface.co/s3nh/beksinski-style-stable-diffusion/resolve/main/model.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/beksinski.ckpt
if Van_Gogh:
    # !wget https://huggingface.co/dallinmackay/Van-Gogh-diffusion/resolve/main/Van-Gogh-Style-lvngvncnt-v2.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/Van_Gogh.ckpt
if Bloodborne:
    # !wget https://huggingface.co/Guizmus/Bloodborne/resolve/main/BloodborneStyle-v1.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/Bloodborne.ckpt
if DarkSouls:
    # !wget https://huggingface.co/Guizmus/DarkSoulsDiffusion/resolve/main/DarkSoulsStyle-v1.2.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/DarkSouls.ckpt
if Borderlands:
    # !wget https://huggingface.co/PublicPrompts/borderlands/resolve/main/borderlands.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/borderlands.ckpt
if Redshift:
    # !wget https://huggingface.co/nitrosocke/redshift-diffusion/resolve/main/redshift-diffusion-v1.ckptt -O /content/stable-diffusion-webui/models/Stable-diffusion/redshift.ckpt
if Starsector_Portrait:
    # !wget https://huggingface.co/Severian-Void/Starsector-Portraits/resolve/main/models/starsectorportrait_v2.1_SD1.5.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/starsector_portrait.ckpt
    # !curl -L --create-dirs https://huggingface.co/Severian-Void/Starsector-Portraits/resolve/main/hypernetworks/HN_ssportrait_v2_1.5_13431.pt -o /content/stable-diffusion-webui/models/hypernetworks/HN_ssportrait.pt
if EpicSpaceMachine:
    # !wget https://huggingface.co/rabidgremlin/sd-db-epic-space-machine/resolve/main/EpicSpaceMachine.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/EpicSpaceMachine.ckpt
if reasonableDrink:
    # !wget https://huggingface.co/elRivx/reasonableDrink/resolve/main/reasonableDrink.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/reasonableDrink.ckpt
if CALARTS:
    # !wget https://huggingface.co/PublicPrompts/CALARTS/resolve/main/CALARTS.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/CALARTS.ckpt
if beeple:
    # !wget https://huggingface.co/riccardogiorato/beeple-diffusion/resolve/main/beeple.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/beeple.ckpt
if megaPals:
    # !wget https://huggingface.co/elRivx/megaPals/resolve/main/megaPals.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/megaPals.ckpt
if pixel_landscape:
    # !wget https://huggingface.co/PublicPrompts/16-bit-landscape_PublicPrompts/resolve/main/16-bit-landscape_PublicPrompts.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/pixel_landscape.ckpt
if Pixel_Art:
    # !wget https://huggingface.co/utnah/ckpt/resolve/main/Pixel_Art.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/Pixel_Art.ckpt
if MinecraftRTX:
    # !wget https://huggingface.co/rabidgremlin/sd-db-block-world-rtx/resolve/main/BlockWorldRTX.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/MinecraftRTX.ckpt
if microworld:
    # !wget https://huggingface.co/utnah/ckpt/resolve/main/microworld.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/microworld.ckpt
if App_Icons:
    # !wget https://huggingface.co/utnah/ckpt/resolve/main/App_Icons.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/App_Icons.ckpt
if bkdbj:
    # !wget https://huggingface.co/utnah/ckpt/resolve/main/bkdbj.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/bkdbj.ckpt
if Anything_V3:
  # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/Anything-V3.0-pruned-fp32.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/anything_v3.ckpt
  # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/Anything-V3.0.vae.pt -O /content/stable-diffusion-webui/models/Stable-diffusion/anything_v3.vae.pt
if Anything_v3_fullema:
  # !wget -nv --show-progress https://huggingface.co/utnah/big_ckpt/resolve/main/Anything_v3_fullema.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/Anything_v3_fullema.ckpt
  # !wget -nv --show-progress https://huggingface.co/utnah/big_ckpt/resolve/main/Anything_v3_fullema.vae.pt -O /content/stable-diffusion-webui/models/Stable-diffusion/Anything_v3_fullema.vae.pt
if GAPE60:
  # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/gape60.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/gape60.ckpt
if Berrymix_Zeipher222:
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/Berrymix_Zeipher222.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/Berrymix_Zeipher222.ckpt
if Anything_Berrymix:
    # !wget -nv --show-progress https://huggingface.co/utnah/big_ckpt/resolve/main/Anything_Berrymix.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/Anything_Berrymix.ckpt
if pyros_blowjob:
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/pbj_v1.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/pyros_blowjob.ckpt
if Пепе:
    # !wget -nv --show-progress https://huggingface.co/SpiteAnon/Pepestyle/resolve/main/pepestylev2_2200.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/pepestyle_person.ckpt
if ГигаЧад:
    # !wget -nv --show-progress https://huggingface.co/SpiteAnon/gigachad-diffusion/resolve/main/gigachad_2000.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/gigachad.ckpt
if James_Webb_Cosmos:
    # !wget -nv --show-progress https://huggingface.co/dallinmackay/JWST-Deep-Space-diffusion/resolve/main/JWST-Deep-Space.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/JWST.ckpt
if Midjourney:
    # !wget -nv --show-progress https://huggingface.co/prompthero/midjourney-v4-diffusion/resolve/main/mdjrny-v4.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/mdjrny-v4_style.ckpt
if Cats_Tabaxi:
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/tabaxi2500person.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/cat_tabaxi_person.ckpt
if Cthulhu_illithid:
    # !wget -nv --show-progress 'https://huggingface.co/VTTRPGResources/DnDAi-illithid_Person/resolve/main/DnDAi%20-%20illithid_Person.ckpt' -O /content/stable-diffusion-webui/models/Stable-diffusion/illithid_person.ckpt
if BubblyDubbly:
    # !wget -nv --show-progress https://huggingface.co/Marre-Barre/bubblydubbly/resolve/main/bubblydubbly_7k.ckpt  -O /content/stable-diffusion-webui/models/Stable-diffusion/bubblydubbly_7k.ckpt
    # !wget -nv --show-progress https://huggingface.co/Marre-Barre/bubblydubbly/resolve/main/bubblydubbly.ckpt  -O /content/stable-diffusion-webui/models/Stable-diffusion/bubblydubbly.ckpt
if Microscopic:
    # !wget -nv --show-progress https://huggingface.co/Fictiverse/Stable_Diffusion_Microscopic_model/resolve/main/Microscopic_v1.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/Microscopic.ckpt
if гнилые_зомби:
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/RottingZombie_person.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/RottingZombie_person.ckpt
if Black_Souls:
    # !wget -nv --show-progress https://huggingface.co/utnah/ckpt/resolve/main/Black_Souls.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/Black_Souls.ckpt
if All_In_1_Pixel:
    # !wget -nv --show-progress https://huggingface.co/PublicPrompts/All-In-One-Pixel-Model/resolve/main/Public-Prompts-Pixel-Model.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/all_in_one_pixel_model.ckpt
if Abstract_Swirls:
    # !wget -nv --show-progress https://huggingface.co/coder119/Abstract_Swirls_Diffusion/resolve/main/Abstract_Swirls.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/abstractswirls.ckpt
if chkn_петухи:
    # !wget -nv --show-progress https://huggingface.co/fake4325634/chkn/resolve/main/chkn.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/chkn.ckpt
if Hogwarts_Legacy:
    # !wget -nv --show-progress https://huggingface.co/Guizmus/Experiments/resolve/main/HogLegStyle-v2.4.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/HogLeg_Style.ckpt


#@markdown <center><font size='3'> <a href='#scrollTo=R-xAdMA5wxXd' >поднятся на верх к #3 ячейке запуска</a></font></center>
from google.colab import output
output.clear()
# !ls -la /content/stable-diffusion-webui/models/Stable-diffusion/*.ckpt
print('          Выбранные модели скачались')
print('[1;32m 🡹 Теперь запускай ячейку #3 для старта WebUI 🡹')
from google.colab import output
output.eval_js('new Audio("https://files.catbox.moe/pvpjjl.mp3").play()')

# %% [markdown]
# ---

# %% [markdown]
# # Скачивание торрентов (можно на гуглодиск)

# %%
#@title <big>libtorrent</big> { display-mode: "form" }
import os
import time
from google.colab import output
if not os.path.exists("/usr/share/doc/python3-libtorrent/copyright"):
  print ("сначала нужно установить торрент-клиент.\n установка...")
  # !python -m pip install jedi>=0.10 --quiet
  # !python -m pip install --upgrade pip setuptools wheel --quiet
  # !python -m pip install lbry-libtorrent --quiet
  # !apt install -qq python3-libtorrent --quiet
  # !rm '/content/=0.10'
  output.clear()
  print("установка клиента завершена")
else:
  # !sleep 1

import ipywidgets as widgets
import libtorrent as lt
from threading import Thread

ses = lt.session()
ses.listen_on(6881, 6891)
downloads = []

# !sleep 1
#@markdown чтобы скачать на гуглодиск, сначала [примонтируй его](#scrollTo=NEUvrT9BPTwa), если этого не сделал ранее, или укажи дргую папку для загрузки
куда_качать = "/content/drive/My Drive/Torrent" #@param {type:"string"}
#@markdown Поставь галочку, если нужно после запуска выбрать файлы .torrent с компьютера:
torrent_файл = False #@param {type:"boolean"}
#@markdown Или вставь magnet-ссылку:


# выбрать торрент файлы?
if torrent_файл:
  from google.colab import files

  source = files.upload()
  if not source:                         
    print ('Нечего скачивать...')
    print ('Ты либо загрузи torrent-файлы, либо сними галочку и укажи magnet-ссылку')
    print ('попробуй еще раз')
    exit
  else:
    params = {
        "save_path": f"{куда_качать}",
        "ti": lt.torrent_info(list(source.keys())[0]),
    }
    downloads.append(ses.add_torrent(params))
    print ('ГОТОВО !!!')
else:
  from numpy import empty
  import libtorrent as lt
  import time
  import datetime
  ses = lt.session()
  ses.listen_on(6881, 6891)
  params = {
      'save_path': f'{куда_качать}',
      }
  link = "magnet:?xt=urn:btih:ED295B74E820777FF1E5C84B6657CB2AEB539AE1&tr=http%3A%2F%2Fbt3.t-ru.org%2Fann%3Fmagnet&dn=%D0%9C%D0%B8%D1%85%D0%B0%D0%B8%D0%BB%20%D0%91%D0%B5%D0%B9%D0%BB%D1%8C%D0%BA%D0%B8%D0%BD%20-%20%D0%A1%D0%B5%D1%80%D0%B8%D1%8F%20%D0%BA%D0%BD%D0%B8%D0%B3%20%22%D0%A1%D0%B5%D0%BA%D1%81-%D0%BB%D0%B8%D0%BA%D0%B1%D0%B5%D0%B7%22%20%D0%BF%D0%BE%20%D0%B3%D0%BE%D0%BC%D0%BE%D1%81%D0%B5%D0%BA%D1%81%D1%83%D0%B0%D0%BB%D1%8C%D0%BD%D0%BE%D1%81%D1%82%D0%B8%20%D0%B8%20%D1%81%D0%B5%D0%BA%D1%81%D0%BE%D0%BB%D0%BE%D0%B3%D0%B8%D0%B8%20%5B2006-2009%2C%20DOC%5D" #@param {type:"string"}

  if not link:                         
      print ('Ты не ввел магнет-ссылку !!!')
      exit
  if "magnet:?xt=urn:btih" not in link:
    print ('Это не магнет-ссылка !!!')
    print ('Либо вставь нормальную магнет-ссылку, либо отметь галочку и запусти и загрузи торрент-файлы.')
    exit
  else:
    handle = lt.add_magnet_uri(ses, link, params)
    ses.start_dht()

    begin = time.time()
    print(datetime.datetime.now())

    print ('Получаю метаданные...')
    while (not handle.has_metadata()):
      time.sleep(1)
    print ('Запускаю загрузку...')

    while (handle.status().state != lt.torrent_status.seeding):
        s = handle.status()
        state_str = ['очередь', 'проверка', 'получение метаданных', \
                'идет скачивание', 'готово', 'раздача', 'распределение']
        print ('%.2f%% (загрузка: %.1f kb/s отдача: %.1f kB/s пиры: %d) %s ' % \
                (s.progress * 100, s.download_rate / 1000, s.upload_rate / 1000, \
                s.num_peers, state_str[s.state]))
        time.sleep(5)

    end = time.time()
    print("ГОТОВО!")

    print("Затрачено времени: ",int((end-begin)//60),"min :", int((end-begin)%60), "sec")


#@markdown Обрати внимание: путь до папки загрузок приведен для примера (если подключен гуглодиск, допустим)! Это не путь до папки с моделями в колабе!
#@markdown Путь до стандартной папки с моделями: `/content/stable-diffusion-webui/models/Stable-diffusion`
#@markdown Торент может содержать вложенные папки и т.п., поэтому скачать лучше куда-то, а потом непосредственно файл можели перетянуть в папку где лежат все модели:
#@markdown <b><font color='forestgreen' size='2'><details><summary>скрин где найти тут папку</summary> <img src='https://files.catbox.moe/4pi0d7.png' /></details>

# %%
#@title Конвертация моделей из .bin в .ckpt { display-mode: "form" }

import os
import argparse
import os.path as osp
import torch
from IPython.display import clear_output

#@markdown нужно указать путь до папки с файлами модели формата diffusers, а не просто файла .bin!
#@markdown <details><summary><font color=gold>как должно выглядить <u>содержимое</u> папки</font></summary><img src='https://dl.uploadgram.me/6373cae8820b1h?dl' height='500' /></details>

#@markdown [пример такой модели](https://huggingface.co/lambdalabs/sd-image-variations-diffusers/tree/main) - так вот, скачивать нужно все папку, и вот такая папка указывается в параметрах, именно вся эта папка будет сконвертированна в один файлик модели с расширением .ckpt, пригодным для WebUI <hr>
конвертируемая_модель_bin = "/content/drive/MyDrive/uncut-penis" #@param {type:"string"}
имя_модели_ckpt = "uncut-penis" #@param {type:"string"}
куда_сохранить_ckpt = "/content/drive/MyDrive/SD_Models" #@param {type:"string"}

if not os.path.exists(куда_сохранить_ckpt):
   print("\033[01;38;05;203mуказанная папка для сохранения модели не существует!\nпридется сохранить модель в корень гуглодиска!")
   куда_сохранить_ckpt = '/content/gdrive/MyDrive'

if not os.path.exists(конвертируемая_модель_bin):
  print("\033[01;38;05;203mпуть до модели .bin указан не верно!")

else:
  print(f"\033[01;38;05;110mисходная модель: \033[01;38;05;107m{конвертируемая_модель_bin}\n\033[01;38;05;110mбудет сконвертирована в: \033[01;38;05;107m{куда_сохранить_ckpt}/{имя_модели_ckpt}.ckpt\033[0m")
  unet_conversion_map = [
      ("time_embed.0.weight", "time_embedding.linear_1.weight"),
      ("time_embed.0.bias", "time_embedding.linear_1.bias"),
      ("time_embed.2.weight", "time_embedding.linear_2.weight"),
      ("time_embed.2.bias", "time_embedding.linear_2.bias"),
      ("input_blocks.0.0.weight", "conv_in.weight"),
      ("input_blocks.0.0.bias", "conv_in.bias"),
      ("out.0.weight", "conv_norm_out.weight"),
      ("out.0.bias", "conv_norm_out.bias"),
      ("out.2.weight", "conv_out.weight"),
      ("out.2.bias", "conv_out.bias"),
  ]

  unet_conversion_map_resnet = [
      ("in_layers.0", "norm1"),
      ("in_layers.2", "conv1"),
      ("out_layers.0", "norm2"),
      ("out_layers.3", "conv2"),
      ("emb_layers.1", "time_emb_proj"),
      ("skip_connection", "conv_shortcut"),
  ]

  unet_conversion_map_layer = []

  for i in range(4):

      for j in range(2):
          hf_down_res_prefix = f"down_blocks.{i}.resnets.{j}."
          sd_down_res_prefix = f"input_blocks.{3*i + j + 1}.0."
          unet_conversion_map_layer.append((sd_down_res_prefix, hf_down_res_prefix))

          if i < 3:
              hf_down_atn_prefix = f"down_blocks.{i}.attentions.{j}."
              sd_down_atn_prefix = f"input_blocks.{3*i + j + 1}.1."
              unet_conversion_map_layer.append((sd_down_atn_prefix, hf_down_atn_prefix))

      for j in range(3):
          hf_up_res_prefix = f"up_blocks.{i}.resnets.{j}."
          sd_up_res_prefix = f"output_blocks.{3*i + j}.0."
          unet_conversion_map_layer.append((sd_up_res_prefix, hf_up_res_prefix))

          if i > 0:
              hf_up_atn_prefix = f"up_blocks.{i}.attentions.{j}."
              sd_up_atn_prefix = f"output_blocks.{3*i + j}.1."
              unet_conversion_map_layer.append((sd_up_atn_prefix, hf_up_atn_prefix))

      if i < 3:
          hf_downsample_prefix = f"down_blocks.{i}.downsamplers.0.conv."
          sd_downsample_prefix = f"input_blocks.{3*(i+1)}.0.op."
          unet_conversion_map_layer.append((sd_downsample_prefix, hf_downsample_prefix))

          hf_upsample_prefix = f"up_blocks.{i}.upsamplers.0."
          sd_upsample_prefix = f"output_blocks.{3*i + 2}.{1 if i == 0 else 2}."
          unet_conversion_map_layer.append((sd_upsample_prefix, hf_upsample_prefix))

  hf_mid_atn_prefix = "mid_block.attentions.0."
  sd_mid_atn_prefix = "middle_block.1."
  unet_conversion_map_layer.append((sd_mid_atn_prefix, hf_mid_atn_prefix))

  for j in range(2):
      hf_mid_res_prefix = f"mid_block.resnets.{j}."
      sd_mid_res_prefix = f"middle_block.{2*j}."
      unet_conversion_map_layer.append((sd_mid_res_prefix, hf_mid_res_prefix))


  def convert_unet_state_dict(unet_state_dict):
      mapping = {k: k for k in unet_state_dict.keys()}
      for sd_name, hf_name in unet_conversion_map:
          mapping[hf_name] = sd_name
      for k, v in mapping.items():
          if "resnets" in k:
              for sd_part, hf_part in unet_conversion_map_resnet:
                  v = v.replace(hf_part, sd_part)
              mapping[k] = v
      for k, v in mapping.items():
          for sd_part, hf_part in unet_conversion_map_layer:
              v = v.replace(hf_part, sd_part)
          mapping[k] = v
      new_state_dict = {v: unet_state_dict[k] for k, v in mapping.items()}
      return new_state_dict

  vae_conversion_map = [
      ("nin_shortcut", "conv_shortcut"),
      ("norm_out", "conv_norm_out"),
      ("mid.attn_1.", "mid_block.attentions.0."),
  ]

  for i in range(4):
      for j in range(2):
          hf_down_prefix = f"encoder.down_blocks.{i}.resnets.{j}."
          sd_down_prefix = f"encoder.down.{i}.block.{j}."
          vae_conversion_map.append((sd_down_prefix, hf_down_prefix))

      if i < 3:
          hf_downsample_prefix = f"down_blocks.{i}.downsamplers.0."
          sd_downsample_prefix = f"down.{i}.downsample."
          vae_conversion_map.append((sd_downsample_prefix, hf_downsample_prefix))

          hf_upsample_prefix = f"up_blocks.{i}.upsamplers.0."
          sd_upsample_prefix = f"up.{3-i}.upsample."
          vae_conversion_map.append((sd_upsample_prefix, hf_upsample_prefix))

      for j in range(3):
          hf_up_prefix = f"decoder.up_blocks.{i}.resnets.{j}."
          sd_up_prefix = f"decoder.up.{3-i}.block.{j}."
          vae_conversion_map.append((sd_up_prefix, hf_up_prefix))

  for i in range(2):
      hf_mid_res_prefix = f"mid_block.resnets.{i}."
      sd_mid_res_prefix = f"mid.block_{i+1}."
      vae_conversion_map.append((sd_mid_res_prefix, hf_mid_res_prefix))


  vae_conversion_map_attn = [
      ("norm.", "group_norm."),
      ("q.", "query."),
      ("k.", "key."),
      ("v.", "value."),
      ("proj_out.", "proj_attn."),
  ]


  def reshape_weight_for_sd(w):
      return w.reshape(*w.shape, 1, 1)


  def convert_vae_state_dict(vae_state_dict):
      mapping = {k: k for k in vae_state_dict.keys()}
      for k, v in mapping.items():
          for sd_part, hf_part in vae_conversion_map:
              v = v.replace(hf_part, sd_part)
          mapping[k] = v
      for k, v in mapping.items():
          if "attentions" in k:
              for sd_part, hf_part in vae_conversion_map_attn:
                  v = v.replace(hf_part, sd_part)
              mapping[k] = v
      new_state_dict = {v: vae_state_dict[k] for k, v in mapping.items()}
      weights_to_convert = ["q", "k", "v", "proj_out"]
      print("[1;32mConverting to CKPT ...")    
      for k, v in new_state_dict.items():
          for weight_name in weights_to_convert:
              if f"mid.attn_1.{weight_name}.weight" in k:
                  new_state_dict[k] = reshape_weight_for_sd(v)
      return new_state_dict


  def convert_text_enc_state_dict(text_enc_dict):
      return text_enc_dict


  if __name__ == "__main__":
      

      model_path = конвертируемая_модель_bin
      checkpoint_path= куда_сохранить_ckpt+'/'+ имя_модели_ckpt+'.ckpt'
      
      unet_path = osp.join(model_path, "unet", "diffusion_pytorch_model.bin")
      vae_path = osp.join(model_path, "vae", "diffusion_pytorch_model.bin")
      text_enc_path = osp.join(model_path, "text_encoder", "pytorch_model.bin")

      unet_state_dict = torch.load(unet_path, map_location='cpu')
      unet_state_dict = convert_unet_state_dict(unet_state_dict)
      unet_state_dict = {"model.diffusion_model." + k: v for k, v in unet_state_dict.items()}

      vae_state_dict = torch.load(vae_path, map_location='cpu')
      vae_state_dict = convert_vae_state_dict(vae_state_dict)
      vae_state_dict = {"first_stage_model." + k: v for k, v in vae_state_dict.items()}

      text_enc_dict = torch.load(text_enc_path, map_location='cpu')
      text_enc_dict = convert_text_enc_state_dict(text_enc_dict)
      text_enc_dict = {"cond_stage_model.transformer." + k: v for k, v in text_enc_dict.items()}

      # сохранение сконвертированной модели
      state_dict = {**unet_state_dict, **vae_state_dict, **text_enc_dict}
      
      state_dict = {k:v.half() for k,v in state_dict.items()}
      state_dict = {"state_dict": state_dict}
      torch.save(state_dict, checkpoint_path)

  if os.path.exists(куда_сохранить_ckpt+'/'+ имя_модели_ckpt+'.ckpt'):
      print("[1;32mВСЁ! модель в формате ckpt создана.")
  else:
      print("[1;31mчто-то пошло не так...")

# %% [markdown]
# # Выгрузка моделей на HuggingFace в твой репозиторий

# %%
#@title Выгрузка моделей/файлов до 5 Гб { display-mode: "form" }
HuggingFace_токен = "\u0442\u0432\u043E\u0439 \u0442\u043E\u043A\u0435\u043D" #@param {type:"string"}
источник = "\u0444\u0430\u0439\u043B" #@param ["\u043F\u0430\u043F\u043A\u0430", "\u0444\u0430\u0439\u043B"]
что_загрузить = "/content/Anonmix.ckpt" #@param {type:"string"}
репозиторий = "\u044E\u0437\u0435\u0440\u043D\u0435\u0439\u043C/\u0440\u0435\u043F\u043E\u0437\u0438\u0442\u043E\u0440\u0438\u0439" #@param {type:"string"}
#@markdown Токент нужно получить [здесь](https://huggingface.co/settings/tokens). При создании токена нужно указать **Role : Write**. <details><summary>скрин создания токена</summary><img src="https://dl.uploadgram.me/6373ee91cbbe5h?dl" height='300px'></details><br> В качестве источника можно указать путь до одного файла модели, или путь до папки с несколькими файлами - все содержимое папки будет отправленно в указанный репозиторий. В поле "репозиторий" нужно вписать твой юзернейм на HuggingFace и имя репозитория через слеш. Если репозитория еще нет - его <a href='https://huggingface.co/new'>нужно создать</a>, он должен быть публичным, чтобы загружаемые файлы потом были доступны по прямым ссылкам. Если в источнике будет файл недопустимого размера (больше 5 гигов) - загрузка даже не начнется, т.к. от дураков стоит проверка на размер файла, без этого случилось переполнение памяти и крах колаба. Для огромных файлов более 5гб нужно использовать ячейку ниже.  
import os
if not os.path.exists("/usr/local/lib/python3.7/dist-packages/huggingface_hub"):
  from google.colab import output
  # !python -m pip install huggingface_hub
  output.clear()
else:
  # !sleep 1

if not HuggingFace_токен or len(HuggingFace_токен) < 36 or "hf_" not in HuggingFace_токен:
  print("Токен указан неверно. Получить токен можно тут: https://huggingface.co/settings/tokens")
else:
  hf_token=f"{HuggingFace_токен}"
  from huggingface_hub.commands.user import _login
  from huggingface_hub.hf_api import HfApi, HfFolder
  _login(HfApi(), token=hf_token)

# !sleep 1

import enum
class SIZE_UNIT(enum.Enum):
   BYTES = 1
   KB = 2
   MB = 3
   GB = 4
def convert_unit(size_in_bytes, unit):
   if unit == SIZE_UNIT.KB:
       return size_in_bytes/1024
   elif unit == SIZE_UNIT.MB:
       return size_in_bytes/(1024*1024)
   elif unit == SIZE_UNIT.GB:
       return size_in_bytes/(1024*1024*1024)
   else:
       return size_in_bytes
import os
def get_file_size(file_name, size_type = SIZE_UNIT.BYTES ):
   size = os.path.getsize(file_name)
   return convert_unit(size, size_type)
file_path = что_загрузить
size = get_file_size(file_path, SIZE_UNIT.GB)
if size > 4.999:
  print('Размер модели : ', size ,  'Гб!\nЭто очень большой размер для данного метода загрузки.\nВоспользуйся методом в ячейке ниже, он предназначен для загрузки файлов более 5Гб.')
else:
  if not что_загрузить or not репозиторий:
    print("Не указан репозиторий или файл/папка для загрузки")
  if источник == "файл":
    from pathlib import Path
    p = Path(f"{что_загрузить}")
    print(p.name)
    print("жди, идет загрузка...")
    from huggingface_hub import HfApi
    api = HfApi()
    api.upload_file(
        path_or_fileobj=f"{что_загрузить}",
        path_in_repo=(p.name),
        repo_id=f"{репозиторий}",
        repo_type="model",
    )
  elif источник == "папка":
    print("жди, идет загрузка...")
    from huggingface_hub import HfApi
    api = HfApi()
    api.upload_folder(
        folder_path=f"{что_загрузить}",
        repo_id=f"{репозиторий}",
        repo_type="model",
    )

  filename = os.path.basename(f'{что_загрузить}')
  if источник == "папка":
    print(f"загрузка завершена!\nтвои файлы тут: https://huggingface.co/{репозиторий}/tree/main \nпрямые ссылки ищи там вида https://huggingface.co/{репозиторий}/resolve/main/xxx.ckpt ")
  if источник == "файл":
    print(f"загрузка завершена!\nтвои файлы тут: https://huggingface.co/{репозиторий}/tree/main \nпрямая ссылка на модель: https://huggingface.co/{репозиторий}/resolve/main/{filename} ")

# %%
#@title Выгрузка файлов больше 5 гб { display-mode: "form" }
HuggingFace_токен = "\u0442\u0432\u043E\u0439 \u0442\u043E\u043A\u0435\u043D" #@param {type:"string"}
username = "\u044E\u0437\u0435\u0440\u043D\u0435\u0439\u043C"  #@param {type:"string"}
LFS_репозиторий = "\u0440\u0435\u043F\u043E\u0437\u0438\u0442\u043E\u0440\u0438\u0439" #@param {type:"string"}
что_выгружаем = "/content/models/my_biggest_model.ckpt" #@param {type:"string"}
#@markdown можно указать файл или целую папку с файлами. Если это папка - будет загружено все ее содержимое в репозиторий, но не сама папка, если не поставлена опция "сохранить структуру".
сохранить_структуру = False #@param {type:"boolean"}
#@markdown Копировать в папку репозитория или переместить? Перемещение быстрее, но исходные файлы с диска колаба удалятся, переместившись в папку репы. 
файлы_с_диска = "\u043F\u0435\u0440\u0435\u043C\u0435\u0449\u0430\u0435\u043C" #@param ["копируем", "перемещаем"]


import os
if not os.path.exists("/usr/local/lib/python3.7/dist-packages/huggingface_hub"):
  from google.colab import output
  # !python -m pip install huggingface_hub
  output.clear()
else:
  # !sleep 1

if not HuggingFace_токен or len(HuggingFace_токен) < 36 or "hf_" not in HuggingFace_токен:
  print("Токен указан неверно. Получить токен можно тут: https://huggingface.co/settings/tokens")
else:
  hf_token=f"{HuggingFace_токен}"
  from huggingface_hub.commands.user import _login
  from huggingface_hub.hf_api import HfApi, HfFolder
  _login(HfApi(), token=hf_token)

# !sleep 1

#!git lfs install --skip-smudge

# !git -c filter.lfs.smudge= clone https://huggingface.co/{username}/{LFS_репозиторий}

if сохранить_структуру:
  if файлы_с_диска == "копируем":
    # !cp -f -i -R {что_выгружаем} /content/{LFS_репозиторий}
  elif файлы_с_диска == "перемещаем":
    # !mv -f -i {что_выгружаем} /content/{LFS_репозиторий}
if not сохранить_структуру:
  if файлы_с_диска == "копируем":
    # !cp -f -i -R -t /content/{LFS_репозиторий} {что_выгружаем}
  elif файлы_с_диска == "перемещаем":
    # !mv -f -i -t /content/{LFS_репозиторий} {что_выгружаем}

from huggingface_hub import Repository
repo = Repository(local_dir=f"/content/{LFS_репозиторий}")
# !huggingface-cli lfs-enable-largefiles /content/{LFS_репозиторий}

# !sleep 2

#запустить выгрузку
repo.push_to_hub(commit_message="upload with huggingface-cli")
# !sleep 1
print(f"загрузка завершена!\nтвои файлы тут: https://huggingface.co/{username}/{LFS_репозиторий}/tree/main")
